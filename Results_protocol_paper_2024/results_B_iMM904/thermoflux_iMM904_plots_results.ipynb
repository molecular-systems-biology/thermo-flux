# %% [markdown]
# ##     Case study iMM904 curation
#  Using the iMM904 model as a case study, we have used Thermo-Flux and did the few manual curation steps to show how models can be converted into a combined thermodynamic-stoichiometric model.
# Here, we present the steps that required manual attention when following the protocol described in the publication. "

# %%
import cobra
from cobra import Model, Reaction, Metabolite
import sys
sys.path.append('/home/nathan/public_thermo_flux/')
from thermo_flux.core.metabolite import ThermoMetabolite
import thermo_flux
from thermo_flux.io import load_excel as ex
from thermo_flux.core.model import ThermoModel, ThermoReaction
from equilibrator_api import  Q_
import pandas as pd
from thermo_flux.io import load_gams as gs
from thermo_flux.io import helper_load as hl
from thermo_flux.utils.vis import compare_met
import numpy as np
import gurobipy as  gp
from gurobipy import GRB


import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Import sbml model from BiGG

# %%
from cobra.io import load_json_model
model=load_json_model('iMM904.json')

#set objective to biomass
model.objective = model.reactions.BIOMASS_SC5_notrace
model.reactions.EX_co2_e.id='co2_EX'
model.reactions.EX_o2_e.id='o2_EX'
model.reactions.EX_etoh_e.id='etoh_EX'
model.repair()

for rxn in model.reactions:
    if 'EX_' not in rxn.id:
        rxn.lower_bound=-500 if rxn.lower_bound==-999999.0 else rxn.lower_bound
        rxn.upper_bound=500 if rxn.upper_bound==999999.0 else rxn.upper_bound
    else:
        rxn.lower_bound=-500 if rxn.lower_bound==-999999.0 else rxn.lower_bound
        rxn.upper_bound=500 if rxn.upper_bound==999999.0 else rxn.upper_bound
       # print(rxn.id,rxn.lower_bound,rxn.upper_bound)

#reset O2 exchange bound
model.optimize().to_frame().loc['BIOMASS_SC5_notrace']['fluxes']
model.reactions.o2_EX.bounds=(-500,0)

print(model.optimize().to_frame().loc['BIOMASS_SC5_notrace']['fluxes'])
model.optimize().to_frame().loc[[rxn.id for rxn in model.boundary]]
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2594640
# Academic license - for non-commercial use only - expires 2025-12-03
# 0.9748814206733547
#                   fluxes  reduced_costs
# EX_epistest_SC_e     0.0     -96.275549
# EX_epist_e           0.0      -1.676719
# EX_ergst_e           0.0      -1.722387
# EX_ergstest_SC_e     0.0     -96.321217
# EX_13BDglcn_e        0.0      -0.196130
# ...                  ...            ...
# EX_xyl__D_e          0.0      -0.163442
# EX_xylt_e            0.0      -0.176421
# EX_rib__D_e          0.0      -0.174979
# EX_zymst_e           0.0      -1.620476
# EX_zymstest_SC_e     0.0     -96.219306
#
# [164 rows x 2 columns]

# %%
#plot biomass yield for stoichiometric model
#GUR_range=[-0.25, -0.57, -0.6 , -1.1 , -1.67, -2.14, -2.22, -2.83, -3.24, -3.7, -4.67, -5.44, -7.62, -8.09, -8.33, -10.23, -13.18, -15.7, -22.42]
GUR_range = np.linspace(-0, -23, 50)

GUR_plot_range=[-x for x in GUR_range]
biomass_flux=[]
etoh_flux=[]
o2_flux=[]
co2_flux=[]
for GUR in GUR_range:
    model.reactions.EX_glc__D_e.upper_bound=0
    model.reactions.EX_glc__D_e.lower_bound=GUR
    sol = model.optimize()
    #add values to list
    biomass_flux.append(sol.fluxes.loc['BIOMASS_SC5_notrace'])
    etoh_flux.append(sol.fluxes.loc['etoh_EX'])
    o2_flux.append(sol.fluxes.loc['o2_EX'])
    co2_flux.append(sol.fluxes.loc['co2_EX'])
#plot biomass vs GUR in a scatter plot
sns.scatterplot(x=GUR_plot_range,y=biomass_flux)
plt.xlabel('Glucose uptake rate (mmol/(gDW.h))')
plt.ylabel('Biomass production (mmol/(gDW.h))')
fba_flux=pd.DataFrame({'biomass_EX':biomass_flux,'etoh_EX':etoh_flux,'o2_EX':o2_flux,'co2_EX':co2_flux},index=GUR_range)
# plt.savefig('Figures/growth_stoichio_only.png',dpi=300)
# model.optimize().to_frame().loc['BIOMASS_SC5_notrace']/model.optimize().to_frame().loc['EX_glc__D_e']
# Out:
# Solver status is 'infeasible'.

# %% [markdown]
# ### Step 1 - Physical and Biochemical parameters

# %%
tmodel=ThermoModel(model,split_biomass=True, add_charge_exchange= True)
# Out:
# Initializing component contribution object...
# cxcalc is not installed, operating in read-only mode. A local cache may be loaded, but no compounds can be created. Install cxcalc and obtain a ChemAxon license to enable compound creation.
# Loading compounds from iMM904_compound.sqlite
# added reaction:  biomass_ce: biomass_c <=> biomass_e
# added reaction:  biomass_EX: biomass_e <=>
# added reaction:  charge_ce: charge_e <=> charge_c
# added reaction:  EX_charge: charge_e <=>
# added reaction:  charge_cm: charge_m <=> charge_c
# added reaction:  charge_cx: charge_x <=> charge_c
# added reaction:  charge_cr: charge_r <=> charge_c
# added reaction:  charge_cv: charge_v <=> charge_c
# added reaction:  charge_cg: charge_g <=> charge_c
# added reaction:  charge_cn: charge_n <=> charge_c

# %%
#define the biochemical parameters of the model

tmodel.phi={'ec': Q_(-0.06,'volt'), 'cm': Q_(-0.16,'volt'),'cx':Q_(0,'volt'),'cr':Q_(0,'volt'),'cv':Q_(0,'volt'),'cg':Q_(0,'volt'),'cn':Q_(0,'volt')}
tmodel.pH={'c':Q_(7),'e':Q_(5),'m':Q_(7.4),'r':Q_(7),'v':Q_(5.5),'g':Q_(7),'x':Q_(7),'n':Q_(7)} #On the intracellular pH of baker’s yeast(r), Martinez-Munoz et al. 2008(v), Juan Llopis et al 1998 (g), 7 is default pH

##from first version
# tmodel.pH={'c':Q_(7.2),'e':Q_(5),'m':Q_(7.4),'r':Q_(7.4),'v':Q_(7.4),'g':Q_(7.4),'x':Q_(7.4),'n':Q_(7.4)}
# tmodel.phi={'ec': Q_(-0.06,'volt'), 'cm': Q_(-0.16,'volt'),'cx':Q_(-0.16,'volt'),'cr':Q_(-0.16,'volt'),'cv':Q_(-0.16,'volt'),'cg':Q_(-0.16,'volt'),'cn':Q_(-0.16,'volt')}
#assuming same membrane potential between cytosol and organelles than c and mitochondria ?

#change max drGcalc_drGt
tmodel._max_drG=Q_(1e6,'kJ/mol') #max is already 1e8 shouldnt need to change

# %% [markdown]
# ### Step 2 - Definition of metabolites

# %%
tmodel.get_compounds(search = True)
# Out:
# [█████████████████████████████████.......] 1032/1236 pydx_c
# WARNING: dolichol_c has inconsistent formula with eQuilibrator identified metabolite. COBRA:{'C': 15, 'H': 28, 'O': 1}, eQuilibrator:{'C': 25, 'O': 1}. Defining as unknown compound
# WARNING: dolmanp_r has inconsistent formula with eQuilibrator identified metabolite. COBRA:{'C': 21, 'H': 38, 'O': 9, 'P': 1}, eQuilibrator:{'C': 31, 'O': 9, 'P': 1}. Defining as unknown compound
# WARNING: glycogen_c has inconsistent formula with eQuilibrator identified metabolite. COBRA:{'C': 6, 'H': 10, 'O': 5}, eQuilibrator:{'O': 21, 'C': 24}. Defining as unknown compound
# WARNING: glycogen_v has inconsistent formula with eQuilibrator identified metabolite. COBRA:{'C': 6, 'H': 10, 'O': 5}, eQuilibrator:{'O': 21, 'C': 24}. Defining as unknown compound
# WARNING: mhpglu_c has inconsistent formula with eQuilibrator identified metabolite. COBRA:{'C': 25, 'H': 36, 'N': 8, 'O': 12}, eQuilibrator:{'C': 30, 'N': 9, 'O': 12}. Defining as unknown compound
# WARNING: macchitppdol_g has inconsistent formula with eQuilibrator identified metabolite. COBRA:{'C': 37, 'H': 64, 'N': 2, 'O': 22, 'P': 2}, eQuilibrator:{'C': 47, 'O': 22, 'P': 2, 'N': 2}. Defining as unknown compound
# WARNING: hpglu_c has inconsistent formula with eQuilibrator identified metabolite. COBRA:{'C': 24, 'H': 34, 'N': 8, 'O': 12}, eQuilibrator:{'N': 9, 'C': 29, 'O': 12}. Defining as unknown compound
# [███████████████████████████████████████.] 1227/1236 biomass_c
# WARNING: trdox_c has inconsistent formula with eQuilibrator identified metabolite. COBRA:{'X': 1}, eQuilibrator:{'N': 4, 'C': 10, 'S': 2, 'O': 4}. Defining as unknown compound
# WARNING: trdox_m has inconsistent formula with eQuilibrator identified metabolite. COBRA:{'X': 1}, eQuilibrator:{'N': 4, 'C': 10, 'S': 2, 'O': 4}. Defining as unknown compound
# WARNING: trdox_n has inconsistent formula with eQuilibrator identified metabolite. COBRA:{'X': 1}, eQuilibrator:{'N': 4, 'C': 10, 'S': 2, 'O': 4}. Defining as unknown compound
# WARNING: trdox_x has inconsistent formula with eQuilibrator identified metabolite. COBRA:{'X': 1}, eQuilibrator:{'N': 4, 'C': 10, 'S': 2, 'O': 4}. Defining as unknown compound
# WARNING: trdrd_c has inconsistent formula with eQuilibrator identified metabolite. COBRA:{'X': 1, 'H': 2}, eQuilibrator:{'N': 4, 'C': 10, 'S': 2, 'O': 4}. Defining as unknown compound
# WARNING: trdrd_m has inconsistent formula with eQuilibrator identified metabolite. COBRA:{'X': 1, 'H': 2}, eQuilibrator:{'N': 4, 'C': 10, 'S': 2, 'O': 4}. Defining as unknown compound
# WARNING: trdrd_n has inconsistent formula with eQuilibrator identified metabolite. COBRA:{'X': 1, 'H': 2}, eQuilibrator:{'N': 4, 'C': 10, 'S': 2, 'O': 4}. Defining as unknown compound
# WARNING: trdrd_x has inconsistent formula with eQuilibrator identified metabolite. COBRA:{'X': 1, 'H': 2}, eQuilibrator:{'N': 4, 'C': 10, 'S': 2, 'O': 4}. Defining as unknown compound
# [████████████████████████████████████████] 1236/1236 charge_n
# [<ThermoMetabolite biomass_c at 0x7cc5c7ddf250>,
#  <ThermoMetabolite biomass_e at 0x7cc5c7ddece0>]

# %%
#define biomass parameters 
#if the biomass formula is not automatically calcualted it's important to specifiy the hydrogen atoms in biomass to ensure correct proton balancing 
tmodel.metabolites.biomass_c.formula = 'H67'
tmodel.metabolites.biomass_e.formula = 'H67'

#manually define charge of cytochrome C so electron movement is correctly calcualted
tmodel.metabolites.focytc_m.charge = 2
tmodel.metabolites.focytc_m.redox= True #define as redox metabolite 
tmodel.metabolites.ficytc_m.charge = 3
tmodel.metabolites.ficytc_m.redox = True

# %% [markdown]
# ### Step 3 - metabolites formation energies

# %% [markdown]
# When specifying the value of `dfGprime` for the biomass metabolite, we should plug in the values in units of **J/gDW**. This differs from all the other reactions in the model, for which values of **kJ/mol** are used.
#
# The reason for this discrepancy has to do with the units of the fluxes.
#
# For a normal reaction:
# $g_{diss, rxn} = \Delta_rG \times v = (kJ/mol) \times (mmol/gDW/h) = (10^3 J/mol) \times (10^{-3} mol/gDW/h) = J/gDW/h$
#
# For the biomass reaction:
# $g_{diss, bio} = \Delta_fG_{bio} \times \mu = (J/gDW) \times (gDW/gDW/h) = J/gDW/h $
#
# Since thermoflux handles all reactions the same when determining the gibbs energy dissipation rate (multiplying $v$ by $\Delta_rG$), we have to **pretend** that the biomass formation energy has units of kJ/mol. E.g:
# `tmodel.metabolites.biomass_c.dfGprime = Q_(701.767, "kJ/mol")` (where 701.767 is the formation energy of E.coli biomass at cytosolic pH, in units of J/gDW)

# %%
#define biomass properties
tmodel.reactions.BIOMASS_SC5_notrace.id='biomass_c' #update biomass reaction name for convenience

tmodel.metabolites.biomass_c.dfG0 = Q_(-3.04,'kJ/mol')*1000 #From Battley 1991, *1000 for mmol flux units (actual units here are J/gDW)
tmodel.metabolites.biomass_e.dfG0 = Q_(-3.04,'kJ/mol')*1000

# %% [markdown]
# ### Step 4 - Transporters

# %%
#idenfity transporters where the transported metabolite is empty
#these could either be redox reactions or proton pumps just moving electrons (charge) and protons 
#or they could be transporters with chemcial transformation during the transport process
for reaction in tmodel.reactions:
    if len(reaction.compartments) > 1:
        if thermo_flux.tools.drg_tools.calc_transported_mets(reaction) == {}:
            print(reaction.id, reaction, thermo_flux.tools.drg_tools.calc_transported_mets(reaction))
# Out:
# ASPOcm ASPOcm: asp__L_c + fad_m --> fadh2_m + h_c + iasp_c {}
# ATPS ATPS: atp_c + h2o_c --> adp_c + h_e + pi_c {}
# DHORD4i DHORD4i: dhor__S_c + q6_m --> orot_c + q6h2_m {}
# DOLPMTcer DOLPMTcer: dolp_c + gdpmann_c --> dolmanp_r + gdp_c {}
# DXHPScm DXHPScm: h2o_c + q6_m + spmd_c --> 13dampp_c + 4abutn_c + q6h2_m {}
# D_LACDcm D_LACDcm: 2.0 ficytc_m + lac__D_c --> 2.0 focytc_m + pyr_c {}
# FDNG FDNG: for_c + h_c + q6_m --> co2_c + q6h2_m {}
# FRDcm FRDcm: fadh2_m + fum_c --> fad_m + succ_c {}
# L_LACD2cm L_LACD2cm: 2.0 ficytc_m + lac__L_c --> 2.0 focytc_m + pyr_c {}
# NADH2_u6cm NADH2_u6cm: h_c + nadh_c + q6_m --> nad_c + q6h2_m {}

# %%
#DOLPMTcer involved chemcial transformation of dolp. We assume transport of dolmanp for thermodynamic calcualtion
tmodel.reactions.DOLPMTcer.transported_mets = {tmodel.metabolites.dolmanp_r: -1}

# %%
## add proton transport reactions ##the directions are constrained by pH gradients

tmodel.add_proton_exchange()
# Out:
# added reaction:  H_cm: h_m <=> h_c
# added reaction:  H_cx: h_x <=> h_c
# added reaction:  H_cr: h_r <=> h_c
# added reaction:  H_cv: h_v <=> h_c
# added reaction:  H_cg: h_g <=> h_c
# added reaction:  H_cn: h_n <=> h_c

# %%
## add transporter variants for all phosphate transporters

for rxn in [r for r in tmodel.reactions if len(r.compartments) > 1 and any(m.id.split('_')[0] == 'pi' for m in r.metabolites)
            and not any(m.id.split('_')[0] == 'atp' for m in r.metabolites )]:
    new_reactions = thermo_flux.tools.drg_tools.add_transporter_varaints(rxn,balance_charge=True,add_charge_neutral = True, round_dp=2)
    if new_reactions is not None:
        if len(new_reactions) > 0:
            for new_reaction in new_reactions:
                print(new_reaction)
# Out:
# PIt2m0: 1.83 h_c + pi_c <=> 2.0 h_m + pi_m
# PIt2v0: 1.83 h_c + pi_c <=> 1.14 h_v + pi_v

# %% [markdown]
# to remove

# %%
tmodel.reactions.ATPS
# Out:
# <ThermoReaction ATPS at 0x7cc5c7e69ea0>

# %% [markdown]
# ### Step 5 - charge and proton balancing

# %%
for rxn in tmodel.reactions:
    thermo_flux.tools.drg_tools.reaction_balance(rxn, balance_charge=True, balance_mg=False)
# Out:
# WARNING: ATPS3v is not balanced and could not be automatically balanced, please check reaction stoichiometry or define reaction.transported_h
# WARNING: ASPOcm is a transporter but the transported metabolites could not be automatically calculated and no transported metabolites were manually defined, please check reaction stoichiometry or define reaction.transported_mets
# WARNING: ATPS is a transporter but the transported metabolites could not be automatically calculated and no transported metabolites were manually defined, please check reaction stoichiometry or define reaction.transported_mets
# WARNING: DHORD4i is a transporter but the transported metabolites could not be automatically calculated and no transported metabolites were manually defined, please check reaction stoichiometry or define reaction.transported_mets
# WARNING: DXHPScm is a transporter but the transported metabolites could not be automatically calculated and no transported metabolites were manually defined, please check reaction stoichiometry or define reaction.transported_mets
# WARNING: D_LACDcm is a transporter but the transported metabolites could not be automatically calculated and no transported metabolites were manually defined, please check reaction stoichiometry or define reaction.transported_mets
# WARNING: FDNG is a transporter but the transported metabolites could not be automatically calculated and no transported metabolites were manually defined, please check reaction stoichiometry or define reaction.transported_mets
# WARNING: FRDcm is a transporter but the transported metabolites could not be automatically calculated and no transported metabolites were manually defined, please check reaction stoichiometry or define reaction.transported_mets
# WARNING: L_LACD2cm is a transporter but the transported metabolites could not be automatically calculated and no transported metabolites were manually defined, please check reaction stoichiometry or define reaction.transported_mets
# WARNING: NADH2_u6cm is a transporter but the transported metabolites could not be automatically calculated and no transported metabolites were manually defined, please check reaction stoichiometry or define reaction.transported_mets

# %% [markdown]
# manually curate all reactions that gave a warning

# %%
#ATPS3v is vacuolar ATP synthase transporting three protons per ATP
tmodel.reactions.ATPS3v.transported_h = {'v': 3.0, 'c': -3.0}
thermo_flux.tools.drg_tools.reaction_balance(tmodel.reactions.ATPS3v, balance_charge=True, balance_mg=False)

# %%
tmodel.reactions.ASPOcm.transported_h= {'m': 2.0, 'c': -2.0}
tmodel.reactions.ASPOcm.transported_charge= {'m': -2.0, 'c': 2.0}
thermo_flux.tools.drg_tools.reaction_balance(tmodel.reactions.ASPOcm, balance_charge=True, balance_mg=False)

# %%
tmodel.reactions.ATPS.transported_h={'c':-1,'e':1}
thermo_flux.tools.drg_tools.reaction_balance(tmodel.reactions.ATPS, balance_charge=True, balance_mg=False)

# %%
#DHORD4i
tmodel.reactions.DHORD4i.transported_h = {'m': 2.0, 'c': -2.0}
tmodel.reactions.DHORD4i.transported_charge= {'m': -2.0, 'c': 2.0}
thermo_flux.tools.drg_tools.reaction_balance(tmodel.reactions.DHORD4i, balance_charge=True, balance_mg=False)

# %%
#DXHPScm is fine

# %%
# D_LACDcm
tmodel.reactions.D_LACDcm.transported_charge= {'m': 2.0, 'c': -2.0}
thermo_flux.tools.drg_tools.reaction_balance(tmodel.reactions.D_LACDcm, balance_charge=True, balance_mg=False)

# %%
##FDNG
tmodel.reactions.FDNG.transported_h = {'m': 2.0, 'c': -2.0}
tmodel.reactions.FDNG.transported_charge= {'m': -2.0, 'c': 2.0}
thermo_flux.tools.drg_tools.reaction_balance(tmodel.reactions.FDNG, balance_charge=True, balance_mg=False)

# %%
#FRDcm ## opposite then others h transport rxn we did until now
tmodel.reactions.FRDcm.transported_h = {'m': -2.0, 'c': 2.0}
tmodel.reactions.FRDcm.transported_charge= {'m': 2.0, 'c': -2.0}
thermo_flux.tools.drg_tools.reaction_balance(tmodel.reactions.FRDcm, balance_charge=True, balance_mg=False)

# %%
# L_LACD2cm
tmodel.reactions.L_LACD2cm.transported_charge= {'m': 2.0, 'c': -2.0}
thermo_flux.tools.drg_tools.reaction_balance(tmodel.reactions.L_LACD2cm, balance_charge=True, balance_mg=False)
tmodel.reactions.L_LACD2cm
# Out:
# <ThermoReaction L_LACD2cm at 0x7cc5c7d56050>

# %%
# NADH2_u6cm
tmodel.reactions.NADH2_u6cm.transported_h = {'m': 2.0, 'c': -2.0}
tmodel.reactions.NADH2_u6cm.transported_charge= {'m': -2.0, 'c': 2.0}
thermo_flux.tools.drg_tools.reaction_balance(tmodel.reactions.NADH2_u6cm, balance_charge=True, balance_mg=False)

# %% [markdown]
# ### Step 6 - Calculation of Gibbs energy of reactions
# Add thermodynamic constraints and parameters

# %%
#change max flux to 500 for all reactions

tmodel.reactions.get_by_id("biomass_EX").bounds = (0,500)
tmodel.reactions.get_by_id("biomass_c").bounds = (0,500)
tmodel.reactions.get_by_id("biomass_ce").bounds = (0,500)


for rxn in tmodel.reactions:
    rxn.lower_bound = -500 if rxn.lower_bound == -1000 else rxn.lower_bound
    rxn.upper_bound = 500 if rxn.upper_bound == 1000 else rxn.upper_bound
tmodel.objective = tmodel.reactions.biomass_EX

# %%
tmodel.update_thermo_info(fit_unknown_dfG0=False,search=True)
# Out:
# Identifying compounds...
# [█████████████████████████████████.......] 1045/1244 pheac_c
# WARNING: dolichol_c has inconsistent formula with eQuilibrator identified metabolite. COBRA:{'C': 15, 'H': 28, 'O': 1}, eQuilibrator:{'C': 25, 'O': 1}. Defining as unknown compound
# WARNING: dolmanp_r has inconsistent formula with eQuilibrator identified metabolite. COBRA:{'C': 21, 'H': 38, 'O': 9, 'P': 1}, eQuilibrator:{'C': 31, 'O': 9, 'P': 1}. Defining as unknown compound
# WARNING: glycogen_c has inconsistent formula with eQuilibrator identified metabolite. COBRA:{'C': 6, 'H': 10, 'O': 5}, eQuilibrator:{'O': 21, 'C': 24}. Defining as unknown compound
# WARNING: glycogen_v has inconsistent formula with eQuilibrator identified metabolite. COBRA:{'C': 6, 'H': 10, 'O': 5}, eQuilibrator:{'O': 21, 'C': 24}. Defining as unknown compound
# WARNING: mhpglu_c has inconsistent formula with eQuilibrator identified metabolite. COBRA:{'C': 25, 'H': 36, 'N': 8, 'O': 12}, eQuilibrator:{'C': 30, 'N': 9, 'O': 12}. Defining as unknown compound
# WARNING: macchitppdol_g has inconsistent formula with eQuilibrator identified metabolite. COBRA:{'C': 37, 'H': 64, 'N': 2, 'O': 22, 'P': 2}, eQuilibrator:{'C': 47, 'O': 22, 'P': 2, 'N': 2}. Defining as unknown compound
# WARNING: hpglu_c has inconsistent formula with eQuilibrator identified metabolite. COBRA:{'C': 24, 'H': 34, 'N': 8, 'O': 12}, eQuilibrator:{'N': 9, 'C': 29, 'O': 12}. Defining as unknown compound
# [████████████████████████████████████████] 1244/1244 Mg_n
#
# Estimating dfG0'...
# WARNING: trdox_c has inconsistent formula with eQuilibrator identified metabolite. COBRA:{'X': 1}, eQuilibrator:{'N': 4, 'C': 10, 'S': 2, 'O': 4}. Defining as unknown compound
# WARNING: trdox_m has inconsistent formula with eQuilibrator identified metabolite. COBRA:{'X': 1}, eQuilibrator:{'N': 4, 'C': 10, 'S': 2, 'O': 4}. Defining as unknown compound
# WARNING: trdox_n has inconsistent formula with eQuilibrator identified metabolite. COBRA:{'X': 1}, eQuilibrator:{'N': 4, 'C': 10, 'S': 2, 'O': 4}. Defining as unknown compound
# WARNING: trdox_x has inconsistent formula with eQuilibrator identified metabolite. COBRA:{'X': 1}, eQuilibrator:{'N': 4, 'C': 10, 'S': 2, 'O': 4}. Defining as unknown compound
# WARNING: trdrd_c has inconsistent formula with eQuilibrator identified metabolite. COBRA:{'X': 1, 'H': 2}, eQuilibrator:{'N': 4, 'C': 10, 'S': 2, 'O': 4}. Defining as unknown compound
# WARNING: trdrd_m has inconsistent formula with eQuilibrator identified metabolite. COBRA:{'X': 1, 'H': 2}, eQuilibrator:{'N': 4, 'C': 10, 'S': 2, 'O': 4}. Defining as unknown compound
# WARNING: trdrd_n has inconsistent formula with eQuilibrator identified metabolite. COBRA:{'X': 1, 'H': 2}, eQuilibrator:{'N': 4, 'C': 10, 'S': 2, 'O': 4}. Defining as unknown compound
# WARNING: trdrd_x has inconsistent formula with eQuilibrator identified metabolite. COBRA:{'X': 1, 'H': 2}, eQuilibrator:{'N': 4, 'C': 10, 'S': 2, 'O': 4}. Defining as unknown compound
# ficytc_m 0 kilojoule / mole
# focytc_m 0 kilojoule / mole
# biomass_c 0 kilojoule / mole
# biomass_e 0 kilojoule / mole
# [████████████████████████████████████████] 1244/1244 Mg_n
#
# Estimating drG0'...
# [█████████████...........................] 556/1595 EX_ile__L_e
# WARNING: DXHPScm is a transporter but no transported metabolites could be automatically identified. Please update the reaction.transported_mets
# WARNING: D_LACDcm is a transporter but no transported metabolites could be automatically identified. Please update the reaction.transported_mets
# [████████████████████████████............] 1151/1595 NH4t
# WARNING: L_LACD2cm is a transporter but no transported metabolites could be automatically identified. Please update the reaction.transported_mets
# [████████████████████████████████████████] 1595/1595 PIt2v0

# %%
for met in tmodel.metabolites:
    if met.ignore_conc:
        print(met.id,met.ignore_conc)
# Out:
# h2o_c True
# h2o_e True
# h2o_g True
# h2o_m True
# h2o_n True
# h2o_r True
# h2o_v True
# h2o_x True
# h_c True
# h_e True
# h_g True
# h_m True
# h_n True
# h_r True
# h_v True
# h_x True
# oh1_c True
# oh1_m True
# biomass_c True
# biomass_e True
# charge_c True
# charge_e True
# charge_m True
# charge_x True
# charge_r True
# charge_v True
# charge_g True
# charge_n True

# %%
#ignore snd for charge ?
for rxn in tmodel.reactions:
    if 'charge' in rxn.id and 'EX' not in rxn.id:#charge reactions are constrained by 2nd law 
        print(rxn.id,rxn.ignore_snd)
        rxn.ignore_snd=True
        print(rxn.id,rxn.ignore_snd)
        


#tmodel.reactions.EX_charge.ignore_snd=True
# Out:
# charge_ce False
# charge_ce True
# charge_cm False
# charge_cm True
# charge_cx False
# charge_cx True
# charge_cr False
# charge_cr True
# charge_cv False
# charge_cv True
# charge_cg False
# charge_cg True
# charge_cn False
# charge_cn True

# %% [markdown]
# ### Step 7 - Establishment of the thermodynamic-stoichiometric solution space
# Note : In our curation of the iMM904 model, due to the limited information available for the membrane potential of organelles, we chose to allow the free leakage of ions (charges) across the membrane.
# Allowing free movement of charges between compartments prevents over-constraining the model to potentially incorrect information.
# For more detailed analysis of charge transport or models where more information is available on membrane physiology then a constraint on the second law could be added for these charge transport reactions.

# %%
##x r v g n
tmodel.reactions.H_cm.ignore_snd=False
tmodel.reactions.H_cv.ignore_snd=False
tmodel.reactions.H_cx.ignore_snd=False
tmodel.reactions.H_cr.ignore_snd=False
tmodel.reactions.H_cg.ignore_snd=False
tmodel.reactions.H_cn.ignore_snd=False

# %%
# add the TFBA variables to the model
tmodel.m = None #reset the gurobi model object in case you're re-running this cell 
tmodel.add_TFBA_variables(gdiss_constraint = False, sigmac_limit = (5000/tmodel.T.m), error_type = 'covariance',qnorm=1,alpha=0.95)
tmodel.m.update()
# Out:
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 10

# %%
tmodel.optimize()
# Out:
# <Solution 3.309 at 0x7cc5c77009a0>

# %%
thermo_flux.solver.gurobi.model_start(tmodel,'fixed_dir_firstTFBA.sol', ignore_vars=['all'],fix_vars=['qm'],fix='bound')

# %%
tmodel.m.params.TimeLimit=10 ## in seconds
tmodel.m.optimize()
# Out:
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 24.04.3 LTS")
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-1260P, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 15733 rows, 12900 columns and 351055 nonzeros
# Model fingerprint: 0x15e79e31
# Model has 1 general constraint
# Variable types: 11305 continuous, 1595 integer (1595 binary)
# Coefficient statistics:
#   Matrix range     [6e-06, 1e+06]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-06, 1e+06]
#   RHS range        [7e-15, 1e+06]
#
# Warning: Completing partial solution with 1595 unfixed non-continuous variables out of 1595
# User MIP start did not produce a new incumbent solution
# User MIP start violates constraint mass_balance_neg[1228] by 42.805236648
#
# Presolve removed 10934 rows and 8601 columns
# Presolve time: 0.09s
# Presolved: 4799 rows, 4299 columns, 14606 nonzeros
# Variable types: 3337 continuous, 962 integer (962 binary)
#
# Root relaxation: objective 2.608601e+00, 2924 iterations, 0.06 seconds (0.07 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.60860    0   32          -    2.60860      -     -    0s
# H    0     0                      -0.0000000    2.60860      -     -    0s
#      0     0    2.18771    0   34   -0.00000    2.18771      -     -    0s
#      0     0    2.18771    0   32   -0.00000    2.18771      -     -    0s
#      0     0    2.18771    0   32   -0.00000    2.18771      -     -    0s
#      0     0    2.18771    0   32   -0.00000    2.18771      -     -    0s
#      0     0    2.18771    0   31   -0.00000    2.18771      -     -    0s
#      0     0    2.18019    0   29   -0.00000    2.18019      -     -    0s
#      0     0    2.18019    0   26   -0.00000    2.18019      -     -    0s
#      0     0    2.18019    0   26   -0.00000    2.18019      -     -    0s
#      0     0    2.18019    0   26   -0.00000    2.18019      -     -    0s
# H    0     0                       0.0000000    2.18019      -     -    0s
#      0     0    2.18019    0   15    0.00000    2.18019      -     -    0s
#      0     0    2.18019    0   10    0.00000    2.18019      -     -    0s
#      0     0    2.18019    0    9    0.00000    2.18019      -     -    0s
#      0     0    2.18019    0    8    0.00000    2.18019      -     -    0s
#      0     0    2.18019    0    7    0.00000    2.18019      -     -    0s
#      0     0    2.18019    0    7    0.00000    2.18019      -     -    0s
# H    0     0                       0.0000000    2.18019      -     -    0s
#      0     0    2.18019    0    8    0.00000    2.18019      -     -    0s
#      0     0    2.18019    0    7    0.00000    2.18019      -     -    0s
#      0     0    2.18019    0    7    0.00000    2.18019      -     -    0s
# H    0     0                       2.1801606    2.18019  0.00%     -    0s
#      0     0    2.18019    0    7    2.18016    2.18019  0.00%     -    0s
#
# Cutting planes:
#   Learned: 31
#   Cover: 2
#   Implied bound: 16
#   MIR: 14
#   Flow cover: 21
#   Relax-and-lift: 5
#
# Explored 1 nodes (6229 simplex iterations) in 0.87 seconds (0.64 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 4: 2.18016 3.31587e-10 1.07658e-10 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.180160611892e+00, best bound 2.180190507147e+00, gap 0.0014%

# %%
# tmodel.m.write('fixed_dir_firstTFBA.sol')

# %% [markdown]
# # analysis for results

# %%
sns.set_palette('viridis')
OUTPUT_FOLDER='./Figures/'
def scale_rcparams(fig,scalingf=None):
    default_figsize = (5, 5)
    current_figsize = fig.get_size_inches()
    scale_x = current_figsize[0] / default_figsize[0]
    scale_y = current_figsize[1] / default_figsize[1]
    scale = min(scale_x, scale_y) if scalingf is None else scalingf
    
    # Update rcParams with scaled values
    plt.rcParams['axes.linewidth'] = 2.05 * scale
    plt.rcParams['lines.linewidth'] = 1.5 * scale
    plt.rcParams['font.size'] = 12.5# 25 * scale #fixed size of 12.5 for all
    plt.rcParams['xtick.major.size'] = 9.84 * scale
    plt.rcParams['ytick.major.size'] = 9.84 * scale
    plt.rcParams['xtick.minor.size'] = 6.56 * scale
    plt.rcParams['ytick.minor.size'] = 6.56 * scale
    #width
    # 'ytick.minor.width': 1.0
    plt.rcParams['xtick.major.width'] = 2.05 * scale
    plt.rcParams['ytick.major.width'] = 2.05 * scale
    plt.rcParams['xtick.minor.width'] = 1.64 * scale
    plt.rcParams['ytick.minor.width'] = 1.64 * scale
    # plt.rcParams['lines.linewidth'] = 1.5 * scale
    plt.rcParams['legend.fontsize'] = 12.5#5 * scale
    plt.rcParams['xtick.labelsize'] =12.5 #25 * scale
    plt.rcParams['ytick.labelsize'] = 12.5#25 * scale
    plt.rcParams['axes.labelsize'] =12.5# 25 * scale
    
    return plt.rcParams

def rescale_axlim(ax,how='both',nbins=4):
    def rescale_ylim(ax,nbins):
        yticks = ax.get_yticks()
        ax.set_yticks(np.linspace(yticks[0], yticks[-1], nbins))
        return ax
    def rescale_xlim(ax,nbins):
        xticks = ax.get_xticks()
        ax.set_xticks(np.linspace(xticks[0], xticks[-1], nbins))
        return ax
    if how=='both':
        ax=rescale_ylim(rescale_xlim(ax,nbins),nbins)
    elif how=='x':
        ax=rescale_xlim(ax,nbins)
    elif how=='y':
        ax=rescale_ylim(ax,nbins)
    return ax

# %%
# # add the TFBA variables to the model
# tmodel.m = None #reset the gurobi model object in case you're re-running this cell 
# tmodel.add_TFBA_variables(gdiss_constraint = True, sigmac_limit = (3700/tmodel.T.m), error_type = 'covariance',qnorm=1,alpha=0.95)
# tmodel.m.update()
# tmodel.m.params.timelimit=60*5

# GUR_range = np.linspace(-0, -23, 50)

# thermo_flux.solver.gurobi.variable_scan(tmodel, GUR_range, var = tmodel.mvars['v'][0][tmodel.reactions.index(tmodel.reactions.get_by_id('EX_glc__D_e'))]) # here we get the index for the glucose uptake reaction and use this to index the v variable in the gurobi model
# thermo_flux.solver.gurobi.model_start(tmodel,'fixed_dir_firstTFBA.sol',ignore_vars=['all'],fix_vars=['qm'],fix='bound') #fix the drG error term to that from the initial TFBA to speed up optimisations

# tmodel.m.optimize()

# fluxes_gdiss = thermo_flux.solver.gurobi.multi_scenario_sol(tmodel,var = 'v') 
# fluxes_gdiss= pd.DataFrame(fluxes_gdiss[0].T, index = [rxn.id for rxn in tmodel.reactions])

# %%
#plot biomass yield for stoichiometric model with balanced reactions and pH specified
df_data2 = pd.read_csv('plotting_Yeast_ALL_experimental_data.csv',index_col=0)
df_data2['regression'].fillna('Not fitted',inplace=True)
df_data2['regression'].replace('yes', 'Fitted', inplace=True)
df_data2.rename(columns={'regression':'Exp. data'}, inplace=True)
#rename index in Condition
df_data2.index.rename('Condition', inplace=True)

GUR_plot_range=[-x for x in GUR_range]
#plot biomass vs GUR in a scatter plot

sns.scatterplot(x=GUR_plot_range,y=fluxes_gdiss.loc['biomass_EX'],color='b',label='TFBA')
# sns.scatterplot(x=GUR_plot_range,y=tbiomass_flux,color='b',label='FBA and balanced')
# sns.scatterplot(x=GUR_plot_range,y=biomass_flux,color='g',label='FBA')
sns.scatterplot(x=df_data2['glc-D_EX'], y=df_data2['biomass_EX'], color=['red'],label='Experimental data')
plt.xlabel('Glucose uptake rate (mmol/(gDW.h))',fontsize=14)
plt.ylabel('Biomass production rate (mmol/(gDW.h))',fontsize=14)

# plt.savefig('Figures/growth_all_TFBA_gdissconstraint.png',dpi=300)
# Out:
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 12
#       9 GUR_plot_range=[-x for x in GUR_range]
#      10 #plot biomass vs GUR in a scatter plot
# ---> 12 sns.scatterplot(x=GUR_plot_range,y=fluxes_gdiss.loc['biomass_EX'],color='b',label='TFBA')
#      13 # sns.scatterplot(x=GUR_plot_range,y=tbiomass_flux,color='b',label='FBA and balanced')
#      14 # sns.scatterplot(x=GUR_plot_range,y=biomass_flux,color='g',label='FBA')
#      15 sns.scatterplot(x=df_data2['glc-D_EX'], y=df_data2['biomass_EX'], color=['red'],label='Experimental data')
#
# NameError: name 'fluxes_gdiss' is not defined

# %% [markdown]
# ### do a gur_scan without gdiss, then compare reaction directions with FBA  ?

# %%
# add the TFBA variables to the model
tmodel.m = None #reset the gurobi model object in case you're re-running this cell 
tmodel.add_TFBA_variables(gdiss_constraint = True, sigmac_limit = (3700/tmodel.T.m), error_type = 'covariance',qnorm=1,alpha=0.95)
tmodel.m.update()
tmodel.m.params.timelimit=60*5

GUR_range = np.linspace(-0, -20, 20)

thermo_flux.solver.gurobi.variable_scan(tmodel, GUR_range, var = tmodel.mvars['v'][0][tmodel.reactions.index(tmodel.reactions.get_by_id('EX_glc__D_e'))]) # here we get the index for the glucose uptake reaction and use this to index the v variable in the gurobi model
thermo_flux.solver.gurobi.model_start(tmodel,'fixed_dir_firstTFBA.sol',ignore_vars=['all'],fix_vars=['qm'],fix='bound') #fix the drG error term to that from the initial TFBA to speed up optimisations

tmodel.m.optimize()

fluxes_TFBA = thermo_flux.solver.gurobi.multi_scenario_sol(tmodel,var = 'v') 
fluxes_TFBA = pd.DataFrame(fluxes_TFBA[0].T, index = [rxn.id for rxn in tmodel.reactions])
fluxes_TFBA.columns=GUR_range
# Out:
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 10
# Set parameter TimeLimit to value 300
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 24.04.3 LTS")
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-1260P, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 15734 rows, 13067 columns and 351222 nonzeros
# Model fingerprint: 0xf7fe29f3
# Model has 166 quadratic constraints
# Model has 1 general constraint
# Variable types: 11472 continuous, 1595 integer (1595 binary)
# Coefficient statistics:
#   Matrix range     [6e-06, 1e+06]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-06, 1e+06]
#   RHS range        [7e-15, 1e+06]
#
# Solving a multi-scenario model with 20 scenarios...
#
# Presolve removed 10922 rows and 8665 columns
# Presolve time: 0.09s
# Presolved: 5143 rows, 4422 columns, 15619 nonzeros
# Presolved model has 82 bilinear constraint(s)
# Presolved model has 20 scenario(s)
#
# Solving non-convex MIQCP
#
# Variable types: 3438 continuous, 984 integer (984 binary)
#
# Root relaxation: objective 2.191645e+00, 3359 iterations, 0.07 seconds (0.07 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.19165    0   35          -    2.19165      -     -    0s
#      0     0    1.84352    0   51          -    1.84352      -     -    0s
#      0     0    1.19758    0   52          -    1.19758      -     -    0s
#      0     0    1.19758    0   50          -    1.19758      -     -    0s
#      0     0    1.17715    0   52          -    1.17715      -     -    0s
#      0     0    1.17715    0   52          -    1.17715      -     -    0s
#      0     0    1.17715    0   52          -    1.17715      -     -    0s
#      0     0    1.17715    0   51          -    1.17715      -     -    0s
#      0     0    1.17715    0   51          -    1.17715      -     -    0s
#      0     0    1.17715    0   50          -    1.17715      -     -    0s
#      0     0    1.17715    0   51          -    1.17715      -     -    0s
#      0     0    1.17715    0   51          -    1.17715      -     -    0s
#      0     0    1.17715    0   51          -    1.17715      -     -    0s
#      0     0    1.17715    0   26          -    1.17715      -     -    0s
#      0     0    1.17715    0   28          -    1.17715      -     -    0s
#      0     0    1.17715    0   22          -    1.17715      -     -    0s
#      0     0    1.17715    0   23          -    1.17715      -     -    0s
#      0     0    1.17715    0   24          -    1.17715      -     -    0s
#      0     0    1.17715    0   22          -    1.17715      -     -    0s
# H    0     0                      -0.0000000    1.17715      -     -    0s
#      0     2    1.17715    0   20   -0.00000    1.17715      -     -    1s
# H  620   622                       0.0330110    1.02156  2995%  14.7    4s
# Scenario 0 has been solved. 19/20 scenarios left.
# H  708   742                       0.0330110    1.02156  2995%  16.8    4s
# H  740   742                       0.0330110    1.02156  2995%  17.0    4s
#   1112  1155   -0.00000   63    4    0.03301    1.02156  2995%  16.9    5s
# * 2021  1033              96       0.1887782    1.02156   441%  15.6    5s
# H 2106   962                       0.2620489    1.02156   290%  15.5    5s
# H 2147   962                       0.3639964    1.02156   181%  15.4    5s
# H 2344  1109                       0.4037786    0.99056   145%  14.9    6s
#   2364   526    0.52453   25    7    0.40378    0.99056   145%  14.7   10s
# H 2380   195                       0.4038350    0.41088  1.75%  17.9   14s
#   2384   179    0.41088   35   12    0.40384    0.41088  1.75%  17.9   15s
#   2404    36    0.41088   55    7    0.40384    0.41088  1.75%  21.1   20s
# Scenario 1 has been solved. 18/20 scenarios left.
# H 2411    11                       0.4039937    0.41088  1.71%  23.8   39s
# Scenario 2 has been solved. 17/20 scenarios left.
#   2411    13    0.40959   43   19    0.40399    0.41088  1.71%  23.9   40s
# Scenario 17 has been solved (gap 0.0026%). 16/20 scenarios left.
#
# Optimal solution found at node 4155 - now completing multiple scenarios...
#
#     Nodes    |    Current Node    |    Scenario Obj. Bounds   |     Work
#              |                    |   Worst                   |
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#   4155   694 infeasible   91         0.28247    0.40390  43.0%  24.0   44s
# Scenario 18 has been solved (gap 0.0079%). 15/20 scenarios left.
#   5211  1105    0.40218   68   11    0.28247    0.40388  43.0%  21.1   45s
# Scenario 19 has been solved (gap 0.0021%). 14/20 scenarios left.
#  13036  1170     cutoff   90         0.28247    0.40333  42.8%  13.8   50s
#  18387  1385    0.30822   91   12    0.28247    0.40333  42.8%  13.6   55s
# Scenario 16 has been solved (gap 0.0013%). 13/20 scenarios left.
# Scenario 15 has been solved (gap 0.0023%). 12/20 scenarios left.
#  25071  2408 infeasible   87         0.28247    0.39420  39.6%  14.6   60s
# Scenario 14 has been solved (gap 0.0096%). 11/20 scenarios left.
#  29621  3334 infeasible   80         0.28247    0.39414  39.5%  14.9   65s
#  35238  2096 infeasible   92         0.28247    0.38499  36.3%  16.1   70s
# Scenario 13 has been solved. 10/20 scenarios left.
#  41537  3579    0.37516   79   18    0.28247    0.37705  33.5%  16.5   75s
#  47580  4345    0.37545   89   15    0.28247    0.37623  33.2%  17.4   80s
# Scenario 12 has been solved. 9/20 scenarios left.
#  56083  1620 infeasible   96         0.28247    0.37443  32.6%  17.3   85s
#  62117  3560 infeasible   89         0.28247    0.36865  30.5%  17.8   90s
#  67547  4136 infeasible   87         0.28247    0.36641  29.7%  17.8   95s
# Scenario 11 has been solved. 8/20 scenarios left.
#  74013  2602 infeasible   79         0.28247    0.35888  27.1%  18.5  101s
#  76783  2956 infeasible   85         0.28247    0.35874  27.0%  18.9  108s
#  79219  3616    0.35632   89   20    0.28247    0.35863  27.0%  19.1  110s
#  83710  4269 infeasible   79         0.28247    0.35857  26.9%  19.7  115s
#  87264  5082 infeasible   81         0.28247    0.35852  26.9%  19.8  123s
# Scenario 3 has been solved (gap 0.0096%). 7/20 scenarios left.
#  88132  5327    0.35682   89   14    0.30059    0.35852  19.3%  19.9  143s
# Scenario 8 has been solved (gap 0.0002%). 6/20 scenarios left.
# Scenario 9 has been solved (gap 0.0100%). 5/20 scenarios left.
# Scenario 10 has been solved (gap 0.0097%). 4/20 scenarios left.
#  89213  4250 infeasible   82         0.30082    0.35852  19.2%  20.0  188s
# Scenario 4 has been solved (gap 0.0096%). 3/20 scenarios left.
# Scenario 7 has been solved (gap 0.0050%). 2/20 scenarios left.
#  94389  1347    0.31036   81   14    0.31034    0.32127  3.52%  19.2  190s
# Scenario 6 has been solved (gap 0.0091%). 1/20 scenarios left.
# Scenario 5 has been solved (gap 0.0100%). 0/20 scenarios left.
#
# Cutting planes:
#   Learned: 129
#   Gomory: 6
#   Cover: 16
#   Implied bound: 41
#   Projected implied bound: 1
#   MIR: 27
#   Mixing: 4
#   Flow cover: 146
#   RLT: 8
#   Relax-and-lift: 3
#
# Explored 98781 nodes (1905100 simplex iterations) in 194.95 seconds (78.92 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 10: 0.403994 0.403871 0.403871 ... 0.40386
# No other solutions better than 0.403994
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.039936673892e-01, best bound 4.039936673892e-01, gap 0.0000%

# %%
fluxes_FBA=pd.DataFrame(index=[rxn.id for rxn in tmodel.reactions])
for gur in GUR_range:
    tmodel.reactions.get_by_id('EX_glc__D_e').bounds = gur,gur
    sol=tmodel.optimize()
    fluxes_FBA[gur]=sol.to_frame()['fluxes']

# %%
def row_sign(row):
    return row.apply(lambda x:1 if x>0 else (-1 if x<0 else 0))
df_vdir_FBA=fluxes_FBA.apply(row_sign)
df_vdir_TFBA=fluxes_TFBA.apply(row_sign)

# %%
matches_per_row = (df_vdir_FBA == df_vdir_TFBA).sum(axis=1)
mismatches_per_row = (df_vdir_FBA != df_vdir_TFBA).sum(axis=1)

print(mismatches_per_row.value_counts())
print(df_vdir_FBA.shape[0]-1344) 
df_vdir_FBA.shape[0]
# Out:
# 0     1359
# 1       28
# 14      21
# 11      18
# 8       17
# 19      17
# 2       16
# 4       13
# 16      13
# 3       13
# 5       12
# 9       11
# 15       9
# 10       8
# 7        8
# 13       8
# 17       7
# 6        7
# 18       5
# 20       4
# 12       1
# Name: count, dtype: int64
# 251
# 1595

# %% [markdown]
# ### adding TFBA change direction compared to FBA for 177 reactions, what are these reactions

# %%
diff_rxn=mismatches_per_row[mismatches_per_row>0].index
df_diff_rxn=pd.DataFrame(index=diff_rxn)
for rxnid in diff_rxn:
    try:
        df_diff_rxn.loc[rxnid,'Subsystem']=model.reactions.get_by_id(rxnid).subsystem
    except:
        pass

# %%
counts=df_diff_rxn.value_counts()
threshold = 4.5
counts_agg = counts.copy()


# Convert to percentages
counts_agg = counts_agg / counts_agg.sum() * 100
# Group low-frequency categories into "Other"
low_freq = counts_agg[counts_agg < threshold]
counts_agg = counts_agg[counts_agg >= threshold]
counts_agg["Other"] = low_freq.sum()

# %%
counts_agg
# Out:
# Subsystem
# S_Transport__Mitochondrial      16.228070
# S_Nucleotide_Salvage_Pathway    10.087719
# S_Oxidative_Phosphorylation      6.578947
# S_Fatty_Acid__Biosynthesis       5.263158
# Other                           61.842105
# Name: count, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(2.5,2.5))
scale_rcparams(fig)

pieplot = counts_agg.copy()
# Move first element to position 4
pieplot = pd.concat([pieplot.iloc[1:5][::-1], pieplot.iloc[[0]], pieplot.iloc[5:]])
c=sns.color_palette('viridis',n_colors=8)
colors = [c[4]] + [c[3]] +[c[2]]  + [c[1]]+ [c[0]] + [c[-3]] + [c[-1]]
ax.pie(
    pieplot ,explode=[0,0.0,0.0,0,0.05,0],
    wedgeprops={"linewidth": 2, "edgecolor": "white"},startangle=18,     
    labels = pieplot.index,colors=colors,
    autopct='%1.0f%%',)

#save
# plt.savefig(f'{OUTPUT_FOLDER}/PIE_TFBAgdiss_FBA_directionnalitychanges.png',dpi=300)
# plt.savefig(f'{OUTPUT_FOLDER}/PIE_TFBAgdiss_FBA_directionnalitychanges.svg',dpi=300)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 9
#       7 c=sns.color_palette('viridis',n_colors=8)
#       8 colors = [c[4]] + [c[3]] +[c[2]]  + [c[1]]+ [c[0]] + [c[-3]] + [c[-1]]
# ----> 9 ax.pie(
#      10     pieplot ,explode=[0,0.0,0.0,0,0.05,0],
#      11     wedgeprops={"linewidth": 2, "edgecolor": "white"},startangle=18,
#      12     labels = pieplot.index,colors=colors,
#      13     autopct='%1.0f%%',)
#      15 #save
#      16 # plt.savefig(f'{OUTPUT_FOLDER}/PIE_TFBAgdiss_FBA_directionnalitychanges.png',dpi=300)
#      17 # plt.savefig(f'{OUTPUT_FOLDER}/PIE_TFBAgdiss_FBA_directionnalitychanges.svg',dpi=300)
#
# File ~/anaconda3/envs/tf_env/lib/python3.10/site-packages/matplotlib/__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File ~/anaconda3/envs/tf_env/lib/python3.10/site-packages/matplotlib/axes/_axes.py:3300, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch)
#    3298     raise ValueError("'label' must be of length 'x'")
#    3299 if len(x) != len(explode):
# -> 3300     raise ValueError("'explode' must be of length 'x'")
#    3301 if colors is None:
#    3302     get_next_color = self._get_patches_for_fill.get_next_color
#
# ValueError: 'explode' must be of length 'x'

# %% [markdown]
# ## first do variability analysis then check the magnitude of ranges

# %%
FVA_fluxes=cobra.flux_analysis.flux_variability_analysis(model, [r for r in model.reactions if r.id in [tr.id for tr in tmodel.reactions]],
                                                         fraction_of_optimum=0)
##explore whole space don't restrict on solutions that are close to the FBA optimum

# %%
##first maybe check ranges ?
FVA_fluxes['range']=FVA_fluxes['maximum']-FVA_fluxes['minimum']
# FVA_fluxes['range'].plot(kind='hist')
range_FVA=FVA_fluxes['range']
nlargeFVA=len(range_FVA[range_FVA>200])
# Out:
# 312

# %%
##also do it for fully reversible FVA
for r in model.reactions : 
    try:
        r.bounds=-500,500
    except:
        pass
for r in tmodel.reactions : 
    try:
        model.reactions.get_by_id(r.id).bounds=-500,500
    except:
        pass

FVA_free_fluxes=cobra.flux_analysis.flux_variability_analysis(model, [r for r in model.reactions if r.id in [tr.id for tr in tmodel.reactions]],
                                                         fraction_of_optimum=0)

# %%
FVA_free_fluxes['range']=FVA_free_fluxes['maximum']-FVA_free_fluxes['minimum']

# %%
## how much reactions are fully reversible ? 
FBArev_rxn=[]
for r in FVA_fluxes.index:
    if FVA_fluxes.loc[r,'minimum']<0 and FVA_fluxes.loc[r,'maximum']>0:
        FBArev_rxn.append(r)
len(FBArev_rxn)
# Out:
# 94

# %%
var_tfba_model=thermo_flux.solver.gurobi.variability_analysis(tmodel,tmodel.mvars['v'][0])
var_tfba_model.params.TimeLimit=60*60*10
                                                    
var_tfba_model.optimize()
# Out:
# 0
# Set parameter TimeLimit to value 36000
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 24.04.3 LTS")
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-1260P, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 15733 rows, 12900 columns and 351055 nonzeros
# Model fingerprint: 0xb92d07a9
# Model has 1 general constraint
# Variable types: 11305 continuous, 1595 integer (1595 binary)
# Coefficient statistics:
#   Matrix range     [6e-06, 1e+06]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-06, 1e+06]
#   RHS range        [7e-15, 1e+06]
#
# Solving a multi-scenario model with 3190 scenarios...
#
#
# Warning: Completing partial solution with 4785 unfixed non-continuous variables out of 4785
# User MIP start did not produce a new incumbent solution
# User MIP start violates constraint mass_balance_neg[1228] by 42.805236648
# MIP start from previous solve produced solution with objective 199.14 (1.62s)
# MIP start from previous solve produced solution with objective -0 (1.62s)
# MIP start from previous solve produced solution with objective -0 (1.62s)
# MIP start from previous solve produced solution with objective -0 (1.62s)
# MIP start from previous solve produced solution with objective -0 (1.63s)
# MIP start from previous solve produced solution with objective -0 (1.63s)
# MIP start from previous solve produced solution with objective -0 (1.63s)
# MIP start from previous solve produced solution with objective -2.47405 (1.63s)
# MIP start from previous solve produced solution with objective 2.47405 (1.63s)
# MIP start from previous solve produced solution with objective -0 (1.63s)
# MIP start from previous solve produced solution with objective -0 (1.63s)
# MIP start from previous solve produced solution with objective -0 (1.63s)
# MIP start from previous solve produced solution with objective -0 (1.63s)
# MIP start from previous solve produced solution with objective -0 (1.63s)
# MIP start from previous solve produced solution with objective -0 (1.63s)
# MIP start from previous solve produced solution with objective -0 (1.63s)
# MIP start from previous solve produced solution with objective -0 (1.63s)
# MIP start from previous solve produced solution with objective -0 (1.64s)
# MIP start from previous solve produced solution with objective -0 (1.64s)
# MIP start from previous solve produced solution with objective -0 (1.64s)
# MIP start from previous solve produced solution with objective -0 (1.64s)
# MIP start from previous solve produced solution with objective -0 (1.64s)
# MIP start from previous solve produced solution with objective -0 (1.64s)
# MIP start from previous solve produced solution with objective -0 (1.64s)
# MIP start from previous solve produced solution with objective -0 (1.64s)
# MIP start from previous solve produced solution with objective -0 (1.64s)
# MIP start from previous solve produced solution with objective -0 (1.64s)
# MIP start from previous solve produced solution with objective -0 (1.64s)
# MIP start from previous solve produced solution with objective -0 (1.65s)
# MIP start from previous solve produced solution with objective -0 (1.65s)
# MIP start from previous solve produced solution with objective -0 (1.65s)
# MIP start from previous solve produced solution with objective -0 (1.65s)
# MIP start from previous solve produced solution with objective -0 (1.65s)
# MIP start from previous solve produced solution with objective -0 (1.65s)
# MIP start from previous solve produced solution with objective -0 (1.65s)
# MIP start from previous solve produced solution with objective -0 (1.65s)
# MIP start from previous solve produced solution with objective -0 (1.65s)
# MIP start from previous solve produced solution with objective -0 (1.65s)
# MIP start from previous solve produced solution with objective -0 (1.66s)
# MIP start from previous solve produced solution with objective -0 (1.66s)
# MIP start from previous solve produced solution with objective -0 (1.66s)
# MIP start from previous solve produced solution with objective -0 (1.66s)
# MIP start from previous solve produced solution with objective -0 (1.66s)
# MIP start from previous solve produced solution with objective -0 (1.66s)
# MIP start from previous solve produced solution with objective -0 (1.66s)
# MIP start from previous solve produced solution with objective -0 (1.66s)
# MIP start from previous solve produced solution with objective -0 (1.66s)
# MIP start from previous solve produced solution with objective -0 (1.66s)
# MIP start from previous solve produced solution with objective -0 (1.67s)
# MIP start from previous solve produced solution with objective -0 (1.67s)
# MIP start from previous solve produced solution with objective -0 (1.67s)
# MIP start from previous solve produced solution with objective -0 (1.67s)
# MIP start from previous solve produced solution with objective -0 (1.67s)
# MIP start from previous solve produced solution with objective -0 (1.67s)
# MIP start from previous solve produced solution with objective -0 (1.67s)
# MIP start from previous solve produced solution with objective -0 (1.68s)
# MIP start from previous solve produced solution with objective -0 (1.68s)
# MIP start from previous solve produced solution with objective -0 (1.68s)
# MIP start from previous solve produced solution with objective -0 (1.68s)
# MIP start from previous solve produced solution with objective -0 (1.68s)
# MIP start from previous solve produced solution with objective -0 (1.68s)
# MIP start from previous solve produced solution with objective -0.866832 (1.69s)
# MIP start from previous solve produced solution with objective 0.866832 (1.69s)
# MIP start from previous solve produced solution with objective -0 (1.69s)
# MIP start from previous solve produced solution with objective -0 (1.69s)
# MIP start from previous solve produced solution with objective -0.05385 (1.69s)
# MIP start from previous solve produced solution with objective 0.05385 (1.69s)
# MIP start from previous solve produced solution with objective -0.709424 (1.69s)
# MIP start from previous solve produced solution with objective 0.709424 (1.69s)
# MIP start from previous solve produced solution with objective -0.113608 (1.69s)
# MIP start from previous solve produced solution with objective 0.113608 (1.70s)
# MIP start from previous solve produced solution with objective -0 (1.70s)
# MIP start from previous solve produced solution with objective -0 (1.70s)
# MIP start from previous solve produced solution with objective -0 (1.70s)
# MIP start from previous solve produced solution with objective -0 (1.70s)
# MIP start from previous solve produced solution with objective -0 (1.70s)
# MIP start from previous solve produced solution with objective -0 (1.71s)
# MIP start from previous solve produced solution with objective -0 (1.71s)
# MIP start from previous solve produced solution with objective -0 (1.71s)
# MIP start from previous solve produced solution with objective -0 (1.71s)
# MIP start from previous solve produced solution with objective -0 (1.71s)
# MIP start from previous solve produced solution with objective -0.040769 (1.71s)
# MIP start from previous solve produced solution with objective 0.040769 (1.71s)
# MIP start from previous solve produced solution with objective -0 (1.71s)
# MIP start from previous solve produced solution with objective -0 (1.71s)
# MIP start from previous solve produced solution with objective -0 (1.72s)
# MIP start from previous solve produced solution with objective -0 (1.72s)
# MIP start from previous solve produced solution with objective -0.124923 (1.72s)
# MIP start from previous solve produced solution with objective 0.124923 (1.72s)
# MIP start from previous solve produced solution with objective -0 (1.72s)
# MIP start from previous solve produced solution with objective -0 (1.72s)
# MIP start from previous solve produced solution with objective -0.709424 (1.72s)
# MIP start from previous solve produced solution with objective 0.709424 (1.72s)
# MIP start from previous solve produced solution with objective -0.420117 (1.72s)
# MIP start from previous solve produced solution with objective 0.420117 (1.72s)
# MIP start from previous solve produced solution with objective -0 (1.72s)
# MIP start from previous solve produced solution with objective -0 (1.73s)
# MIP start from previous solve produced solution with objective -0.623962 (1.73s)
# MIP start from previous solve produced solution with objective 0.623962 (1.73s)
# MIP start from previous solve produced solution with objective -0.420117 (1.73s)
# MIP start from previous solve produced solution with objective 0.420117 (1.73s)
# MIP start from previous solve produced solution with objective -0 (1.73s)
# MIP start from previous solve produced solution with objective -0 (1.73s)
# MIP start from previous solve produced solution with objective -0 (1.73s)
# MIP start from previous solve produced solution with objective -0 (1.73s)
# MIP start from previous solve produced solution with objective -0 (1.73s)
# MIP start from previous solve produced solution with objective -0 (1.73s)
# MIP start from previous solve produced solution with objective -0 (1.73s)
# MIP start from previous solve produced solution with objective -0 (1.74s)
# MIP start from previous solve produced solution with objective -1.22307 (1.74s)
# MIP start from previous solve produced solution with objective 1.22307 (1.74s)
# MIP start from previous solve produced solution with objective -0 (1.74s)
# MIP start from previous solve produced solution with objective -0 (1.74s)
# MIP start from previous solve produced solution with objective -0 (1.74s)
# MIP start from previous solve produced solution with objective -0 (1.74s)
# MIP start from previous solve produced solution with objective -0 (1.74s)
# MIP start from previous solve produced solution with objective -0 (1.74s)
# MIP start from previous solve produced solution with objective -0 (1.74s)
# MIP start from previous solve produced solution with objective -0 (1.74s)
# MIP start from previous solve produced solution with objective -0.360359 (1.74s)
# MIP start from previous solve produced solution with objective 0.360359 (1.75s)
# MIP start from previous solve produced solution with objective -0.215814 (1.75s)
# MIP start from previous solve produced solution with objective 0.215814 (1.75s)
# MIP start from previous solve produced solution with objective -18.0059 (1.75s)
# MIP start from previous solve produced solution with objective 18.0059 (1.75s)
# MIP start from previous solve produced solution with objective -18.0059 (1.75s)
# MIP start from previous solve produced solution with objective 18.0059 (1.75s)
# MIP start from previous solve produced solution with objective -0 (1.76s)
# MIP start from previous solve produced solution with objective -0 (1.76s)
# MIP start from previous solve produced solution with objective -0 (1.76s)
# MIP start from previous solve produced solution with objective -0 (1.76s)
# MIP start from previous solve produced solution with objective -0 (1.76s)
# MIP start from previous solve produced solution with objective -0 (1.76s)
# MIP start from previous solve produced solution with objective -0 (1.76s)
# MIP start from previous solve produced solution with objective -0 (1.76s)
# MIP start from previous solve produced solution with objective -0 (1.76s)
# MIP start from previous solve produced solution with objective -0 (1.76s)
# MIP start from previous solve produced solution with objective -0 (1.77s)
# MIP start from previous solve produced solution with objective -0 (1.77s)
# MIP start from previous solve produced solution with objective -0 (1.77s)
# MIP start from previous solve produced solution with objective -0 (1.77s)
# MIP start from previous solve produced solution with objective -0 (1.77s)
# MIP start from previous solve produced solution with objective -0 (1.77s)
# MIP start from previous solve produced solution with objective -0 (1.77s)
# MIP start from previous solve produced solution with objective -0 (1.77s)
# MIP start from previous solve produced solution with objective -0 (1.78s)
# MIP start from previous solve produced solution with objective -0 (1.78s)
# MIP start from previous solve produced solution with objective -0 (1.78s)
# MIP start from previous solve produced solution with objective -0 (1.78s)
# MIP start from previous solve produced solution with objective -0 (1.78s)
# MIP start from previous solve produced solution with objective -0 (1.78s)
# MIP start from previous solve produced solution with objective 1.11387 (1.78s)
# MIP start from previous solve produced solution with objective -1.11387 (1.78s)
# MIP start from previous solve produced solution with objective -0 (1.78s)
# MIP start from previous solve produced solution with objective -0 (1.78s)
# MIP start from previous solve produced solution with objective -0 (1.78s)
# MIP start from previous solve produced solution with objective -0 (1.78s)
# MIP start from previous solve produced solution with objective -0 (1.79s)
# MIP start from previous solve produced solution with objective -0 (1.79s)
# MIP start from previous solve produced solution with objective -0 (1.79s)
# MIP start from previous solve produced solution with objective -0 (1.79s)
# MIP start from previous solve produced solution with objective -0 (1.79s)
# MIP start from previous solve produced solution with objective -0 (1.79s)
# MIP start from previous solve produced solution with objective -0.222376 (1.79s)
# MIP start from previous solve produced solution with objective 0.222376 (1.79s)
# MIP start from previous solve produced solution with objective -0 (1.79s)
# MIP start from previous solve produced solution with objective -0 (1.79s)
# MIP start from previous solve produced solution with objective -0 (1.79s)
# MIP start from previous solve produced solution with objective -0 (1.80s)
# MIP start from previous solve produced solution with objective -20.3406 (1.80s)
# MIP start from previous solve produced solution with objective 20.3406 (1.80s)
# MIP start from previous solve produced solution with objective -0 (1.80s)
# MIP start from previous solve produced solution with objective -0 (1.80s)
# MIP start from previous solve produced solution with objective -0 (1.80s)
# MIP start from previous solve produced solution with objective -0 (1.80s)
# MIP start from previous solve produced solution with objective -0.709424 (1.80s)
# MIP start from previous solve produced solution with objective 0.709424 (1.80s)
# MIP start from previous solve produced solution with objective -0 (1.81s)
# MIP start from previous solve produced solution with objective -0 (1.81s)
# MIP start from previous solve produced solution with objective -0 (1.81s)
# MIP start from previous solve produced solution with objective -0 (1.81s)
# MIP start from previous solve produced solution with objective -0 (1.81s)
# MIP start from previous solve produced solution with objective -0 (1.81s)
# MIP start from previous solve produced solution with objective -0 (1.81s)
# MIP start from previous solve produced solution with objective -0 (1.82s)
# MIP start from previous solve produced solution with objective -0 (1.82s)
# MIP start from previous solve produced solution with objective -0 (1.82s)
# MIP start from previous solve produced solution with objective -0 (1.82s)
# MIP start from previous solve produced solution with objective -0 (1.82s)
# MIP start from previous solve produced solution with objective -0 (1.82s)
# MIP start from previous solve produced solution with objective -0 (1.82s)
# MIP start from previous solve produced solution with objective -0 (1.83s)
# MIP start from previous solve produced solution with objective -0 (1.83s)
# MIP start from previous solve produced solution with objective -0 (1.83s)
# MIP start from previous solve produced solution with objective -0 (1.83s)
# MIP start from previous solve produced solution with objective -0 (1.83s)
# MIP start from previous solve produced solution with objective -0 (1.83s)
# MIP start from previous solve produced solution with objective -0 (1.83s)
# MIP start from previous solve produced solution with objective -0 (1.83s)
# MIP start from previous solve produced solution with objective -0 (1.83s)
# MIP start from previous solve produced solution with objective -0 (1.83s)
# MIP start from previous solve produced solution with objective -0 (1.84s)
# MIP start from previous solve produced solution with objective -0 (1.84s)
# MIP start from previous solve produced solution with objective -0 (1.84s)
# MIP start from previous solve produced solution with objective -0 (1.84s)
# MIP start from previous solve produced solution with objective -1.20018 (1.84s)
# MIP start from previous solve produced solution with objective 1.20018 (1.84s)
# MIP start from previous solve produced solution with objective -0 (1.84s)
# MIP start from previous solve produced solution with objective -0 (1.85s)
# MIP start from previous solve produced solution with objective -0 (1.85s)
# MIP start from previous solve produced solution with objective -0 (1.85s)
# MIP start from previous solve produced solution with objective -0 (1.85s)
# MIP start from previous solve produced solution with objective -0 (1.85s)
# MIP start from previous solve produced solution with objective -0 (1.85s)
# MIP start from previous solve produced solution with objective -0 (1.85s)
# MIP start from previous solve produced solution with objective -0 (1.85s)
# MIP start from previous solve produced solution with objective -0 (1.85s)
# MIP start from previous solve produced solution with objective -0 (1.86s)
# MIP start from previous solve produced solution with objective -0 (1.86s)
# MIP start from previous solve produced solution with objective -0 (1.86s)
# MIP start from previous solve produced solution with objective -0 (1.86s)
# MIP start from previous solve produced solution with objective -0 (1.86s)
# MIP start from previous solve produced solution with objective -0 (1.86s)
# MIP start from previous solve produced solution with objective -0 (1.86s)
# MIP start from previous solve produced solution with objective -0 (1.86s)
# MIP start from previous solve produced solution with objective -0 (1.87s)
# MIP start from previous solve produced solution with objective -0 (1.87s)
# MIP start from previous solve produced solution with objective -0 (1.87s)
# MIP start from previous solve produced solution with objective -0 (1.87s)
# MIP start from previous solve produced solution with objective -0 (1.87s)
# MIP start from previous solve produced solution with objective -0 (1.87s)
# MIP start from previous solve produced solution with objective -0 (1.87s)
# MIP start from previous solve produced solution with objective -0 (1.87s)
# MIP start from previous solve produced solution with objective -0 (1.87s)
# MIP start from previous solve produced solution with objective -0 (1.87s)
# MIP start from previous solve produced solution with objective -0 (1.88s)
# MIP start from previous solve produced solution with objective -0 (1.88s)
# MIP start from previous solve produced solution with objective -0 (1.88s)
# MIP start from previous solve produced solution with objective -0 (1.88s)
# MIP start from previous solve produced solution with objective -0 (1.88s)
# MIP start from previous solve produced solution with objective -0 (1.88s)
# MIP start from previous solve produced solution with objective -0 (1.88s)
# MIP start from previous solve produced solution with objective -0 (1.88s)
# MIP start from previous solve produced solution with objective -0 (1.88s)
# MIP start from previous solve produced solution with objective -0 (1.88s)
# MIP start from previous solve produced solution with objective 0.6462 (1.88s)
# MIP start from previous solve produced solution with objective -0.6462 (1.88s)
# MIP start from previous solve produced solution with objective -0 (1.88s)
# MIP start from previous solve produced solution with objective -0 (1.88s)
# MIP start from previous solve produced solution with objective -0 (1.89s)
# MIP start from previous solve produced solution with objective -0 (1.89s)
# MIP start from previous solve produced solution with objective -0 (1.89s)
# MIP start from previous solve produced solution with objective -0 (1.89s)
# MIP start from previous solve produced solution with objective -0.05385 (1.89s)
# MIP start from previous solve produced solution with objective 0.05385 (1.89s)
# MIP start from previous solve produced solution with objective -0 (1.89s)
# MIP start from previous solve produced solution with objective -0 (1.89s)
# MIP start from previous solve produced solution with objective -0 (1.89s)
# MIP start from previous solve produced solution with objective -0 (1.89s)
# MIP start from previous solve produced solution with objective -3.48538 (1.90s)
# MIP start from previous solve produced solution with objective 3.48538 (1.90s)
# MIP start from previous solve produced solution with objective -0 (1.90s)
# MIP start from previous solve produced solution with objective -0 (1.90s)
# MIP start from previous solve produced solution with objective -0 (1.90s)
# MIP start from previous solve produced solution with objective -0 (1.90s)
# MIP start from previous solve produced solution with objective -0 (1.90s)
# MIP start from previous solve produced solution with objective -0 (1.90s)
# MIP start from previous solve produced solution with objective -0 (1.90s)
# MIP start from previous solve produced solution with objective -0 (1.90s)
# MIP start from previous solve produced solution with objective -0 (1.90s)
# MIP start from previous solve produced solution with objective -0 (1.91s)
# MIP start from previous solve produced solution with objective -0 (1.91s)
# MIP start from previous solve produced solution with objective -0 (1.91s)
# MIP start from previous solve produced solution with objective -0 (1.91s)
# MIP start from previous solve produced solution with objective -0 (1.91s)
# MIP start from previous solve produced solution with objective -1.07526 (1.91s)
# MIP start from previous solve produced solution with objective 1.07526 (1.91s)
# MIP start from previous solve produced solution with objective -0 (1.91s)
# MIP start from previous solve produced solution with objective -0 (1.92s)
# MIP start from previous solve produced solution with objective -0 (1.92s)
# MIP start from previous solve produced solution with objective -0 (1.92s)
# MIP start from previous solve produced solution with objective -0 (1.92s)
# MIP start from previous solve produced solution with objective -0 (1.92s)
# MIP start from previous solve produced solution with objective -0 (1.92s)
# MIP start from previous solve produced solution with objective -0 (1.92s)
# MIP start from previous solve produced solution with objective -0 (1.92s)
# MIP start from previous solve produced solution with objective -0 (1.93s)
# MIP start from previous solve produced solution with objective -0 (1.93s)
# MIP start from previous solve produced solution with objective -0 (1.93s)
# MIP start from previous solve produced solution with objective -0.040769 (1.93s)
# MIP start from previous solve produced solution with objective 0.040769 (1.93s)
# MIP start from previous solve produced solution with objective -0 (1.93s)
# MIP start from previous solve produced solution with objective -0 (1.93s)
# MIP start from previous solve produced solution with objective -0 (1.94s)
# MIP start from previous solve produced solution with objective -0 (1.94s)
# MIP start from previous solve produced solution with objective -0 (1.94s)
# MIP start from previous solve produced solution with objective -0 (1.94s)
# MIP start from previous solve produced solution with objective -0 (1.94s)
# MIP start from previous solve produced solution with objective -0 (1.94s)
# MIP start from previous solve produced solution with objective -0 (1.94s)
# MIP start from previous solve produced solution with objective -0 (1.94s)
# MIP start from previous solve produced solution with objective -0 (1.94s)
# MIP start from previous solve produced solution with objective -0 (1.94s)
# MIP start from previous solve produced solution with objective -0 (1.95s)
# MIP start from previous solve produced solution with objective -0 (1.95s)
# MIP start from previous solve produced solution with objective -0 (1.95s)
# MIP start from previous solve produced solution with objective -0 (1.95s)
# MIP start from previous solve produced solution with objective -0.124923 (1.95s)
# MIP start from previous solve produced solution with objective 0.124923 (1.95s)
# MIP start from previous solve produced solution with objective -0 (1.95s)
# MIP start from previous solve produced solution with objective -0 (1.95s)
# MIP start from previous solve produced solution with objective -0 (1.95s)
# MIP start from previous solve produced solution with objective -0 (1.96s)
# MIP start from previous solve produced solution with objective -0.252681 (1.96s)
# MIP start from previous solve produced solution with objective 0.252681 (1.96s)
# MIP start from previous solve produced solution with objective -0 (1.96s)
# MIP start from previous solve produced solution with objective -0 (1.96s)
# MIP start from previous solve produced solution with objective -0 (1.96s)
# MIP start from previous solve produced solution with objective -0 (1.96s)
# MIP start from previous solve produced solution with objective -0 (1.96s)
# MIP start from previous solve produced solution with objective -0 (1.96s)
# MIP start from previous solve produced solution with objective -0 (1.96s)
# MIP start from previous solve produced solution with objective -0 (1.97s)
# MIP start from previous solve produced solution with objective -0 (1.97s)
# MIP start from previous solve produced solution with objective -0 (1.97s)
# MIP start from previous solve produced solution with objective -0 (1.97s)
# MIP start from previous solve produced solution with objective -0 (1.97s)
# MIP start from previous solve produced solution with objective -0.215814 (1.97s)
# MIP start from previous solve produced solution with objective 0.215814 (1.97s)
# MIP start from previous solve produced solution with objective -0.252681 (1.97s)
# MIP start from previous solve produced solution with objective 0.252681 (1.97s)
# MIP start from previous solve produced solution with objective -0 (1.97s)
# MIP start from previous solve produced solution with objective -0 (1.97s)
# MIP start from previous solve produced solution with objective -0 (1.98s)
# MIP start from previous solve produced solution with objective -0 (1.98s)
# MIP start from previous solve produced solution with objective -0 (1.98s)
# MIP start from previous solve produced solution with objective -0 (1.98s)
# MIP start from previous solve produced solution with objective -0 (1.98s)
# MIP start from previous solve produced solution with objective -0 (1.98s)
# MIP start from previous solve produced solution with objective -0.0619166 (1.98s)
# MIP start from previous solve produced solution with objective 0.0619166 (1.98s)
# MIP start from previous solve produced solution with objective -0 (1.98s)
# MIP start from previous solve produced solution with objective -0 (1.99s)
# MIP start from previous solve produced solution with objective -0 (1.99s)
# MIP start from previous solve produced solution with objective -0 (1.99s)
# MIP start from previous solve produced solution with objective -138.852 (1.99s)
# MIP start from previous solve produced solution with objective 138.852 (1.99s)
# MIP start from previous solve produced solution with objective -0 (1.99s)
# MIP start from previous solve produced solution with objective -0 (1.99s)
# MIP start from previous solve produced solution with objective -0.0619166 (1.99s)
# MIP start from previous solve produced solution with objective 0.0619166 (2.00s)
# MIP start from previous solve produced solution with objective -0 (2.00s)
# MIP start from previous solve produced solution with objective -0 (2.00s)
# MIP start from previous solve produced solution with objective -0 (2.00s)
# MIP start from previous solve produced solution with objective -0 (2.00s)
# MIP start from previous solve produced solution with objective -0 (2.00s)
# MIP start from previous solve produced solution with objective -0 (2.00s)
# MIP start from previous solve produced solution with objective -0 (2.00s)
# MIP start from previous solve produced solution with objective -0 (2.00s)
# MIP start from previous solve produced solution with objective -0 (2.00s)
# MIP start from previous solve produced solution with objective -0 (2.01s)
# MIP start from previous solve produced solution with objective -0 (2.01s)
# MIP start from previous solve produced solution with objective -0 (2.01s)
# MIP start from previous solve produced solution with objective -0 (2.01s)
# MIP start from previous solve produced solution with objective -0 (2.01s)
# MIP start from previous solve produced solution with objective -0 (2.01s)
# MIP start from previous solve produced solution with objective -0 (2.01s)
# MIP start from previous solve produced solution with objective -0 (2.01s)
# MIP start from previous solve produced solution with objective -0 (2.01s)
# MIP start from previous solve produced solution with objective -0 (2.01s)
# MIP start from previous solve produced solution with objective -0 (2.01s)
# MIP start from previous solve produced solution with objective -0 (2.02s)
# MIP start from previous solve produced solution with objective -0 (2.02s)
# MIP start from previous solve produced solution with objective -0 (2.02s)
# MIP start from previous solve produced solution with objective -0 (2.02s)
# MIP start from previous solve produced solution with objective -0.124923 (2.02s)
# MIP start from previous solve produced solution with objective 0.124923 (2.02s)
# MIP start from previous solve produced solution with objective -0 (2.02s)
# MIP start from previous solve produced solution with objective -0 (2.02s)
# MIP start from previous solve produced solution with objective -0 (2.02s)
# MIP start from previous solve produced solution with objective -0 (2.02s)
# MIP start from previous solve produced solution with objective -0 (2.02s)
# MIP start from previous solve produced solution with objective -0 (2.02s)
# MIP start from previous solve produced solution with objective -0 (2.03s)
# MIP start from previous solve produced solution with objective -0 (2.03s)
# MIP start from previous solve produced solution with objective -0 (2.03s)
# MIP start from previous solve produced solution with objective -0 (2.03s)
# MIP start from previous solve produced solution with objective -0.00479635 (2.03s)
# MIP start from previous solve produced solution with objective 0.00479635 (2.03s)
# MIP start from previous solve produced solution with objective -0 (2.03s)
# MIP start from previous solve produced solution with objective -0 (2.03s)
# MIP start from previous solve produced solution with objective -0 (2.03s)
# MIP start from previous solve produced solution with objective -0 (2.03s)
# MIP start from previous solve produced solution with objective -0.00152611 (2.04s)
# MIP start from previous solve produced solution with objective 0.00152611 (2.04s)
# MIP start from previous solve produced solution with objective -0.00479635 (2.04s)
# MIP start from previous solve produced solution with objective 0.00479635 (2.04s)
# MIP start from previous solve produced solution with objective -0.350352 (2.04s)
# MIP start from previous solve produced solution with objective 0.350352 (2.04s)
# MIP start from previous solve produced solution with objective -0.350352 (2.04s)
# MIP start from previous solve produced solution with objective 0.350352 (2.04s)
# MIP start from previous solve produced solution with objective -0 (2.05s)
# MIP start from previous solve produced solution with objective -0 (2.05s)
# MIP start from previous solve produced solution with objective -0 (2.05s)
# MIP start from previous solve produced solution with objective -0 (2.05s)
# MIP start from previous solve produced solution with objective -0 (2.05s)
# MIP start from previous solve produced solution with objective -0 (2.05s)
# MIP start from previous solve produced solution with objective -0 (2.05s)
# MIP start from previous solve produced solution with objective -0 (2.05s)
# MIP start from previous solve produced solution with objective -0 (2.06s)
# MIP start from previous solve produced solution with objective -0 (2.06s)
# MIP start from previous solve produced solution with objective -0 (2.06s)
# MIP start from previous solve produced solution with objective -0 (2.06s)
# MIP start from previous solve produced solution with objective 0.947934 (2.06s)
# MIP start from previous solve produced solution with objective -0.947934 (2.06s)
# MIP start from previous solve produced solution with objective -0.00479635 (2.06s)
# MIP start from previous solve produced solution with objective 0.00479635 (2.06s)
# MIP start from previous solve produced solution with objective -0.00479635 (2.06s)
# MIP start from previous solve produced solution with objective 0.00479635 (2.06s)
# MIP start from previous solve produced solution with objective -0.00479635 (2.07s)
# MIP start from previous solve produced solution with objective 0.00479635 (2.07s)
# MIP start from previous solve produced solution with objective -0 (2.07s)
# MIP start from previous solve produced solution with objective -0 (2.07s)
# MIP start from previous solve produced solution with objective -0.00479635 (2.07s)
# MIP start from previous solve produced solution with objective 0.00479635 (2.07s)
# MIP start from previous solve produced solution with objective -0 (2.07s)
# MIP start from previous solve produced solution with objective -0 (2.07s)
# MIP start from previous solve produced solution with objective -0.00479635 (2.07s)
# MIP start from previous solve produced solution with objective 0.00479635 (2.08s)
# MIP start from previous solve produced solution with objective -0.221722 (2.08s)
# MIP start from previous solve produced solution with objective 0.221722 (2.08s)
# MIP start from previous solve produced solution with objective -0 (2.08s)
# MIP start from previous solve produced solution with objective -0 (2.08s)
# MIP start from previous solve produced solution with objective -0 (2.08s)
# MIP start from previous solve produced solution with objective -0 (2.08s)
# MIP start from previous solve produced solution with objective -0 (2.08s)
# MIP start from previous solve produced solution with objective -0 (2.09s)
# MIP start from previous solve produced solution with objective -0 (2.09s)
# MIP start from previous solve produced solution with objective -0 (2.09s)
# MIP start from previous solve produced solution with objective -0 (2.09s)
# MIP start from previous solve produced solution with objective -0 (2.09s)
# MIP start from previous solve produced solution with objective -0 (2.09s)
# MIP start from previous solve produced solution with objective -0 (2.10s)
# MIP start from previous solve produced solution with objective -0 (2.10s)
# MIP start from previous solve produced solution with objective -0 (2.10s)
# MIP start from previous solve produced solution with objective -0 (2.10s)
# MIP start from previous solve produced solution with objective -0 (2.10s)
# MIP start from previous solve produced solution with objective -0 (2.10s)
# MIP start from previous solve produced solution with objective -0 (2.11s)
# MIP start from previous solve produced solution with objective -0 (2.11s)
# MIP start from previous solve produced solution with objective -0 (2.11s)
# MIP start from previous solve produced solution with objective -0 (2.11s)
# MIP start from previous solve produced solution with objective -0 (2.11s)
# MIP start from previous solve produced solution with objective -0 (2.12s)
# MIP start from previous solve produced solution with objective -0 (2.12s)
# MIP start from previous solve produced solution with objective -0.241126 (2.12s)
# MIP start from previous solve produced solution with objective 0.241126 (2.12s)
# MIP start from previous solve produced solution with objective -0 (2.12s)
# MIP start from previous solve produced solution with objective -0 (2.12s)
# MIP start from previous solve produced solution with objective -0 (2.12s)
# MIP start from previous solve produced solution with objective -0 (2.13s)
# MIP start from previous solve produced solution with objective -0 (2.13s)
# MIP start from previous solve produced solution with objective -0 (2.13s)
# MIP start from previous solve produced solution with objective -0.947934 (2.13s)
# MIP start from previous solve produced solution with objective 0.947934 (2.13s)
# MIP start from previous solve produced solution with objective -0 (2.13s)
# MIP start from previous solve produced solution with objective -0 (2.13s)
# MIP start from previous solve produced solution with objective -0 (2.13s)
# MIP start from previous solve produced solution with objective -0 (2.13s)
# MIP start from previous solve produced solution with objective -0.591478 (2.14s)
# MIP start from previous solve produced solution with objective 0.591478 (2.14s)
# MIP start from previous solve produced solution with objective -0 (2.14s)
# MIP start from previous solve produced solution with objective -0 (2.14s)
# MIP start from previous solve produced solution with objective -0 (2.14s)
# MIP start from previous solve produced solution with objective -0 (2.14s)
# MIP start from previous solve produced solution with objective -0 (2.14s)
# MIP start from previous solve produced solution with objective -0 (2.14s)
# MIP start from previous solve produced solution with objective -8.76015 (2.14s)
# MIP start from previous solve produced solution with objective 8.76015 (2.14s)
# MIP start from previous solve produced solution with objective 11.6384 (2.14s)
# MIP start from previous solve produced solution with objective -11.6384 (2.14s)
# MIP start from previous solve produced solution with objective 0.57687 (2.15s)
# MIP start from previous solve produced solution with objective -0.57687 (2.15s)
# MIP start from previous solve produced solution with objective -0 (2.15s)
# MIP start from previous solve produced solution with objective -0 (2.15s)
# MIP start from previous solve produced solution with objective -0 (2.15s)
# MIP start from previous solve produced solution with objective -0 (2.15s)
# MIP start from previous solve produced solution with objective -0 (2.15s)
# MIP start from previous solve produced solution with objective -0 (2.16s)
# MIP start from previous solve produced solution with objective -0 (2.16s)
# MIP start from previous solve produced solution with objective -0 (2.16s)
# MIP start from previous solve produced solution with objective -0 (2.16s)
# MIP start from previous solve produced solution with objective -0 (2.16s)
# MIP start from previous solve produced solution with objective -0 (2.16s)
# MIP start from previous solve produced solution with objective -0 (2.16s)
# MIP start from previous solve produced solution with objective -0 (2.16s)
# MIP start from previous solve produced solution with objective -0 (2.16s)
# MIP start from previous solve produced solution with objective -0 (2.17s)
# MIP start from previous solve produced solution with objective -0 (2.17s)
# MIP start from previous solve produced solution with objective 11.6384 (2.17s)
# MIP start from previous solve produced solution with objective -11.6384 (2.17s)
# MIP start from previous solve produced solution with objective -0 (2.17s)
# MIP start from previous solve produced solution with objective -0 (2.17s)
# MIP start from previous solve produced solution with objective -0 (2.17s)
# MIP start from previous solve produced solution with objective -0 (2.17s)
# MIP start from previous solve produced solution with objective -0 (2.17s)
# MIP start from previous solve produced solution with objective -0 (2.17s)
# MIP start from previous solve produced solution with objective -0 (2.17s)
# MIP start from previous solve produced solution with objective -0 (2.18s)
# MIP start from previous solve produced solution with objective -0 (2.18s)
# MIP start from previous solve produced solution with objective -0 (2.18s)
# MIP start from previous solve produced solution with objective -0 (2.18s)
# MIP start from previous solve produced solution with objective -0 (2.18s)
# MIP start from previous solve produced solution with objective -0 (2.18s)
# MIP start from previous solve produced solution with objective -0 (2.18s)
# MIP start from previous solve produced solution with objective -0 (2.19s)
# MIP start from previous solve produced solution with objective -0 (2.19s)
# MIP start from previous solve produced solution with objective -0 (2.19s)
# MIP start from previous solve produced solution with objective -0 (2.19s)
# MIP start from previous solve produced solution with objective -0 (2.19s)
# MIP start from previous solve produced solution with objective -0 (2.19s)
# MIP start from previous solve produced solution with objective -0 (2.19s)
# MIP start from previous solve produced solution with objective -0 (2.19s)
# MIP start from previous solve produced solution with objective -0 (2.19s)
# MIP start from previous solve produced solution with objective -0 (2.20s)
# MIP start from previous solve produced solution with objective -0 (2.20s)
# MIP start from previous solve produced solution with objective -0 (2.20s)
# MIP start from previous solve produced solution with objective -0 (2.20s)
# MIP start from previous solve produced solution with objective -0 (2.20s)
# MIP start from previous solve produced solution with objective -0 (2.20s)
# MIP start from previous solve produced solution with objective -0 (2.20s)
# MIP start from previous solve produced solution with objective -0 (2.20s)
# MIP start from previous solve produced solution with objective -0 (2.21s)
# MIP start from previous solve produced solution with objective -1 (2.21s)
# MIP start from previous solve produced solution with objective 1 (2.21s)
# MIP start from previous solve produced solution with objective -0 (2.21s)
# MIP start from previous solve produced solution with objective -0 (2.21s)
# MIP start from previous solve produced solution with objective -0 (2.21s)
# MIP start from previous solve produced solution with objective -0 (2.21s)
# MIP start from previous solve produced solution with objective -0 (2.21s)
# MIP start from previous solve produced solution with objective -0 (2.21s)
# MIP start from previous solve produced solution with objective -0 (2.21s)
# MIP start from previous solve produced solution with objective -0 (2.21s)
# MIP start from previous solve produced solution with objective -0 (2.22s)
# MIP start from previous solve produced solution with objective -0 (2.22s)
# MIP start from previous solve produced solution with objective -0 (2.22s)
# MIP start from previous solve produced solution with objective -0 (2.22s)
# MIP start from previous solve produced solution with objective -0 (2.22s)
# MIP start from previous solve produced solution with objective -0 (2.22s)
# MIP start from previous solve produced solution with objective -0 (2.22s)
# MIP start from previous solve produced solution with objective -0 (2.22s)
# MIP start from previous solve produced solution with objective -0.144545 (2.22s)
# MIP start from previous solve produced solution with objective 0.144545 (2.22s)
# MIP start from previous solve produced solution with objective -8.28689 (2.22s)
# MIP start from previous solve produced solution with objective 8.28689 (2.23s)
# MIP start from previous solve produced solution with objective -0 (2.23s)
# MIP start from previous solve produced solution with objective -0 (2.23s)
# MIP start from previous solve produced solution with objective -121.555 (2.23s)
# MIP start from previous solve produced solution with objective 121.555 (2.23s)
# MIP start from previous solve produced solution with objective -0 (2.23s)
# MIP start from previous solve produced solution with objective -0 (2.23s)
# MIP start from previous solve produced solution with objective -0 (2.24s)
# MIP start from previous solve produced solution with objective -0 (2.24s)
# MIP start from previous solve produced solution with objective -0 (2.24s)
# MIP start from previous solve produced solution with objective -0 (2.24s)
# MIP start from previous solve produced solution with objective -0 (2.24s)
# MIP start from previous solve produced solution with objective -0 (2.24s)
# MIP start from previous solve produced solution with objective -0 (2.24s)
# MIP start from previous solve produced solution with objective -0 (2.24s)
# MIP start from previous solve produced solution with objective -0 (2.25s)
# MIP start from previous solve produced solution with objective -0 (2.25s)
# MIP start from previous solve produced solution with objective 5.63952 (2.25s)
# MIP start from previous solve produced solution with objective -5.63952 (2.25s)
# MIP start from previous solve produced solution with objective -0 (2.25s)
# MIP start from previous solve produced solution with objective -0 (2.25s)
# MIP start from previous solve produced solution with objective -0 (2.26s)
# MIP start from previous solve produced solution with objective -0 (2.26s)
# MIP start from previous solve produced solution with objective -0 (2.26s)
# MIP start from previous solve produced solution with objective -0 (2.26s)
# MIP start from previous solve produced solution with objective -0.00152611 (2.26s)
# MIP start from previous solve produced solution with objective 0.00152611 (2.26s)
# MIP start from previous solve produced solution with objective -0 (2.27s)
# MIP start from previous solve produced solution with objective -0 (2.27s)
# MIP start from previous solve produced solution with objective -0 (2.27s)
# MIP start from previous solve produced solution with objective -0 (2.27s)
# MIP start from previous solve produced solution with objective -0 (2.27s)
# MIP start from previous solve produced solution with objective -0 (2.27s)
# MIP start from previous solve produced solution with objective -0 (2.27s)
# MIP start from previous solve produced solution with objective -0 (2.27s)
# MIP start from previous solve produced solution with objective -0 (2.27s)
# MIP start from previous solve produced solution with objective -0 (2.27s)
# MIP start from previous solve produced solution with objective -0.5143 (2.27s)
# MIP start from previous solve produced solution with objective 0.5143 (2.28s)
# MIP start from previous solve produced solution with objective -0.576216 (2.28s)
# MIP start from previous solve produced solution with objective 0.576216 (2.28s)
# MIP start from previous solve produced solution with objective -0 (2.28s)
# MIP start from previous solve produced solution with objective -0 (2.28s)
# MIP start from previous solve produced solution with objective 59.6406 (2.28s)
# MIP start from previous solve produced solution with objective -59.6406 (2.28s)
# MIP start from previous solve produced solution with objective 0.0228917 (2.28s)
# MIP start from previous solve produced solution with objective -0.0228917 (2.28s)
# MIP start from previous solve produced solution with objective 47.5233 (2.28s)
# MIP start from previous solve produced solution with objective -47.5233 (2.28s)
# MIP start from previous solve produced solution with objective -0 (2.28s)
# MIP start from previous solve produced solution with objective -0 (2.29s)
# MIP start from previous solve produced solution with objective -0 (2.29s)
# MIP start from previous solve produced solution with objective -0 (2.29s)
# MIP start from previous solve produced solution with objective -0 (2.29s)
# MIP start from previous solve produced solution with objective -0 (2.29s)
# MIP start from previous solve produced solution with objective -0 (2.29s)
# MIP start from previous solve produced solution with objective -0 (2.29s)
# MIP start from previous solve produced solution with objective -0 (2.29s)
# MIP start from previous solve produced solution with objective -0 (2.29s)
# MIP start from previous solve produced solution with objective -0 (2.29s)
# MIP start from previous solve produced solution with objective -0 (2.29s)
# MIP start from previous solve produced solution with objective -0 (2.29s)
# MIP start from previous solve produced solution with objective -0 (2.30s)
# MIP start from previous solve produced solution with objective -0 (2.30s)
# MIP start from previous solve produced solution with objective -0 (2.30s)
# MIP start from previous solve produced solution with objective -0 (2.30s)
# MIP start from previous solve produced solution with objective -0 (2.30s)
# MIP start from previous solve produced solution with objective 14.7011 (2.30s)
# MIP start from previous solve produced solution with objective -14.7011 (2.30s)
# MIP start from previous solve produced solution with objective -0 (2.30s)
# MIP start from previous solve produced solution with objective -0 (2.30s)
# ...
# Scenario 2762 has been solved. 264/3190 scenarios left.
#  249382  7265   68.75849  108   11    0.00000  500.00000      -  14.7  486s
# Scenario 2763 has been solved. 263/3190 scenarios left.
# Scenario 2764 has been solved. 262/3190 scenarios left.
# Scenario 2765 has been solved. 261/3190 scenarios left.
# Scenario 2767 has been solved. 260/3190 scenarios left.
# Scenario 2768 has been solved. 259/3190 scenarios left.
# Scenario 2769 has been solved. 258/3190 scenarios left.
# Scenario 2770 has been solved. 257/3190 scenarios left.
# Scenario 2771 has been solved. 256/3190 scenarios left.
# Scenario 2772 has been solved. 255/3190 scenarios left.
# Scenario 2773 has been solved. 254/3190 scenarios left.
# Scenario 2774 has been solved. 253/3190 scenarios left.
# Scenario 2775 has been solved. 252/3190 scenarios left.
# Scenario 2776 has been solved. 251/3190 scenarios left.
# Scenario 2780 has been solved. 250/3190 scenarios left.
# Scenario 2782 has been solved. 249/3190 scenarios left.
# Scenario 2784 has been solved. 248/3190 scenarios left.
# Scenario 2786 has been solved. 247/3190 scenarios left.
# Scenario 2787 has been solved. 246/3190 scenarios left.
# Scenario 2788 has been solved. 245/3190 scenarios left.
# Scenario 2789 has been solved. 244/3190 scenarios left.
# Scenario 2790 has been solved. 243/3190 scenarios left.
# Scenario 2791 has been solved. 242/3190 scenarios left.
# Scenario 2792 has been solved. 241/3190 scenarios left.
# Scenario 2793 has been solved. 240/3190 scenarios left.
# Scenario 2794 has been solved. 239/3190 scenarios left.
# Scenario 2795 has been solved. 238/3190 scenarios left.
# Scenario 2796 has been solved. 237/3190 scenarios left.
# Scenario 2797 has been solved. 236/3190 scenarios left.
# Scenario 2798 has been solved. 235/3190 scenarios left.
# Scenario 2799 has been solved. 234/3190 scenarios left.
# Scenario 2800 has been solved. 233/3190 scenarios left.
#  255244 10251  500.00000   81   13    0.00000  500.00000      -  15.1  491s
# Scenario 2801 has been solved. 232/3190 scenarios left.
# Scenario 2802 has been solved. 231/3190 scenarios left.
# Scenario 2803 has been solved. 230/3190 scenarios left.
# Scenario 2804 has been solved. 229/3190 scenarios left.
# Scenario 2805 has been solved. 228/3190 scenarios left.
# Scenario 2807 has been solved. 227/3190 scenarios left.
# Scenario 2808 has been solved. 226/3190 scenarios left.
# Scenario 2809 has been solved. 225/3190 scenarios left.
# Scenario 2810 has been solved (gap 0.0001%). 224/3190 scenarios left.
# Scenario 2813 has been solved. 223/3190 scenarios left.
# Scenario 2814 has been solved. 222/3190 scenarios left.
# Scenario 2815 has been solved. 221/3190 scenarios left.
# Scenario 2816 has been solved. 220/3190 scenarios left.
# Scenario 2817 has been solved. 219/3190 scenarios left.
# Scenario 3186 has been solved (gap 0.0000%). 218/3190 scenarios left.
# Scenario 2818 has been solved. 217/3190 scenarios left.
# Scenario 2819 has been solved. 216/3190 scenarios left.
# Scenario 2820 has been solved. 215/3190 scenarios left.
# Scenario 2821 has been solved. 214/3190 scenarios left.
# Scenario 2822 has been solved. 213/3190 scenarios left.
# Scenario 2823 has been solved. 212/3190 scenarios left.
# Scenario 2824 has been solved. 211/3190 scenarios left.
# Scenario 2825 has been solved. 210/3190 scenarios left.
# Scenario 2826 has been solved. 209/3190 scenarios left.
# Scenario 2827 has been solved. 208/3190 scenarios left.
# Scenario 2828 has been solved. 207/3190 scenarios left.
# Scenario 2829 has been solved. 206/3190 scenarios left.
# Scenario 2830 has been solved. 205/3190 scenarios left.
# Scenario 2831 has been solved. 204/3190 scenarios left.
# Scenario 2832 has been solved. 203/3190 scenarios left.
# Scenario 2833 has been solved. 202/3190 scenarios left.
#  260247 12763  490.21314   78   18    0.00000  500.00000      -  15.4  495s
# Scenario 2834 has been solved. 201/3190 scenarios left.
# Scenario 2835 has been solved. 200/3190 scenarios left.
# Scenario 2836 has been solved. 199/3190 scenarios left.
# Scenario 2837 has been solved. 198/3190 scenarios left.
# Scenario 2838 has been solved. 197/3190 scenarios left.
# Scenario 2839 has been solved. 196/3190 scenarios left.
# Scenario 2840 has been solved. 195/3190 scenarios left.
# Scenario 2841 has been solved. 194/3190 scenarios left.
# Scenario 2842 has been solved. 193/3190 scenarios left.
# Scenario 2843 has been solved. 192/3190 scenarios left.
# Scenario 2844 has been solved. 191/3190 scenarios left.
# Scenario 2845 has been solved. 190/3190 scenarios left.
# Scenario 2846 has been solved. 189/3190 scenarios left.
# Scenario 2847 has been solved. 188/3190 scenarios left.
# Scenario 2848 has been solved. 187/3190 scenarios left.
# Scenario 2849 has been solved. 186/3190 scenarios left.
#  262857 14899  500.00000   76   12    0.00000  500.00000      -  15.6  501s
# Scenario 2850 has been solved. 185/3190 scenarios left.
# Scenario 2851 has been solved. 184/3190 scenarios left.
# Scenario 2852 has been solved. 183/3190 scenarios left.
# Scenario 2853 has been solved. 182/3190 scenarios left.
# Scenario 2854 has been solved. 181/3190 scenarios left.
# Scenario 2855 has been solved. 180/3190 scenarios left.
# Scenario 2856 has been solved. 179/3190 scenarios left.
# Scenario 2857 has been solved. 178/3190 scenarios left.
# Scenario 2858 has been solved. 177/3190 scenarios left.
# Scenario 2859 has been solved. 176/3190 scenarios left.
# Scenario 2860 has been solved. 175/3190 scenarios left.
# Scenario 2861 has been solved. 174/3190 scenarios left.
# Scenario 2862 has been solved. 173/3190 scenarios left.
# Scenario 2863 has been solved. 172/3190 scenarios left.
# Scenario 2864 has been solved. 171/3190 scenarios left.
# Scenario 2865 has been solved. 170/3190 scenarios left.
# Scenario 2866 has been solved. 169/3190 scenarios left.
# Scenario 2867 has been solved. 168/3190 scenarios left.
# Scenario 2868 has been solved. 167/3190 scenarios left.
# Scenario 2869 has been solved. 166/3190 scenarios left.
# Scenario 2870 has been solved. 165/3190 scenarios left.
# Scenario 2871 has been solved. 164/3190 scenarios left.
# Scenario 2872 has been solved. 163/3190 scenarios left.
# Scenario 2873 has been solved. 162/3190 scenarios left.
# Scenario 2874 has been solved. 161/3190 scenarios left.
# Scenario 2875 has been solved. 160/3190 scenarios left.
# Scenario 2876 has been solved. 159/3190 scenarios left.
# Scenario 2877 has been solved (gap 0.0003%). 158/3190 scenarios left.
# Scenario 2878 has been solved. 157/3190 scenarios left.
# Scenario 2879 has been solved. 156/3190 scenarios left.
# Scenario 2880 has been solved (gap 0.0000%). 155/3190 scenarios left.
# Scenario 2881 has been solved. 154/3190 scenarios left.
#  268926 16611 infeasible  114         0.00000  500.00000      -  16.2  505s
# Scenario 2882 has been solved. 153/3190 scenarios left.
# Scenario 2883 has been solved. 152/3190 scenarios left.
# Scenario 2884 has been solved. 151/3190 scenarios left.
# Scenario 2885 has been solved. 150/3190 scenarios left.
# Scenario 2886 has been solved. 149/3190 scenarios left.
# Scenario 2887 has been solved. 148/3190 scenarios left.
# Scenario 2888 has been solved. 147/3190 scenarios left.
# Scenario 2889 has been solved. 146/3190 scenarios left.
# Scenario 2890 has been solved. 145/3190 scenarios left.
# Scenario 2891 has been solved. 144/3190 scenarios left.
# Scenario 2892 has been solved. 143/3190 scenarios left.
# Scenario 2893 has been solved. 142/3190 scenarios left.
# Scenario 2894 has been solved. 141/3190 scenarios left.
# Scenario 2895 has been solved. 140/3190 scenarios left.
# Scenario 2896 has been solved. 139/3190 scenarios left.
# Scenario 2897 has been solved. 138/3190 scenarios left.
# Scenario 2898 has been solved. 137/3190 scenarios left.
# Scenario 2899 has been solved. 136/3190 scenarios left.
# Scenario 2900 has been solved. 135/3190 scenarios left.
# Scenario 2901 has been solved. 134/3190 scenarios left.
# Scenario 2902 has been solved. 133/3190 scenarios left.
# Scenario 2903 has been solved. 132/3190 scenarios left.
# Scenario 2905 has been solved. 131/3190 scenarios left.
# Scenario 2906 has been solved. 130/3190 scenarios left.
# Scenario 2907 has been solved. 129/3190 scenarios left.
# Scenario 2908 has been solved. 128/3190 scenarios left.
# Scenario 2909 has been solved. 127/3190 scenarios left.
# Scenario 2911 has been solved. 126/3190 scenarios left.
# Scenario 2912 has been solved. 125/3190 scenarios left.
# Scenario 2914 has been solved. 124/3190 scenarios left.
#  273212 17962 infeasible  104         0.00000  500.00000      -  16.6  511s
# Scenario 2916 has been solved. 123/3190 scenarios left.
# Scenario 2917 has been solved. 122/3190 scenarios left.
# Scenario 2918 has been solved. 121/3190 scenarios left.
# Scenario 2920 has been solved. 120/3190 scenarios left.
# Scenario 2921 has been solved. 119/3190 scenarios left.
# Scenario 2922 has been solved. 118/3190 scenarios left.
# Scenario 2923 has been solved. 117/3190 scenarios left.
# Scenario 2925 has been solved. 116/3190 scenarios left.
# Scenario 2927 has been solved. 115/3190 scenarios left.
# Scenario 2928 has been solved. 114/3190 scenarios left.
# Scenario 2929 has been solved. 113/3190 scenarios left.
# Scenario 2930 has been solved. 112/3190 scenarios left.
# Scenario 2931 has been solved. 111/3190 scenarios left.
# Scenario 2932 has been solved. 110/3190 scenarios left.
# Scenario 2933 has been solved. 109/3190 scenarios left.
# Scenario 2935 has been solved. 108/3190 scenarios left.
# Scenario 2937 has been solved. 107/3190 scenarios left.
# Scenario 2938 has been solved. 106/3190 scenarios left.
# Scenario 2939 has been solved. 105/3190 scenarios left.
# Scenario 2940 has been solved. 104/3190 scenarios left.
# Scenario 2941 has been solved. 103/3190 scenarios left.
# Scenario 2942 has been solved. 102/3190 scenarios left.
# Scenario 2943 has been solved. 101/3190 scenarios left.
# Scenario 2945 has been solved (gap 0.0014%). 100/3190 scenarios left.
# Scenario 2947 has been solved (gap 0.0002%). 99/3190 scenarios left.
# Scenario 2949 has been solved. 98/3190 scenarios left.
# Scenario 2950 has been solved. 97/3190 scenarios left.
# Scenario 2952 has been solved. 96/3190 scenarios left.
# Scenario 2953 has been solved. 95/3190 scenarios left.
# Scenario 2954 has been solved. 94/3190 scenarios left.
# Scenario 2955 has been solved. 93/3190 scenarios left.
#  276425 19926   13.17853   91   20    0.00000  500.00000      -  17.0  516s
# Scenario 2957 has been solved. 92/3190 scenarios left.
# Scenario 2959 has been solved. 91/3190 scenarios left.
# Scenario 2960 has been solved. 90/3190 scenarios left.
# Scenario 2961 has been solved. 89/3190 scenarios left.
# Scenario 2962 has been solved. 88/3190 scenarios left.
# Scenario 2964 has been solved. 87/3190 scenarios left.
# Scenario 2965 has been solved. 86/3190 scenarios left.
# Scenario 2966 has been solved. 85/3190 scenarios left.
# Scenario 2968 has been solved. 84/3190 scenarios left.
# Scenario 2970 has been solved. 83/3190 scenarios left.
# Scenario 2971 has been solved. 82/3190 scenarios left.
# Scenario 2973 has been solved (gap 0.0014%). 81/3190 scenarios left.
# Scenario 2975 has been solved. 80/3190 scenarios left.
# Scenario 2976 has been solved. 79/3190 scenarios left.
# Scenario 2977 has been solved. 78/3190 scenarios left.
# Scenario 2979 has been solved. 77/3190 scenarios left.
# Scenario 2981 has been solved. 76/3190 scenarios left.
# Scenario 2982 has been solved. 75/3190 scenarios left.
# Scenario 2985 has been solved. 74/3190 scenarios left.
# Scenario 2986 has been solved. 73/3190 scenarios left.
# Scenario 2992 has been solved. 72/3190 scenarios left.
# Scenario 2993 has been solved. 71/3190 scenarios left.
# Scenario 2996 has been solved. 70/3190 scenarios left.
# Scenario 2998 has been solved. 69/3190 scenarios left.
# Scenario 3003 has been solved (gap 0.0002%). 68/3190 scenarios left.
# Scenario 3005 has been solved. 67/3190 scenarios left.
# Scenario 3007 has been solved (gap 0.0014%). 66/3190 scenarios left.
#  280181 20820  346.80488   82   20    0.00000  500.00000      -  17.8  521s
# Scenario 3038 has been solved. 65/3190 scenarios left.
# Scenario 3039 has been solved. 64/3190 scenarios left.
# Scenario 3043 has been solved. 63/3190 scenarios left.
# Scenario 3047 has been solved. 62/3190 scenarios left.
# Scenario 3048 has been solved. 61/3190 scenarios left.
# Scenario 3050 has been solved. 60/3190 scenarios left.
# Scenario 3059 has been solved. 59/3190 scenarios left.
# Scenario 3061 has been solved. 58/3190 scenarios left.
# Scenario 3077 has been solved. 57/3190 scenarios left.
# Scenario 3092 has been solved. 56/3190 scenarios left.
# Scenario 3108 has been solved. 55/3190 scenarios left.
# Scenario 3109 has been solved. 54/3190 scenarios left.
# Scenario 3111 has been solved. 53/3190 scenarios left.
# Scenario 3113 has been solved. 52/3190 scenarios left.
# Scenario 3117 has been solved. 51/3190 scenarios left.
# Scenario 3118 has been solved. 50/3190 scenarios left.
#  281656 20887  279.83740   75   22    0.00000  500.00000      -  18.1  525s
# Scenario 3119 has been solved. 49/3190 scenarios left.
# Scenario 3121 has been solved. 48/3190 scenarios left.
# Scenario 3123 has been solved. 47/3190 scenarios left.
# Scenario 3127 has been solved. 46/3190 scenarios left.
# Scenario 3128 has been solved. 45/3190 scenarios left.
# Scenario 3129 has been solved. 44/3190 scenarios left.
# Scenario 3137 has been solved. 43/3190 scenarios left.
# Scenario 3138 has been solved. 42/3190 scenarios left.
# Scenario 3148 has been solved. 41/3190 scenarios left.
# Scenario 3168 has been solved. 40/3190 scenarios left.
# Scenario 3169 has been solved. 39/3190 scenarios left.
# Scenario 3170 has been solved. 38/3190 scenarios left.
# Scenario 3171 has been solved. 37/3190 scenarios left.
# Scenario 3172 has been solved. 36/3190 scenarios left.
# Scenario 3176 has been solved. 35/3190 scenarios left.
# Scenario 3177 has been solved. 34/3190 scenarios left.
# Scenario 3179 has been solved (gap 0.0014%). 33/3190 scenarios left.
# Scenario 3181 has been solved. 32/3190 scenarios left.
# Scenario 3182 has been solved (gap 0.0003%). 31/3190 scenarios left.
# Scenario 3183 has been solved. 30/3190 scenarios left.
# Scenario 3184 has been solved. 29/3190 scenarios left.
# Scenario 3185 has been solved. 28/3190 scenarios left.
# Scenario 3188 has been solved. 27/3190 scenarios left.
# Scenario 2216 has been solved. 26/3190 scenarios left.
# Scenario 2274 has been solved. 25/3190 scenarios left.
# Scenario 2305 has been solved. 24/3190 scenarios left.
# Scenario 2328 has been solved. 23/3190 scenarios left.
# Scenario 2348 has been solved. 22/3190 scenarios left.
# Scenario 2352 has been solved. 21/3190 scenarios left.
# Scenario 2354 has been solved. 20/3190 scenarios left.
# Scenario 2434 has been solved. 19/3190 scenarios left.
# Scenario 2456 has been solved. 18/3190 scenarios left.
# Scenario 2464 has been solved. 17/3190 scenarios left.
# Scenario 2487 has been solved. 16/3190 scenarios left.
# Scenario 2620 has been solved. 15/3190 scenarios left.
# Scenario 2624 has been solved. 14/3190 scenarios left.
# Scenario 2636 has been solved. 13/3190 scenarios left.
# Scenario 2704 has been solved. 12/3190 scenarios left.
# Scenario 2712 has been solved. 11/3190 scenarios left.
# Scenario 2766 has been solved. 10/3190 scenarios left.
# Scenario 2806 has been solved. 9/3190 scenarios left.
# Scenario 2811 has been solved. 8/3190 scenarios left.
# Scenario 2904 has been solved. 7/3190 scenarios left.
# Scenario 2910 has been solved. 6/3190 scenarios left.
# Scenario 2946 has been solved. 5/3190 scenarios left.
# Scenario 2956 has been solved. 4/3190 scenarios left.
# Scenario 2967 has been solved. 3/3190 scenarios left.
# Scenario 2987 has been solved. 2/3190 scenarios left.
# Scenario 2999 has been solved. 1/3190 scenarios left.
# Scenario 3032 has been solved. 0/3190 scenarios left.
#
# Cutting planes:
#   Learned: 28
#   Gomory: 2
#   Implied bound: 12
#   MIR: 6
#   Flow cover: 35
#   RLT: 6
#   Relax-and-lift: 2
#
# Explored 304679 nodes (5418123 simplex iterations) in 529.20 seconds (311.63 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 10: 500 500 500 ... 500
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.000000005058e+02, best bound 5.000000005058e+02, gap 0.0000%

# %%
TFVA_fluxes=thermo_flux.solver.gurobi.variability_results(tmodel)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 2
#       1 TFVA_fluxes=thermo_flux.solver.gurobi.variability_results(tmodel)
# ----> 2 TFVA_fluxes.to_csv('TFVA_fluxes.csv')
#
# AttributeError: 'tuple' object has no attribute 'to_csv'

# %%
df_TFVA_fluxes=pd.DataFrame(TFVA_fluxes[1]).T
df_TFVA_fluxes.index=[r.id for r in tmodel.reactions]
##replace inf in 0 by -500 and 500 in 1
df_TFVA_fluxes.loc[:,0]=df_TFVA_fluxes[0].replace(np.inf,-500)
df_TFVA_fluxes.loc[:,1]=df_TFVA_fluxes[1].replace(np.inf,500)
df_TFVA_fluxes['range']=df_TFVA_fluxes[1]-df_TFVA_fluxes[0]
# df_TFVA_fluxes.to_csv('TFVA_fluxes.csv')
# df_TFVA_fluxes['range'].plot(kind='hist')
range_TFVA=df_TFVA_fluxes['range']
nlargeTFVA=len(range_TFVA[range_TFVA>200])

# %%
## small barplot
# Out:
# 88.77742946708464

# %%
## how much reactions are fully reversible ? 
df_TFVA_fluxes[abs(df_TFVA_fluxes)<1e-5]=0
commonind_TFVA=df_TFVA_fluxes.loc[FVA_fluxes.index]
TFBArev_rxn=[]
for r in commonind_TFVA.index:
    if commonind_TFVA.loc[r,0]<0 and commonind_TFVA.loc[r,1]>0:
        TFBArev_rxn.append(r)
len(TFBArev_rxn)
# Out:
# 62

# %%
fig, ax = plt.subplots(figsize=(2.5,2.5))
scale_rcparams(fig)
sns.kdeplot(range_FVA, label='FVA',cumulative=True,ax=ax,linewidth=3)
sns.kdeplot(range_TFVA, label='TFVA', cumulative=True,ax=ax,linewidth=3)
sns.kdeplot(FVA_free_fluxes['range'],label='Reversible FVA',cumulative=True,ax=ax,linewidth=3,linestyle='--',color=sns.color_palette('viridis')[1])


ax.legend(frameon=False,bbox_to_anchor=(1.05, 0.8))
# ax.set_title("Value Distribution in DataFrame")
ax.set_ylim(0,1)
rescale_axlim(ax,how='y',nbins=3)
ax.set_xlabel('Flux range')
# ax.set_xscale('symlog',linthresh=1)

# plt.savefig(f'{OUTPUT_FOLDER}/R3_fluxranges_FVATFVA.png',dpi=300,bbox_inches='tight')
# plt.savefig(f'{OUTPUT_FOLDER}/R3_fluxranges_FVATFVA.svg',dpi=300,bbox_inches='tight')
# Out:
# Text(0.5, 0, 'Flux range')

# %%
fig,ax=plt.subplots(figsize=(0.5,0.75))
ax.bar([0,0.4],[nlargeFVA,nlargeTFVA],width=0.2)
ax.set_xlim(-0.2,0.6)
ax.set_xticks([])
# Out:
# []

# %% [markdown]
# ## FBA when fixing growth rate - as in gecko paper ?

# %%
##reset model with only one scenario
tmodel.m = None #reset the gurobi model object in case you're re-running this cell 
tmodel.add_TFBA_variables(gdiss_constraint = True, sigmac_limit = (3800/tmodel.T.m), error_type = 'covariance',qnorm=1,alpha=0.95)
thermo_flux.solver.gurobi.model_start(tmodel,'fixed_dir_firstTFBA.sol',ignore_vars=['all'],fix_vars=['qm'],fix='bound') #fix the drG error term to that from the initial TFBA to speed up optimisations

tmodel.m.update()
tmodel.m.params.timelimit=60*5
# Out:
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 10
# Set parameter TimeLimit to value 300

# %%
df_data2.iloc[:,:-1].columns
# Out:
# Index(['glc-D_EX', 'ac_EX', 'etoh_EX', 'glyc_EX', 'o2_EX', 'co2tot_EX',
#        'biomass_EX'],
#       dtype='object')

# %%
ex_data=['biomass_EX', 'EX_ac_e', 'EX_glyc_e', 'co2_EX', 'etoh_EX', 'o2_EX']
ex_flux_df=pd.DataFrame(index=ex_data)
j=0
glc_flux=[]
for i,row in df_data2.iterrows():
    try :
        bio=row['glc-D_EX']
        tmodel.mvars['v'][0][tmodel.reactions.index('EX_glc__D_e')].lb=-bio
        tmodel.mvars['v'][0][tmodel.reactions.index('EX_glc__D_e')].ub=-bio
        tmodel.m.optimize()
        ex_flux_df[j]=tmodel.solution().loc[ex_flux_df.index,'v']
        glc_flux.append(tmodel.solution().loc['EX_glc__D_e','v'])
    except Exception as e:
        print(e)
        pass
    j+=1
# Out:
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 24.04.3 LTS")
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-1260P, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 15734 rows, 13067 columns and 351222 nonzeros
# Model fingerprint: 0xe6211e07
# Model has 166 quadratic constraints
# Model has 1 general constraint
# Variable types: 11472 continuous, 1595 integer (1595 binary)
# Coefficient statistics:
#   Matrix range     [6e-06, 1e+06]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-06, 1e+06]
#   RHS range        [7e-15, 1e+06]
# Presolve removed 10926 rows and 8670 columns
# Presolve time: 0.11s
# Presolved: 5132 rows, 4397 columns, 15531 nonzeros
# Presolved model has 81 bilinear constraint(s)
#
# Solving non-convex MIQCP
#
# Variable types: 3434 continuous, 963 integer (963 binary)
#
# Root relaxation: objective 1.925179e+00, 3230 iterations, 0.05 seconds (0.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.92518    0   47          -    1.92518      -     -    0s
#      0     0    1.76959    0   61          -    1.76959      -     -    0s
#      0     0    1.16617    0   61          -    1.16617      -     -    0s
#      0     0    1.16617    0   58          -    1.16617      -     -    0s
#      0     0    1.16617    0   58          -    1.16617      -     -    0s
#      0     0    1.16617    0   28          -    1.16617      -     -    0s
#      0     0    1.16617    0   26          -    1.16617      -     -    0s
# H    0     0                      -0.0000000    1.16617      -     -    0s
#      0     0    1.16617    0   27   -0.00000    1.16617      -     -    0s
#      0     0    1.16617    0   27   -0.00000    1.16617      -     -    0s
#      0     0    1.15976    0   24   -0.00000    1.15976      -     -    0s
#      0     0    1.15976    0   17   -0.00000    1.15976      -     -    0s
#      0     0    1.15976    0   19   -0.00000    1.15976      -     -    0s
#      0     0    1.15976    0   18   -0.00000    1.15976      -     -    0s
#      0     0    1.15976    0   18   -0.00000    1.15976      -     -    0s
#      0     0    1.15976    0   20   -0.00000    1.15976      -     -    0s
#      0     0    1.15976    0   20   -0.00000    1.15976      -     -    0s
#      0     0    1.15976    0   19   -0.00000    1.15976      -     -    1s
#      0     0    1.15976    0   19   -0.00000    1.15976      -     -    1s
#      0     0    1.15976    0   19   -0.00000    1.15976      -     -    1s
#      0     0    1.15976    0   19   -0.00000    1.15976      -     -    1s
#      0     0    1.15974    0   19   -0.00000    1.15974      -     -    1s
#      0     0    1.15974    0   18   -0.00000    1.15974      -     -    1s
# H    0     0                       0.0000022    1.15974      -     -    1s
#      0     1    1.15974    0   19    0.00000    1.15974      -     -    1s
# H   32    20                       0.0000022    0.95780      -  44.4    1s
# H  191   156                       0.0000027    0.95755      -  26.6    1s
# *  991   784              54       0.2788699    0.95755   243%  17.9    2s
# *  992   784              54       0.2930172    0.95755   227%  17.9    2s
# H 1004   783                       0.2930173    0.95755   227%  17.8    2s
# H 1010   783                       0.2930173    0.95755   227%  17.8    2s
# H 1270   890                       0.3088523    0.95755   210%  17.4    2s
# * 1418   984              78       0.3091633    0.95755   210%  16.7    2s
# * 1419   984              78       0.3091635    0.95755   210%  16.7    2s
# * 1535  1038              79       0.3092692    0.95755   210%  16.3    2s
# * 1633  1115              80       0.3092744    0.95755   210%  16.4    2s
# * 1643   948              75       0.3808688    0.95755   151%  16.3    2s
# * 1747   913              76       0.3815786    0.95755   151%  16.3    2s
# * 1752   913              78       0.3815809    0.95755   151%  16.3    2s
# * 1873   978              81       0.3815810    0.95755   151%  16.2    2s
# * 2059  1005              67       0.3993251    0.95755   140%  15.7    2s
# * 2061  1005              68       0.4001329    0.95755   139%  15.7    2s
# * 2168   924              70       0.4001346    0.95755   139%  16.0    3s
# * 2290   973              73       0.4001347    0.95755   139%  16.0    3s
# * 2405   988              47       0.4004506    0.95755   139%  15.8    3s
# * 2589   906              59       0.4074315    0.95625   135%  15.7    3s
# * 2590   906              59       0.4074328    0.95625   135%  15.7    3s
# * 2732   872              62       0.4078037    0.95625   134%  15.6    3s
# * 2733   872              62       0.4078049    0.95625   134%  15.6    3s
# * 2894  1030              62       0.4078165    0.95625   134%  15.3    3s
# * 2895  1030              62       0.4078177    0.95625   134%  15.3    3s
# H 2998   887                       0.4094484    0.95625   134%  14.9    3s
#   3010   876    0.41055   36    4    0.40945    0.41055  0.27%  14.9    5s
#   3052   909    0.40972   17    7    0.40945    0.40972  0.07%  19.1   10s
# H 3064   872                       0.4094500    0.40971  0.06%  20.2   11s
# H 3064   828                       0.4094500    0.40971  0.06%  20.2   11s
# H 3067   788                       0.4097036    0.40971  0.00%  20.2   12s
#
# Cutting planes:
#   Learned: 9
#   Gomory: 7
#   Cover: 4
#   Implied bound: 5
#   Projected implied bound: 1
#   MIR: 8
#   Mixing: 1
#   Flow cover: 22
#   Network: 1
#   Relax-and-lift: 2
#
# Explored 3067 nodes (74126 simplex iterations) in 12.40 seconds (7.67 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 10: 0.409704 0.40945 0.409448 ... 0.407431
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.097035702788e-01, best bound 4.097111961438e-01, gap 0.0019%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 24.04.3 LTS")
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-1260P, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 15734 rows, 13067 columns and 351222 nonzeros
# Model fingerprint: 0xdd8a5a58
# Model has 166 quadratic constraints
# Model has 1 general constraint
# Variable types: 11472 continuous, 1595 integer (1595 binary)
# Coefficient statistics:
#   Matrix range     [6e-06, 1e+06]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-06, 1e+06]
#   RHS range        [7e-15, 1e+06]
#
# MIP start from previous solve did not produce a new incumbent solution
#
# Presolve removed 10926 rows and 8670 columns
# Presolve time: 0.12s
# Presolved: 5132 rows, 4397 columns, 15531 nonzeros
# Presolved model has 81 bilinear constraint(s)
#
# Solving non-convex MIQCP
#
# Variable types: 3434 continuous, 963 integer (963 binary)
#
# Root relaxation: objective 2.220483e+00, 3396 iterations, 0.07 seconds (0.07 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.22048    0   39          -    2.22048      -     -    0s
#      0     0    1.87225    0   59          -    1.87225      -     -    0s
#      0     0    1.22703    0   58          -    1.22703      -     -    0s
#      0     0    1.22703    0   50          -    1.22703      -     -    0s
#      0     0    1.22703    0   51          -    1.22703      -     -    0s
#      0     0    1.22703    0   51          -    1.22703      -     -    0s
#      0     0    1.20473    0   50          -    1.20473      -     -    0s
#      0     0    1.20473    0   24          -    1.20473      -     -    0s
#      0     0    1.20473    0   25          -    1.20473      -     -    0s
#      0     0    1.20473    0   24          -    1.20473      -     -    0s
#      0     0    1.20473    0   25          -    1.20473      -     -    0s
#      0     0    1.20473    0   23          -    1.20473      -     -    0s
#      0     0    1.20473    0   23          -    1.20473      -     -    0s
#      0     0    1.20473    0   26          -    1.20473      -     -    0s
#      0     0    1.20473    0   22          -    1.20473      -     -    0s
#      0     0    1.20473    0   24          -    1.20473      -     -    0s
#      0     0    1.20473    0   22          -    1.20473      -     -    0s
#      0     0    1.20473    0   26          -    1.20473      -     -    0s
# H    0     0                      -0.0000000    1.20473      -     -    1s
#      0     2    1.20473    0   26   -0.00000    1.20473      -     -    1s
# * 1245   973              90       0.0000000    1.02104      -  16.1    2s
# * 1330   977              89       0.0305166    1.02104  3246%  16.0    2s
# * 1420   973              89       0.0305166    1.02104  3246%  15.8    2s
# * 1700  1267             110       0.0305546    1.02104  3242%  15.1    2s
# * 1701  1261             110       0.0308588    1.02104  3209%  15.1    2s
# H 1779   968                       0.2693416    1.02104   279%  14.9    2s
# H 1800   910                       0.3512001    1.02104   191%  14.8    2s
#   2424  1208    0.42051   50    7    0.35120    0.42188  20.1%  14.1    5s
# H 2442  1160                       0.3553684    0.42188  18.7%  15.9    7s
# H 2442  1102                       0.3573969    0.42188  18.0%  15.9    7s
# H 2444  1047                       0.3579600    0.42188  17.9%  15.9    8s
# H 2492  1026                       0.3987530    0.41669  4.50%  19.4    9s
# H 2836  1110                       0.4022936    0.41660  3.56%  19.9    9s
# H 2837  1062                       0.4039879    0.41660  3.12%  19.9    9s
# * 2941  1056              58       0.4083645    0.41649  1.99%  20.3    9s
# * 2944  1012              60       0.4124362    0.41649  0.98%  20.3    9s
# * 3026   958              61       0.4126385    0.41649  0.93%  20.6    9s
# * 3031   917              64       0.4126436    0.41649  0.93%  20.5    9s
# * 3159   879              52       0.4142448    0.41649  0.54%  20.4    9s
# * 3162   843              54       0.4144289    0.41649  0.50%  20.3    9s
# * 3164   809              55       0.4144381    0.41649  0.49%  20.3    9s
# * 3165   778              55       0.4144383    0.41649  0.49%  20.3    9s
# * 3377   629              57       0.4144383    0.41649  0.49%  19.7    9s
#   3494   563 infeasible   35         0.41444    0.41648  0.49%  19.9   10s
#
# Cutting planes:
#   Learned: 46
#   Gomory: 5
#   Cover: 6
#   Implied bound: 19
#   MIR: 65
#   Mixing: 2
#   Flow cover: 140
#   RLT: 2
#   Relax-and-lift: 13
#   BQP: 1
#   PSD: 2
#
# Explored 4064 nodes (98225 simplex iterations) in 10.82 seconds (7.28 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 10: 0.414438 0.414438 0.414429 ... 0.402294
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.144382871054e-01, best bound 4.144407354545e-01, gap 0.0006%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 24.04.3 LTS")
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-1260P, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 15734 rows, 13067 columns and 351222 nonzeros
# Model fingerprint: 0x6f6775d1
# Model has 166 quadratic constraints
# Model has 1 general constraint
# Variable types: 11472 continuous, 1595 integer (1595 binary)
# Coefficient statistics:
#   Matrix range     [6e-06, 1e+06]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-06, 1e+06]
#   RHS range        [7e-15, 1e+06]
#
# MIP start from previous solve did not produce a new incumbent solution
#
# Presolve removed 10926 rows and 8670 columns
# Presolve time: 0.11s
# Presolved: 5132 rows, 4397 columns, 15531 nonzeros
# Presolved model has 81 bilinear constraint(s)
#
# Solving non-convex MIQCP
#
# Variable types: 3434 continuous, 963 integer (963 binary)
#
# Root relaxation: objective 4.079423e-02, 3483 iterations, 0.06 seconds (0.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.04079    0   49          -    0.04079      -     -    0s
#      0     0    0.04079    0   66          -    0.04079      -     -    0s
#      0     0    0.01805    0   68          -    0.01805      -     -    0s
#      0     0    0.01805    0   38          -    0.01805      -     -    0s
#      0     0    0.01805    0   39          -    0.01805      -     -    0s
# H    0     0                      -0.0000000    0.01805      -     -    0s
#      0     0    0.01805    0   24   -0.00000    0.01805      -     -    0s
#      0     0    0.01805    0   25   -0.00000    0.01805      -     -    0s
#      0     0    0.01805    0   32   -0.00000    0.01805      -     -    0s
#      0     0    0.01805    0   31   -0.00000    0.01805      -     -    0s
#      0     0    0.01805    0   21   -0.00000    0.01805      -     -    0s
#      0     0    0.01805    0   22   -0.00000    0.01805      -     -    0s
#      0     0    0.01805    0   22   -0.00000    0.01805      -     -    0s
#      0     0    0.01805    0   20   -0.00000    0.01805      -     -    0s
#      0     0    0.01805    0   11   -0.00000    0.01805      -     -    0s
#      0     0    0.01805    0   11   -0.00000    0.01805      -     -    0s
#      0     0    0.01805    0   10   -0.00000    0.01805      -     -    1s
# H    0     0                       0.0175095    0.01805  3.07%     -    1s
#      0     0    0.01805    0   29    0.01751    0.01805  3.07%     -    1s
#      0     0    0.01805    0   27    0.01751    0.01805  3.07%     -    1s
# H    0     0                       0.0177259    0.01805  1.81%     -    1s
# H    0     0                       0.0177733    0.01805  1.54%     -    1s
#      0     0    0.01805    0    5    0.01777    0.01805  1.53%     -    1s
#      0     0    0.01805    0    8    0.01777    0.01805  1.53%     -    1s
#      0     0    0.01802    0    8    0.01777    0.01802  1.41%     -    1s
#      0     0    0.01802    0    7    0.01777    0.01802  1.41%     -    1s
#      0     0    0.01802    0    7    0.01777    0.01802  1.41%     -    1s
#      0     0    0.01802    0    7    0.01777    0.01802  1.41%     -    1s
#      0     0    0.01802    0    6    0.01777    0.01802  1.41%     -    1s
#      0     0    0.01802    0    6    0.01777    0.01802  1.41%     -    1s
#      0     0    0.01802    0    6    0.01777    0.01802  1.41%     -    1s
#      0     0    0.01802    0    6    0.01777    0.01802  1.41%     -    1s
#      0     2    0.01802    0    6    0.01777    0.01802  1.41%     -    1s
# *  151   124              13       0.0179196    0.01802  0.59%  26.3    1s
# *  188   135              15       0.0179479    0.01802  0.43%  24.6    1s
# *  255   210              18       0.0180295    0.01803  0.00%  21.3    2s
#
# Cutting planes:
#   Learned: 65
#   Cover: 4
#   Implied bound: 25
#   MIR: 22
#   Flow cover: 37
#   RLT: 1
#   Relax-and-lift: 2
#
# Explored 336 nodes (15201 simplex iterations) in 2.03 seconds (1.45 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 7: 0.0180295 0.0179479 0.0179196 ... -0
# No other solutions better than 0.0180295
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.802947135769e-02, best bound 1.802947135769e-02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 24.04.3 LTS")
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-1260P, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 15734 rows, 13067 columns and 351222 nonzeros
# Model fingerprint: 0xdf697c03
# Model has 166 quadratic constraints
# Model has 1 general constraint
# Variable types: 11472 continuous, 1595 integer (1595 binary)
# Coefficient statistics:
#   Matrix range     [6e-06, 1e+06]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-06, 1e+06]
#   RHS range        [7e-15, 1e+06]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint integer_rev_AGTi_ by 0.000939516
#
# Presolve removed 10926 rows and 8670 columns
# Presolve time: 0.10s
# Presolved: 5132 rows, 4397 columns, 15531 nonzeros
# Presolved model has 81 bilinear constraint(s)
#
# Solving non-convex MIQCP
#
# Variable types: 3434 continuous, 963 integer (963 binary)
#
# Root relaxation: objective 9.301083e-02, 3511 iterations, 0.07 seconds (0.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.09301    0   42          -    0.09301      -     -    0s
#      0     0    0.09301    0   63          -    0.09301      -     -    0s
#      0     0    0.04846    0   63          -    0.04846      -     -    0s
#      0     0    0.04846    0   39          -    0.04846      -     -    0s
#      0     0    0.04846    0   39          -    0.04846      -     -    0s
# H    0     0                      -0.0000000    0.04846      -     -    0s
#      0     0    0.04846    0   23   -0.00000    0.04846      -     -    0s
#      0     0    0.04846    0   16   -0.00000    0.04846      -     -    0s
#      0     0    0.04846    0    9   -0.00000    0.04846      -     -    0s
#      0     0    0.04846    0    8   -0.00000    0.04846      -     -    0s
#      0     0    0.04846    0    9   -0.00000    0.04846      -     -    0s
# H    0     0                       0.0484589    0.04846  0.00%     -    0s
#      0     0    0.04846    0    9    0.04846    0.04846  0.00%     -    0s
#
# Cutting planes:
#   Learned: 40
#   Cover: 1
#   Implied bound: 2
#   MIR: 3
#   Flow cover: 7
#   RLT: 1
#   Relax-and-lift: 2
#
# Explored 1 nodes (7285 simplex iterations) in 0.86 seconds (0.65 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 0.0484589 -0
# No other solutions better than 0.0484589
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.845889984702e-02, best bound 4.845889984702e-02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 24.04.3 LTS")
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-1260P, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 15734 rows, 13067 columns and 351222 nonzeros
# Model fingerprint: 0xd705ad95
# Model has 166 quadratic constraints
# Model has 1 general constraint
# Variable types: 11472 continuous, 1595 integer (1595 binary)
# Coefficient statistics:
#   Matrix range     [6e-06, 1e+06]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-06, 1e+06]
#   RHS range        [7e-15, 1e+06]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint integer_rev_AGTi_ by 0.002525193
#
# Presolve removed 10926 rows and 8670 columns
# Presolve time: 0.11s
# Presolved: 5132 rows, 4397 columns, 15531 nonzeros
# Presolved model has 81 bilinear constraint(s)
#
# Solving non-convex MIQCP
#
# Variable types: 3434 continuous, 963 integer (963 binary)
#
# Root relaxation: objective 9.790614e-02, 3226 iterations, 0.06 seconds (0.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.09791    0   56          -    0.09791      -     -    0s
#      0     0    0.09791    0   60          -    0.09791      -     -    0s
#      0     0    0.09791    0   60          -    0.09791      -     -    0s
# H    0     0                      -0.0000000    0.09791      -     -    0s
#      0     0    0.09791    0   34   -0.00000    0.09791      -     -    0s
#      0     0    0.05131    0   23   -0.00000    0.05131      -     -    0s
#      0     0    0.05131    0   22   -0.00000    0.05131      -     -    0s
#      0     0    0.05131    0   18   -0.00000    0.05131      -     -    0s
#      0     0    0.05131    0   18   -0.00000    0.05131      -     -    0s
#      0     0    0.05131    0   16   -0.00000    0.05131      -     -    0s
#      0     0    0.05131    0   16   -0.00000    0.05131      -     -    0s
# H    0     0                       0.0000000    0.05131      -     -    0s
#      0     0    0.05131    0   19    0.00000    0.05131      -     -    0s
#      0     0    0.05131    0   12    0.00000    0.05131      -     -    0s
#      0     0    0.05131    0   12    0.00000    0.05131      -     -    0s
#      0     0    0.05131    0   12    0.00000    0.05131      -     -    0s
#      0     0    0.05131    0   12    0.00000    0.05131      -     -    0s
#      0     0    0.05131    0   12    0.00000    0.05131      -     -    0s
#      0     0    0.05131    0   12    0.00000    0.05131      -     -    1s
#      0     0    0.05131    0   12    0.00000    0.05131      -     -    1s
#      0     0    0.05131    0   11    0.00000    0.05131      -     -    1s
#      0     0    0.05131    0   11    0.00000    0.05131      -     -    1s
#      0     0    0.05131    0   11    0.00000    0.05131      -     -    1s
#      0     0    0.05131    0   13    0.00000    0.05131      -     -    1s
#      0     2    0.05131    0   13    0.00000    0.05131      -     -    1s
# H   48    52                       0.0000000    0.05131      -  33.4    1s
# *  456   412              18       0.0022671    0.05131  2163%  23.8    2s
# *  587   466              29       0.0143277    0.05131   258%  20.6    2s
# H  616   483                       0.0458826    0.05131  11.8%  20.2    2s
# *  797   623              50       0.0488957    0.05131  4.94%  18.1    2s
# *  931   733              52       0.0507801    0.05131  1.04%  17.0    2s
# * 1001   733              51       0.0508563    0.05131  0.89%  16.2    2s
# * 1111   782              35       0.0512841    0.05131  0.05%  15.2    2s
# * 1306   705              38       0.0513089    0.05131  0.00%  13.9    2s
# * 1309   705              40       0.0513100    0.05131  0.00%  13.9    2s
#
# Cutting planes:
#   Learned: 74
#   Gomory: 1
#   Cover: 1
#   Implied bound: 40
#   MIR: 4
#   Flow cover: 13
#   Inf proof: 1
#   RLT: 2
#   Relax-and-lift: 1
#
# Explored 1405 nodes (26685 simplex iterations) in 2.44 seconds (1.68 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 10: 0.05131 0.0513089 0.0512841 ... 3.59598e-08
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.131002334600e-02, best bound 5.131007899187e-02, gap 0.0001%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 24.04.3 LTS")
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-1260P, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 15734 rows, 13067 columns and 351222 nonzeros
# Model fingerprint: 0x6cbefb70
# Model has 166 quadratic constraints
# Model has 1 general constraint
# Variable types: 11472 continuous, 1595 integer (1595 binary)
# Coefficient statistics:
#   Matrix range     [6e-06, 1e+06]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-06, 1e+06]
#   RHS range        [7e-15, 1e+06]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint integer_rev_CTPS1_ by 0.002293558
#
# Presolve removed 10926 rows and 8670 columns
# Presolve time: 0.11s
# Presolved: 5132 rows, 4397 columns, 15531 nonzeros
# Presolved model has 81 bilinear constraint(s)
#
# Solving non-convex MIQCP
#
# Variable types: 3434 continuous, 963 integer (963 binary)
#
# Root relaxation: objective 1.794946e-01, 3504 iterations, 0.07 seconds (0.07 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.17949    0   61          -    0.17949      -     -    0s
#      0     0    0.17949    0   82          -    0.17949      -     -    0s
#      0     0    0.17949    0   82          -    0.17949      -     -    0s
#      0     0    0.17949    0   41          -    0.17949      -     -    0s
#      0     0    0.11348    0   40          -    0.11348      -     -    0s
# H    0     0                      -0.0000000    0.11348      -     -    0s
#      0     0    0.09883    0   25   -0.00000    0.09883      -     -    0s
#      0     0    0.09883    0   20   -0.00000    0.09883      -     -    0s
#      0     0    0.09883    0   23   -0.00000    0.09883      -     -    0s
#      0     0    0.09883    0   19   -0.00000    0.09883      -     -    0s
#      0     0    0.09883    0   14   -0.00000    0.09883      -     -    0s
#      0     0    0.09883    0   17   -0.00000    0.09883      -     -    0s
#      0     0    0.09883    0   14   -0.00000    0.09883      -     -    0s
#      0     0    0.09883    0   12   -0.00000    0.09883      -     -    1s
#      0     0    0.09883    0   13   -0.00000    0.09883      -     -    1s
#      0     0    0.09883    0   13   -0.00000    0.09883      -     -    1s
# H    0     0                       0.0941420    0.09883  4.98%     -    1s
# H    0     0                       0.0988297    0.09883  0.00%     -    1s
#      0     0    0.09883    0   10    0.09883    0.09883  0.00%     -    1s
#
# Cutting planes:
#   Learned: 37
#   Gomory: 1
#   Cover: 2
#   Implied bound: 5
#   MIR: 2
#   StrongCG: 1
#   Flow cover: 10
#   RLT: 1
#   Relax-and-lift: 4
#
# Explored 1 nodes (7847 simplex iterations) in 1.09 seconds (0.84 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 0.0988297 0.094142 -0
# No other solutions better than 0.0988297
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.882973140605e-02, best bound 9.882973140605e-02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 24.04.3 LTS")
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-1260P, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 15734 rows, 13067 columns and 351222 nonzeros
# Model fingerprint: 0x208d01eb
# Model has 166 quadratic constraints
# Model has 1 general constraint
# Variable types: 11472 continuous, 1595 integer (1595 binary)
# Coefficient statistics:
#   Matrix range     [6e-06, 1e+06]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-06, 1e+06]
#   RHS range        [7e-15, 1e+06]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint integer_fwd_DCMPDA_ by 0.000237191
#
# Presolve removed 10926 rows and 8670 columns
# Presolve time: 0.10s
# Presolved: 5132 rows, 4397 columns, 15531 nonzeros
# Presolved model has 81 bilinear constraint(s)
#
# Solving non-convex MIQCP
#
# Variable types: 3434 continuous, 963 integer (963 binary)
#
# Root relaxation: objective 2.725054e-01, 3427 iterations, 0.07 seconds (0.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.27251    0   41          -    0.27251      -     -    0s
#      0     0    0.27251    0   49          -    0.27251      -     -    0s
#      0     0    0.20838    0   50          -    0.20838      -     -    0s
#      0     0    0.20838    0   30          -    0.20838      -     -    0s
#      0     0    0.20838    0   32          -    0.20838      -     -    0s
# H    0     0                      -0.0000000    0.20838      -     -    0s
#      0     0    0.20838    0   24   -0.00000    0.20838      -     -    0s
#      0     0    0.20838    0   24   -0.00000    0.20838      -     -    0s
#      0     0    0.15300    0   21   -0.00000    0.15300      -     -    0s
#      0     0    0.15300    0   19   -0.00000    0.15300      -     -    0s
#      0     0    0.15300    0   18   -0.00000    0.15300      -     -    0s
#      0     0    0.15300    0   18   -0.00000    0.15300      -     -    0s
#      0     0    0.15300    0   12   -0.00000    0.15300      -     -    0s
#      0     0    0.15300    0    8   -0.00000    0.15300      -     -    0s
#      0     0    0.15300    0    8   -0.00000    0.15300      -     -    0s
#      0     0    0.15300    0    8   -0.00000    0.15300      -     -    0s
#      0     0    0.15300    0    9   -0.00000    0.15300      -     -    0s
#      0     2    0.15300    0    9   -0.00000    0.15300      -     -    1s
# *  353   268              22       0.1025368    0.15300  49.2%  20.9    1s
# *  376   268              21       0.1203747    0.15300  27.1%  19.9    1s
# *  455   321              26       0.1207862    0.15300  26.7%  18.9    1s
# *  456   321              26       0.1207894    0.15300  26.7%  18.9    1s
# *  504   321              27       0.1354491    0.15300  13.0%  18.5    1s
# *  590   371              28       0.1361862    0.15300  12.3%  18.2    1s
# *  594   371              30       0.1361901    0.15300  12.3%  18.1    1s
# *  596   371              31       0.1361912    0.15300  12.3%  18.0    1s
# *  687   446              32       0.1361914    0.15300  12.3%  17.5    1s
# *  802   520              42       0.1361914    0.15300  12.3%  19.5    1s
# *  837   549              46       0.1500832    0.15300  1.94%  19.2    1s
# *  871   595              39       0.1504550    0.15300  1.69%  19.2    2s
# *  917   595              47       0.1516711    0.15300  0.88%  19.4    2s
# *  919   595              48       0.1517503    0.15300  0.82%  19.3    2s
# *  989   611              28       0.1529626    0.15300  0.03%  18.5    2s
# * 1130   598              30       0.1530012    0.15300  0.00%  17.8    2s
# * 1134   598              33       0.1530021    0.15300  0.00%  17.7    2s
#
# Cutting planes:
#   Learned: 95
#   Gomory: 1
#   Cover: 5
#   Implied bound: 54
#   MIR: 7
#   StrongCG: 1
#   Flow cover: 15
#   Inf proof: 1
#   RLT: 2
#   Relax-and-lift: 1
#
# Explored 1265 nodes (30623 simplex iterations) in 2.22 seconds (1.43 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 10: 0.153002 0.153001 0.152963 ... 0.136191
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max constraint violation (1.8812e-06) exceeds tolerance
# Best objective 1.530020892827e-01, best bound 1.530021351582e-01, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 24.04.3 LTS")
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-1260P, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 15734 rows, 13067 columns and 351222 nonzeros
# Model fingerprint: 0xa1ea2786
# Model has 166 quadratic constraints
# Model has 1 general constraint
# Variable types: 11472 continuous, 1595 integer (1595 binary)
# Coefficient statistics:
#   Matrix range     [6e-06, 1e+06]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-06, 1e+06]
#   RHS range        [7e-15, 1e+06]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint integer_fwd_DCMPDA_ by 0.000367205
#
# Presolve removed 10926 rows and 8670 columns
# Presolve time: 0.11s
# Presolved: 5132 rows, 4397 columns, 15531 nonzeros
# Presolved model has 81 bilinear constraint(s)
#
# Solving non-convex MIQCP
#
# Variable types: 3434 continuous, 963 integer (963 binary)
#
# Root relaxation: objective 3.491986e-01, 3781 iterations, 0.09 seconds (0.08 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.34920    0   63          -    0.34920      -     -    0s
#      0     0    0.34920    0   70          -    0.34920      -     -    0s
#      0     0    0.20952    0   68          -    0.20952      -     -    0s
# H    0     0                      -0.0000000    0.20952      -     -    0s
#      0     0    0.19767    0   35   -0.00000    0.19767      -     -    0s
#      0     0    0.19767    0   32   -0.00000    0.19767      -     -    0s
#      0     0    0.19767    0   31   -0.00000    0.19767      -     -    0s
#      0     0    0.19767    0   31   -0.00000    0.19767      -     -    0s
#      0     0    0.19767    0   31   -0.00000    0.19767      -     -    0s
#      0     0    0.19767    0   18   -0.00000    0.19767      -     -    0s
#      0     0    0.19767    0   16   -0.00000    0.19767      -     -    0s
#      0     0    0.19767    0   24   -0.00000    0.19767      -     -    0s
#      0     0    0.19767    0   20   -0.00000    0.19767      -     -    0s
#      0     0    0.19767    0   15   -0.00000    0.19767      -     -    0s
#      0     0    0.19767    0   16   -0.00000    0.19767      -     -    0s
#      0     0    0.19767    0   13   -0.00000    0.19767      -     -    1s
#      0     0    0.19767    0   11   -0.00000    0.19767      -     -    1s
#      0     0    0.19767    0   15   -0.00000    0.19767      -     -    1s
#      0     0    0.19767    0   10   -0.00000    0.19767      -     -    1s
#      0     0    0.19767    0   10   -0.00000    0.19767      -     -    1s
#      0     0    0.19767    0    9   -0.00000    0.19767      -     -    1s
#      0     0    0.19767    0    9   -0.00000    0.19767      -     -    1s
#      0     0    0.19767    0   15   -0.00000    0.19767      -     -    1s
#      0     2    0.19767    0   15   -0.00000    0.19767      -     -    1s
# *  527   500              30       0.1624224    0.19767  21.7%  28.0    2s
# *  617   521              31       0.1704398    0.19767  16.0%  30.0    2s
# *  623   521              34       0.1704498    0.19767  16.0%  29.7    2s
# *  776   654              38       0.1704503    0.19767  16.0%  28.0    2s
# *  782   654              41       0.1704503    0.19767  16.0%  27.8    2s
# *  803   654              43       0.1781110    0.19767  11.0%  27.3    2s
# *  805   654              44       0.1869310    0.19767  5.75%  27.2    2s
# *  895   721              48       0.1928869    0.19767  2.48%  25.5    2s
# *  928   721              55       0.1933588    0.19767  2.23%  25.2    2s
# * 1034   779              49       0.1942079    0.19767  1.78%  23.9    2s
# * 1037   779              51       0.1942647    0.19767  1.75%  23.8    2s
# * 1040   779              53       0.1942672    0.19767  1.75%  23.7    2s
# * 1069   779              56       0.1944788    0.19767  1.64%  23.5    2s
# * 1070   779              57       0.1944988    0.19767  1.63%  23.5    2s
# * 1072   779              58       0.1945369    0.19767  1.61%  23.4    2s
# * 1075   779              59       0.1945383    0.19767  1.61%  23.4    2s
# * 1127   779              48       0.1948075    0.19767  1.47%  23.0    2s
# * 1129   779              47       0.1948215    0.19767  1.46%  23.0    2s
# * 1185   815              46       0.1958459    0.19767  0.93%  22.8    2s
# * 1227   815              48       0.1961520    0.19767  0.77%  22.3    2s
# * 1358   828              57       0.1964841    0.19767  0.60%  21.8    2s
# * 1361   828              59       0.1965396    0.19767  0.58%  21.7    2s
# * 1364   828              61       0.1965420    0.19767  0.57%  21.7    2s
# * 1660   898              43       0.1976206    0.19767  0.03%  20.7    2s
# * 1808   815              45       0.1976689    0.19767  0.00%  20.3    2s
# * 1811   815              47       0.1976706    0.19767  0.00%  20.3    2s
# * 1814   815              49       0.1976706    0.19767  0.00%  20.3    2s
#
# Cutting planes:
#   Learned: 107
#   Gomory: 1
#   Cover: 4
#   Implied bound: 72
#   MIR: 17
#   Flow cover: 41
#   Inf proof: 4
#   RLT: 2
#
# Explored 1829 nodes (44942 simplex iterations) in 2.84 seconds (1.94 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 10: 0.197671 0.197669 0.197621 ... 0.194808
# No other solutions better than 0.197671
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.976706084275e-01, best bound 1.976706084275e-01, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 24.04.3 LTS")
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-1260P, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 15734 rows, 13067 columns and 351222 nonzeros
# Model fingerprint: 0x6ae18930
# Model has 166 quadratic constraints
# Model has 1 general constraint
# Variable types: 11472 continuous, 1595 integer (1595 binary)
# Coefficient statistics:
#   Matrix range     [6e-06, 1e+06]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-06, 1e+06]
#   RHS range        [7e-15, 1e+06]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint integer_fwd_DCMPDA_ by 0.000474409
#
# Presolve removed 10926 rows and 8670 columns
# Presolve time: 0.10s
# Presolved: 5132 rows, 4397 columns, 15531 nonzeros
# Presolved model has 81 bilinear constraint(s)
#
# Solving non-convex MIQCP
#
# Variable types: 3434 continuous, 963 integer (963 binary)
#
# Root relaxation: objective 3.622527e-01, 3914 iterations, 0.09 seconds (0.09 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.36225    0   32          -    0.36225      -     -    0s
#      0     0    0.36225    0   43          -    0.36225      -     -    0s
#      0     0    0.36225    0   44          -    0.36225      -     -    0s
#      0     0    0.36225    0   30          -    0.36225      -     -    0s
#      0     0    0.24583    0   34          -    0.24583      -     -    0s
# H    0     0                      -0.0000000    0.24583      -     -    0s
#      0     0    0.24583    0   21   -0.00000    0.24583      -     -    0s
#      0     0    0.20527    0   16   -0.00000    0.20527      -     -    0s
#      0     0    0.20527    0   19   -0.00000    0.20527      -     -    0s
#      0     0    0.20527    0   16   -0.00000    0.20527      -     -    0s
#      0     0    0.20527    0   13   -0.00000    0.20527      -     -    0s
#      0     0    0.20527    0   13   -0.00000    0.20527      -     -    0s
#      0     0    0.20527    0   10   -0.00000    0.20527      -     -    0s
#      0     0    0.20527    0    9   -0.00000    0.20527      -     -    0s
#      0     0    0.20527    0    9   -0.00000    0.20527      -     -    0s
#      0     0    0.20527    0   10   -0.00000    0.20527      -     -    0s
#      0     0    0.20527    0   10   -0.00000    0.20527      -     -    0s
#      0     0    0.20527    0   10   -0.00000    0.20527      -     -    0s
#      0     0    0.20527    0   10   -0.00000    0.20527      -     -    0s
#      0     0    0.20527    0   10   -0.00000    0.20527      -     -    1s
#      0     0    0.20527    0   10   -0.00000    0.20527      -     -    1s
#      0     0    0.20527    0   10   -0.00000    0.20527      -     -    1s
#      0     0    0.20527    0   16   -0.00000    0.20527      -     -    1s
#      0     2    0.20527    0   16   -0.00000    0.20527      -     -    1s
# H  444   399                       0.1661166    0.20527  23.6%  25.8    1s
# H 1078   811                       0.1685104    0.20527  21.8%  19.4    2s
# H 1116   811                       0.1685677    0.20527  21.8%  19.0    2s
# H 1126   811                       0.1943178    0.20527  5.64%  19.0    2s
# * 1375   962              57       0.2031179    0.20527  1.06%  17.5    2s
# * 1603   936              47       0.2032441    0.20527  1.00%  16.5    2s
# * 1607   936              46       0.2032476    0.20527  1.00%  16.5    2s
# * 1610   936              48       0.2032595    0.20527  0.99%  16.4    2s
# * 1613   936              50       0.2032600    0.20527  0.99%  16.4    2s
# * 1716   938              50       0.2032851    0.20527  0.98%  16.5    2s
# * 1719   938              52       0.2032855    0.20527  0.98%  16.5    2s
# * 1857   931              55       0.2032855    0.20527  0.98%  15.9    2s
# * 1947   931              49       0.2034523    0.20527  0.90%  15.6    2s
# * 1950   931              51       0.2034677    0.20527  0.89%  15.6    2s
# * 1952   931              52       0.2034685    0.20527  0.89%  15.6    2s
# * 2165   974              55       0.2034961    0.20527  0.87%  15.1    2s
# * 2167   974              56       0.2035793    0.20527  0.83%  15.0    2s
# * 2171   974              59       0.2035795    0.20527  0.83%  15.0    2s
# * 2173   974              60       0.2035795    0.20527  0.83%  15.0    2s
# * 2408   929              47       0.2035852    0.20527  0.83%  14.4    2s
# * 2411   929              49       0.2035963    0.20527  0.82%  14.4    2s
# * 2421   929              47       0.2036816    0.20527  0.78%  14.4    2s
# * 2424   929              49       0.2036898    0.20527  0.78%  14.4    2s
# * 2427   929              51       0.2036898    0.20527  0.78%  14.3    2s
# * 2684   960              65       0.2036898    0.20527  0.78%  13.9    2s
# * 2744   960              48       0.2040658    0.20527  0.59%  13.9    2s
# * 2780   960              51       0.2044206    0.20527  0.42%  13.8    2s
# * 2940   843              53       0.2044531    0.20527  0.40%  13.6    3s
# * 2944   843              54       0.2044549    0.20527  0.40%  13.6    3s
# * 3080   877              55       0.2044624    0.20527  0.40%  13.3    3s
# * 3081   877              55       0.2044624    0.20527  0.40%  13.3    3s
# * 3091   936              53       0.2044640    0.20527  0.40%  13.3    3s
# * 3236   936              48       0.2044641    0.20527  0.40%  13.4    3s
# * 3247   948              58       0.2044645    0.20527  0.40%  13.4    3s
# * 3361   948              46       0.2044645    0.20527  0.40%  13.3    3s
# * 3440   950              45       0.2051891    0.20527  0.04%  13.1    3s
# * 3442   950              46       0.2052397    0.20527  0.02%  13.1    3s
# * 3622   856              48       0.2052419    0.20527  0.02%  12.8    3s
# * 3637   856              43       0.2052703    0.20527  0.00%  12.8    3s
# * 3639   856              44       0.2052737    0.20527  0.00%  12.8    3s
# * 3643   856              47       0.2052738    0.20527  0.00%  12.8    3s
#
# Cutting planes:
#   Learned: 116
#   Gomory: 1
#   Cover: 9
#   Implied bound: 81
#   MIR: 18
#   Flow cover: 22
#   Inf proof: 5
#   RLT: 2
#   Relax-and-lift: 1
#
# Explored 3844 nodes (54579 simplex iterations) in 3.64 seconds (2.02 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 10: 0.205274 0.205274 0.20527 ... 0.204464
# No other solutions better than 0.205274
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.052737528138e-01, best bound 2.052737528138e-01, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 24.04.3 LTS")
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-1260P, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 15734 rows, 13067 columns and 351222 nonzeros
# Model fingerprint: 0xe07d321c
# Model has 166 quadratic constraints
# Model has 1 general constraint
# Variable types: 11472 continuous, 1595 integer (1595 binary)
# Coefficient statistics:
#   Matrix range     [6e-06, 1e+06]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-06, 1e+06]
#   RHS range        [7e-15, 1e+06]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint integer_fwd_DCMPDA_ by 0.000492657
#
# Presolve removed 10926 rows and 8670 columns
# Presolve time: 0.12s
# Presolved: 5132 rows, 4397 columns, 15531 nonzeros
# Presolved model has 81 bilinear constraint(s)
#
# Solving non-convex MIQCP
#
# Variable types: 3434 continuous, 963 integer (963 binary)
#
# Root relaxation: objective 4.617906e-01, 3754 iterations, 0.09 seconds (0.09 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.46179    0   30          -    0.46179      -     -    0s
#      0     0    0.46179    0   40          -    0.46179      -     -    0s
#      0     0    0.28464    0   40          -    0.28464      -     -    0s
# H    0     0                      -0.0000000    0.28464      -     -    0s
#      0     0    0.28464    0   25   -0.00000    0.28464      -     -    0s
#      0     0    0.28464    0   15   -0.00000    0.28464      -     -    0s
#      0     0    0.28464    0   15   -0.00000    0.28464      -     -    0s
# H    0     0                       0.0497827    0.28464   472%     -    0s
#      0     0    0.28464    0   12    0.04978    0.28464   472%     -    0s
#      0     0    0.26325    0   10    0.04978    0.26325   429%     -    0s
#      0     0    0.26325    0   10    0.04978    0.26325   429%     -    0s
#      0     0    0.26325    0   10    0.04978    0.26325   429%     -    0s
#      0     0    0.26325    0    9    0.04978    0.26325   429%     -    0s
#      0     0    0.26325    0   10    0.04978    0.26325   429%     -    0s
#      0     0    0.26325    0    7    0.04978    0.26325   429%     -    0s
#      0     0    0.26325    0    6    0.04978    0.26325   429%     -    0s
#      0     0    0.26325    0    6    0.04978    0.26325   429%     -    0s
#      0     0    0.26325    0    6    0.04978    0.26325   429%     -    0s
#      0     0    0.26325    0   19    0.04978    0.26325   429%     -    1s
#      0     2    0.26325    0   19    0.04978    0.26325   429%     -    1s
# H  495   479                       0.0803723    0.26325   228%  21.9    1s
# H  496   479                       0.2219967    0.26325  18.6%  22.0    1s
# H  497   479                       0.2378031    0.26325  10.7%  22.1    1s
# H  513   479                       0.2449922    0.26325  7.45%  21.8    1s
# *  749   667              34       0.2490682    0.26325  5.69%  21.1    2s
# *  796   667              41       0.2615897    0.26325  0.63%  20.4    2s
# *  930   636              44       0.2616604    0.26325  0.61%  21.6    2s
# *  934   636              46       0.2616621    0.26325  0.61%  21.5    2s
# * 1188   651              52       0.2616622    0.26325  0.61%  20.5    2s
# * 1262   659              25       0.2628873    0.26325  0.14%  20.0    2s
# * 1305   659              26       0.2630266    0.26325  0.08%  20.1    2s
# * 1333   659              28       0.2632138    0.26325  0.01%  19.9    2s
# * 1392   448              24       0.2632477    0.26325  0.00%  19.7    2s
#
# Cutting planes:
#   Learned: 80
#   Gomory: 1
#   Cover: 2
#   Implied bound: 55
#   MIR: 7
#   Flow cover: 13
#   Relax-and-lift: 2
#
# Explored 1636 nodes (35784 simplex iterations) in 2.49 seconds (1.66 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 10: 0.263248 0.263214 0.263027 ... 0.244992
# No other solutions better than 0.263248
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.632477287591e-01, best bound 2.632477287591e-01, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 24.04.3 LTS")
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-1260P, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 15734 rows, 13067 columns and 351222 nonzeros
# Model fingerprint: 0x80997086
# Model has 166 quadratic constraints
# Model has 1 general constraint
# Variable types: 11472 continuous, 1595 integer (1595 binary)
# Coefficient statistics:
#   Matrix range     [6e-06, 1e+06]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-06, 1e+06]
#   RHS range        [7e-15, 1e+06]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint integer_fwd_DCMPDA_ by 0.000631795
#
# Presolve removed 10926 rows and 8670 columns
# Presolve time: 0.11s
# Presolved: 5132 rows, 4397 columns, 15531 nonzeros
# ...
#
# Solving non-convex MIQCP
#
# Variable types: 3434 continuous, 963 integer (963 binary)
#
# Root relaxation: objective 1.228885e+00, 3288 iterations, 0.06 seconds (0.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.22889    0   47          -    1.22889      -     -    0s
#      0     0    0.88454    0   59          -    0.88454      -     -    0s
#      0     0    0.78596    0   58          -    0.78596      -     -    0s
#      0     0    0.78596    0   64          -    0.78596      -     -    0s
#      0     0    0.78596    0   67          -    0.78596      -     -    0s
# H    0     0                      -0.0000000    0.78596      -     -    0s
#      0     0    0.78596    0   23   -0.00000    0.78596      -     -    0s
#      0     0    0.78596    0   15   -0.00000    0.78596      -     -    0s
#      0     0    0.78596    0   14   -0.00000    0.78596      -     -    0s
#      0     0    0.78596    0    9   -0.00000    0.78596      -     -    0s
#      0     0    0.78596    0    9   -0.00000    0.78596      -     -    0s
#      0     0    0.78596    0    9   -0.00000    0.78596      -     -    0s
#      0     0    0.78596    0    9   -0.00000    0.78596      -     -    0s
#      0     0    0.78596    0   11   -0.00000    0.78596      -     -    0s
#      0     0    0.78596    0   11   -0.00000    0.78596      -     -    0s
#      0     0    0.78596    0   11   -0.00000    0.78596      -     -    0s
#      0     0    0.78596    0   11   -0.00000    0.78596      -     -    0s
#      0     0    0.78596    0   12   -0.00000    0.78596      -     -    1s
#      0     0    0.78596    0   14   -0.00000    0.78596      -     -    1s
#      0     2    0.78596    0   14   -0.00000    0.78596      -     -    1s
# H   73    42                       0.0000000    0.78596      -  54.9    1s
# H  136    94                       0.0000000    0.78596      -  41.6    1s
# H  916   639                       0.0402186    0.78596  1854%  26.8    2s
# *  935   693              65       0.1495768    0.78596   425%  26.6    2s
# *  939   693              68       0.1495772    0.78596   425%  26.5    2s
# H 1021   692                       0.3058688    0.78596   157%  25.9    2s
# * 1671   943              90       0.3083343    0.78596   155%  22.9    3s
# * 1783   911              94       0.3083395    0.78596   155%  22.2    3s
# * 1900   897              99       0.3083457    0.78595   155%  23.6    3s
# * 1903   897              96       0.3083460    0.78595   155%  23.5    3s
# * 1926   897             107       0.3097778    0.78595   154%  23.6    3s
# * 1955   897             111       0.3097792    0.78595   154%  23.3    3s
# * 2342   949             101       0.3114090    0.77252   148%  25.2    4s
# * 2343   949             101       0.3114100    0.77252   148%  25.2    4s
# * 2476  1026             100       0.3185516    0.77252   143%  24.5    4s
# H 2809   777                       0.3305494    0.77252   134%  24.8    4s
#   2810   748    0.33987   54   11    0.33055    0.77252   134%  24.8    5s
#   2875   780    0.35030   30   36    0.33055    0.35030  5.97%  29.3   10s
# * 4394  1500              96       0.3327180    0.35030  5.28%  25.4   11s
# H 4398  1456                       0.3327181    0.35030  5.28%  25.3   11s
# H 4525  1345                       0.3341545    0.35030  4.83%  25.1   11s
# * 4876   987             107       0.3417191    0.35030  2.51%  24.3   12s
# * 5813  1109             101       0.3417312    0.35029  2.51%  24.2   13s
# * 5814  1109             101       0.3417312    0.35029  2.51%  24.2   13s
# H 6350   864                       0.3436684    0.34955  1.71%  25.4   14s
#   6961   885    0.34575   55   19    0.34367    0.34952  1.70%  26.1   15s
# * 7208   915              69       0.3439264    0.34952  1.63%  26.1   15s
# * 7547   902              76       0.3439459    0.34894  1.45%  25.9   16s
# * 7999   876              94       0.3439785    0.34811  1.20%  26.0   16s
# * 8001   876              95       0.3439785    0.34811  1.20%  26.0   16s
# * 8008   876              76       0.3441217    0.34811  1.16%  25.9   16s
# * 8033   876              64       0.3444266    0.34811  1.07%  26.0   16s
# * 8041   876              65       0.3447725    0.34811  0.97%  26.0   16s
# * 8227   854              66       0.3449642    0.34796  0.87%  26.4   17s
# * 8383   821              65       0.3449701    0.34796  0.87%  26.4   17s
# * 8580   842              82       0.3449968    0.34747  0.72%  26.9   17s
# * 8712   842              82       0.3449969    0.34747  0.72%  27.0   17s
#   9559   718 infeasible   48         0.34500    0.34675  0.51%  31.6   20s
# *10170   709              76       0.3450058    0.34636  0.39%  32.9   21s
# *10513   714              81       0.3450075    0.34636  0.39%  32.3   21s
# *11178   669              71       0.3450075    0.34566  0.19%  31.1   22s
# *11907   491              71       0.3450075    0.34512  0.03%  29.9   22s
#
# Cutting planes:
#   Learned: 186
#   Gomory: 9
#   Cover: 23
#   Implied bound: 136
#   Clique: 3
#   MIR: 298
#   Mixing: 39
#   Flow cover: 857
#   Inf proof: 3
#   RLT: 11
#   Relax-and-lift: 11
#   PSD: 1
#
# Explored 13093 nodes (371474 simplex iterations) in 23.84 seconds (12.24 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 10: 0.345008 0.345008 0.345008 ... 0.344427
# No other solutions better than 0.345008
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max constraint violation (2.3967e-06) exceeds tolerance
# Best objective 3.450075421410e-01, best bound 3.450075421410e-01, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 24.04.3 LTS")
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-1260P, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 15734 rows, 13067 columns and 351222 nonzeros
# Model fingerprint: 0x7114b2ca
# Model has 166 quadratic constraints
# Model has 1 general constraint
# Variable types: 11472 continuous, 1595 integer (1595 binary)
# Coefficient statistics:
#   Matrix range     [6e-06, 1e+06]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-06, 1e+06]
#   RHS range        [7e-15, 1e+06]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint integer_fwd_NDPK6_ by 0.001242027
#
# Presolve removed 10926 rows and 8670 columns
# Presolve time: 0.11s
# Presolved: 5132 rows, 4397 columns, 15531 nonzeros
# Presolved model has 81 bilinear constraint(s)
#
# Solving non-convex MIQCP
#
# Variable types: 3434 continuous, 963 integer (963 binary)
#
# Root relaxation: objective 1.413081e+00, 3295 iterations, 0.06 seconds (0.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.41308    0   29          -    1.41308      -     -    0s
#      0     0    1.25816    0   41          -    1.25816      -     -    0s
#      0     0    0.96654    0   40          -    0.96654      -     -    0s
#      0     0    0.96654    0   39          -    0.96654      -     -    0s
#      0     0    0.96654    0   37          -    0.96654      -     -    0s
#      0     0    0.96654    0   13          -    0.96654      -     -    0s
#      0     0    0.96654    0   13          -    0.96654      -     -    0s
#      0     0    0.96654    0   10          -    0.96654      -     -    0s
#      0     0    0.96654    0   10          -    0.96654      -     -    0s
#      0     0    0.96654    0   11          -    0.96654      -     -    0s
#      0     0    0.96654    0   11          -    0.96654      -     -    0s
# H    0     0                      -0.0000000    0.96654      -     -    0s
#      0     0    0.96654    0   10   -0.00000    0.96654      -     -    0s
#      0     0    0.96654    0   10   -0.00000    0.96654      -     -    0s
#      0     0    0.96654    0   10   -0.00000    0.96654      -     -    0s
#      0     0    0.96654    0   14   -0.00000    0.96654      -     -    0s
# H    0     0                       0.0000033    0.96654      -     -    1s
#      0     1    0.96654    0   12    0.00000    0.96654      -     -    1s
# * 1346  1100              88       0.0125159    0.90128  7101%  24.1    2s
# * 1578  1118             106       0.2377388    0.90128   279%  23.5    3s
# * 1682  1064             111       0.2378968    0.90128   279%  22.8    3s
# * 1685  1064             113       0.2379050    0.90128   279%  22.8    3s
# * 1789  1136             115       0.2379055    0.90128   279%  22.5    3s
# H 2000   907                       0.3277555    0.90128   175%  22.8    3s
# H 2009   907                       0.3327932    0.90128   171%  22.8    3s
# H 2194   912                       0.3422525    0.89882   163%  22.5    3s
# H 2225   912                       0.3500499    0.89882   157%  22.4    3s
# H 2642  1054                       0.3580284    0.89882   151%  20.9    4s
#   2643  1025    0.77966   56   10    0.35803    0.89882   151%  20.9    5s
#   2681  1051    0.36568   42    7    0.35803    0.61148  70.8%  22.7   10s
#   2711  1075    0.36585   16   16    0.35803    0.36585  2.19%  29.0   15s
# * 3448  1218             107       0.3580286    0.36394  1.65%  27.6   19s
# * 3644  1280             109       0.3594418    0.36394  1.25%  26.6   19s
# * 3888  1275             124       0.3597194    0.36394  1.17%  25.4   19s
# * 4103  1366             127       0.3605873    0.36394  0.93%  24.4   19s
#   4282  1279    0.36153  107   12    0.36059    0.36394  0.93%  23.6   20s
# * 4338  1217             132       0.3617939    0.36394  0.59%  23.4   20s
# * 4867   699             128       0.3617942    0.36383  0.56%  21.5   20s
#
# Cutting planes:
#   Learned: 47
#   Gomory: 8
#   Cover: 11
#   Implied bound: 40
#   MIR: 48
#   Mixing: 2
#   Flow cover: 120
#   RLT: 3
#   Relax-and-lift: 10
#   BQP: 2
#
# Explored 8447 nodes (274974 simplex iterations) in 24.82 seconds (14.79 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 10: 0.361794 0.361794 0.360587 ... 0.342253
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max bound violation (1.5149e-06) exceeds tolerance
# Best objective 3.617942331515e-01, best bound 3.618283625555e-01, gap 0.0094%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 24.04.3 LTS")
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-1260P, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 15734 rows, 13067 columns and 351222 nonzeros
# Model fingerprint: 0xab10d9e5
# Model has 166 quadratic constraints
# Model has 1 general constraint
# Variable types: 11472 continuous, 1595 integer (1595 binary)
# Coefficient statistics:
#   Matrix range     [6e-06, 1e+06]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e-06, 1e+06]
#   RHS range        [7e-15, 1e+06]
#
# MIP start from previous solve did not produce a new incumbent solution
#
# Presolve removed 10926 rows and 8670 columns
# Presolve time: 0.11s
# Presolved: 5132 rows, 4397 columns, 15531 nonzeros
# Presolved model has 81 bilinear constraint(s)
#
# Solving non-convex MIQCP
#
# Variable types: 3434 continuous, 963 integer (963 binary)
#
# Root relaxation: objective 1.689258e+00, 3692 iterations, 0.07 seconds (0.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.68926    0   40          -    1.68926      -     -    0s
#      0     0    1.53483    0   52          -    1.53483      -     -    0s
#      0     0    1.24690    0   51          -    1.24690      -     -    0s
#      0     0    1.14265    0   57          -    1.14265      -     -    0s
#      0     0    1.14265    0   59          -    1.14265      -     -    0s
#      0     0    1.14265    0   20          -    1.14265      -     -    0s
#      0     0    1.14265    0   20          -    1.14265      -     -    0s
#      0     0    1.14265    0   17          -    1.14265      -     -    0s
#      0     0    1.14265    0   18          -    1.14265      -     -    0s
#      0     0    1.14265    0   12          -    1.14265      -     -    0s
#      0     0    1.14265    0   12          -    1.14265      -     -    0s
#      0     0    1.14265    0   11          -    1.14265      -     -    0s
#      0     0    1.14265    0   12          -    1.14265      -     -    0s
#      0     0    1.14265    0   12          -    1.14265      -     -    0s
#      0     0    1.14265    0   12          -    1.14265      -     -    0s
#      0     0    1.14265    0   12          -    1.14265      -     -    0s
#      0     0    1.14265    0   16          -    1.14265      -     -    1s
# H    0     0                      -0.0000000    1.14265      -     -    1s
#      0     2    1.14265    0   16   -0.00000    1.14265      -     -    1s
# H   82    37                       0.0000000    0.96802      -  37.3    1s
# H   84    37                       0.0000000    0.96802      -  46.6    1s
# * 1035   892              75       0.1392724    0.96759   595%  24.3    2s
# H 1133   883                       0.1869046    0.96759   418%  23.5    2s
# H 1135   883                       0.2197311    0.96759   340%  23.5    2s
# H 1166   883                       0.2846560    0.96759   240%  23.1    2s
# * 1325   975              88       0.2859216    0.96759   238%  22.8    2s
# * 1581  1017             102       0.3002177    0.96759   222%  20.8    2s
# * 1720   973             104       0.3082411    0.96759   214%  20.7    2s
# * 1721   973             104       0.3082412    0.96759   214%  20.7    2s
# * 1950  1152             102       0.3085041    0.96759   214%  19.9    3s
# * 1952  1152             103       0.3085041    0.96759   214%  19.8    3s
# * 2038  1077             101       0.3531840    0.96759   174%  19.4    3s
# * 2087  1073              85       0.3534056    0.96759   174%  19.3    3s
# * 2138  1116             108       0.3556320    0.96759   172%  19.1    3s
# * 2211   942              83       0.3852150    0.96759   151%  19.0    3s
# * 2353   922              84       0.3854473    0.96654   151%  18.8    3s
# * 2387   965              55       0.3856628    0.96654   151%  18.7    3s
# * 2390   965              57       0.3857001    0.96654   151%  18.7    3s
# * 2520   934              60       0.3857003    0.96654   151%  18.5    3s
# * 2523   934              62       0.3857003    0.96654   151%  18.5    3s
# H 2668   897                       0.3857003    0.96654   151%  18.1    3s
# H 2743   897                       0.3857003    0.96654   151%  18.0    3s
# H 3152  1044                       0.3857034    0.96654   151%  18.8    4s
#   3155  1046    0.88530   27   16    0.38570    0.96654   151%  18.7    5s
#   3195  1074    0.38847   35    9    0.38570    0.38948  0.98%  20.2   10s
# H 3211  1031                       0.3877176    0.38890  0.31%  22.0   12s
# H 3212   980                       0.3877177    0.38888  0.30%  22.0   12s
# H 3212   931                       0.3877177    0.38888  0.30%  22.0   12s
#   3232   946    0.38880   41   14    0.38772    0.38880  0.28%  23.7   15s
#   3267   971    0.38772   55   11    0.38772    0.38837  0.17%  26.5   20s
# H 3267   922                       0.3878573    0.38837  0.13%  26.5   20s
# H 3301   900                       0.3878574    0.38802  0.04%  29.0   23s
#   3318   912    0.38802   26   11    0.38786    0.38802  0.04%  29.9   25s
#
# Cutting planes:
#   Learned: 6
#   Gomory: 1
#   Cover: 3
#   Implied bound: 5
#   MIR: 3
#   Flow cover: 20
#   RLT: 2
#   Relax-and-lift: 2
#
# Explored 3338 nodes (113437 simplex iterations) in 27.67 seconds (15.97 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 10: 0.387857 0.387857 0.387718 ... 0.3857
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.878574324243e-01, best bound 3.878900899424e-01, gap 0.0084%

# %%
ex_flux_df.loc['glc-D_EX']=glc_flux
df_data2
# Out:
#            glc-D_EX  ac_EX  etoh_EX  glyc_EX  o2_EX  co2tot_EX  biomass_EX  \
# Condition
# batch         15.70    NaN    22.30      NaN    NaN        NaN        0.41
# batch         22.42  0.746    36.03    1.184    NaN        NaN        0.46
# chemostat      0.25  0.000     0.00    0.000    0.7        0.7        0.02
# chemostat      0.57    NaN     0.00      NaN    1.4        1.4        0.05
# chemostat      0.60  0.000     0.00    0.000    1.5        1.6        0.05
# chemostat      1.10  0.000     0.00    0.000    2.7        2.8        0.10
# chemostat      1.67    NaN     0.00      NaN    2.5        2.6        0.15
# chemostat      2.14  0.000     0.00    0.000    5.1        5.3        0.20
# chemostat      2.22    NaN     0.00      NaN    3.7        4.0        0.20
# chemostat      2.83    NaN     0.00      NaN    6.8        7.6        0.25
# chemostat      3.24    NaN     0.00      NaN    8.3        8.4        0.28
# chemostat      3.70    NaN     0.50      NaN    8.8        9.5        0.30
# chemostat      4.67  0.150     3.20    0.010    6.8       10.0        0.30
# chemostat      5.44  0.200     4.40    0.010    6.8       11.4        0.32
# chemostat      7.62  0.430     8.70    0.020    5.0       14.0        0.35
# chemostat      8.09    NaN     6.90      NaN    6.6       13.3        0.35
# chemostat      8.33    NaN     6.70      NaN    7.1       15.3        0.36
# chemostat     10.23  0.670    14.90    0.060    4.2       18.1        0.38
# chemostat     13.18    NaN    12.50      NaN    4.2       20.7        0.38
#
#             Exp. data
# Condition
# batch      Not fitted
# batch      Not fitted
# chemostat      Fitted
# chemostat  Not fitted
# chemostat      Fitted
# chemostat      Fitted
# chemostat  Not fitted
# chemostat      Fitted
# chemostat  Not fitted
# chemostat  Not fitted
# chemostat  Not fitted
# chemostat  Not fitted
# chemostat      Fitted
# chemostat      Fitted
# chemostat      Fitted
# chemostat  Not fitted
# chemostat  Not fitted
# chemostat      Fitted
# chemostat  Not fitted

# %%
ex_flux_df
# Out:
#                    0          1         2         3         4         5   \
# biomass_EX   0.409704   0.414438  0.018029  0.048459  0.051310  0.098830
# EX_ac_e      0.000000   0.000000  0.000000  0.000000  0.000000  0.000000
# EX_glyc_e    0.000000   0.000000  0.000000  0.000000  0.000000  0.000000
# co2_EX      28.191283  34.550550  0.851984  1.678289  1.755811  3.047859
# etoh_EX     25.641569  31.614692  0.000000  0.000000  0.000000  0.000000
# o2_EX       -2.256022  -0.818411 -0.839060 -1.643551 -1.719032 -2.977014
# glc-D_EX   -15.700000 -22.420000 -0.250000 -0.570000 -0.600000 -1.100000
#
#                   6         7         8         9         10        11  \
# biomass_EX  0.153002  0.197671  0.205274  0.263248  0.297782  0.303661
# EX_ac_e     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# EX_glyc_e   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# co2_EX      4.520791  5.735317  5.942045  7.518342  8.428315  8.798242
# etoh_EX     0.000000  0.000000  0.000000  0.000000  0.000000  0.536065
# o2_EX      -4.411113 -5.593619 -5.794896 -7.329636 -8.214854 -8.044501
# glc-D_EX   -1.670000 -2.140000 -2.220000 -2.830000 -3.240000 -3.700000
#
#                    12         13         14         15         16         17  \
# biomass_EX   0.312462   0.319393   0.338741   0.342897   0.345008   0.361794
# EX_ac_e      0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# EX_glyc_e    0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# co2_EX      10.278130  11.898221  15.423055  16.165573  16.544811  19.546337
# etoh_EX      0.000000   4.498850   9.060944  10.025003  10.517459  14.415022
# o2_EX       -7.644471  -7.170418  -6.119288  -5.894767  -5.780037  -4.871966
# glc-D_EX    -4.670000  -5.440000  -7.620000  -8.090000  -8.330000 -10.230000
#
#                    18
# biomass_EX   0.387857
# EX_ac_e      0.000000
# EX_glyc_e    0.000000
# co2_EX      24.206595
# etoh_EX     20.466508
# o2_EX       -3.462055
# glc-D_EX   -13.180000

# %%
## scatter plot conditions vs fluxes

fig, ax = plt.subplots(figsize=(2.5,2.5))
axin=ax.inset_axes([0.65,0.15,0.3,0.3])

scale_rcparams(fig)
mapping_rxnnames={'biomass_EX':'biomass_EX','EX_ac_e':'ac_EX','EX_glyc_e':'glyc_EX','co2_EX':'co2tot_EX','etoh_EX':'etoh_EX','o2_EX':'o2_EX'}
vircols=sns.color_palette('viridis',n_colors=len(ex_data))
for rxn,color in zip(ex_data,vircols):
    x=df_data2[mapping_rxnnames[rxn]]
    y=ex_flux_df.loc[rxn] if rxn not in ['o2_EX'] else -ex_flux_df.loc[rxn]
    ax.scatter(x,y,s=75,edgecolor='black',color=color,label=rxn)

    ## add an inset ax with zoom bottom right
    axin.scatter(x,y,s=75,edgecolor='black',color=color)

#fformating
ax.set_xlabel('Measured fluxes \n(mmol.gCDW-1.h-1)')
ax.set_ylabel('Predicted fluxes \n(mmol.gCDW-1.h-1)')
#diag
ax.plot([0,1],[0,1],transform=ax.transAxes,color='grey',linestyle='--')
ax.legend(frameon=False,bbox_to_anchor=(1.05, 1))
ax.set_xticks([0,20,40])
ax.set_yticks([0,20,40])


axin.plot([0,1],[0,1],transform=axin.transAxes,color='grey',linestyle='--')
axin.set_xlim(0,1)
axin.set_ylim(0,1)
axin.set_xticks([0,1])
axin.set_yticks([0,1])
axin.set_xlabel('')
axin.set_ylabel('')
ax.indicate_inset_zoom(axin,edgecolor='black')

#save 
# plt.savefig(f'{OUTPUT_FOLDER}/scatter_predictions_allglucoseconds.png',dpi=300)
# plt.savefig(f'{OUTPUT_FOLDER}/scatter_predictions_allglucoseconds.svg',dpi=300)

# %%
y
# Out:
# 0     2.256022
# 1     0.818411
# 2     0.839060
# 3     1.643551
# 4     1.719032
# 5     2.977014
# 6     4.411113
# 7     5.593619
# 8     5.794896
# 9     7.329636
# 10    8.214854
# 11    8.044501
# 12    7.644471
# 13    7.170418
# 14    6.119288
# 15    5.894767
# 16    5.780037
# 17    4.871966
# 18    3.462055
# Name: o2_EX, dtype: float64

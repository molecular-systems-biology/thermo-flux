# %%
import cobra
import thermo_flux
import thermo_flux.tools
import pandas as pd
import numpy as np

import os.path as path

from thermo_flux.io import load_excel as ex
from thermo_flux.io import helper_load as hl

from equilibrator_api import  Q_

from thermo_flux.solver.gurobi import variability_analysis

from cobra.flux_analysis import flux_variability_analysis

# %% [markdown]
# notebook to parameterize the ecoli model adapted from iJR904 (Niebel et al.2019) and generate mps files for thermodynamically constrained flux variability analyses.
# The notebook includes first generating mps files for metabolite concentration variability analyses then using the metabolite concentration bounds in the thermo-flux FVA.
#
# code from L.Sillje
#
# Included plotting/analysis of intermediate steps

# %%
INPUT_MODEL = "datafiles/model.xlsx"
INPUT_KEGGS = "datafiles/ecoli_kegg_id.csv"
INPUT_REED = "datafiles/reed.csv"
INPUT_INCHI = "datafiles/InChIs.csv"
INPUT_GAMS = "datafiles/model_Ecoli_from-gams.xlsx"
INPUT_EXP_DATA = "datafiles/allPhysioData_formatted_forGSM_20230831.csv"
INPUT_EXP_CONC = "datafiles/allConcRange_20230912.csv"
INPUT_METABOLOMICS = "datafiles/metabolomics-Kochanowski_20230925.csv"

MODEL_NAME = "ecoli"
CONDITIONS = ["WT-Glc_I", "WT-Ace_I"]

INCLUDE_CO2 = True
INCLUDE_O2 = True
ALLOW_OTHER_EXCRETION = False
RELAX_EXP_FLUX_BOUNDS = 2.0

# %%
def gen_model(name: str, model_xlsx: str, kegg: str, reed: str, inchi:str, gams: str,  update_thermodynamics=True):
    tmodel = ex.create_thermo_model(name, model_excel=model_xlsx, keggids_csv=kegg, edit_mets={})

    # ADD HYDROXYBENZOATE TRANSPORT & EXCHANGE:
    # Define extracellular orotate:
    hbz_e = cobra.Metabolite(id="4hbz_e", compartment="e")
    hbz_e = thermo_flux.core.metabolite.ThermoMetabolite(hbz_e, model=tmodel)
    hbz_e.annotation = tmodel.metabolites.get_by_id("4hbz_c").annotation  
    tmodel.metabolites.append(hbz_e)

    # Hydroxybenzoate H+ antiporter (aaeB):
    HBZt3 = cobra.Reaction("HBZt3")
    HBZt3.lower_bound = -1000
    HBZt3.upper_bound = 1000
    HBZt3.add_metabolites({tmodel.metabolites.get_by_id("4hbz_e"): +1,
                      tmodel.metabolites.h_e: -1,
                      tmodel.metabolites.get_by_id("4hbz_c"): -1,
                      tmodel.metabolites.h_c: +1})
    HBZt3 = thermo_flux.core.reaction.ThermoReaction(HBZt3, model=tmodel)

    # Exchange:
    EX_4hbz = cobra.Reaction("EX_4hbz")
    EX_4hbz.add_metabolites({tmodel.metabolites.get_by_id("4hbz_e"): -1})
    EX_4hbz = thermo_flux.core.reaction.ThermoReaction(EX_4hbz, model=tmodel)

    tmodel.add_reactions([HBZt3, EX_4hbz])

    # ADD ISOPROPYLMALATE TRANSPORT & EXCHANGE:
    # Define extracellular orotate:
    ipm_e = cobra.Metabolite(id="3c3hmp_e", compartment="e")
    ipm_e = thermo_flux.core.metabolite.ThermoMetabolite(ipm_e, model=tmodel)
    ipm_e.annotation = tmodel.metabolites.get_by_id("3c3hmp_c").annotation  
    tmodel.metabolites.append(ipm_e)

    # Diffusion across the membrane:
    ipm_diff = cobra.Reaction("IPMex")
    ipm_diff.lower_bound = -1000
    ipm_diff.upper_bound = 1000
    ipm_diff.add_metabolites({tmodel.metabolites.get_by_id("3c3hmp_c"): -1,
                            tmodel.metabolites.get_by_id("3c3hmp_e"): +1})
    ipm_diff = thermo_flux.core.reaction.ThermoReaction(ipm_diff, model=tmodel)

    # Exchange:
    EX_3c3hmp = cobra.Reaction("EX_3c3hmp")
    EX_3c3hmp.add_metabolites({tmodel.metabolites.get_by_id("3c3hmp_e"): -1})
    EX_3c3hmp = thermo_flux.core.reaction.ThermoReaction(EX_3c3hmp, model=tmodel)

    tmodel.add_reactions([ipm_diff, EX_3c3hmp])

    # ADD OROTATE TRANSPORT AND EXCHANGE
    # Define extracellular orotate:
    oro_e = cobra.Metabolite(id="orot_e", compartment="e")
    oro_e = thermo_flux.core.metabolite.ThermoMetabolite(oro_e, model=tmodel)
    oro_e.annotation = tmodel.metabolites.orot_c.annotation  
    tmodel.metabolites.append(oro_e)

    # Diffusion across the membrane:
    oro_diff = cobra.Reaction("OROTex")
    oro_diff.lower_bound = -1000
    oro_diff.upper_bound = 1000
    oro_diff.add_metabolites({tmodel.metabolites.orot_c: -1,
                            tmodel.metabolites.orot_e: +1})
    oro_diff = thermo_flux.core.reaction.ThermoReaction(oro_diff, model=tmodel)

    # Dicarboxylate/H+ symporter (dctA):
    dcta = cobra.Reaction("DCTA")
    dcta.lower_bound = -1000
    dcta.upper_bound = 0
    dcta.add_metabolites({tmodel.metabolites.orot_e: +1,
                        tmodel.metabolites.h_e: +1,
                        tmodel.metabolites.orot_c: -1,
                        tmodel.metabolites.h_c: -1})
    dcta = thermo_flux.core.reaction.ThermoReaction(dcta, model=tmodel)

    # Exchange:
    EX_oro = cobra.Reaction("EX_oro")
    EX_oro.add_metabolites({tmodel.metabolites.orot_e: -1})
    EX_oro = thermo_flux.core.reaction.ThermoReaction(EX_oro, model=tmodel)

    tmodel.add_reactions([oro_diff, dcta, EX_oro])

    # Define thermodynamic parameters
    tmodel.pH = {"c": Q_(7.6), "e": Q_(7)} #pH
    tmodel.I = {"c": Q_(0.25,'M'), "e": Q_(0.25,'M')} #ionic stength
    tmodel.phi = {'ce':Q_(0.15,'V')} #membrane potential ‘ce’ represents the voltage between compartment ‘c’ and compartment 'e’ defined as Phic - Phie
    tmodel.pMg = {'e': Q_(3), 'c': Q_(3)}

    # Update metabolite annotations with the IDs from KEGG
    for met in tmodel.metabolites:
        met.annotation["bigg.metabolite"] = met.id[:-2]

    # Update the inchi strings of some unknown metabolites
    df = pd.read_csv(reed, header=None).set_index(0)

    unknown_mets = []
    for met in tmodel.metabolites:
        if met.id[:-2] in df.index:
            met.annotation['InChI'] = df.loc[met.id[:-2]].iloc[1]
            unknown_mets.append(met)

    for met in tmodel.metabolites:
        if ('kegg' in met.annotation):
            if (met.annotation['kegg'] in df.index):
            
                inchi = df.loc[met.annotation['kegg']].iloc[0]

                if type(inchi) is str:
                    met.annotation['InChI'] = df.loc[met.annotation['kegg']].iloc[0]
                    unknown_mets.append(met)

    # Additional data from excel spredsheet needs to be imported for some compounds with unknown structure
    sheets = ex.read_excelfile(model_xlsx)

    for met in tmodel.metabolites:
        if met.id[:-2] in sheets['Metabolites']['Unnamed: 0'].values:

            common_name = sheets['Metabolites'].loc[sheets['Metabolites']['Unnamed: 0'] == met.id[:-2]]['Unnamed: 11'].values
            protons = sheets['Metabolites'].loc[sheets['Metabolites']['Unnamed: 0'] == met.id[:-2]]['Unnamed: 9'].values
            charge =  sheets['Metabolites'].loc[sheets['Metabolites']['Unnamed: 0'] == met.id[:-2]]['Unnamed: 8'].values
            formula =  sheets['Metabolites'].loc[sheets['Metabolites']['Unnamed: 0'] == met.id[:-2]]['Unnamed: 12'].values

            met.formula = 'H'+str(protons[0])

            if len(common_name) > 0:
                met.notes['common name'] = common_name[0]
                met.charge = charge[0]
            else:
                met.notes['common name'] = ''

    # Hydrogenase reactions are missing protons
    for rxn in tmodel.reactions:
        if 'HYD' in rxn.id:
            if 'ATP' not in rxn.id:
                rxn.add_metabolites({tmodel.metabolites.h_e:2,
                                    tmodel.metabolites.h_c:-2})

    # Remove duplicate/additional reactions
    RXNS_TO_REMOVE = []
    for rxn in tmodel.reactions:
        if rxn.id.endswith("_add"):
            RXNS_TO_REMOVE.append(rxn)   
    tmodel.remove_reactions(RXNS_TO_REMOVE)

    # FDH reactions are missing protons and water is on wrong side of membrane 
    tmodel.reactions.FDH2.add_metabolites({tmodel.metabolites.h_e:2,
                                        tmodel.metabolites.h_c:-2,
                                        tmodel.metabolites.h2o_c:1,
                                        tmodel.metabolites.h2o_e:-1})
    tmodel.reactions.FDH3.add_metabolites({tmodel.metabolites.h_e:2,
                                        tmodel.metabolites.h_c:-2,
                                        tmodel.metabolites.h2o_c:1,
                                        tmodel.metabolites.h2o_e:-1})

    # Missing transporterd metabolites
    tmodel.reactions.TMAOR1e.transported_mets = {tmodel.metabolites.tmao_e: -1}
    tmodel.reactions.TMAOR2e.transported_mets = {tmodel.metabolites.tmao_e: -1}
    tmodel.reactions.GLCDe.transported_mets = {tmodel.metabolites.get_by_id('glc-D_e'): -1}

    #D MSOR1e protons are incorrect - this resets the reaction to the bigg version 
    tmodel.reactions.DMSOR1e.add_metabolites({tmodel.metabolites.h_e:-2,
                                            tmodel.metabolites.h_c:2 })
    tmodel.reactions.DMSOR2e.add_metabolites({tmodel.metabolites.h_e:-2,
                                            tmodel.metabolites.h_c:2 })

    tmodel.reactions.DMSOR1e.transported_mets = {tmodel.metabolites.dmso_e: -1}
    tmodel.reactions.DMSOR2e.transported_mets = {tmodel.metabolites.dmso_e: -1}

    tmodel.reactions.SHCHF.add_metabolites({tmodel.metabolites.scl_c:-1,
                                            tmodel.metabolites.srch_c:1})

    # Sirohydrochlorin dehydrogenase is incorrectly defined in model 
    tmodel.reactions.SHCHD2.add_metabolites({tmodel.metabolites.scl_c:2,
                                            tmodel.metabolites.srch_c:-2})

    #Update srch metabolite name
    tmodel.metabolites.srch_c.annotation = {'bigg.metabolite': 'dscl'}

    # Specific reaction that invovled chemcial transformation as part of transport
    tmodel.reactions.NMNt7.transported_mets = {tmodel.metabolites.nmn_e:-1}

    # PTS mechanism 
    for rxn in tmodel.reactions:
        if 'pts' in rxn.id:
            rxn.transported_mets = {met:stoich for met, stoich in rxn.metabolites.items() if met.compartment == 'e'}

    #in imported model any charge metabolite represents a free cation that is transported 
    for rxn in tmodel.reactions:
        if 'biomass' not in rxn.id:   # ignore biomass reaction 
            
            transported_charge = {}
            for met, stoich in rxn.metabolites.items():
                if (met in tmodel.charge_dict.values()):
                    transported_charge[met.compartment] = stoich
            
            if len(transported_charge) != 0:
                rxn.transported_charge = transported_charge

    # Load default concentration bounds from the GAMS model:
    df_conc = hl.excel_to_df(gams)["ConcLimits"]

    # Rearrange data for easier use:
    df_conc = df_conc.reset_index()
    df_conc["met"] = df_conc["dim1"] + "_"+ df_conc["dim2"]
    df_conc = df_conc.pivot_table(columns="dim3", values="Value", index="met")

    # Change upper and lower concentration bounds the values in the dataframe df_conc (taken from GAMS)
    # (values are in mM)
    for met, row in df_conc.iterrows():
        tmodel.metabolites.get_by_id(met).upper_bound = Q_(row["up"], "mM")
        tmodel.metabolites.get_by_id(met).lower_bound = Q_(row["lo"], "mM")

    # Find correct biomass reaction
    biomass_rxns = [r for r in tmodel.reactions if 'biomass' in r.id.lower()]
    for r in biomass_rxns:
        print(r.id, ":", r.reaction[:80])

    # Correct reaction is 'biomass'
    # Define the protons in biomass 
    tmodel.metabolites.biomass_c.formula = 'H74'  # estimated http://www.ncbi.nlm.nih.gov/pubmed/20506321
    tmodel.metabolites.biomass_e.formula = 'H74'

    # Assign biomass
    tmodel.metabolites.biomass_c.biomass = True
    tmodel.metabolites.biomass_e.biomass = True

    tmodel.reactions.biomass.add_metabolites({tmodel.metabolites.atp_c: -31.2622,
                                                tmodel.metabolites.h2o_c: -31.2622,
                                                tmodel.metabolites.adp_c: +31.2622,
                                                tmodel.metabolites.pi_c:  +31.2622})


    # Define biomass formation energy: dfG0(biomass) [kJ gCDW-1] = -2.692234848 fom Battley 1991
    base_dfg = (Q_(-2.692234848, "kJ/mol") * 1000) # values in J/gDW 

    tmodel.metabolites.biomass_c.dfG0 = base_dfg
    tmodel.metabolites.biomass_e.dfG0 = base_dfg

    tmodel.reactions.biomass_ce.ignore_snd = True

    if update_thermodynamics:
        for rxn in tmodel.reactions:
            thermo_flux.tools.drg_tools.reaction_balance(rxn, balance_charge=True, balance_mg=False)

        for met in tmodel.metabolites:
            if met.id in ['charge_c', 'charge_m', 'charge_e']:
                met.ignore_conc = True
        tmodel.update_thermo_info(fit_unknown_dfG0=True)

    return tmodel

# %%
def apply_metabolome_physio_data(tmodel, condition :str, input_exp: str, input_conc: str, input_metabolomics: str, input_gams: str, relax_flux_bounds, include_CO2: bool, include_O2: bool, allow_other_excr: bool, output_log: str, open_exchanges=False, flux_limit = 100):
    "Apply metabolome and physiological data to base stoichiometric-thermodynamic ecoli model"
    df_conc = hl.excel_to_df(input_gams)["ConcLimits"]

    # Rearrange data for easier use:
    df_conc = df_conc.reset_index()
    df_conc["met"] = df_conc["dim1"] + "_"+ df_conc["dim2"]
    df_conc = df_conc.pivot_table(columns="dim3", values="Value", index="met")

    # Import experimental data:
    reg_data = pd.read_csv(input_exp)

    reg_data.set_index(["cond", "rxn"], inplace=True) 
    reg_data.head()

    # Store gas fluxes:
    reg_data_gas = reg_data.swaplevel().copy()
    reg_data_gas = reg_data_gas.loc[["EX_co2", "EX_o2"]]
    reg_data_gas = reg_data_gas.swaplevel()
    reg_data_gas

    if include_CO2 is False:
        reg_data_no_gas = reg_data.swaplevel().copy()
        reg_data_no_gas = reg_data_no_gas.drop(["EX_co2"])
        reg_data_no_gas = reg_data_no_gas.swaplevel()
        reg_data = reg_data_no_gas
        
        
    if include_O2 is False:
        reg_data_no_gas = reg_data.swaplevel().copy()
        reg_data_no_gas = reg_data_no_gas.drop(["EX_o2"]) 
        reg_data_no_gas = reg_data_no_gas.swaplevel()
        reg_data = reg_data_no_gas

    # Set metabolite concentrations to the values in the GAMS model:   
    for met, row in df_conc.iterrows():
        tmodel.metabolites.get_by_id(met).upper_bound = Q_(row["up"], "mM")
        tmodel.metabolites.get_by_id(met).lower_bound = Q_(row["lo"], "mM")

    # Import experimental data:
    conc_data = pd.read_csv(input_conc)

    conc_data.set_index(["cond", "met"], inplace=True) 
    conc_data.head()


    # Import experimental data:

    met_data_all=pd.read_csv(input_metabolomics, index_col=(0,1))

    df_bounds=thermo_flux.solver.gurobi.calc_conc_bounds(tmodel,[condition],met_data_all,conc_units='mM')
    df_bounds_cond=df_bounds.loc[condition]
    for met_id,row in df_bounds_cond.iterrows():
        tmodel.metabolites.get_by_id(met_id).upper_bound=Q_(row['ub'],'M')
        tmodel.metabolites.get_by_id(met_id).lower_bound=Q_(row['lb'],'M')
    
    exchanges = [rxn.id for rxn in tmodel.exchanges]

    exchanges_to_relax = ["EX_C", "EX_h", "EX_h2o", "EX_k", "EX_nh3", "EX_pi", "EX_so4"]

    if include_CO2 is False:
        exchanges_to_relax += ["EX_co2"]
        
    if include_O2 is False:
        exchanges_to_relax += ["EX_o2"]

    if allow_other_excr is True:
        upper_bound_exchanges = 100
    else:
        upper_bound_exchanges = 0

    # Reset all flux bounds to +- flux limit (default -100 / 100):
    for rxn in tmodel.reactions:
        tmodel.reactions.get_by_id(rxn.id).lower_bound = -flux_limit
        tmodel.reactions.get_by_id(rxn.id).upper_bound = flux_limit
    
    # Add non-growth associate ATP maintenance cost:
    tmodel.reactions.ATPHYD.lower_bound = 3.15

    # Fix exchange reaction directions:
    for rxn in exchanges:
        tmodel.reactions.get_by_id(rxn).lower_bound = 0
        tmodel.reactions.get_by_id(rxn).upper_bound = upper_bound_exchanges
  
    # Relax essential exchanges:
    for rxn_rel in exchanges_to_relax:
        tmodel.reactions.get_by_id(rxn_rel).lower_bound = -flux_limit
        tmodel.reactions.get_by_id(rxn_rel).upper_bound = +flux_limit

    # Fix flux for the measured exchange reactions:
    for rxn, row in reg_data.loc[condition].iterrows():
        tmodel.reactions.get_by_id(rxn).lower_bound = -flux_limit
        tmodel.reactions.get_by_id(rxn).upper_bound = flux_limit

        if not open_exchanges:
            tmodel.reactions.get_by_id(rxn).lower_bound = row["mean"] - relax_flux_bounds * row["sd"]
            tmodel.reactions.get_by_id(rxn).upper_bound = row["mean"] + relax_flux_bounds * row["sd"]

    if condition.startswith("dptsG-Glc"):
        tmodel.reactions.GLCpts.lower_bound = 0
        tmodel.reactions.GLCpts.upper_bound = 0
        
    # Fix concentration for the measured extracellular metabolites:
    for met, row in conc_data.loc[condition].iterrows():
        tmodel.metabolites.get_by_id(met).lower_bound = Q_(1e-9, "M")
        tmodel.metabolites.get_by_id(met).upper_bound = Q_(100, "M")
        tmodel.metabolites.get_by_id(met).lower_bound = Q_(row["conc_M_min"], "M")
        tmodel.metabolites.get_by_id(met).upper_bound = Q_(row["conc_M_max"], "M")

    #Normalize reaction fluxes to native floats otherwise SBML will error out when exporting

    for met_id, row in df_bounds_cond.iterrows():
        print(f"model: {tmodel.metabolites.get_by_id(met_id).lower_bound}, {tmodel.metabolites.get_by_id(met_id).upper_bound}, metabolome: {row['lb']}, {row['ub']}")
        is_same = abs(tmodel.metabolites.get_by_id(met_id).lower_bound.m - Q_(row['lb'],'M').m) < 0.0000001 and abs(tmodel.metabolites.get_by_id(met_id).upper_bound.m - Q_(row['ub'],'M').m) < 0.0000001
        print(f"Metabolome data applied: {is_same}")
        
    for r in tmodel.reactions:
        r.lower_bound = float(r.lower_bound)
        r.upper_bound = float(r.upper_bound)

    return tmodel

# %%
def remove_orphan_metabolites(model):
    """
    Cleanup helper function that removes metabolites from the model that do not participate in any reaction
    """

    linked_metabolites = set()
    for rxn in model.reactions:
        for met in rxn.metabolites:
            linked_metabolites.add(met)
            
    all_metabolites = set(model.metabolites)
    orphan_metabolites = list(all_metabolites - linked_metabolites)
    
    orphan_ids = [m.id for m in orphan_metabolites]
    
    if orphan_metabolites:
        print(f"\nRemoving {len(orphan_metabolites)} orphan metabolites:")
        print(f"Orphaned IDs: {', '.join(orphan_ids)}")
        
        model.remove_metabolites(orphan_metabolites)
        
    else:
        print("\nNo orphan metabolites found. ")
        
    return len(orphan_metabolites)

# %%
def clean_fva_bounds(lb, ub, tol=1e-7):
    """
    Cleans numerical noise from TFVA bounds to improve solver stability (for example 5e-13 -> 0.0 )
    """
    old_lb = lb
    old_ub = ub
    if abs(lb) < tol: lb = 0.0
    if abs(ub) < tol: ub = 0.0
    
    if abs(lb - round(lb)) < tol: lb = round(lb, 8)
    if abs(ub - round(ub)) < tol: ub = round(ub, 8)

    if abs(ub - lb) < tol:
        # If abs difference is below tolerance fluxes are the same, set to average of lb/ub
        avg = (lb + ub) / 2
        lb, ub = avg, avg

    if lb > ub:
        lb = ub 
    
    print(f"Before/after: {old_lb}, {old_ub} ---> {lb}, {ub}")

    return lb, ub

# %%
def apply_met_tva(tmodel, met_tva_file):
    "Applies metabolite TVA results to the given model. Note that metaboltite indices need to 100% match."
    bounds_dict = dict()
    with open(met_tva_file, "r") as f:
        for line in f:
            clean_line = line.strip()
            if not clean_line:
                print(f"Skipping line {clean_line}")
                continue
            try:
                index_str, bounds_str = clean_line.split(':', 1)
                index = int(index_str.strip())

                cleaned_bounds_str = bounds_str.strip().strip('[] ')
                lower_str, upper_str = cleaned_bounds_str.split(',')

                lower = float(lower_str.strip())
                upper = float(upper_str.strip())

                linear_lower = np.exp(lower) * 1e3 # From molar conc back to millimolar
                linear_upper = np.exp(upper) * 1e3 # Same


                bounds_dict[index] = [linear_lower, linear_upper]
            except ValueError as e:
                print(f"Skipping line due to parsing error: '{line.strip()}' - Error: {e}")
            except Exception as e:
                print(f"unexpected error occurred while processing line: '{line.strip()}' - Error: {e}") 
    
    for met in tmodel.metabolites:
        met_index = tmodel.metabolites.index(met)

        if met_index not in bounds_dict:
            print(f"Skipped metabolite {met.id} as it was not found in TVA data.")
            continue

        cur_lower, cur_upper = met.lower_bound, met.upper_bound
        new_lower, new_upper = bounds_dict[met_index][0], bounds_dict[met_index][1]

        # Fix for floating point errors
        # Sometimes the upper bound can, for example, be 0.99999999 while the lower bound is 1.000000002
        # In this case both are equal, however floating point precision causes cobra to see the upper bound as smaller than the lower bound
        difference = abs(new_upper - new_lower)
        if difference < 1e-6:
            new_lower = new_upper

        met.upper_bound = Q_(new_upper, "millimolar")
        met.lower_bound = Q_(new_lower, "millimolar")

        print(f"Metabolite {met.id} - Old: {cur_lower}, {cur_upper} | New: {met.lower_bound, met.upper_bound}")

# %%
def add_rq_constraint(tmodel, condition, phys_data):
    "Add respiratory constraint from physiological data. "
    "Gas exchange rates in physiological data are underestimated, thus we only constrain these exchange fluxes through the respiratory quotient. see Jose Losa Thesis (2024)"
    reg_data = pd.read_csv(phys_data)

    reg_data.set_index(["cond", "rxn"], inplace=True) 

    reg_data_gas = reg_data.swaplevel().copy()
    reg_data_gas = reg_data_gas.loc[["EX_co2", "EX_o2"]]
    reg_data_gas = reg_data_gas.swaplevel()

    data_gas = reg_data_gas.loc[condition]
    vo2, vo2_err = data_gas.loc["EX_o2"]
    vco2, vco2_err = data_gas.loc["EX_co2"]
    rq = - vco2 / vo2
    rq_err = rq * np.sqrt( (vo2_err / vo2)**2 + (vco2_err / vco2)**2)
    print(f">>>>>> RQ: {rq :.2} (vCO2 = {vco2 :.3} / vO2 = {vo2 :.3}) ERR: {rq_err}")

    rq_lb = rq - abs(6 * rq_err)
    rq_ub = rq + abs(6 * rq_err)

    mrq = tmodel.m.addMVar(lb=rq_lb, ub=rq_ub, shape=(1,1), name="RQ") 
    tmodel.mvars["rq"] = mrq
    
    idx_o2 = tmodel.reactions.index("EX_o2")
    idx_co2 = tmodel.reactions.index("EX_co2")
    tmodel.m.addConstr(tmodel.mvars["v"][0, idx_co2] == (-mrq)*tmodel.mvars["v"][0, idx_o2], name="enforce_RQ")
    tmodel.m.update()

# %%
def tva_run_scenarios_one_model_mets(tmodel, name, condition, output_folder):
    "Writes metabolite TVA scenarios into one single mps.gz file"
    tmodel.m.Params.MIPGap = 0.001

    vars = []
    for i, met in enumerate(tmodel.metabolites):
        v = tmodel.mvars["ln_conc"][0][i]
        vars.append(v)
        print(f"Added {met.id} : { v }")

    gm = variability_analysis(tmodel, vars)
    gm.write(f"{output_folder}{path.sep}{name}_{condition}_mets.mps.gz")

# %%
def save_multiscenario_solutions(m, output_folder, name):
    #save multiscenario solutions
    no_scenarios = m.NumScenarios
    if no_scenarios > 0:
        obj_val = {}
        obj_bound = {}
        optimal_bounds = {}
        MIPGaps = {}
        for i in range(0, no_scenarios, 2):
            rxn_idx = int(i / 2)
            # Minimization:
            m.params.ScenarioNumber = i
            m.update()
            ObjBound = m.ScenNObjBound
            ObjVal = m.ScenNObjVal
        #  print(rxn_idx, ObjBound, ObjVal)
            if ObjVal != 0:
                MIPGap = abs((ObjBound-ObjVal)/ObjVal)
            else:
                MIPGap = 0

            obj_val[rxn_idx] = [(-1) * ObjVal]
            obj_bound[rxn_idx] = [(-1) * ObjBound]
            MIPGaps[rxn_idx] = [MIPGap]

            if MIPGap <= m.params.MIPGap:
                optimal_bounds[rxn_idx] = [(-1) * ObjBound]
            else:
                optimal_bounds[rxn_idx] = [float('nan')]

            # Maximization:
            m.params.ScenarioNumber = i + 1
            m.update()
            ObjBound = m.ScenNObjBound
            ObjVal = m.ScenNObjVal
            if ObjVal != 0:
                MIPGap = abs((ObjBound-ObjVal)/ObjVal)
            else:
                MIPGap = 0
            obj_val[rxn_idx].append((+1) * m.ScenNObjVal)
            obj_bound[rxn_idx].append((1) * m.ScenNObjBound)
            MIPGaps[rxn_idx].append(MIPGap)
            if MIPGap <= 0.0001:
                optimal_bounds[rxn_idx].append((1) * ObjBound)
            else:
                optimal_bounds[rxn_idx].append(float('nan'))

        with open(f"{output_folder}/{name}_objval.txt", "w") as f:
            for k, val in obj_val.items():
                f.writelines(f"{k}: {val}\n")

# %%
def tva_run_scenarios_one_model_mets_locally(tmodel, name, condition, output_folder):
    "Writes metabolite TVA scenarios into one single mps.gz file"
    tmodel.m.Params.MIPGap = 0.001
    tmodel.m.Params.TimeLimit =  2000
    vars = []
    for i, met in enumerate(tmodel.metabolites):
        v = tmodel.mvars["ln_conc"][0][i]
        vars.append(v)
        print(f"Added {met.id} : { v }")

    gm = variability_analysis(tmodel, vars)
    gm.optimize()
    save_multiscenario_solutions(gm, output_folder, "ecoli_WT_Ace_mets")
    gm.write(f"{output_folder}{path.sep}{name}_{condition}_mets.sol")
   #gm.write(f"{output_folder}{path.sep}{name}_{condition}_mets.mps.gz")

# %%
def tfva_run_scenarios_one_model(tmodel, name, condition, output_folder):
    "Writes TFVA scenario files to the specified output folder, 1 file for each reaction"

    for rxn in tmodel.reactions:
        idx = tmodel.reactions.index(rxn)

        v_var = tmodel.mvars["v"][0][idx]
        gm = variability_analysis(tmodel, [v_var])

        gm.write(f"{output_folder}{path.sep}{idx}_{name}_{condition}_{rxn.id}.mps.gz")

# %%
def save_flux_bounds_tfva(tmodel, flux_objvals, output_file):
    "Save flux bounds from TFVA optimization and return a list of reaction IDs that were present in the input file"
    bounds = []
    with open(flux_objvals, "r") as f:
        for line in f:
            tokens = line.strip().split("\t")
            bounds.append( (tmodel.reactions[int(tokens[0])].id, float(tokens[1]), float(tokens[2])) )

    reaction_ids = [x[0] for x in bounds]

    df = pd.DataFrame(bounds, columns=["rxn", "lb", "ub"])
    df.to_csv(output_file)

    return reaction_ids

# %%
def save_flux_bounds_before_tfva(tmodel, reaction_ids, output_file):
    "Save flux bounds for a model before TFVA is applied using a list of reaction ids"

    bounds = []
    for r in reaction_ids:
        rxn = tmodel.reactions.get_by_id(r)

        bounds.append( (r, float(rxn.lower_bound), float(rxn.upper_bound)) )

    df = pd.DataFrame(bounds, columns=["rxn", "lb", "ub"])
    df.to_csv(output_file)

# %%
def save_flux_bounds_complete(tmodel, output_file):
    "Save all flux bounds for a model"

    bounds = []
    for r in tmodel.reactions:
        bounds.append( (r.id, float(r.lower_bound), float(r.upper_bound)) )

    df = pd.DataFrame(bounds, columns=["rxn", "lb", "ub"])
    df.to_csv(output_file)

# %%
def save_conc_bounds_linear(tmodel, output_file, conc_unit="millimolar"):
    bounds = []
    for m in tmodel.metabolites:
        bounds.append( (m.id, float(m.lower_bound.to(conc_unit).m), float(m.upper_bound.to(conc_unit).m)))

    df = pd.DataFrame(bounds, columns=["met", "lb", "ub"])
    df.to_csv(output_file)

# %%
def apply_fva_bounds(tmodel, fva_results):
    "Apply base FVA results to a model"

    for row in fva_results.itertuples():
        rxn_id = row[0]
        lb = row.minimum
        ub = row.maximum

        lb_clean, ub_clean = clean_fva_bounds(lb, ub)

        tmodel.reactions.get_by_id(rxn_id).upper_bound = ub_clean
        tmodel.reactions.get_by_id(rxn_id).lower_bound = lb_clean

# %%
def apply_tfva_bounds(tmodel, bounds_file):
    "Apply TFVA bounds to a model"
    df = pd.read_csv(bounds_file)
    #df.set_index("rxn", inplace=True)

    for row in df.itertuples():
        rxn_id = row.rxn
        lb = row.lb
        ub = row.ub

        print(f"{rxn_id}: {tmodel.reactions.get_by_id(rxn_id).lower_bound}, {tmodel.reactions.get_by_id(rxn_id).upper_bound} ---->  {lb}, {ub}")

        lb_clean, ub_clean = clean_fva_bounds(lb, ub)

        # Prevent cobra complaining when chaning the lb/ub 
        if ub_clean <= tmodel.reactions.get_by_id(rxn_id).lower_bound:
            tmodel.reactions.get_by_id(rxn_id).lower_bound = lb_clean
            tmodel.reactions.get_by_id(rxn_id).upper_bound = ub_clean
        else:
            tmodel.reactions.get_by_id(rxn_id).upper_bound = ub_clean
            tmodel.reactions.get_by_id(rxn_id).lower_bound = lb_clean

# %%
from cobra.flux_analysis import find_blocked_reactions

def setup_model(condition, mets_tva=None):
    "Setup the ecoli model given a condition for physiological data"
    tmodel = gen_model(MODEL_NAME, INPUT_MODEL, INPUT_KEGGS, INPUT_REED, INPUT_INCHI, INPUT_GAMS, "", True, True)
    tmodel = apply_metabolome_physio_data(tmodel, condition, INPUT_EXP_DATA, INPUT_EXP_CONC, INPUT_METABOLOMICS, INPUT_GAMS, RELAX_EXP_FLUX_BOUNDS, INCLUDE_CO2, INCLUDE_O2, allow_other_excr=False, output_log="", flux_limit=100)

    blocked = find_blocked_reactions(tmodel, open_exchanges=False, processes=1)

    tmodel.remove_reactions(blocked, remove_orphans=True)
    remove_orphan_metabolites(tmodel)

    for rxn in tmodel.reactions:
        thermo_flux.tools.drg_tools.reaction_balance(rxn, balance_charge=True, balance_mg=False)
    tmodel.update_thermo_info(fit_unknown_dfG0=True)

    #Set co2/o2 fluxes in correct directions
    tmodel.reactions.EX_co2.lower_bound = 0.0
    tmodel.reactions.EX_co2.upper_bound = 100.0
    
    tmodel.reactions.EX_o2.lower_bound = -100.0
    tmodel.reactions.EX_o2.upper_bound = 0.0

    # Apply results from metabolite TVA if present
    if mets_tva is not None:
        apply_met_tva(tmodel, mets_tva)
    
    return tmodel

# %%
# Create model for mets TVA
tmodel_glc = setup_model(CONDITIONS[0], mets_tva=None)
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2749904
# Academic license - for non-commercial use only - expires 2026-12-04
# ['Parameters', 'Exchange reactions', 'Reactions', 'Biomass Composition', 'Transmembrane reactions', 'Metabolites', 'references', 'Transmembrane_reactions_reed', 'Transmembrane reactions_Orth', 'Transmembrane reactions old', 'Sheet3', 'log', 'subsystems']
# *** Reading data from Reactions ***
# unknown metabolite '2dhglcn[c]' created
# unknown metabolite 'nadh[c]' created
# unknown metabolite 'glcn[c]' created
# unknown metabolite 'nad[c]' created
# unknown metabolite 'nadph[c]' created
# unknown metabolite 'nadp[c]' created
# unknown metabolite '2dhguln[c]' created
# unknown metabolite 'idon-L[c]' created
# unknown metabolite '3hcinnm[c]' created
# unknown metabolite 'o2[c]' created
# unknown metabolite 'dhcinnm[c]' created
# unknown metabolite 'h2o[c]' created
# unknown metabolite '3hpppn[c]' created
# unknown metabolite 'dhpppn[c]' created
# unknown metabolite 'phthr[c]' created
# unknown metabolite '4hthr[c]' created
# unknown metabolite 'pi[c]' created
# unknown metabolite '5dglcn[c]' created
# unknown metabolite 'ru5p-D[c]' created
# unknown metabolite 'ara5p[c]' created
# unknown metabolite 'ACP[c]' created
# unknown metabolite 'atp[c]' created
# unknown metabolite 'ttdca[c]' created
# unknown metabolite 'amp[c]' created
# unknown metabolite 'myrsACP[c]' created
# unknown metabolite 'ppi[c]' created
# unknown metabolite 'ttdcea[c]' created
# unknown metabolite 'tdeACP[c]' created
# unknown metabolite 'hdca[c]' created
# unknown metabolite 'palmACP[c]' created
# unknown metabolite 'hdcea[c]' created
# unknown metabolite 'hdeACP[c]' created
# unknown metabolite 'ocdcea[c]' created
# unknown metabolite 'octeACP[c]' created
# unknown metabolite 'dtdp4aaddg[c]' created
# unknown metabolite 'unagamu[c]' created
# unknown metabolite 'dtdp[c]' created
# unknown metabolite 'unagamuf[c]' created
# unknown metabolite 'arbt6p[c]' created
# unknown metabolite 'g6p[c]' created
# unknown metabolite 'hqn[c]' created
# unknown metabolite '4abut[c]' created
# unknown metabolite 'akg[c]' created
# unknown metabolite 'glu-L[c]' created
# unknown metabolite 'sucsal[c]' created
# unknown metabolite '4abutn[c]' created
# unknown metabolite 'acac[c]' created
# unknown metabolite 'accoa[c]' created
# unknown metabolite 'aacoa[c]' created
# unknown metabolite 'ac[c]' created
# unknown metabolite 'coa[c]' created
# unknown metabolite 'acald[c]' created
# unknown metabolite 'adocbip[c]' created
# unknown metabolite 'gtp[c]' created
# unknown metabolite 'agdpcbi[c]' created
# unknown metabolite 'co2tot[c]' created
# unknown metabolite 'adp[c]' created
# unknown metabolite 'malcoa[c]' created
# unknown metabolite 'ppa[c]' created
# unknown metabolite 'ppcoa[c]' created
# unknown metabolite 'uacgam[c]' created
# unknown metabolite 'udcpp[c]' created
# unknown metabolite 'ump[c]' created
# unknown metabolite 'unaga[c]' created
# unknown metabolite 'acglu[c]' created
# unknown metabolite 'acg5p[c]' created
# unknown metabolite '2obut[c]' created
# unknown metabolite 'pyr[c]' created
# unknown metabolite '2ahbut[c]' created
# unknown metabolite 'actp[c]' created
# unknown metabolite 'alac-S[c]' created
# unknown metabolite 'uacmamu[c]' created
# unknown metabolite 'udp[c]' created
# unknown metabolite 'acnam[c]' created
# unknown metabolite 'acmana[c]' created
# unknown metabolite 'acACP[c]' created
# unknown metabolite 'acorn[c]' created
# unknown metabolite 'orn[c]' created
# unknown metabolite 'acon-T[c]' created
# unknown metabolite 'amet[c]' created
# unknown metabolite 'aconm[c]' created
# unknown metabolite 'ahcys[c]' created
# unknown metabolite 'cit[c]' created
# unknown metabolite 'icit[c]' created
# unknown metabolite 'acg5sa[c]' created
# unknown metabolite 'apoACP[c]' created
# unknown metabolite 'pap[c]' created
# unknown metabolite 'adn[c]' created
# unknown metabolite 'ins[c]' created
# unknown metabolite 'nh3[c]' created
# unknown metabolite '4adcho[c]' created
# unknown metabolite '4abz[c]' created
# unknown metabolite 'chor[c]' created
# unknown metabolite 'gln-L[c]' created
# unknown metabolite 'ade[c]' created
# unknown metabolite 'hxan[c]' created
# unknown metabolite 'etoh[c]' created
# unknown metabolite 'gdp[c]' created
# unknown metabolite 'itp[c]' created
# unknown metabolite 'idp[c]' created
# unknown metabolite 'ametam[c]' created
# unknown metabolite 'camp[c]' created
# unknown metabolite 'adocbi[c]' created
# unknown metabolite 'rdmbzi[c]' created
# unknown metabolite 'adocbl[c]' created
# unknown metabolite 'gmp[c]' created
# unknown metabolite 'prpp[c]' created
# unknown metabolite 'aps[c]' created
# unknown metabolite 'paps[c]' created
# unknown metabolite 'dcamp[c]' created
# unknown metabolite 'fum[c]' created
# unknown metabolite '25aics[c]' created
# unknown metabolite 'aicar[c]' created
# unknown metabolite 'asp-L[c]' created
# unknown metabolite 'imp[c]' created
# unknown metabolite 'acgam6p[c]' created
# unknown metabolite 'gam6p[c]' created
# unknown metabolite 'adphep-DD[c]' created
# unknown metabolite 'adphep-LD[c]' created
# unknown metabolite 'agm[c]' created
# unknown metabolite 'ptrc[c]' created
# unknown metabolite 'urea[c]' created
# unknown metabolite 'hcys-L[c]' created
# unknown metabolite 'rhcys[c]' created
# unknown metabolite '10fthf[c]' created
# unknown metabolite 'fprica[c]' created
# unknown metabolite 'thf[c]' created
# unknown metabolite 'air[c]' created
# unknown metabolite '5caiz[c]' created
# unknown metabolite '5aizc[c]' created
# unknown metabolite 'ala-D[c]' created
# unknown metabolite 'alaala[c]' created
# unknown metabolite 'ala-L[c]' created
# unknown metabolite 'pydx5p[c]' created
# unknown metabolite 'pyam5p[c]' created
# unknown metabolite 'glyald[c]' created
# unknown metabolite 'glyc[c]' created
# unknown metabolite 'pacald[c]' created
# unknown metabolite 'pac[c]' created
# unknown metabolite 'alltt[c]' created
# unknown metabolite 'urdglyc[c]' created
# unknown metabolite 'alltn[c]' created
# unknown metabolite 'altrn[c]' created
# unknown metabolite '2ddglcn[c]' created
# unknown metabolite 'malt[c]' created
# unknown metabolite 'malttr[c]' created
# unknown metabolite 'glc-D[c]' created
# unknown metabolite 'maltttr[c]' created
# unknown metabolite 'maltpt[c]' created
# unknown metabolite 'malthx[c]' created
# unknown metabolite 'malthp[c]' created
# unknown metabolite 'acmanap[c]' created
# unknown metabolite '8aonn[c]' created
# unknown metabolite 'amob[c]' created
# unknown metabolite 'dann[c]' created
# unknown metabolite '2dmmq8[c]' created
# unknown metabolite 'mqn8[c]' created
# unknown metabolite '4ampm[c]' created
# unknown metabolite 'for[c]' created
# unknown metabolite 'r5p[c]' created
# unknown metabolite 'anth[c]' created
# unknown metabolite 'pran[c]' created
# unknown metabolite 'pmcoa[c]' created
# unknown metabolite 'ap4a[c]' created
# unknown metabolite 'ap5a[c]' created
# unknown metabolite '5apru[c]' created
# unknown metabolite '5aprbu[c]' created
# unknown metabolite 'arab-L[c]' created
# unknown metabolite 'rbl-L[c]' created
# unknown metabolite 'arg-L[c]' created
# unknown metabolite 'argsuc[c]' created
# unknown metabolite 'citr-L[c]' created
# unknown metabolite 'aspsa[c]' created
# unknown metabolite '4pasp[c]' created
# unknown metabolite 'asn-L[c]' created
# unknown metabolite 'ala-B[c]' created
# unknown metabolite 'cbp[c]' created
# unknown metabolite 'cbasp[c]' created
# unknown metabolite 'q8[c]' created
# unknown metabolite 'iasp[c]' created
# unknown metabolite 'q8h2[c]' created
# unknown metabolite 'mql8[c]' created
# unknown metabolite 'succ[c]' created
# unknown metabolite 'h2o2[c]' created
# unknown metabolite 'oaa[c]' created
# unknown metabolite 'succoa[c]' created
# unknown metabolite 'sucarg[c]' created
# unknown metabolite 'prbatp[c]' created
# unknown metabolite 'betald[c]' created
# unknown metabolite 'glyb[c]' created
# unknown metabolite 'btnso[c]' created
# unknown metabolite 'btn[c]' created
# unknown metabolite 'cys-L[c]' created
# unknown metabolite 'dtbt[c]' created
# unknown metabolite 'but[c]' created
# unknown metabolite 'btcoa[c]' created
# unknown metabolite 'actACP[c]' created
# unknown metabolite 'malACP[c]' created
# unknown metabolite 'ddcaACP[c]' created
# unknown metabolite 'cbi[c]' created
# unknown metabolite 'cbl1[c]' created
# unknown metabolite 'cdpdag1[c]' created
# unknown metabolite 'cmp[c]' created
# unknown metabolite 'paEC[c]' created
# unknown metabolite '4c2me[c]' created
# unknown metabolite '2p4c2me[c]' created
# unknown metabolite 'pphn[c]' created
# unknown metabolite '3psme[c]' created
# unknown metabolite '4hbz[c]' created
# unknown metabolite 'cinnm[c]' created
# unknown metabolite 'cenchddd[c]' created
# unknown metabolite 'pgEC[c]' created
# unknown metabolite 'clpnEC[c]' created
# unknown metabolite 'csn[c]' created
# unknown metabolite 'cpppg3[c]' created
# unknown metabolite 'pppg9[c]' created
# unknown metabolite 'bbtcoa[c]' created
# unknown metabolite 'crn[c]' created
# unknown metabolite 'crncoa[c]' created
# unknown metabolite 'gbbtn[c]' created
# unknown metabolite 'ctbtcoa[c]' created
# unknown metabolite 'ctbt[c]' created
# unknown metabolite 'ura[c]' created
# unknown metabolite 'utp[c]' created
# unknown metabolite 'ctp[c]' created
# unknown metabolite 'cyan[c]' created
# unknown metabolite 'tsul[c]' created
# unknown metabolite 'so3[c]' created
# unknown metabolite 'tcynt[c]' created
# unknown metabolite 'cynt[c]' created
# unknown metabolite 'acser[c]' created
# unknown metabolite 'h2s[c]' created
# unknown metabolite 'cyst-L[c]' created
# unknown metabolite 'cytd[c]' created
# unknown metabolite 'uri[c]' created
# unknown metabolite 'cdp[c]' created
# unknown metabolite 'dcmp[c]' created
# unknown metabolite 'dcdp[c]' created
# unknown metabolite 'fad[c]' created
# unknown metabolite 'fadh2[c]' created
# unknown metabolite 'dad-2[c]' created
# unknown metabolite 'din[c]' created
# unknown metabolite 'damp[c]' created
# unknown metabolite 'dadp[c]' created
# unknown metabolite '12dgrEC[c]' created
# unknown metabolite '26dap-M[c]' created
# unknown metabolite 'lys-L[c]' created
# unknown metabolite '26dap-LL[c]' created
# unknown metabolite 'db4p[c]' created
# unknown metabolite 'dctp[c]' created
# unknown metabolite 'dutp[c]' created
# unknown metabolite 'dcyt[c]' created
# unknown metabolite 'duri[c]' created
# unknown metabolite '2dh3dgal[c]' created
# unknown metabolite '2dh3dgal6p[c]' created
# unknown metabolite '2ddg6p[c]' created
# unknown metabolite 'e4p[c]' created
# unknown metabolite 'pep[c]' created
# unknown metabolite '2dda7p[c]' created
# unknown metabolite 'g3p[c]' created
# unknown metabolite 'dgmp[c]' created
# unknown metabolite 'dgdp[c]' created
# unknown metabolite '23dhmb[c]' created
# unknown metabolite '3mob[c]' created
# unknown metabolite '23dhmp[c]' created
# unknown metabolite '3mop[c]' created
# unknown metabolite 'dha[c]' created
# unknown metabolite 'dhap[c]' created
# unknown metabolite '23ddhb[c]' created
# unknown metabolite '23dhb[c]' created
# unknown metabolite '23dhba[c]' created
# unknown metabolite 'hkntd[c]' created
# unknown metabolite '23dhdp[c]' created
# unknown metabolite 'thdp[c]' created
# unknown metabolite 'dhf[c]' created
# unknown metabolite 'dhpt[c]' created
# unknown metabolite 'dhna[c]' created
# unknown metabolite 'octdp[c]' created
# unknown metabolite 'dhnpt[c]' created
# unknown metabolite '6hmhpt[c]' created
# unknown metabolite 'gcald[c]' created
# unknown metabolite 'dhor-S[c]' created
# unknown metabolite 'orot[c]' created
# unknown metabolite 'cechddd[c]' created
# unknown metabolite '25drapp[c]' created
# unknown metabolite '6hmhptpp[c]' created
# unknown metabolite 'dhptd[c]' created
# unknown metabolite 'hmfurn[c]' created
# unknown metabolite '3dhq[c]' created
# unknown metabolite '3dhsk[c]' created
# unknown metabolite '25dkglcn[c]' created
# unknown metabolite 'dkmpp[c]' created
# unknown metabolite '2kmb[c]' created
# unknown metabolite 'dmpp[c]' created
# unknown metabolite 'ipdp[c]' created
# unknown metabolite 'grdp[c]' created
# unknown metabolite 'h2mb4p[c]' created
# unknown metabolite '2omhmbl[c]' created
# unknown metabolite 'dmso[c]' created
# unknown metabolite 'dms[c]' created
# unknown metabolite '2dmmql8[c]' created
# unknown metabolite 'dhpmp[c]' created
# unknown metabolite 'ahdt[c]' created
# unknown metabolite '23doguln[c]' created
# unknown metabolite '3dhguln[c]' created
# unknown metabolite 'dpcoa[c]' created
# unknown metabolite '2dhp[c]' created
# unknown metabolite 'pant-R[c]' created
# unknown metabolite '2dr5p[c]' created
# unknown metabolite 'dtmp[c]' created
# unknown metabolite 'dump[c]' created
# unknown metabolite '2dr1p[c]' created
# unknown metabolite 'dxyl5p[c]' created
# unknown metabolite '2me4p[c]' created
# unknown metabolite 'dxyl[c]' created
# unknown metabolite '4per[c]' created
# unknown metabolite 'ecaEC[c]' created
# unknown metabolite 'udcpdp[c]' created
# unknown metabolite '6pgc[c]' created
# unknown metabolite 'kdo2lipid4[c]' created
# unknown metabolite 'kdo2lipid4L[c]' created
# unknown metabolite 'lipa[c]' created
# unknown metabolite 'kdo2lipid4p[c]' created
# unknown metabolite 'lipa_cold[c]' created
# unknown metabolite '2pg[c]' created
# unknown metabolite 'seramp[c]' created
# unknown metabolite 'enter[c]' created
# unknown metabolite 'etha[c]' created
# unknown metabolite 'f6p[c]' created
# unknown metabolite 'ocdca[c]' created
# unknown metabolite 'fdp[c]' created
# unknown metabolite 'fuc-L[c]' created
# unknown metabolite 'fcl-L[c]' created
# unknown metabolite 'fc1p[c]' created
# unknown metabolite 'lald-L[c]' created
# unknown metabolite 'fe2[c]' created
# unknown metabolite 'ppp9[c]' created
# unknown metabolite 'pheme[c]' created
# unknown metabolite 'suc6p[c]' created
# unknown metabolite 'fru[c]' created
# unknown metabolite 'h2[c]' created
# unknown metabolite 'fmn[c]' created
# unknown metabolite 'f1p[c]' created
# unknown metabolite 'mal-L[c]' created
# unknown metabolite 'gam1p[c]' created
# unknown metabolite 'acgam1p[c]' created
# unknown metabolite 'g1p[c]' created
# unknown metabolite 'dttp[c]' created
# unknown metabolite 'dtdpglu[c]' created
# unknown metabolite 'glu1sa[c]' created
# unknown metabolite '5aop[c]' created
# unknown metabolite 'glyc3p[c]' created
# unknown metabolite 'glu5sa[c]' created
# unknown metabolite '1pyr5c[c]' created
# unknown metabolite 'glu5p[c]' created
# unknown metabolite '6pgl[c]' created
# unknown metabolite 'galct-D[c]' created
# unknown metabolite '5dh4dglc[c]' created
# unknown metabolite 'galctn-D[c]' created
# unknown metabolite 'gal[c]' created
# unknown metabolite 'gal1p[c]' created
# unknown metabolite 'melib[c]' created
# unknown metabolite 'udpg[c]' created
# unknown metabolite '13dpg[c]' created
# unknown metabolite 'gar[c]' created
# unknown metabolite 'fgam[c]' created
# unknown metabolite 'glyclt[c]' created
# unknown metabolite 'gdpddman[c]' created
# unknown metabolite 'gdpofuc[c]' created
# unknown metabolite 'ser-L[c]' created
# unknown metabolite 'gly[c]' created
# unknown metabolite 'mlthf[c]' created
# unknown metabolite 'glycogen[c]' created
# unknown metabolite '2h3oppan[c]' created
# unknown metabolite 'glcr[c]' created
# unknown metabolite 'adpglc[c]' created
# unknown metabolite 'galt1p[c]' created
# unknown metabolite 'tag6p-D[c]' created
# unknown metabolite 'glucys[c]' created
# unknown metabolite 'pram[c]' created
# unknown metabolite 'glu-D[c]' created
# unknown metabolite 'glutrna[c]' created
# unknown metabolite 'trnaglu[c]' created
# unknown metabolite 'glx[c]' created
# unknown metabolite '2aobut[c]' created
# unknown metabolite 'glyc-R[c]' created
# unknown metabolite '3pg[c]' created
# unknown metabolite 'lgt-S[c]' created
# unknown metabolite 'gthrd[c]' created
# unknown metabolite 'lac-D[c]' created
# unknown metabolite 'gdpmann[c]' created
# unknown metabolite 'gmhep1p[c]' created
# unknown metabolite 'gmhep7p[c]' created
# unknown metabolite 'gmhep17bp[c]' created
# unknown metabolite 'xmp[c]' created
# unknown metabolite 'gdpfuc[c]' created
# unknown metabolite 'gp4g[c]' created
# unknown metabolite 'g3pc[c]' created
# unknown metabolite 'chol[c]' created
# unknown metabolite 'g3pe[c]' created
# unknown metabolite 'g3ps[c]' created
# unknown metabolite 'g3pg[c]' created
# unknown metabolite 'g3pi[c]' created
# unknown metabolite 'inost[c]' created
# unknown metabolite 'frdp[c]' created
# unknown metabolite 'gsn[c]' created
# unknown metabolite 'gtspmd[c]' created
# unknown metabolite 'spmd[c]' created
# unknown metabolite 'gthox[c]' created
# unknown metabolite 'gua[c]' created
# unknown metabolite 'xan[c]' created
# unknown metabolite 'glcur[c]' created
# unknown metabolite 'fruur[c]' created
# unknown metabolite 'galur[c]' created
# unknown metabolite 'tagur[c]' created
# unknown metabolite '3ophb[c]' created
# unknown metabolite 'hemeO[c]' created
# unknown metabolite '4mhetz[c]' created
# unknown metabolite '4mpetz[c]' created
# unknown metabolite 'histd[c]' created
# unknown metabolite 'his-L[c]' created
# unknown metabolite 'hisp[c]' created
# unknown metabolite 'hkndd[c]' created
# unknown metabolite 'op4en[c]' created
# unknown metabolite 'ppbng[c]' created
# unknown metabolite 'hmbil[c]' created
# unknown metabolite '4ahmmp[c]' created
# unknown metabolite '4h2opntn[c]' created
# unknown metabolite 'hpyr[c]' created
# unknown metabolite 'hom-L[c]' created
# unknown metabolite 'phom[c]' created
# unknown metabolite 'suchms[c]' created
# unknown metabolite 'imacp[c]' created
# unknown metabolite 'pydam[c]' created
# unknown metabolite 'ichor[c]' created
# unknown metabolite 'prlp[c]' created
# unknown metabolite 'eig3p[c]' created
# unknown metabolite '2cpr5p[c]' created
# unknown metabolite '3ig3p[c]' created
# unknown metabolite 'ile-L[c]' created
# unknown metabolite '3c2hmp[c]' created
# unknown metabolite '3c4mop[c]' created
# unknown metabolite '2ippm[c]' created
# unknown metabolite '3c3hmp[c]' created
# unknown metabolite '3hmrsACP[c]' created
# unknown metabolite 'kdo[c]' created
# unknown metabolite 'ckdo[c]' created
# unknown metabolite 'kdo8p[c]' created
# unknown metabolite '3dhgulnp[c]' created
# unknown metabolite 'xu5p-L[c]' created
# unknown metabolite 'lcts[c]' created
# unknown metabolite 'lac-L[c]' created
# unknown metabolite '12ppd-S[c]' created
# unknown metabolite '4mop[c]' created
# unknown metabolite 'leu-L[c]' created
# unknown metabolite 'mthgxl[c]' created
# unknown metabolite 'lipidX[c]' created
# unknown metabolite 'u23ga[c]' created
# unknown metabolite 'lipidAds[c]' created
# unknown metabolite 'agpgEC[c]' created
# unknown metabolite 'agpeEC[c]' created
# unknown metabolite 'agpcEC[c]' created
# unknown metabolite 'apgEC[c]' created
# unknown metabolite 'cdpea[c]' created
# unknown metabolite 'lpsEC[c]' created
# unknown metabolite '15dap[c]' created
# unknown metabolite 'mnl1p[c]' created
# unknown metabolite 'man1p[c]' created
# unknown metabolite 'man6p[c]' created
# unknown metabolite 'mana[c]' created
# unknown metabolite '2mcit[c]' created
# unknown metabolite '2mcacn[c]' created
# unknown metabolite 'micit[c]' created
# unknown metabolite '5mdru1p[c]' created
# unknown metabolite '2mecdp[c]' created
# unknown metabolite 'met-L[c]' created
# unknown metabolite '5mthf[c]' created
# unknown metabolite 'mi1p-D[c]' created
# unknown metabolite 'mmcoa-S[c]' created
# unknown metabolite 'mmcoa-R[c]' created
# unknown metabolite 'lipidA[c]' created
# unknown metabolite 'kdolipid4[c]' created
# unknown metabolite '5mta[c]' created
# unknown metabolite '5mtr[c]' created
# unknown metabolite 'methf[c]' created
# unknown metabolite '5mdr1p[c]' created
# unknown metabolite 'nmn[c]' created
# unknown metabolite 'h2o[e]' created
# unknown metabolite 'nad[e]' created
# unknown metabolite 'amp[e]' created
# unknown metabolite 'nmn[e]' created
# unknown metabolite 'dnad[c]' created
# unknown metabolite 'nac[c]' created
# unknown metabolite 'nicrnt[c]' created
# unknown metabolite 'dgtp[c]' created
# unknown metabolite 'dudp[c]' created
# unknown metabolite 'datp[c]' created
# unknown metabolite 'ncam[c]' created
# unknown metabolite 'dmbzid[c]' created
# unknown metabolite '5prdmbz[c]' created
# unknown metabolite 'quln[c]' created
# unknown metabolite 'sbzcoa[c]' created
# unknown metabolite 'xtsn[c]' created
# unknown metabolite 'thymd[c]' created
# unknown metabolite 'dgsn[c]' created
# unknown metabolite 'pppi[c]' created
# unknown metabolite 'no2[c]' created
# unknown metabolite 'ohpb[c]' created
# unknown metabolite '2ohph[c]' created
# unknown metabolite '2omph[c]' created
# unknown metabolite '2ombzl[c]' created
# unknown metabolite '2ommbl[c]' created
# unknown metabolite 'orot5p[c]' created
# unknown metabolite '2oph[c]' created
# unknown metabolite 'thmpp[c]' created
# unknown metabolite 'ssaltpp[c]' created
# unknown metabolite 'pro-L[c]' created
# unknown metabolite 'phaccoa[c]' created
# unknown metabolite 'pnto-R[c]' created
# unknown metabolite 'ugmda[c]' created
# unknown metabolite 'uagmda[c]' created
# unknown metabolite 'trdrd[c]' created
# unknown metabolite 'trdox[c]' created
# unknown metabolite 'pdx5p[c]' created
# unknown metabolite 'pydxn[c]' created
# unknown metabolite 'peamn[c]' created
# unknown metabolite 'peEC[c]' created
# unknown metabolite 'tagdp-D[c]' created
# unknown metabolite '3php[c]' created
# unknown metabolite '2pglyc[c]' created
# unknown metabolite 'pgpEC[c]' created
# unknown metabolite 'phe-L[c]' created
# unknown metabolite 'phpyr[c]' created
# unknown metabolite 'pcEC[c]' created
# unknown metabolite '4r5au[c]' created
# unknown metabolite '2mahmp[c]' created
# unknown metabolite '4ppan[c]' created
# unknown metabolite 'ppap[c]' created
# unknown metabolite '4ppcys[c]' created
# unknown metabolite 'pan4p[c]' created
# unknown metabolite 'r1p[c]' created
# unknown metabolite '34hpp[c]' created
# unknown metabolite 'pppn[c]' created
# unknown metabolite 'uaagmda[c]' created
# unknown metabolite 'peptidoEC[c]' created
# unknown metabolite 'fpram[c]' created
# unknown metabolite 'prbamp[c]' created
# unknown metabolite 'prfp[c]' created
# unknown metabolite 'skm5p[c]' created
# unknown metabolite 'psEC[c]' created
# unknown metabolite 'pser-L[c]' created
# unknown metabolite 'pydx[c]' created
# unknown metabolite 'ribflv[c]' created
# unknown metabolite 'dmlz[c]' created
# unknown metabolite 'rib-D[c]' created
# unknown metabolite 'ru5p-L[c]' created
# unknown metabolite 'xu5p-D[c]' created
# unknown metabolite 'rmn[c]' created
# unknown metabolite 'rml[c]' created
# unknown metabolite 'rml1p[c]' created
# unknown metabolite 's7p[c]' created
# unknown metabolite 'sucorn[c]' created
# unknown metabolite 'so4[c]' created
# unknown metabolite 'sbt6p[c]' created
# unknown metabolite 'sl26da[c]' created
# unknown metabolite 'sl2a6o[c]' created
# unknown metabolite 'seln[c]' created
# unknown metabolite 'selnp[c]' created
# unknown metabolite 'ser-D[c]' created
# unknown metabolite 'sucglu[c]' created
# unknown metabolite 'sucgsa[c]' created
# unknown metabolite '2shchc[c]' created
# unknown metabolite 'scl[c]' created
# unknown metabolite 'srch[c]' created
# unknown metabolite 'sheme[c]' created
# unknown metabolite 'skm[c]' created
# unknown metabolite 'N1aspmd[c]' created
# unknown metabolite 'n8aspmd[c]' created
# unknown metabolite 'o2s[c]' created
# unknown metabolite 'sucbz[c]' created
# unknown metabolite 'tartr-L[c]' created
# unknown metabolite 'taur[c]' created
# unknown metabolite 'aacald[c]' created
# unknown metabolite 'dtdp4addg[c]' created
# unknown metabolite 'dtdp4d6dg[c]' created
# unknown metabolite 'dtdp4d6dm[c]' created
# unknown metabolite 'dtdprmn[c]' created
# unknown metabolite 'thr-L[c]' created
# unknown metabolite 'tyr-L[c]' created
# unknown metabolite '4hba[c]' created
# unknown metabolite 'tmao[c]' created
# unknown metabolite 'tma[c]' created
# unknown metabolite 'thym[c]' created
# unknown metabolite 'thm[c]' created
# unknown metabolite 'thmmp[c]' created
# unknown metabolite 'tre6p[c]' created
# unknown metabolite 'tre[c]' created
# unknown metabolite 'tre[e]' created
# unknown metabolite 'glc-D[e]' created
# unknown metabolite 'trp-L[c]' created
# unknown metabolite 'indole[c]' created
# unknown metabolite 'u3hga[c]' created
# unknown metabolite 'uamag[c]' created
# unknown metabolite 'ugmd[c]' created
# unknown metabolite 'uacmam[c]' created
# unknown metabolite 'u3aga[c]' created
# unknown metabolite 'uaccg[c]' created
# unknown metabolite 'uama[c]' created
# unknown metabolite 'uamr[c]' created
# unknown metabolite 'udpgal[c]' created
# unknown metabolite 'udpgalfur[c]' created
# unknown metabolite 'udpglcur[c]' created
# unknown metabolite 'uppg3[c]' created
# unknown metabolite 'val-L[c]' created
# unknown metabolite 'xyl-D[c]' created
# unknown metabolite 'xylu-D[c]' created
# *** Reading data from Biomass Composition ***
# *** Reading data from Exchange reactions ***
# unknown metabolite '12ppd-S[e]' created
# unknown metabolite '15dap[e]' created
# unknown metabolite '26dap-M[e]' created
# unknown metabolite '2ddglcn[e]' created
# unknown metabolite '3hcinnm[e]' created
# unknown metabolite '3hpppn[e]' created
# unknown metabolite '4abut[e]' created
# unknown metabolite 'ac[e]' created
# unknown metabolite 'acac[e]' created
# unknown metabolite 'acald[e]' created
# unknown metabolite 'acgam[e]' created
# unknown metabolite 'acmana[e]' created
# unknown metabolite 'acnam[e]' created
# unknown metabolite 'ade[e]' created
# unknown metabolite 'adn[e]' created
# unknown metabolite 'akg[e]' created
# unknown metabolite 'ala-D[e]' created
# unknown metabolite 'ala-L[e]' created
# unknown metabolite 'alltn[e]' created
# unknown metabolite 'arab-L[e]' created
# unknown metabolite 'arg-L[e]' created
# unknown metabolite 'asn-L[e]' created
# unknown metabolite 'asp-L[e]' created
# unknown metabolite 'but[e]' created
# unknown metabolite 'charge[e]' created
# unknown metabolite 'cbl1[e]' created
# unknown metabolite 'chol[e]' created
# unknown metabolite 'cit[e]' created
# unknown metabolite 'co2tot[e]' created
# unknown metabolite 'crn[e]' created
# unknown metabolite 'csn[e]' created
# unknown metabolite 'cynt[e]' created
# unknown metabolite 'cys-L[e]' created
# unknown metabolite 'cytd[e]' created
# unknown metabolite 'dad-2[e]' created
# unknown metabolite 'dcyt[e]' created
# unknown metabolite 'dgsn[e]' created
# unknown metabolite 'dha[e]' created
# unknown metabolite 'din[e]' created
# unknown metabolite 'dms[e]' created
# unknown metabolite 'dmso[e]' created
# unknown metabolite 'duri[e]' created
# unknown metabolite 'etoh[e]' created
# unknown metabolite 'fe2[e]' created
# unknown metabolite 'for[e]' created
# unknown metabolite 'fru[e]' created
# unknown metabolite 'fuc1p-L[e]' created
# unknown metabolite 'fuc-L[e]' created
# unknown metabolite 'fum[e]' created
# unknown metabolite 'g6p[e]' created
# unknown metabolite 'gal[e]' created
# unknown metabolite 'galct-D[e]' created
# unknown metabolite 'galctn-D[e]' created
# unknown metabolite 'galt[e]' created
# unknown metabolite 'galur[e]' created
# unknown metabolite 'gam[e]' created
# unknown metabolite 'gbbtn[e]' created
# unknown metabolite 'glcn[e]' created
# unknown metabolite 'glcr[e]' created
# unknown metabolite 'glcur[e]' created
# unknown metabolite 'gln-L[e]' created
# unknown metabolite 'glu-L[e]' created
# unknown metabolite 'gly[e]' created
# unknown metabolite 'glyald[e]' created
# unknown metabolite 'glyb[e]' created
# unknown metabolite 'glyc[e]' created
# unknown metabolite 'glyc3p[e]' created
# unknown metabolite 'glyclt[e]' created
# unknown metabolite 'gsn[e]' created
# unknown metabolite 'gua[e]' created
# unknown metabolite 'h[e]' created
# unknown metabolite 'hdca[e]' created
# unknown metabolite 'his-L[e]' created
# unknown metabolite 'hxan[e]' created
# unknown metabolite 'idon-L[e]' created
# unknown metabolite 'ile-L[e]' created
# unknown metabolite 'indole[e]' created
# unknown metabolite 'ins[e]' created
# unknown metabolite 'k[e]' created
# unknown metabolite 'lac-D[e]' created
# unknown metabolite 'lac-L[e]' created
# unknown metabolite 'lcts[e]' created
# unknown metabolite 'leu-L[e]' created
# unknown metabolite 'lys-L[e]' created
# unknown metabolite 'mal-L[e]' created
# unknown metabolite 'malt[e]' created
# unknown metabolite 'malthx[e]' created
# unknown metabolite 'maltpt[e]' created
# unknown metabolite 'malttr[e]' created
# unknown metabolite 'maltttr[e]' created
# unknown metabolite 'man[e]' created
# unknown metabolite 'man6p[e]' created
# unknown metabolite 'melib[e]' created
# unknown metabolite 'met-D[e]' created
# unknown metabolite 'met-L[e]' created
# unknown metabolite 'mnl[e]' created
# unknown metabolite 'na1[e]' created
# unknown metabolite 'nac[e]' created
# unknown metabolite 'nh3[e]' created
# unknown metabolite 'no2[e]' created
# unknown metabolite 'no3[e]' created
# unknown metabolite 'o2[e]' created
# unknown metabolite 'ocdca[e]' created
# unknown metabolite 'orn[e]' created
# unknown metabolite 'phe-L[e]' created
# unknown metabolite 'pi[e]' created
# unknown metabolite 'pnto-R[e]' created
# unknown metabolite 'pppn[e]' created
# unknown metabolite 'pro-L[e]' created
# unknown metabolite 'ptrc[e]' created
# unknown metabolite 'pyr[e]' created
# unknown metabolite 'rib-D[e]' created
# unknown metabolite 'rmn[e]' created
# unknown metabolite 'sbt-D[e]' created
# unknown metabolite 'ser-D[e]' created
# unknown metabolite 'ser-L[e]' created
# unknown metabolite 'so4[e]' created
# unknown metabolite 'spmd[e]' created
# unknown metabolite 'succ[e]' created
# unknown metabolite 'sucr[e]' created
# unknown metabolite 'tartr-L[e]' created
# unknown metabolite 'taur[e]' created
# unknown metabolite 'thm[e]' created
# unknown metabolite 'thr-L[e]' created
# unknown metabolite 'thymd[e]' created
# unknown metabolite 'tma[e]' created
# unknown metabolite 'tmao[e]' created
# unknown metabolite 'trp-L[e]' created
# unknown metabolite 'tsul[e]' created
# unknown metabolite 'ttdca[e]' created
# unknown metabolite 'tyr-L[e]' created
# unknown metabolite 'ura[e]' created
# unknown metabolite 'urea[e]' created
# unknown metabolite 'uri[e]' created
# unknown metabolite 'val-L[e]' created
# unknown metabolite 'xan[e]' created
# unknown metabolite 'xtsn[e]' created
# unknown metabolite 'xyl-D[e]' created
# *** Reading data from Transmembrane reactions ***
# unknown metabolite 'h[c]' created
# unknown metabolite 'acgam[c]' created
# unknown metabolite 'charge[c]' created
# unknown metabolite 'electron[c]' created
# unknown metabolite 'electron[e]' created
# unknown metabolite 'fuc1p-L[c]' created
# unknown metabolite 'galt[c]' created
# unknown metabolite 'gam[c]' created
# unknown metabolite 'na1[c]' created
# unknown metabolite 'h2[e]' created
# unknown metabolite 'k[c]' created
# unknown metabolite 'malt6p[c]' created
# unknown metabolite 'man[c]' created
# unknown metabolite 'met-D[c]' created
# unknown metabolite 'mnl[c]' created
# unknown metabolite 'no3[c]' created
# unknown metabolite 'sbt-D[c]' created
# unknown metabolite 'sucr[c]' created
# *** Reading data from Parameters ***
# *** Reading data from Metabolites ***
# Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# *** Updating metabolite information ***
# 2dhglcn_c NOTHING DONE!
# nadh_c NOTHING DONE!
# glcn_c NOTHING DONE!
# nad_c NOTHING DONE!
# nadph_c NOTHING DONE!
# nadp_c NOTHING DONE!
# 2dhguln_c NOTHING DONE!
# idon-L_c NOTHING DONE!
# 3hcinnm_c NOTHING DONE!
# o2_c NOTHING DONE!
# dhcinnm_c NOTHING DONE!
# h2o_c NOTHING DONE!
# 3hpppn_c NOTHING DONE!
# dhpppn_c NOTHING DONE!
# phthr_c NOTHING DONE!
# 4hthr_c NOTHING DONE!
# pi_c NOTHING DONE!
# 5dglcn_c NOTHING DONE!
# ru5p-D_c NOTHING DONE!
# ara5p_c NOTHING DONE!
# ACP_c NOTHING DONE!
# atp_c NOTHING DONE!
# ttdca_c NOTHING DONE!
# amp_c NOTHING DONE!
# myrsACP_c NOTHING DONE!
# ppi_c NOTHING DONE!
# ttdcea_c NOTHING DONE!
# tdeACP_c NOTHING DONE!
# hdca_c NOTHING DONE!
# palmACP_c NOTHING DONE!
# hdcea_c NOTHING DONE!
# hdeACP_c NOTHING DONE!
# ocdcea_c NOTHING DONE!
# octeACP_c NOTHING DONE!
# dtdp4aaddg_c NOTHING DONE!
# unagamu_c NOTHING DONE!
# dtdp_c NOTHING DONE!
# unagamuf_c NOTHING DONE!
# arbt6p_c NOTHING DONE!
# g6p_c NOTHING DONE!
# hqn_c NOTHING DONE!
# 4abut_c NOTHING DONE!
# akg_c NOTHING DONE!
# glu-L_c NOTHING DONE!
# sucsal_c NOTHING DONE!
# 4abutn_c NOTHING DONE!
# acac_c NOTHING DONE!
# accoa_c NOTHING DONE!
# aacoa_c NOTHING DONE!
# ac_c NOTHING DONE!
# coa_c NOTHING DONE!
# acald_c NOTHING DONE!
# adocbip_c NOTHING DONE!
# gtp_c NOTHING DONE!
# agdpcbi_c NOTHING DONE!
# co2tot_c NOTHING DONE!
# adp_c NOTHING DONE!
# malcoa_c NOTHING DONE!
# ppa_c NOTHING DONE!
# ppcoa_c NOTHING DONE!
# uacgam_c NOTHING DONE!
# udcpp_c NOTHING DONE!
# ump_c NOTHING DONE!
# unaga_c NOTHING DONE!
# acglu_c NOTHING DONE!
# acg5p_c NOTHING DONE!
# 2obut_c NOTHING DONE!
# pyr_c NOTHING DONE!
# 2ahbut_c NOTHING DONE!
# actp_c NOTHING DONE!
# alac-S_c NOTHING DONE!
# uacmamu_c NOTHING DONE!
# udp_c NOTHING DONE!
# acnam_c NOTHING DONE!
# acmana_c NOTHING DONE!
# acACP_c NOTHING DONE!
# acorn_c NOTHING DONE!
# orn_c NOTHING DONE!
# acon-T_c NOTHING DONE!
# amet_c NOTHING DONE!
# aconm_c NOTHING DONE!
# ahcys_c NOTHING DONE!
# cit_c NOTHING DONE!
# icit_c NOTHING DONE!
# acg5sa_c NOTHING DONE!
# apoACP_c NOTHING DONE!
# pap_c NOTHING DONE!
# adn_c NOTHING DONE!
# ins_c NOTHING DONE!
# nh3_c NOTHING DONE!
# 4adcho_c NOTHING DONE!
# 4abz_c NOTHING DONE!
# chor_c NOTHING DONE!
# gln-L_c NOTHING DONE!
# ade_c NOTHING DONE!
# hxan_c NOTHING DONE!
# etoh_c NOTHING DONE!
# gdp_c NOTHING DONE!
# itp_c NOTHING DONE!
# idp_c NOTHING DONE!
# ametam_c NOTHING DONE!
# camp_c NOTHING DONE!
# adocbi_c NOTHING DONE!
# rdmbzi_c NOTHING DONE!
# adocbl_c NOTHING DONE!
# gmp_c NOTHING DONE!
# prpp_c NOTHING DONE!
# aps_c NOTHING DONE!
# paps_c NOTHING DONE!
# dcamp_c NOTHING DONE!
# fum_c NOTHING DONE!
# 25aics_c NOTHING DONE!
# aicar_c NOTHING DONE!
# asp-L_c NOTHING DONE!
# imp_c NOTHING DONE!
# acgam6p_c NOTHING DONE!
# gam6p_c NOTHING DONE!
# adphep-DD_c NOTHING DONE!
# adphep-LD_c NOTHING DONE!
# agm_c NOTHING DONE!
# ptrc_c NOTHING DONE!
# urea_c NOTHING DONE!
# hcys-L_c NOTHING DONE!
# rhcys_c NOTHING DONE!
# 10fthf_c NOTHING DONE!
# fprica_c NOTHING DONE!
# thf_c NOTHING DONE!
# air_c NOTHING DONE!
# 5caiz_c NOTHING DONE!
# 5aizc_c NOTHING DONE!
# ala-D_c NOTHING DONE!
# alaala_c NOTHING DONE!
# ala-L_c NOTHING DONE!
# pydx5p_c NOTHING DONE!
# pyam5p_c NOTHING DONE!
# glyald_c NOTHING DONE!
# glyc_c NOTHING DONE!
# pacald_c NOTHING DONE!
# pac_c NOTHING DONE!
# alltt_c NOTHING DONE!
# urdglyc_c NOTHING DONE!
# alltn_c NOTHING DONE!
# altrn_c NOTHING DONE!
# 2ddglcn_c NOTHING DONE!
# malt_c NOTHING DONE!
# malttr_c NOTHING DONE!
# glc-D_c NOTHING DONE!
# maltttr_c NOTHING DONE!
# maltpt_c NOTHING DONE!
# malthx_c NOTHING DONE!
# malthp_c NOTHING DONE!
# acmanap_c NOTHING DONE!
# 8aonn_c NOTHING DONE!
# amob_c NOTHING DONE!
# dann_c NOTHING DONE!
# 2dmmq8_c NOTHING DONE!
# mqn8_c NOTHING DONE!
# 4ampm_c NOTHING DONE!
# for_c NOTHING DONE!
# r5p_c NOTHING DONE!
# anth_c NOTHING DONE!
# pran_c NOTHING DONE!
# pmcoa_c NOTHING DONE!
# ap4a_c NOTHING DONE!
# ap5a_c NOTHING DONE!
# 5apru_c NOTHING DONE!
# 5aprbu_c NOTHING DONE!
# arab-L_c NOTHING DONE!
# rbl-L_c NOTHING DONE!
# arg-L_c NOTHING DONE!
# argsuc_c NOTHING DONE!
# citr-L_c NOTHING DONE!
# aspsa_c NOTHING DONE!
# 4pasp_c NOTHING DONE!
# asn-L_c NOTHING DONE!
# ala-B_c NOTHING DONE!
# cbp_c NOTHING DONE!
# cbasp_c NOTHING DONE!
# q8_c NOTHING DONE!
# iasp_c NOTHING DONE!
# q8h2_c NOTHING DONE!
# mql8_c NOTHING DONE!
# succ_c NOTHING DONE!
# h2o2_c NOTHING DONE!
# oaa_c NOTHING DONE!
# succoa_c NOTHING DONE!
# sucarg_c NOTHING DONE!
# prbatp_c NOTHING DONE!
# betald_c NOTHING DONE!
# glyb_c NOTHING DONE!
# btnso_c NOTHING DONE!
# btn_c NOTHING DONE!
# cys-L_c NOTHING DONE!
# dtbt_c NOTHING DONE!
# but_c NOTHING DONE!
# btcoa_c NOTHING DONE!
# actACP_c NOTHING DONE!
# malACP_c NOTHING DONE!
# ddcaACP_c NOTHING DONE!
# cbi_c NOTHING DONE!
# cbl1_c NOTHING DONE!
# cdpdag1_c NOTHING DONE!
# cmp_c NOTHING DONE!
# paEC_c NOTHING DONE!
# 4c2me_c NOTHING DONE!
# 2p4c2me_c NOTHING DONE!
# pphn_c NOTHING DONE!
# 3psme_c NOTHING DONE!
# 4hbz_c NOTHING DONE!
# cinnm_c NOTHING DONE!
# cenchddd_c NOTHING DONE!
# pgEC_c NOTHING DONE!
# clpnEC_c NOTHING DONE!
# csn_c NOTHING DONE!
# cpppg3_c NOTHING DONE!
# pppg9_c NOTHING DONE!
# bbtcoa_c NOTHING DONE!
# crn_c NOTHING DONE!
# crncoa_c NOTHING DONE!
# gbbtn_c NOTHING DONE!
# ctbtcoa_c NOTHING DONE!
# ctbt_c NOTHING DONE!
# ura_c NOTHING DONE!
# utp_c NOTHING DONE!
# ctp_c NOTHING DONE!
# cyan_c NOTHING DONE!
# tsul_c NOTHING DONE!
# so3_c NOTHING DONE!
# tcynt_c NOTHING DONE!
# cynt_c NOTHING DONE!
# acser_c NOTHING DONE!
# h2s_c NOTHING DONE!
# cyst-L_c NOTHING DONE!
# cytd_c NOTHING DONE!
# uri_c NOTHING DONE!
# cdp_c NOTHING DONE!
# dcmp_c NOTHING DONE!
# dcdp_c NOTHING DONE!
# fad_c NOTHING DONE!
# fadh2_c NOTHING DONE!
# dad-2_c NOTHING DONE!
# din_c NOTHING DONE!
# damp_c NOTHING DONE!
# dadp_c NOTHING DONE!
# 12dgrEC_c NOTHING DONE!
# 26dap-M_c NOTHING DONE!
# lys-L_c NOTHING DONE!
# 26dap-LL_c NOTHING DONE!
# db4p_c NOTHING DONE!
# dctp_c NOTHING DONE!
# dutp_c NOTHING DONE!
# dcyt_c NOTHING DONE!
# duri_c NOTHING DONE!
# 2dh3dgal_c NOTHING DONE!
# 2dh3dgal6p_c NOTHING DONE!
# 2ddg6p_c NOTHING DONE!
# e4p_c NOTHING DONE!
# pep_c NOTHING DONE!
# 2dda7p_c NOTHING DONE!
# g3p_c NOTHING DONE!
# dgmp_c NOTHING DONE!
# dgdp_c NOTHING DONE!
# 23dhmb_c NOTHING DONE!
# 3mob_c NOTHING DONE!
# 23dhmp_c NOTHING DONE!
# 3mop_c NOTHING DONE!
# dha_c NOTHING DONE!
# dhap_c NOTHING DONE!
# 23ddhb_c NOTHING DONE!
# 23dhb_c NOTHING DONE!
# 23dhba_c NOTHING DONE!
# hkntd_c NOTHING DONE!
# 23dhdp_c NOTHING DONE!
# thdp_c NOTHING DONE!
# dhf_c NOTHING DONE!
# dhpt_c NOTHING DONE!
# dhna_c NOTHING DONE!
# octdp_c NOTHING DONE!
# dhnpt_c NOTHING DONE!
# 6hmhpt_c NOTHING DONE!
# gcald_c NOTHING DONE!
# dhor-S_c NOTHING DONE!
# orot_c NOTHING DONE!
# cechddd_c NOTHING DONE!
# 25drapp_c NOTHING DONE!
# 6hmhptpp_c NOTHING DONE!
# dhptd_c NOTHING DONE!
# hmfurn_c NOTHING DONE!
# 3dhq_c NOTHING DONE!
# 3dhsk_c NOTHING DONE!
# 25dkglcn_c NOTHING DONE!
# dkmpp_c NOTHING DONE!
# 2kmb_c NOTHING DONE!
# dmpp_c NOTHING DONE!
# ipdp_c NOTHING DONE!
# grdp_c NOTHING DONE!
# h2mb4p_c NOTHING DONE!
# 2omhmbl_c NOTHING DONE!
# dmso_c NOTHING DONE!
# dms_c NOTHING DONE!
# 2dmmql8_c NOTHING DONE!
# dhpmp_c NOTHING DONE!
# ahdt_c NOTHING DONE!
# 23doguln_c NOTHING DONE!
# 3dhguln_c NOTHING DONE!
# dpcoa_c NOTHING DONE!
# 2dhp_c NOTHING DONE!
# pant-R_c NOTHING DONE!
# 2dr5p_c NOTHING DONE!
# dtmp_c NOTHING DONE!
# dump_c NOTHING DONE!
# 2dr1p_c NOTHING DONE!
# dxyl5p_c NOTHING DONE!
# 2me4p_c NOTHING DONE!
# dxyl_c NOTHING DONE!
# 4per_c NOTHING DONE!
# ecaEC_c NOTHING DONE!
# udcpdp_c NOTHING DONE!
# 6pgc_c NOTHING DONE!
# kdo2lipid4_c NOTHING DONE!
# kdo2lipid4L_c NOTHING DONE!
# lipa_c NOTHING DONE!
# kdo2lipid4p_c NOTHING DONE!
# lipa_cold_c NOTHING DONE!
# 2pg_c NOTHING DONE!
# seramp_c NOTHING DONE!
# enter_c NOTHING DONE!
# etha_c NOTHING DONE!
# f6p_c NOTHING DONE!
# ocdca_c NOTHING DONE!
# fdp_c NOTHING DONE!
# fuc-L_c NOTHING DONE!
# fcl-L_c NOTHING DONE!
# fc1p_c NOTHING DONE!
# lald-L_c NOTHING DONE!
# fe2_c NOTHING DONE!
# ppp9_c NOTHING DONE!
# pheme_c NOTHING DONE!
# suc6p_c NOTHING DONE!
# fru_c NOTHING DONE!
# h2_c NOTHING DONE!
# fmn_c NOTHING DONE!
# f1p_c NOTHING DONE!
# mal-L_c NOTHING DONE!
# gam1p_c NOTHING DONE!
# acgam1p_c NOTHING DONE!
# g1p_c NOTHING DONE!
# dttp_c NOTHING DONE!
# dtdpglu_c NOTHING DONE!
# glu1sa_c NOTHING DONE!
# 5aop_c NOTHING DONE!
# glyc3p_c NOTHING DONE!
# glu5sa_c NOTHING DONE!
# 1pyr5c_c NOTHING DONE!
# glu5p_c NOTHING DONE!
# 6pgl_c NOTHING DONE!
# galct-D_c NOTHING DONE!
# 5dh4dglc_c NOTHING DONE!
# galctn-D_c NOTHING DONE!
# gal_c NOTHING DONE!
# gal1p_c NOTHING DONE!
# melib_c NOTHING DONE!
# udpg_c NOTHING DONE!
# 13dpg_c NOTHING DONE!
# gar_c NOTHING DONE!
# fgam_c NOTHING DONE!
# glyclt_c NOTHING DONE!
# gdpddman_c NOTHING DONE!
# gdpofuc_c NOTHING DONE!
# ser-L_c NOTHING DONE!
# gly_c NOTHING DONE!
# mlthf_c NOTHING DONE!
# glycogen_c NOTHING DONE!
# 2h3oppan_c NOTHING DONE!
# glcr_c NOTHING DONE!
# adpglc_c NOTHING DONE!
# galt1p_c NOTHING DONE!
# tag6p-D_c NOTHING DONE!
# glucys_c NOTHING DONE!
# pram_c NOTHING DONE!
# glu-D_c NOTHING DONE!
# glutrna_c NOTHING DONE!
# trnaglu_c NOTHING DONE!
# glx_c NOTHING DONE!
# 2aobut_c NOTHING DONE!
# glyc-R_c NOTHING DONE!
# 3pg_c NOTHING DONE!
# lgt-S_c NOTHING DONE!
# gthrd_c NOTHING DONE!
# lac-D_c NOTHING DONE!
# gdpmann_c NOTHING DONE!
# gmhep1p_c NOTHING DONE!
# gmhep7p_c NOTHING DONE!
# gmhep17bp_c NOTHING DONE!
# xmp_c NOTHING DONE!
# gdpfuc_c NOTHING DONE!
# gp4g_c NOTHING DONE!
# g3pc_c NOTHING DONE!
# chol_c NOTHING DONE!
# g3pe_c NOTHING DONE!
# g3ps_c NOTHING DONE!
# g3pg_c NOTHING DONE!
# g3pi_c NOTHING DONE!
# inost_c NOTHING DONE!
# frdp_c NOTHING DONE!
# gsn_c NOTHING DONE!
# gtspmd_c NOTHING DONE!
# spmd_c NOTHING DONE!
# gthox_c NOTHING DONE!
# gua_c NOTHING DONE!
# xan_c NOTHING DONE!
# glcur_c NOTHING DONE!
# fruur_c NOTHING DONE!
# galur_c NOTHING DONE!
# tagur_c NOTHING DONE!
# 3ophb_c NOTHING DONE!
# hemeO_c NOTHING DONE!
# 4mhetz_c NOTHING DONE!
# 4mpetz_c NOTHING DONE!
# histd_c NOTHING DONE!
# his-L_c NOTHING DONE!
# hisp_c NOTHING DONE!
# hkndd_c NOTHING DONE!
# op4en_c NOTHING DONE!
# ppbng_c NOTHING DONE!
# hmbil_c NOTHING DONE!
# 4ahmmp_c NOTHING DONE!
# 4h2opntn_c NOTHING DONE!
# hpyr_c NOTHING DONE!
# hom-L_c NOTHING DONE!
# phom_c NOTHING DONE!
# suchms_c NOTHING DONE!
# imacp_c NOTHING DONE!
# pydam_c NOTHING DONE!
# ichor_c NOTHING DONE!
# prlp_c NOTHING DONE!
# eig3p_c NOTHING DONE!
# 2cpr5p_c NOTHING DONE!
# 3ig3p_c NOTHING DONE!
# ile-L_c NOTHING DONE!
# 3c2hmp_c NOTHING DONE!
# 3c4mop_c NOTHING DONE!
# 2ippm_c NOTHING DONE!
# 3c3hmp_c NOTHING DONE!
# 3hmrsACP_c NOTHING DONE!
# kdo_c NOTHING DONE!
# ckdo_c NOTHING DONE!
# kdo8p_c NOTHING DONE!
# 3dhgulnp_c NOTHING DONE!
# xu5p-L_c NOTHING DONE!
# lcts_c NOTHING DONE!
# lac-L_c NOTHING DONE!
# 12ppd-S_c NOTHING DONE!
# 4mop_c NOTHING DONE!
# leu-L_c NOTHING DONE!
# mthgxl_c NOTHING DONE!
# lipidX_c NOTHING DONE!
# u23ga_c NOTHING DONE!
# lipidAds_c NOTHING DONE!
# agpgEC_c NOTHING DONE!
# agpeEC_c NOTHING DONE!
# agpcEC_c NOTHING DONE!
# apgEC_c NOTHING DONE!
# cdpea_c NOTHING DONE!
# lpsEC_c NOTHING DONE!
# 15dap_c NOTHING DONE!
# mnl1p_c NOTHING DONE!
# man1p_c NOTHING DONE!
# man6p_c NOTHING DONE!
# mana_c NOTHING DONE!
# 2mcit_c NOTHING DONE!
# 2mcacn_c NOTHING DONE!
# micit_c NOTHING DONE!
# 5mdru1p_c NOTHING DONE!
# 2mecdp_c NOTHING DONE!
# met-L_c NOTHING DONE!
# 5mthf_c NOTHING DONE!
# mi1p-D_c NOTHING DONE!
# mmcoa-S_c NOTHING DONE!
# mmcoa-R_c NOTHING DONE!
# lipidA_c NOTHING DONE!
# kdolipid4_c NOTHING DONE!
# 5mta_c NOTHING DONE!
# 5mtr_c NOTHING DONE!
# methf_c NOTHING DONE!
# 5mdr1p_c NOTHING DONE!
# nmn_c NOTHING DONE!
# h2o_e NOTHING DONE!
# nad_e NOTHING DONE!
# amp_e NOTHING DONE!
# nmn_e NOTHING DONE!
# dnad_c NOTHING DONE!
# nac_c NOTHING DONE!
# nicrnt_c NOTHING DONE!
# dgtp_c NOTHING DONE!
# dudp_c NOTHING DONE!
# datp_c NOTHING DONE!
# ncam_c NOTHING DONE!
# dmbzid_c NOTHING DONE!
# 5prdmbz_c NOTHING DONE!
# quln_c NOTHING DONE!
# sbzcoa_c NOTHING DONE!
# xtsn_c NOTHING DONE!
# thymd_c NOTHING DONE!
# dgsn_c NOTHING DONE!
# pppi_c NOTHING DONE!
# no2_c NOTHING DONE!
# ohpb_c NOTHING DONE!
# 2ohph_c NOTHING DONE!
# 2omph_c NOTHING DONE!
# 2ombzl_c NOTHING DONE!
# 2ommbl_c NOTHING DONE!
# orot5p_c NOTHING DONE!
# 2oph_c NOTHING DONE!
# thmpp_c NOTHING DONE!
# ssaltpp_c NOTHING DONE!
# pro-L_c NOTHING DONE!
# phaccoa_c NOTHING DONE!
# pnto-R_c NOTHING DONE!
# ugmda_c NOTHING DONE!
# uagmda_c NOTHING DONE!
# trdrd_c NOTHING DONE!
# trdox_c NOTHING DONE!
# pdx5p_c NOTHING DONE!
# pydxn_c NOTHING DONE!
# peamn_c NOTHING DONE!
# peEC_c NOTHING DONE!
# tagdp-D_c NOTHING DONE!
# 3php_c NOTHING DONE!
# 2pglyc_c NOTHING DONE!
# pgpEC_c NOTHING DONE!
# phe-L_c NOTHING DONE!
# phpyr_c NOTHING DONE!
# pcEC_c NOTHING DONE!
# 4r5au_c NOTHING DONE!
# 2mahmp_c NOTHING DONE!
# 4ppan_c NOTHING DONE!
# ppap_c NOTHING DONE!
# 4ppcys_c NOTHING DONE!
# pan4p_c NOTHING DONE!
# r1p_c NOTHING DONE!
# 34hpp_c NOTHING DONE!
# pppn_c NOTHING DONE!
# uaagmda_c NOTHING DONE!
# peptidoEC_c NOTHING DONE!
# fpram_c NOTHING DONE!
# prbamp_c NOTHING DONE!
# prfp_c NOTHING DONE!
# skm5p_c NOTHING DONE!
# psEC_c NOTHING DONE!
# pser-L_c NOTHING DONE!
# pydx_c NOTHING DONE!
# ribflv_c NOTHING DONE!
# dmlz_c NOTHING DONE!
# rib-D_c NOTHING DONE!
# ru5p-L_c NOTHING DONE!
# xu5p-D_c NOTHING DONE!
# rmn_c NOTHING DONE!
# rml_c NOTHING DONE!
# rml1p_c NOTHING DONE!
# s7p_c NOTHING DONE!
# sucorn_c NOTHING DONE!
# so4_c NOTHING DONE!
# sbt6p_c NOTHING DONE!
# sl26da_c NOTHING DONE!
# sl2a6o_c NOTHING DONE!
# seln_c NOTHING DONE!
# selnp_c NOTHING DONE!
# ser-D_c NOTHING DONE!
# sucglu_c NOTHING DONE!
# sucgsa_c NOTHING DONE!
# 2shchc_c NOTHING DONE!
# scl_c NOTHING DONE!
# srch_c NOTHING DONE!
# sheme_c NOTHING DONE!
# skm_c NOTHING DONE!
# N1aspmd_c NOTHING DONE!
# n8aspmd_c NOTHING DONE!
# o2s_c NOTHING DONE!
# sucbz_c NOTHING DONE!
# tartr-L_c NOTHING DONE!
# taur_c NOTHING DONE!
# aacald_c NOTHING DONE!
# dtdp4addg_c NOTHING DONE!
# dtdp4d6dg_c NOTHING DONE!
# dtdp4d6dm_c NOTHING DONE!
# dtdprmn_c NOTHING DONE!
# thr-L_c NOTHING DONE!
# tyr-L_c NOTHING DONE!
# 4hba_c NOTHING DONE!
# tmao_c NOTHING DONE!
# tma_c NOTHING DONE!
# thym_c NOTHING DONE!
# thm_c NOTHING DONE!
# thmmp_c NOTHING DONE!
# tre6p_c NOTHING DONE!
# tre_c NOTHING DONE!
# tre_e NOTHING DONE!
# glc-D_e NOTHING DONE!
# trp-L_c NOTHING DONE!
# indole_c NOTHING DONE!
# u3hga_c NOTHING DONE!
# uamag_c NOTHING DONE!
# ugmd_c NOTHING DONE!
# uacmam_c NOTHING DONE!
# u3aga_c NOTHING DONE!
# uaccg_c NOTHING DONE!
# uama_c NOTHING DONE!
# uamr_c NOTHING DONE!
# udpgal_c NOTHING DONE!
# udpgalfur_c NOTHING DONE!
# udpglcur_c NOTHING DONE!
# uppg3_c NOTHING DONE!
# val-L_c NOTHING DONE!
# xyl-D_c NOTHING DONE!
# xylu-D_c NOTHING DONE!
# 12ppd-S_e NOTHING DONE!
# 15dap_e NOTHING DONE!
# 26dap-M_e NOTHING DONE!
# 2ddglcn_e NOTHING DONE!
# 3hcinnm_e NOTHING DONE!
# 3hpppn_e NOTHING DONE!
# 4abut_e NOTHING DONE!
# ac_e NOTHING DONE!
# acac_e NOTHING DONE!
# acald_e NOTHING DONE!
# acgam_e NOTHING DONE!
# acmana_e NOTHING DONE!
# acnam_e NOTHING DONE!
# ade_e NOTHING DONE!
# adn_e NOTHING DONE!
# akg_e NOTHING DONE!
# ala-D_e NOTHING DONE!
# ala-L_e NOTHING DONE!
# alltn_e NOTHING DONE!
# arab-L_e NOTHING DONE!
# arg-L_e NOTHING DONE!
# asn-L_e NOTHING DONE!
# asp-L_e NOTHING DONE!
# but_e NOTHING DONE!
# charge_e NOTHING DONE!
# cbl1_e NOTHING DONE!
# chol_e NOTHING DONE!
# cit_e NOTHING DONE!
# co2tot_e NOTHING DONE!
# crn_e NOTHING DONE!
# csn_e NOTHING DONE!
# cynt_e NOTHING DONE!
# cys-L_e NOTHING DONE!
# cytd_e NOTHING DONE!
# dad-2_e NOTHING DONE!
# dcyt_e NOTHING DONE!
# dgsn_e NOTHING DONE!
# dha_e NOTHING DONE!
# din_e NOTHING DONE!
# dms_e NOTHING DONE!
# dmso_e NOTHING DONE!
# duri_e NOTHING DONE!
# etoh_e NOTHING DONE!
# fe2_e NOTHING DONE!
# for_e NOTHING DONE!
# fru_e NOTHING DONE!
# fuc1p-L_e NOTHING DONE!
# fuc-L_e NOTHING DONE!
# fum_e NOTHING DONE!
# g6p_e NOTHING DONE!
# gal_e NOTHING DONE!
# galct-D_e NOTHING DONE!
# galctn-D_e NOTHING DONE!
# galt_e NOTHING DONE!
# galur_e NOTHING DONE!
# gam_e NOTHING DONE!
# gbbtn_e NOTHING DONE!
# glcn_e NOTHING DONE!
# glcr_e NOTHING DONE!
# glcur_e NOTHING DONE!
# gln-L_e NOTHING DONE!
# glu-L_e NOTHING DONE!
# gly_e NOTHING DONE!
# glyald_e NOTHING DONE!
# glyb_e NOTHING DONE!
# glyc_e NOTHING DONE!
# glyc3p_e NOTHING DONE!
# glyclt_e NOTHING DONE!
# gsn_e NOTHING DONE!
# gua_e NOTHING DONE!
# h_e NOTHING DONE!
# hdca_e NOTHING DONE!
# his-L_e NOTHING DONE!
# hxan_e NOTHING DONE!
# idon-L_e NOTHING DONE!
# ile-L_e NOTHING DONE!
# indole_e NOTHING DONE!
# ins_e NOTHING DONE!
# k_e NOTHING DONE!
# lac-D_e NOTHING DONE!
# lac-L_e NOTHING DONE!
# lcts_e NOTHING DONE!
# leu-L_e NOTHING DONE!
# lys-L_e NOTHING DONE!
# mal-L_e NOTHING DONE!
# malt_e NOTHING DONE!
# malthx_e NOTHING DONE!
# maltpt_e NOTHING DONE!
# malttr_e NOTHING DONE!
# maltttr_e NOTHING DONE!
# man_e NOTHING DONE!
# man6p_e NOTHING DONE!
# melib_e NOTHING DONE!
# met-D_e NOTHING DONE!
# met-L_e NOTHING DONE!
# mnl_e NOTHING DONE!
# na1_e NOTHING DONE!
# nac_e NOTHING DONE!
# nh3_e NOTHING DONE!
# no2_e NOTHING DONE!
# no3_e NOTHING DONE!
# o2_e NOTHING DONE!
# ocdca_e NOTHING DONE!
# orn_e NOTHING DONE!
# phe-L_e NOTHING DONE!
# pi_e NOTHING DONE!
# pnto-R_e NOTHING DONE!
# pppn_e NOTHING DONE!
# pro-L_e NOTHING DONE!
# ptrc_e NOTHING DONE!
# pyr_e NOTHING DONE!
# rib-D_e NOTHING DONE!
# rmn_e NOTHING DONE!
# sbt-D_e NOTHING DONE!
# ser-D_e NOTHING DONE!
# ser-L_e NOTHING DONE!
# so4_e NOTHING DONE!
# spmd_e NOTHING DONE!
# succ_e NOTHING DONE!
# sucr_e NOTHING DONE!
# tartr-L_e NOTHING DONE!
# taur_e NOTHING DONE!
# thm_e NOTHING DONE!
# thr-L_e NOTHING DONE!
# thymd_e NOTHING DONE!
# tma_e NOTHING DONE!
# tmao_e NOTHING DONE!
# trp-L_e NOTHING DONE!
# tsul_e NOTHING DONE!
# ttdca_e NOTHING DONE!
# tyr-L_e NOTHING DONE!
# ura_e NOTHING DONE!
# urea_e NOTHING DONE!
# uri_e NOTHING DONE!
# val-L_e NOTHING DONE!
# xan_e NOTHING DONE!
# xtsn_e NOTHING DONE!
# xyl-D_e NOTHING DONE!
# h_c NOTHING DONE!
# acgam_c NOTHING DONE!
# charge_c NOTHING DONE!
# electron_c NOTHING DONE!
# electron_e NOTHING DONE!
# fuc1p-L_c NOTHING DONE!
# galt_c NOTHING DONE!
# gam_c NOTHING DONE!
# na1_c NOTHING DONE!
# h2_e NOTHING DONE!
# k_c NOTHING DONE!
# malt6p_c NOTHING DONE!
# man_c NOTHING DONE!
# met-D_c NOTHING DONE!
# mnl_c NOTHING DONE!
# no3_c NOTHING DONE!
# sbt-D_c NOTHING DONE!
# sucr_c NOTHING DONE!
# *** Editing special metabolites ***
# *** Removing electrons from the model ***
# Initializing component contribution object...
# cxcalc is not installed, operating in read-only mode. A local cache may be loaded, but no compounds can be created. Install cxcalc and obtain a ChemAxon license to enable compound creation.
# Loading compounds from ecoli_compound.sqlite
# added reaction:  biomass_ce: biomass_c <=> biomass_e
# added reaction:  biomass_EX: biomass_e <=>
# ['Parameters', 'Exchange reactions', 'Reactions', 'Biomass Composition', 'Transmembrane reactions', 'Metabolites', 'references', 'Transmembrane_reactions_reed', 'Transmembrane reactions_Orth', 'Transmembrane reactions old', 'Sheet3', 'log', 'subsystems']
# biomass : 0.05 5mthf_c + 5e-05 accoa_c + 0.488 ala-L_c + 0.001 amp_c + 0.281 arg-L_c + 0.2
# biomass_ce : biomass_c <=> biomass_e
# biomass_EX : biomass_e <=>
# Identifying compounds...
# [████████████████████████████████████████] 777/777 Mg_e
#
# Estimating dfG0'...
# biomass_c 0 kilojoule / mole
# biomass_e 0 kilojoule / mole
# [████████████████████████████████████████] 777/777 Mg_e
#
# Estimating drG0'...
# [████████████████████████████████████████] 1066/1066 EX_oro
#
# model: 0.0002529258990048429 molar, 0.0004342234967378932 molar, metabolome: 0.0002529258990048429, 0.0004342234967378932
# Metabolome data applied: True
# model: 0.001073909284258439 molar, 0.001548858862398621 molar, metabolome: 0.001073909284258439, 0.001548858862398621
# Metabolome data applied: True
# model: 0.0008331641916238633 molar, 0.0011413781466564309 molar, metabolome: 0.0008331641916238633, 0.0011413781466564309
# Metabolome data applied: True
# model: 0.0002233207481051652 molar, 0.00030345089799289286 molar, metabolome: 0.0002233207481051652, 0.00030345089799289286
# Metabolome data applied: True
# model: 0.014483295560995986 molar, 0.01919626245645281 molar, metabolome: 0.014483295560995986, 0.01919626245645281
# Metabolome data applied: True
# model: 0.0008181857847443272 molar, 0.001519364072988153 molar, metabolome: 0.0008181857847443272, 0.001519364072988153
# Metabolome data applied: True
# model: 0.0005804872270140013 molar, 0.0007666542358275789 molar, metabolome: 0.0005804872270140013, 0.0007666542358275789
# Metabolome data applied: True
# model: 6.72461590263574e-06 molar, 1.261393679178146e-05 molar, metabolome: 6.72461590263574e-06, 1.261393679178146e-05
# Metabolome data applied: True
# model: 0.000452789987669252 molar, 0.0005604891102588882 molar, metabolome: 0.000452789987669252, 0.0005604891102588882
# Metabolome data applied: True
# model: 0.001654744489613344 molar, 0.002035418883995996 molar, metabolome: 0.001654744489613344, 0.002035418883995996
# Metabolome data applied: True
# model: 0.00019177065392972636 molar, 0.0009177632504334258 molar, metabolome: 0.00019177065392972636, 0.0009177632504334258
# Metabolome data applied: True
# model: -8.726880850191402e-07 molar, 4.30042248321894e-06 molar, metabolome: -8.726880850191402e-07, 4.30042248321894e-06
# Metabolome data applied: True
# model: 1.956585726149336e-05 molar, 3.027616829436364e-05 molar, metabolome: 1.956585726149336e-05, 3.027616829436364e-05
# Metabolome data applied: True
# model: 0.0003669563385392486 molar, 0.0005519264085196674 molar, metabolome: 0.0003669563385392486, 0.0005519264085196674
# Metabolome data applied: True
# model: 0.0009039711646320857 molar, 0.0010396074177473245 molar, metabolome: 0.0009039711646320857, 0.0010396074177473245
# Metabolome data applied: True
# model: 0.00036417295909872845 molar, 0.003623692481031491 molar, metabolome: 0.00036417295909872845, 0.003623692481031491
# Metabolome data applied: True
# model: 0.0001656664705292036 molar, 0.00021990673024629642 molar, metabolome: 0.0001656664705292036, 0.00021990673024629642
# Metabolome data applied: True
# model: 0.00022880172479817788 molar, 0.0002990276735146682 molar, metabolome: 0.00022880172479817788, 0.0002990276735146682
# Metabolome data applied: True
# model: 0.0005153572358713815 molar, 0.0007403862959467266 molar, metabolome: 0.0005153572358713815, 0.0007403862959467266
# Metabolome data applied: True
# model: 3.45047819818368e-05 molar, 6.25005842265068e-05 molar, metabolome: 3.45047819818368e-05, 6.25005842265068e-05
# Metabolome data applied: True
# model: 0.0008210887873458465 molar, 0.0010352038098127136 molar, metabolome: 0.0008210887873458465, 0.0010352038098127136
# Metabolome data applied: True
# model: 0.00029981024153549106 molar, 0.00046916028600318293 molar, metabolome: 0.00029981024153549106, 0.00046916028600318293
# Metabolome data applied: True
# model: 0.0002949509213346714 molar, 0.0003419853784020026 molar, metabolome: 0.0002949509213346714, 0.0003419853784020026
# Metabolome data applied: True
# model: 0.0011960216637123037 molar, 0.0015632652126261561 molar, metabolome: 0.0011960216637123037, 0.0015632652126261561
# Metabolome data applied: True
# model: 0.001988288588599605 molar, 0.002316049634210295 molar, metabolome: 0.001988288588599605, 0.002316049634210295
# Metabolome data applied: True
# model: 1.1291163185412439e-05 molar, 1.835877687513656e-05 molar, metabolome: 1.1291163185412439e-05, 1.835877687513656e-05
# Metabolome data applied: True
# model: 0.014483295560995986 molar, 0.01919626245645281 molar, metabolome: 0.014483295560995986, 0.01919626245645281
# Metabolome data applied: True
# model: 0.00013042841716804057 molar, 0.0001860306465223834 molar, metabolome: 0.00013042841716804057, 0.0001860306465223834
# Metabolome data applied: True
# model: 5.023376162746396e-05 molar, 6.139149099853745e-05 molar, metabolome: 5.023376162746396e-05, 6.139149099853745e-05
# Metabolome data applied: True
# model: 1.5890905485947e-06 molar, 4.2618760403243e-06 molar, metabolome: 1.5890905485947e-06, 4.2618760403243e-06
# Metabolome data applied: True
# model: 0.0002529258990048429 molar, 0.0004342234967378932 molar, metabolome: 0.0002529258990048429, 0.0004342234967378932
# Metabolome data applied: True
# model: 0.00013042841716804057 molar, 0.0001860306465223834 molar, metabolome: 0.00013042841716804057, 0.0001860306465223834
# Metabolome data applied: True
# model: 7.455074867766725e-05 molar, 0.00010896737577295717 molar, metabolome: 7.455074867766725e-05, 0.00010896737577295717
# Metabolome data applied: True
# model: 4.5925935951462314e-05 molar, 5.679006380595028e-05 molar, metabolome: 4.5925935951462314e-05, 5.679006380595028e-05
# Metabolome data applied: True
#
# Removing 9 orphan metabolites:
# Orphaned IDs: acgam_c, Mg_c, mnl_c, sucr_c, man_c, galt_c, gam_c, Mg_e, sbt-D_c
# Identifying compounds...
# [████████████████████████████████████████] 454/454 orot_e
#
# Estimating dfG0'...
# [████████████████████████████████████████] 454/454 orot_e
#
# Estimating drG0'...
# [████████████████████████████████████████] 623/623 EX_oro

# %%
for m in tmodel_glc.metabolites:
    print(m.id, m.lower_bound.to("millimolar"), m.upper_bound.to("millimolar"))
# Out:
# 2dhglcn_c 0.0001 millimolar 1.0 millimolar
# nadh_c 0.0001 millimolar 2.83314013008588 millimolar
# glcn_c 0.0001 millimolar 0.7510094609224821 millimolar
# nad_c 0.0001 millimolar 21.680209268635856 millimolar
# nadph_c 0.0001 millimolar 2.81973586946604 millimolar
# nadp_c 0.0001 millimolar 0.06950785924102033 millimolar
# 2dhguln_c 0.0001 millimolar 1.0 millimolar
# idon-L_c 0.0001 millimolar 1.0 millimolar
# o2_c 0.1 millimolar 0.3 millimolar
# h2o_c 1000.0 millimolar 1000.0 millimolar
# pi_c 20.0 millimolar 25.0 millimolar
# 5dglcn_c 0.0001 millimolar 1.0 millimolar
# ru5p-D_c 0.25292589900484286 millimolar 0.4342234967378932 millimolar
# ara5p_c 0.0001 millimolar 1.0 millimolar
# ACP_c 0.0001 millimolar 1.0 millimolar
# atp_c 1.0739092842584388 millimolar 1.548858862398621 millimolar
# ttdca_c 0.0001 millimolar 1.0 millimolar
# amp_c 0.0001 millimolar 2.0997531815128596 millimolar
# myrsACP_c 0.0001 millimolar 1.0 millimolar
# ppi_c 0.0001 millimolar 1.0 millimolar
# ttdcea_c 0.0001 millimolar 1.0 millimolar
# tdeACP_c 0.0001 millimolar 1.0 millimolar
# hdca_c 0.0001 millimolar 1.0 millimolar
# palmACP_c 0.0001 millimolar 1.0 millimolar
# hdcea_c 0.0001 millimolar 1.0 millimolar
# hdeACP_c 0.0001 millimolar 1.0 millimolar
# ocdcea_c 0.0001 millimolar 1.0 millimolar
# octeACP_c 0.0001 millimolar 1.0 millimolar
# dtdp_c 0.7920570976154994 millimolar 1.6723844264994925 millimolar
# g6p_c 0.8331641916238633 millimolar 1.1413781466564308 millimolar
# 4abut_c 0.0001 millimolar 1.0 millimolar
# akg_c 0.2233207481051652 millimolar 0.3034508979928929 millimolar
# glu-L_c 14.483295560995986 millimolar 19.19626245645281 millimolar
# sucsal_c 0.0001 millimolar 1.0 millimolar
# 4abutn_c 0.0001 millimolar 1.0 millimolar
# accoa_c 0.0001 millimolar 3.0197434338457088 millimolar
# ac_c 0.0001 millimolar 1.0 millimolar
# coa_c 0.0001 millimolar 94.45831618726834 millimolar
# acald_c 0.0001 millimolar 1.0 millimolar
# gtp_c 0.8181857847443271 millimolar 1.5193640729881528 millimolar
# co2tot_c 0.2 millimolar 0.4 millimolar
# adp_c 0.5804872270140014 millimolar 0.7666542358275789 millimolar
# malcoa_c 0.0001 millimolar 6.25490577465901 millimolar
# ppa_c 0.0001 millimolar 1.0 millimolar
# ppcoa_c 0.00858556644041988 millimolar 0.027807102002743042 millimolar
# uacgam_c 1.9891701059352007 millimolar 48.07363043748245 millimolar
# udcpp_c 0.0001 millimolar 1.0 millimolar
# ump_c 0.0001 millimolar 1.0 millimolar
# acglu_c 0.0001 millimolar 1.0 millimolar
# acg5p_c 0.0001 millimolar 1.0 millimolar
# 2obut_c 0.0001 millimolar 1.0 millimolar
# pyr_c 0.0001 millimolar 16.540937373872378 millimolar
# 2ahbut_c 0.0001 millimolar 1.0 millimolar
# actp_c 0.0001 millimolar 4.9183975755305696 millimolar
# alac-S_c 0.0001 millimolar 1.0 millimolar
# udp_c 2.4224834769649446 millimolar 10.133264217369707 millimolar
# acACP_c 0.0001 millimolar 1.0 millimolar
# acorn_c 0.0001 millimolar 2.6437204883816423 millimolar
# orn_c 0.0001 millimolar 0.23316039947858885 millimolar
# amet_c 0.0001 millimolar 5.425505086089708 millimolar
# cit_c 0.0001 millimolar 58.45368293756951 millimolar
# icit_c 0.452789987669252 millimolar 0.5604891102588883 millimolar
# acg5sa_c 0.0001 millimolar 1.0 millimolar
# pap_c 0.0001 millimolar 1.0 millimolar
# adn_c 0.00020709858744249337 millimolar 0.0006919119473422751 millimolar
# ins_c 0.0001 millimolar 1.0 millimolar
# nh3_c 0.05 millimolar 1.0 millimolar
# 4adcho_c 0.0001 millimolar 1.0 millimolar
# 4abz_c 0.0001 millimolar 1.0 millimolar
# chor_c 0.0001 millimolar 1.0 millimolar
# gln-L_c 1.654744489613344 millimolar 2.035418883995996 millimolar
# ade_c 0.002956854832177801 millimolar 0.09141525331664888 millimolar
# hxan_c 0.0001 millimolar 1.0 millimolar
# gdp_c 0.19177065392972636 millimolar 0.9177632504334258 millimolar
# ametam_c 0.0001 millimolar 1.0 millimolar
# gmp_c 0.01956585726149336 millimolar 0.03027616829436364 millimolar
# prpp_c 0.0001 millimolar 1.0 millimolar
# aps_c 0.01156617111060714 millimolar 0.03321019014989525 millimolar
# paps_c 0.0001 millimolar 1.0 millimolar
# dcamp_c 0.0001 millimolar 1.0 millimolar
# fum_c 0.3669563385392486 millimolar 0.5519264085196675 millimolar
# 25aics_c 0.0001 millimolar 1.0 millimolar
# aicar_c 0.0001 millimolar 1.0 millimolar
# asp-L_c 0.9039711646320857 millimolar 1.0396074177473245 millimolar
# imp_c 0.36417295909872843 millimolar 3.623692481031491 millimolar
# gam6p_c 0.0001 millimolar 5.405067300319661 millimolar
# adphep-DD_c 0.0001 millimolar 1.0 millimolar
# adphep-LD_c 0.0001 millimolar 1.0 millimolar
# ptrc_c 0.0001 millimolar 1.0 millimolar
# hcys-L_c 0.8668690873452989 millimolar 1.4843648755912653 millimolar
# 10fthf_c 0.0001 millimolar 1.0 millimolar
# fprica_c 0.0001 millimolar 1.0 millimolar
# thf_c 0.0001 millimolar 1.0 millimolar
# air_c 0.0001 millimolar 1.0 millimolar
# 5caiz_c 0.0001 millimolar 1.0 millimolar
# 5aizc_c 0.0001 millimolar 1.0 millimolar
# ala-D_c 0.0001 millimolar 1.0 millimolar
# alaala_c 0.0001 millimolar 1.0 millimolar
# ala-L_c 0.0001 millimolar 11.043674674399016 millimolar
# pydx5p_c 0.0001 millimolar 1.0 millimolar
# pyam5p_c 0.0001 millimolar 1.0 millimolar
# glyc_c 0.0001 millimolar 1.0 millimolar
# malt_c 0.0001 millimolar 1.0 millimolar
# malttr_c 0.0001 millimolar 1.0 millimolar
# glc-D_c 0.0001 millimolar 1.0 millimolar
# maltttr_c 0.0001 millimolar 1.0 millimolar
# maltpt_c 0.0001 millimolar 1.0 millimolar
# malthx_c 0.0001 millimolar 1.0 millimolar
# malthp_c 0.0001 millimolar 1.0 millimolar
# 2dmmq8_c 0.0001 millimolar 1.0 millimolar
# mqn8_c 0.0001 millimolar 1.0 millimolar
# for_c 0.0001 millimolar 1.0 millimolar
# r5p_c 0.1656664705292036 millimolar 0.21990673024629642 millimolar
# anth_c 0.0011908847344743643 millimolar 0.014329068932374352 millimolar
# pran_c 0.0001 millimolar 1.0 millimolar
# 5apru_c 0.0001 millimolar 1.0 millimolar
# 5aprbu_c 0.0001 millimolar 1.0 millimolar
# arab-L_c 0.0001 millimolar 1.0 millimolar
# arg-L_c 0.0001 millimolar 48.512102021072494 millimolar
# argsuc_c 0.0001 millimolar 1.0 millimolar
# citr-L_c 0.47569956151805637 millimolar 5.8385018439923115 millimolar
# aspsa_c 0.0001 millimolar 1.0 millimolar
# 4pasp_c 0.0001 millimolar 1.0 millimolar
# asn-L_c 0.22880172479817787 millimolar 0.2990276735146682 millimolar
# ala-B_c 0.0001 millimolar 1.0 millimolar
# cbp_c 0.0001 millimolar 1.0 millimolar
# cbasp_c 0.0001 millimolar 3.505080259562841 millimolar
# q8_c 0.0001 millimolar 1.0 millimolar
# iasp_c 0.0001 millimolar 1.0 millimolar
# q8h2_c 0.0001 millimolar 1.0 millimolar
# mql8_c 0.0001 millimolar 1.0 millimolar
# succ_c 0.5153572358713815 millimolar 0.7403862959467267 millimolar
# h2o2_c 0.0001 millimolar 1.0 millimolar
# oaa_c 0.0001 millimolar 1.0 millimolar
# succoa_c 0.0001 millimolar 10.005830987914186 millimolar
# sucarg_c 0.0001 millimolar 1.0 millimolar
# prbatp_c 0.0001 millimolar 1.0 millimolar
# betald_c 0.0001 millimolar 1.0 millimolar
# glyb_c 0.0001 millimolar 1.0 millimolar
# btnso_c 0.0001 millimolar 1.0 millimolar
# btn_c 0.0001 millimolar 1.0 millimolar
# cys-L_c 0.0001 millimolar 1.0 millimolar
# actACP_c 0.0001 millimolar 1.0 millimolar
# malACP_c 0.0001 millimolar 1.0 millimolar
# ddcaACP_c 0.0001 millimolar 1.0 millimolar
# cdpdag1_c 0.0001 millimolar 1.0 millimolar
# cmp_c 0.25293577480075163 millimolar 2.4284209364673104 millimolar
# paEC_c 0.0001 millimolar 1.0 millimolar
# pphn_c 0.0001 millimolar 1.0 millimolar
# 3psme_c 0.0001 millimolar 1.0 millimolar
# pgEC_c 0.0001 millimolar 1.0 millimolar
# clpnEC_c 0.0001 millimolar 1.0 millimolar
# csn_c 0.016565512011598522 millimolar 0.08401505195846563 millimolar
# ura_c 0.0001 millimolar 1.0 millimolar
# utp_c 2.3163362417798075 millimolar 34.99142800060476 millimolar
# ctp_c 0.0001 millimolar 12.785329461759433 millimolar
# so3_c 0.0001 millimolar 1.0 millimolar
# acser_c 0.0001 millimolar 1.0 millimolar
# h2s_c 0.0001 millimolar 1.0 millimolar
# cyst-L_c 0.0001 millimolar 1.0 millimolar
# cytd_c 0.0008193694113263792 millimolar 0.01913841112929005 millimolar
# uri_c 0.0001 millimolar 1.0 millimolar
# cdp_c 0.0001 millimolar 1.0 millimolar
# dcmp_c 0.0001 millimolar 1.0 millimolar
# dcdp_c 0.0001 millimolar 1.0 millimolar
# fad_c 0.0001 millimolar 1.543896995050693 millimolar
# fadh2_c 0.0001 millimolar 1.0 millimolar
# dad-2_c 0.0035981004584332275 millimolar 0.01632801363150392 millimolar
# din_c 0.0001 millimolar 1.0 millimolar
# damp_c 0.0001 millimolar 0.0809275730172358 millimolar
# dadp_c 0.0001 millimolar 1.0 millimolar
# 12dgrEC_c 0.0001 millimolar 1.0 millimolar
# 26dap-M_c 0.0001 millimolar 1.0 millimolar
# lys-L_c 0.0001 millimolar 2.2170958472402766 millimolar
# 26dap-LL_c 0.0001 millimolar 1.0 millimolar
# db4p_c 0.0001 millimolar 1.0 millimolar
# dctp_c 0.058543350693319514 millimolar 0.17555088595326032 millimolar
# dutp_c 0.0001 millimolar 1.0 millimolar
# dcyt_c 0.0001 millimolar 1.0 millimolar
# duri_c 0.0001 millimolar 1.0 millimolar
# 2ddg6p_c 0.0001 millimolar 0.05702705893004537 millimolar
# e4p_c 0.012362503741650776 millimolar 0.10785233540287933 millimolar
# pep_c 0.0345047819818368 millimolar 0.0625005842265068 millimolar
# 2dda7p_c 0.0001 millimolar 1.0 millimolar
# g3p_c 0.0001 millimolar 1.0 millimolar
# dgmp_c 0.08870564496533404 millimolar 0.25352952075098817 millimolar
# dgdp_c 0.0001 millimolar 1.0 millimolar
# 23dhmb_c 0.0001 millimolar 1.0 millimolar
# 3mob_c 0.0001 millimolar 1.0 millimolar
# 23dhmp_c 0.0001 millimolar 1.0 millimolar
# 3mop_c 0.0001 millimolar 1.0 millimolar
# dha_c 0.0001 millimolar 1.0 millimolar
# dhap_c 0.8210887873458464 millimolar 1.0352038098127136 millimolar
# 23dhdp_c 0.0001 millimolar 1.0 millimolar
# thdp_c 0.0001 millimolar 1.0 millimolar
# dhf_c 0.0001 millimolar 1.0 millimolar
# dhpt_c 0.0001 millimolar 1.0 millimolar
# dhnpt_c 0.0001 millimolar 1.0 millimolar
# 6hmhpt_c 0.0001 millimolar 1.0 millimolar
# gcald_c 0.0001 millimolar 1.0 millimolar
# dhor-S_c 0.002839802059131176 millimolar 0.048489252602648004 millimolar
# orot_c 0.0001 millimolar 1.0 millimolar
# 25drapp_c 0.0001 millimolar 1.0 millimolar
# 6hmhptpp_c 0.0001 millimolar 1.0 millimolar
# 3dhq_c 0.0001 millimolar 1.0 millimolar
# 3dhsk_c 0.0001 millimolar 1.0 millimolar
# 25dkglcn_c 0.0001 millimolar 1.0 millimolar
# dkmpp_c 0.0001 millimolar 1.0 millimolar
# 2kmb_c 0.0001 millimolar 1.0 millimolar
# dmpp_c 0.0001 millimolar 1.0 millimolar
# ipdp_c 0.0001 millimolar 1.0 millimolar
# h2mb4p_c 0.0001 millimolar 1.0 millimolar
# dmso_c 0.0001 millimolar 1.0 millimolar
# dms_c 0.0001 millimolar 1.0 millimolar
# 2dmmql8_c 0.0001 millimolar 1.0 millimolar
# dhpmp_c 0.0001 millimolar 1.0 millimolar
# ahdt_c 0.0001 millimolar 1.0 millimolar
# dpcoa_c 0.0001 millimolar 1.0 millimolar
# 2dhp_c 0.0001 millimolar 1.0 millimolar
# pant-R_c 0.0001 millimolar 1.0 millimolar
# 2dr5p_c 0.0001 millimolar 1.0 millimolar
# dtmp_c 0.0001 millimolar 1.0 millimolar
# dump_c 0.0001 millimolar 1.0 millimolar
# 2dr1p_c 0.0001 millimolar 1.0 millimolar
# udcpdp_c 0.0001 millimolar 1.0 millimolar
# 6pgc_c 0.2998102415354911 millimolar 0.46916028600318294 millimolar
# kdo2lipid4_c 0.0001 millimolar 1.0 millimolar
# kdo2lipid4L_c 0.0001 millimolar 1.0 millimolar
# lipa_c 0.0001 millimolar 1.0 millimolar
# 2pg_c 0.0001 millimolar 1.0 millimolar
# etha_c 0.0001 millimolar 1.0 millimolar
# f6p_c 0.29495092133467143 millimolar 0.3419853784020026 millimolar
# fdp_c 1.1960216637123036 millimolar 1.5632652126261561 millimolar
# fmn_c 0.0001 millimolar 0.34516027331605886 millimolar
# f1p_c 0.0072598626267834105 millimolar 1.2053878900373487 millimolar
# mal-L_c 1.9882885885996051 millimolar 2.316049634210295 millimolar
# gam1p_c 0.0001 millimolar 1.0 millimolar
# acgam1p_c 0.0001 millimolar 1.0 millimolar
# g1p_c 0.0001 millimolar 1.0 millimolar
# dttp_c 0.4691562388011643 millimolar 20.009238522970257 millimolar
# glyc3p_c 0.0001 millimolar 5.533469910918428 millimolar
# glu5sa_c 0.0001 millimolar 1.0 millimolar
# 1pyr5c_c 0.0001 millimolar 1.0 millimolar
# glu5p_c 0.0001 millimolar 1.0 millimolar
# 6pgl_c 0.0001 millimolar 1.0 millimolar
# gal_c 0.0001 millimolar 1.0 millimolar
# udpg_c 0.13675544478304505 millimolar 17.574880127000583 millimolar
# 13dpg_c 0.011291163185412439 millimolar 0.01835877687513656 millimolar
# gar_c 0.0001 millimolar 1.0 millimolar
# fgam_c 0.0001 millimolar 1.0 millimolar
# glyclt_c 0.0001 millimolar 1.0 millimolar
# ser-L_c 0.0001 millimolar 0.7354694733786731 millimolar
# gly_c 0.0001 millimolar 1.0 millimolar
# mlthf_c 0.0001 millimolar 1.0 millimolar
# glycogen_c 0.0001 millimolar 1.0 millimolar
# 2h3oppan_c 0.0001 millimolar 1.0 millimolar
# adpglc_c 0.005854335069331952 millimolar 0.0240467109845785 millimolar
# pram_c 0.0001 millimolar 1.0 millimolar
# glu-D_c 14.483295560995986 millimolar 19.19626245645281 millimolar
# glx_c 0.0001 millimolar 1.0 millimolar
# 2aobut_c 0.0001 millimolar 1.0 millimolar
# glyc-R_c 0.45599688978163655 millimolar 10.402429048143588 millimolar
# 3pg_c 1.184341411757472 millimolar 10.632899414949682 millimolar
# lgt-S_c 0.0001 millimolar 1.0 millimolar
# gthrd_c 6.432086230704947 millimolar 70.85368339488974 millimolar
# lac-D_c 0.0001 millimolar 1.0 millimolar
# gmhep1p_c 0.0001 millimolar 1.0 millimolar
# gmhep7p_c 0.0001 millimolar 1.0 millimolar
# gmhep17bp_c 0.0001 millimolar 1.0 millimolar
# xmp_c 0.0001 millimolar 1.0 millimolar
# g3pc_c 0.0001 millimolar 1.0 millimolar
# chol_c 0.0001 millimolar 1.0 millimolar
# g3pe_c 0.0001 millimolar 1.0 millimolar
# g3pg_c 0.0001 millimolar 1.0 millimolar
# gsn_c 0.002719356452083198 millimolar 0.008292651771636536 millimolar
# gtspmd_c 0.0001 millimolar 1.0 millimolar
# spmd_c 0.0001 millimolar 1.0 millimolar
# gua_c 0.0001 millimolar 1.0153055749044255 millimolar
# xan_c 0.0001 millimolar 1.0 millimolar
# histd_c 0.0001 millimolar 0.1727546252638132 millimolar
# his-L_c 0.0001 millimolar 0.6163809999312369 millimolar
# hisp_c 0.0001 millimolar 1.0 millimolar
# hpyr_c 0.0001 millimolar 1.0 millimolar
# hom-L_c 0.0001 millimolar 1.0 millimolar
# phom_c 0.0001 millimolar 1.0 millimolar
# suchms_c 0.0001 millimolar 1.0 millimolar
# imacp_c 0.0001 millimolar 1.0 millimolar
# pydam_c 0.0001 millimolar 1.0 millimolar
# prlp_c 0.0001 millimolar 1.0 millimolar
# eig3p_c 0.0001 millimolar 1.0 millimolar
# 2cpr5p_c 0.0001 millimolar 1.0 millimolar
# 3ig3p_c 0.0001 millimolar 1.0 millimolar
# ile-L_c 0.0001 millimolar 1.0 millimolar
# 3c2hmp_c 0.0001 millimolar 1.0 millimolar
# 3c4mop_c 0.0001 millimolar 1.0 millimolar
# 2ippm_c 0.0001 millimolar 1.0 millimolar
# 3c3hmp_c 0.0001 millimolar 1.0 millimolar
# 3hmrsACP_c 0.0001 millimolar 1.0 millimolar
# kdo_c 0.0001 millimolar 1.0 millimolar
# ckdo_c 0.0001 millimolar 1.0 millimolar
# kdo8p_c 0.0001 millimolar 1.0 millimolar
# lac-L_c 0.0001 millimolar 1.0 millimolar
# 4mop_c 0.0001 millimolar 1.0 millimolar
# leu-L_c 0.0001 millimolar 1.0 millimolar
# mthgxl_c 0.0001 millimolar 1.0 millimolar
# lipidX_c 0.0001 millimolar 1.0 millimolar
# u23ga_c 0.0001 millimolar 1.0 millimolar
# lipidAds_c 0.0001 millimolar 1.0 millimolar
# agpgEC_c 0.0001 millimolar 1.0 millimolar
# agpeEC_c 0.0001 millimolar 1.0 millimolar
# agpcEC_c 0.0001 millimolar 1.0 millimolar
# apgEC_c 0.0001 millimolar 1.0 millimolar
# cdpea_c 0.0001 millimolar 1.0 millimolar
# lpsEC_c 0.0001 millimolar 1.0 millimolar
# 2mcit_c 0.0001 millimolar 1.0 millimolar
# 2mcacn_c 0.0001 millimolar 1.0 millimolar
# micit_c 0.0001 millimolar 1.0 millimolar
# 5mdru1p_c 0.0001 millimolar 1.0 millimolar
# met-L_c 0.0001 millimolar 0.6333290135856067 millimolar
# 5mthf_c 0.0001 millimolar 1.0 millimolar
# mmcoa-S_c 0.0001 millimolar 1.0 millimolar
# mmcoa-R_c 0.0001 millimolar 1.0 millimolar
# lipidA_c 0.0001 millimolar 1.0 millimolar
# kdolipid4_c 0.0001 millimolar 1.0 millimolar
# 5mta_c 0.0001 millimolar 1.0 millimolar
# 5mtr_c 0.0001 millimolar 1.0 millimolar
# methf_c 0.0001 millimolar 1.0 millimolar
# 5mdr1p_c 0.0001 millimolar 1.0 millimolar
# nmn_c 0.0001 millimolar 1.0 millimolar
# h2o_e 1000.0 millimolar 1000.0 millimolar
# nmn_e 0.0001 millimolar 1.0 millimolar
# dnad_c 0.0001 millimolar 1.0 millimolar
# nac_c 0.0001 millimolar 1.0 millimolar
# nicrnt_c 0.0001 millimolar 1.0 millimolar
# dgtp_c 0.0001 millimolar 1.0 millimolar
# dudp_c 0.0001 millimolar 1.0 millimolar
# datp_c 0.0001 millimolar 0.3969615781581213 millimolar
# ncam_c 0.0001 millimolar 1.0 millimolar
# quln_c 0.0001 millimolar 0.1494062726111795 millimolar
# xtsn_c 0.0001 millimolar 1.0 millimolar
# thymd_c 0.0001 millimolar 1.0 millimolar
# dgsn_c 0.0009416810770750989 millimolar 0.002563003351854252 millimolar
# pppi_c 0.0001 millimolar 1.0 millimolar
# no2_c 0.0001 millimolar 1.0 millimolar
# orot5p_c 0.0001 millimolar 1.0 millimolar
# pro-L_c 0.0001 millimolar 1.5773850744616515 millimolar
# pnto-R_c 0.0001 millimolar 1.0 millimolar
# ugmda_c 0.0001 millimolar 1.0 millimolar
# uagmda_c 0.0001 millimolar 1.0 millimolar
# trdrd_c 0.0001 millimolar 1.0 millimolar
# trdox_c 0.0001 millimolar 1.0 millimolar
# pdx5p_c 0.0001 millimolar 1.0 millimolar
# pydxn_c 0.0001 millimolar 1.0 millimolar
# peEC_c 0.0001 millimolar 1.0 millimolar
# 3php_c 0.0001 millimolar 1.0 millimolar
# pgpEC_c 0.0001 millimolar 1.0 millimolar
# phe-L_c 0.050233761627463965 millimolar 0.061391490998537454 millimolar
# phpyr_c 0.0001 millimolar 1.8545957687244532 millimolar
# 4r5au_c 0.0001 millimolar 1.0 millimolar
# 4ppan_c 0.0001 millimolar 1.0 millimolar
# ppap_c 0.0001 millimolar 1.0 millimolar
# 4ppcys_c 0.0001 millimolar 1.0 millimolar
# pan4p_c 0.0001 millimolar 1.0 millimolar
# r1p_c 0.0015890905485946999 millimolar 0.0042618760403243 millimolar
# 34hpp_c 0.0001 millimolar 1.0 millimolar
# uaagmda_c 0.0001 millimolar 1.0 millimolar
# peptidoEC_c 0.0001 millimolar 1.0 millimolar
# fpram_c 0.0001 millimolar 1.0 millimolar
# prbamp_c 0.0001 millimolar 1.0 millimolar
# prfp_c 0.0001 millimolar 1.0 millimolar
# skm5p_c 0.0001 millimolar 1.0 millimolar
# psEC_c 0.0001 millimolar 1.0 millimolar
# pser-L_c 0.0001 millimolar 1.0 millimolar
# pydx_c 0.0001 millimolar 1.0 millimolar
# ribflv_c 0.015311375157527536 millimolar 0.08292651771636537 millimolar
# dmlz_c 0.0001 millimolar 1.0 millimolar
# xu5p-D_c 0.13042841716804057 millimolar 0.1860306465223834 millimolar
# s7p_c 0.07455074867766724 millimolar 0.10896737577295718 millimolar
# sucorn_c 0.0001 millimolar 1.0 millimolar
# so4_c 0.0001 millimolar 1.0 millimolar
# sl26da_c 0.0001 millimolar 1.0 millimolar
# sl2a6o_c 0.0001 millimolar 1.0 millimolar
# sucglu_c 0.0001 millimolar 1.0 millimolar
# sucgsa_c 0.0001 millimolar 1.0 millimolar
# skm_c 0.008454942331367852 millimolar 0.09753266809218342 millimolar
# thr-L_c 0.0001 millimolar 0.7303075187909025 millimolar
# tyr-L_c 0.04592593595146231 millimolar 0.05679006380595028 millimolar
# tmao_c 0.0001 millimolar 1.0 millimolar
# tma_c 0.0001 millimolar 1.0 millimolar
# tre6p_c 0.0001 millimolar 1.0 millimolar
# tre_c 0.0001 millimolar 1.0 millimolar
# tre_e 0.0001 millimolar 1.0 millimolar
# glc-D_e 24.5115452930728 millimolar 27.769760213143798 millimolar
# trp-L_c 0.0001 millimolar 0.06728716860537388 millimolar
# indole_c 0.0001 millimolar 1.0 millimolar
# u3hga_c 0.0001 millimolar 1.0 millimolar
# uamag_c 0.0001 millimolar 1.0 millimolar
# ugmd_c 0.0001 millimolar 1.0 millimolar
# u3aga_c 0.0001 millimolar 1.0 millimolar
# uaccg_c 0.0001 millimolar 1.0 millimolar
# uama_c 0.0001 millimolar 1.0 millimolar
# uamr_c 0.0001 millimolar 1.0 millimolar
# val-L_c 0.0001 millimolar 17.990502292166138 millimolar
# xyl-D_c 0.0001 millimolar 1.0 millimolar
# 4abut_e 0.0001 millimolar 1.0 millimolar
# ac_e 9.999999999999999e-05 millimolar 2.9638913352753 millimolar
# ala-L_e 0.0001 millimolar 1.0 millimolar
# arab-L_e 0.0001 millimolar 1.0 millimolar
# arg-L_e 0.0001 millimolar 1.0 millimolar
# asn-L_e 0.0001 millimolar 1.0 millimolar
# asp-L_e 0.0001 millimolar 1.0 millimolar
# charge_e 0.0001 millimolar 10 millimolar
# chol_e 0.0001 millimolar 1.0 millimolar
# co2tot_e 0.06 millimolar 0.1 millimolar
# dms_e 0.0001 millimolar 1.0 millimolar
# dmso_e 0.0001 millimolar 1.0 millimolar
# for_e 0.0001 millimolar 1.0 millimolar
# fru_e 26.8 millimolar 27.8 millimolar
# fum_e 0.0001 millimolar 0.15 millimolar
# gal_e 0.0001 millimolar 1.0 millimolar
# glcn_e 24.5 millimolar 25.5 millimolar
# glu-L_e 0.0001 millimolar 1.0 millimolar
# glyb_e 0.0001 millimolar 1.0 millimolar
# glyc3p_e 0.0001 millimolar 1.0 millimolar
# h_e 0.00013676323053056464 millimolar 0.00013676323053056464 millimolar
# his-L_e 0.0001 millimolar 1.0 millimolar
# ile-L_e 0.0001 millimolar 1.0 millimolar
# k_e 0.0001 millimolar 1.0 millimolar
# leu-L_e 0.0001 millimolar 1.0 millimolar
# lys-L_e 0.0001 millimolar 1.0 millimolar
# na1_e 0.0001 millimolar 93.0 millimolar
# nh3_e 21.8 millimolar 22.7 millimolar
# o2_e 0.1 millimolar 0.3 millimolar
# orn_e 0.0001 millimolar 1.0 millimolar
# pi_e 64.1 millimolar 64.2 millimolar
# pro-L_e 0.0001 millimolar 1.0 millimolar
# ptrc_e 0.0001 millimolar 1.0 millimolar
# ser-L_e 0.0001 millimolar 1.0 millimolar
# so4_e 12.3 millimolar 12.4 millimolar
# succ_e 0.0001 millimolar 42.4 millimolar
# thr-L_e 0.0001 millimolar 1.0 millimolar
# tma_e 0.0001 millimolar 1.0 millimolar
# tmao_e 0.0001 millimolar 1.0 millimolar
# val-L_e 0.0001 millimolar 1.0 millimolar
# xyl-D_e 0.0001 millimolar 1.0 millimolar
# h_c 3.347513949028939e-05 millimolar 3.347513949028939e-05 millimolar
# charge_c 0.0001 millimolar 10 millimolar
# na1_c 0.0001 millimolar 1.0 millimolar
# h2_e 0.0001 millimolar 1.0 millimolar
# k_c 0.0001 millimolar 1.0 millimolar
# no3_c 0.0001 millimolar 1.0 millimolar
# biomass_c 0.0001 millimolar 10 millimolar
# biomass_e 0.0001 millimolar 10 millimolar
# orot_e 9.999999999999999e-05 millimolar 0.07687379884689302 millimolar

# %%
save_conc_bounds_linear(tmodel_glc, "results/bounds/ecoli_WT_Glc_concs_before_tva.csv")

# %%
# Apply thermodynamic variables and additional respiratory constraint
tmodel_glc.m = None
tmodel_glc.objective = tmodel_glc.reactions.biomass_EX
tmodel_glc.add_TFBA_variables(qnorm='sep_norm')

add_rq_constraint(tmodel_glc, "WT-Glc_I", INPUT_EXP_DATA)
# Out:
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 10
# >>>>>> RQ: 0.74 (vCO2 = 12.9 / vO2 = -17.4) ERR: 0.17932102098560615

# %%
# Optional: quickly optimize model to make sure it is feasible
tmodel_glc.m.Params.TimeLimit = 20
tmodel_glc.m.optimize()
# Out:
# Set parameter TimeLimit to value 20
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (linux64 - "Ubuntu 24.04.2 LTS")
#
# CPU model: AMD Ryzen 7 7800X3D 8-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  20
# NonConvex  2
#
# Academic license 2731723 - for non-commercial use only - registered to l.___@student.rug.nl
# Optimize a model with 6731 rows, 5418 columns and 155311 nonzeros
# Model fingerprint: 0x6407c076
# Model has 1 quadratic constraint
# Model has 300 simple general constraints
#   300 ABS
# Variable types: 4795 continuous, 623 integer (623 binary)
# Coefficient statistics:
#   Matrix range     [3e-06, 7e+05]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [3e-01, 1e+06]
#   RHS range        [2e-14, 1e+05]
# Presolve removed 4100 rows and 3194 columns
# Presolve time: 0.38s
# Presolved: 2635 rows, 2225 columns, 116793 nonzeros
# Presolved model has 1 bilinear constraint(s)
#
# Solving non-convex MIQCP
#
# Variable types: 1823 continuous, 402 integer (402 binary)
#
# Root relaxation: objective 7.018798e-01, 1747 iterations, 0.10 seconds (0.24 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.70188    0   39          -    0.70188      -     -    1s
#      0     0    0.70188    0   53          -    0.70188      -     -    1s
#      0     0    0.70188    0   52          -    0.70188      -     -    1s
#      0     0    0.70188    0    9          -    0.70188      -     -    1s
#      0     0    0.70188    0    9          -    0.70188      -     -    1s
#      0     0    0.70188    0    5          -    0.70188      -     -    2s
#      0     0    0.70188    0    7          -    0.70188      -     -    2s
#      0     0    0.70188    0    9          -    0.70188      -     -    2s
#      0     0    0.70188    0    5          -    0.70188      -     -    2s
#      0     0    0.70188    0    5          -    0.70188      -     -    2s
#      0     0    0.70188    0    4          -    0.70188      -     -    2s
#      0     0    0.70188    0    6          -    0.70188      -     -    2s
#      0     0    0.70188    0    6          -    0.70188      -     -    2s
#      0     0    0.70188    0    8          -    0.70188      -     -    2s
#      0     0    0.70188    0    8          -    0.70188      -     -    3s
#      0     2    0.70188    0    8          -    0.70188      -     -    3s
#    498   631    0.70188   51   43          -    0.70188      -  77.4    5s
# * 1153   932              75       0.7018798    0.70188  0.00%  86.8    6s
#
# Cutting planes:
#   Learned: 110
#   Gomory: 4
#   Cover: 17
#   Implied bound: 47
#   Clique: 2
#   MIR: 7
#   Flow cover: 19
#   Inf proof: 3
#   RLT: 1
#   Relax-and-lift: 1
#
# Explored 1667 nodes (136291 simplex iterations) in 6.94 seconds (14.93 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 0.70188
# No other solutions better than 0.70188
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.018798083526e-01, best bound 7.018798083526e-01, gap 0.0000%

# %%
# Create one .mps.gz file containing all TVA scenarios for the metabolites
# Make sure output folder exists
tva_run_scenarios_one_model_mets(tmodel_glc, "ecoli", "WT_Glc", "../results/WT_Glc")
# Out:
# Set parameter MIPGap to value 0.001
# Added 2dhglcn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,0] (value -13.324994505486456)>)
# Added nadh_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,1] (value -15.951434870181808)>)
# Added glcn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,2] (value -7.194092308513203)>)
# Added nad_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,3] (value -16.11809565095832)>)
# Added nadph_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,4] (value -13.315198368088057)>)
# Added nadp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,5] (value -16.11809565095832)>)
# Added 2dhguln_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,6] (value -14.33724951069142)>)
# Added idon-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,7] (value -6.907755278982137)>)
# Added o2_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,8] (value -9.210340371976182)>)
# Added h2o_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,9] (value 0.0)>)
# Added pi_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,10] (value -3.6888794541139363)>)
# Added 5dglcn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,11] (value -16.11809565095832)>)
# Added ru5p-D_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,12] (value -8.282414001446126)>)
# Added ara5p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,13] (value -11.682943990121313)>)
# Added ACP_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,14] (value -6.907755278982137)>)
# Added atp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,15] (value -6.836449751771576)>)
# Added ttdca_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,16] (value -6.907755278982137)>)
# Added amp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,17] (value -7.469658863055638)>)
# Added myrsACP_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,18] (value -16.11809565095832)>)
# Added ppi_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,19] (value -13.514187324351909)>)
# Added ttdcea_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,20] (value -16.11809565095832)>)
# Added tdeACP_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,21] (value -16.11809565095832)>)
# Added hdca_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,22] (value -16.11809565095832)>)
# Added palmACP_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,23] (value -16.11809565095832)>)
# Added hdcea_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,24] (value -16.11809565095832)>)
# Added hdeACP_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,25] (value -16.11809565095832)>)
# Added ocdcea_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,26] (value -16.11809565095832)>)
# Added octeACP_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,27] (value -16.11809565095832)>)
# Added dtdp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,28] (value -6.393504870592016)>)
# Added g6p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,29] (value -6.775518846131839)>)
# Added 4abut_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,30] (value -6.907755278982137)>)
# Added akg_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,31] (value -8.40690148760311)>)
# Added glu-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,32] (value -3.9530396826242598)>)
# Added sucsal_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,33] (value -16.11809565095832)>)
# Added 4abutn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,34] (value -16.11809565095832)>)
# Added accoa_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,35] (value -5.8025834068845255)>)
# Added ac_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,36] (value -6.907755278982137)>)
# Added coa_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,37] (value -16.11809565095832)>)
# Added acald_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,38] (value -6.907755278982137)>)
# Added gtp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,39] (value -7.1084211264351955)>)
# Added co2tot_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,40] (value -7.824046010856292)>)
# Added adp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,41] (value -7.173474658984534)>)
# Added malcoa_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,42] (value -5.074389199180081)>)
# Added ppa_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,43] (value -12.355675756037186)>)
# Added ppcoa_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,44] (value -11.665428085544507)>)
# Added uacgam_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,45] (value -3.035021475952972)>)
# Added udcpp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,46] (value -6.907755278982137)>)
# Added ump_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,47] (value -6.907755278982137)>)
# Added acglu_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,48] (value -6.907755278982137)>)
# Added acg5p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,49] (value -15.939139388672157)>)
# Added 2obut_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,50] (value -8.15596615686436)>)
# Added pyr_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,51] (value -16.11809565095832)>)
# Added 2ahbut_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,52] (value -16.11809565095832)>)
# Added actp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,53] (value -12.165898489549338)>)
# Added alac-S_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,54] (value -16.11809565095832)>)
# Added udp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,55] (value -6.022962034876919)>)
# Added acACP_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,56] (value -16.11809565095832)>)
# Added acorn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,57] (value -5.935568078019076)>)
# Added orn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,58] (value -14.247263694473437)>)
# Added amet_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,59] (value -16.11809565095832)>)
# Added cit_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,60] (value -2.8395205829965944)>)
# Added icit_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,61] (value -7.700082143357647)>)
# Added acg5sa_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,62] (value -6.907755278982137)>)
# Added pap_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,63] (value -6.907755278982137)>)
# Added adn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,64] (value -14.664056853901002)>)
# Added ins_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,65] (value -12.521606264440896)>)
# Added nh3_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,66] (value -6.907755278982137)>)
# Added 4adcho_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,67] (value -16.11809565095832)>)
# Added 4abz_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,68] (value -6.907755278982137)>)
# Added chor_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,69] (value -6.907755278982137)>)
# Added gln-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,70] (value -6.197053641468211)>)
# Added ade_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,71] (value -10.282119537165695)>)
# Added hxan_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,72] (value -6.907755278982137)>)
# Added gdp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,73] (value -8.114390973631075)>)
# Added ametam_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,74] (value -6.907755278982137)>)
# Added gmp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,75] (value -10.405149679860466)>)
# Added prpp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,76] (value -6.907755278982137)>)
# Added aps_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,77] (value -10.31265379691013)>)
# Added paps_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,78] (value -10.228932223816653)>)
# Added dcamp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,79] (value -9.568489077761631)>)
# Added fum_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,80] (value -7.502095838473953)>)
# Added 25aics_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,81] (value -6.907755278982137)>)
# Added aicar_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,82] (value -8.41270901884254)>)
# Added asp-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,83] (value -6.868912120028739)>)
# Added imp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,84] (value -5.620261750629411)>)
# Added gam6p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,85] (value -14.868680255763836)>)
# Added adphep-DD_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,86] (value -6.907755278982137)>)
# Added adphep-LD_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,87] (value -7.101753253255289)>)
# Added ptrc_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,88] (value -9.860204309273167)>)
# Added hcys-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,89] (value -6.512768291418834)>)
# Added 10fthf_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,90] (value -9.332562623972565)>)
# Added fprica_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,91] (value -8.96087435751769)>)
# Added thf_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,92] (value -14.035537604680574)>)
# Added air_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,93] (value -16.11809565095832)>)
# Added 5caiz_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,94] (value -6.907755278982137)>)
# Added 5aizc_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,95] (value -16.11809565095832)>)
# Added ala-D_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,96] (value -16.11809565095832)>)
# Added alaala_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,97] (value -16.11809565095832)>)
# Added ala-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,98] (value -11.384915424873594)>)
# Added pydx5p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,99] (value -16.11809565095832)>)
# Added pyam5p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,100] (value -10.847606324365133)>)
# Added glyc_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,101] (value -6.907755278982137)>)
# Added malt_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,102] (value -13.453141663769257)>)
# Added malttr_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,103] (value -6.907755278982137)>)
# Added glc-D_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,104] (value -6.907755278982137)>)
# Added maltttr_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,105] (value -6.907755278982137)>)
# Added maltpt_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,106] (value -9.492354378583435)>)
# Added malthx_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,107] (value -12.611230553286786)>)
# Added malthp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,108] (value -16.11809565095832)>)
# Added 2dmmq8_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,109] (value -11.298123310747165)>)
# Added mqn8_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,110] (value -14.173889463687615)>)
# Added for_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,111] (value -10.527463046109071)>)
# Added r5p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,112] (value -8.705534004464804)>)
# Added anth_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,113] (value -13.640814052732773)>)
# Added pran_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,114] (value -10.32364071396848)>)
# Added 5apru_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,115] (value -6.907755278982137)>)
# Added 5aprbu_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,116] (value -6.907755278982137)>)
# Added arab-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,117] (value -6.907755278982137)>)
# Added arg-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,118] (value -14.804670997294679)>)
# Added argsuc_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,119] (value -11.621124097373439)>)
# Added citr-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,120] (value -7.650724076287959)>)
# Added aspsa_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,121] (value -16.11809565095832)>)
# Added 4pasp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,122] (value -11.230521433160666)>)
# Added asn-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,123] (value -8.114974435295641)>)
# Added ala-B_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,124] (value -16.11809565095832)>)
# Added cbp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,125] (value -6.907755278982137)>)
# Added cbasp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,126] (value -5.6535418601663565)>)
# Added q8_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,127] (value -16.11809565095832)>)
# Added iasp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,128] (value -6.907755278982137)>)
# Added q8h2_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,129] (value -6.907755278982137)>)
# Added mql8_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,130] (value -16.11809565095832)>)
# Added succ_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,131] (value -7.208338486422278)>)
# Added h2o2_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,132] (value -16.11809565095832)>)
# Added oaa_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,133] (value -6.907755278982137)>)
# Added succoa_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,134] (value -4.604587257132716)>)
# Added sucarg_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,135] (value -6.907755278982137)>)
# Added prbatp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,136] (value -16.11809565095832)>)
# Added betald_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,137] (value -16.11809565095832)>)
# Added glyb_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,138] (value -6.907755278982137)>)
# Added btnso_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,139] (value -6.907755278982137)>)
# Added btn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,140] (value -16.11809565095832)>)
# Added cys-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,141] (value -6.907755278982137)>)
# Added actACP_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,142] (value -16.11809565095832)>)
# Added malACP_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,143] (value -16.11809565095832)>)
# Added ddcaACP_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,144] (value -16.11809565095832)>)
# Added cdpdag1_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,145] (value -16.11809565095832)>)
# Added cmp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,146] (value -8.282374956005755)>)
# Added paEC_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,147] (value -16.11809565095832)>)
# Added pphn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,148] (value -6.907755278982137)>)
# Added 3psme_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,149] (value -16.11809565095832)>)
# Added pgEC_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,150] (value -6.907755278982137)>)
# Added clpnEC_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,151] (value -16.11809565095832)>)
# Added csn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,152] (value -9.384514585191834)>)
# Added ura_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,153] (value -15.918335857044669)>)
# Added utp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,154] (value -6.067768547693658)>)
# Added ctp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,155] (value -4.359456901172543)>)
# Added so3_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,156] (value -6.907755278982137)>)
# Added acser_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,157] (value -6.907755278982137)>)
# Added h2s_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,158] (value -16.11809565095832)>)
# Added cyst-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,159] (value -16.11809565095832)>)
# Added cytd_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,160] (value -11.169574782012381)>)
# Added uri_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,161] (value -9.199769835492367)>)
# Added cdp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,162] (value -6.907755278982137)>)
# Added dcmp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,163] (value -16.11809565095832)>)
# Added dcdp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,164] (value -16.11809565095832)>)
# Added fad_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,165] (value -6.473445542655036)>)
# Added fadh2_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,166] (value -16.11809565095832)>)
# Added dad-2_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,167] (value -12.535104502193903)>)
# Added din_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,168] (value -6.907755278982137)>)
# Added damp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,169] (value -16.11809565095832)>)
# Added dadp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,170] (value -6.907755278982137)>)
# Added 12dgrEC_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,171] (value -16.11809565095832)>)
# Added 26dap-M_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,172] (value -16.11809565095832)>)
# Added lys-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,173] (value -16.11809565095832)>)
# Added 26dap-LL_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,174] (value -16.11809565095832)>)
# Added db4p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,175] (value -6.907755278982137)>)
# Added dctp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,176] (value -8.647581608633656)>)
# Added dutp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,177] (value -16.11809565095832)>)
# Added dcyt_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,178] (value -16.11809565095832)>)
# Added duri_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,179] (value -6.907755278982137)>)
# Added 2ddg6p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,180] (value -9.771984684701728)>)
# Added e4p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,181] (value -9.134747531187578)>)
# Added pep_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,182] (value -9.680334653641498)>)
# Added 2dda7p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,183] (value -16.11809565095832)>)
# Added g3p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,184] (value -8.115509643001248)>)
# Added dgmp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,185] (value -8.280030289046502)>)
# Added dgdp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,186] (value -7.927387615029632)>)
# Added 23dhmb_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,187] (value -9.543296237205837)>)
# Added 3mob_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,188] (value -14.243631452790789)>)
# Added 23dhmp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,189] (value -16.11809565095832)>)
# Added 3mop_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,190] (value -6.907755278982137)>)
# Added dha_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,191] (value -6.907755278982137)>)
# Added dhap_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,192] (value -6.873156953957106)>)
# Added 23dhdp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,193] (value -6.907755278982137)>)
# Added thdp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,194] (value -6.907755278982137)>)
# Added dhf_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,195] (value -16.11809565095832)>)
# Added dhpt_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,196] (value -16.11809565095832)>)
# Added dhnpt_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,197] (value -6.907755278982137)>)
# Added 6hmhpt_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,198] (value -6.907755278982137)>)
# Added gcald_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,199] (value -16.11809565095832)>)
# Added dhor-S_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,200] (value -12.60019211580878)>)
# Added orot_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,201] (value -6.907755278982137)>)
# Added 25drapp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,202] (value -16.11809565095832)>)
# Added 6hmhptpp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,203] (value -6.907755278982137)>)
# Added 3dhq_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,204] (value -6.907755278982137)>)
# Added 3dhsk_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,205] (value -11.768824701454179)>)
# Added 25dkglcn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,206] (value -16.11809565095832)>)
# Added dkmpp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,207] (value -16.11809565095832)>)
# Added 2kmb_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,208] (value -6.907755278982137)>)
# Added dmpp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,209] (value -6.907755278982137)>)
# Added ipdp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,210] (value -9.264086984147745)>)
# Added h2mb4p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,211] (value -16.11809565095832)>)
# Added dmso_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,212] (value -16.11809565095832)>)
# Added dms_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,213] (value -6.907755278982137)>)
# Added 2dmmql8_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,214] (value -6.907755278982137)>)
# Added dhpmp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,215] (value -6.907755278982137)>)
# Added ahdt_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,216] (value -6.907755278982137)>)
# Added dpcoa_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,217] (value -6.907755278982137)>)
# Added 2dhp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,218] (value -16.11809565095832)>)
# Added pant-R_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,219] (value -16.11809565095832)>)
# Added 2dr5p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,220] (value -7.788965285254805)>)
# Added dtmp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,221] (value -6.907755278982137)>)
# Added dump_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,222] (value -16.11809565095832)>)
# Added 2dr1p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,223] (value -6.907755278982137)>)
# Added udcpdp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,224] (value -6.907755278982137)>)
# Added 6pgc_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,225] (value -7.664566086704235)>)
# Added kdo2lipid4_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,226] (value -16.11809565095832)>)
# Added kdo2lipid4L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,227] (value -6.907755278982137)>)
# Added lipa_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,228] (value -6.907755278982137)>)
# Added 2pg_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,229] (value -6.907755278982137)>)
# Added etha_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,230] (value -16.11809565095832)>)
# Added f6p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,231] (value -8.12870158382225)>)
# Added fdp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,232] (value -6.728754510145918)>)
# Added fmn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,233] (value -16.11809565095832)>)
# Added f1p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,234] (value -6.720953863392419)>)
# Added mal-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,235] (value -6.220481015991664)>)
# Added gam1p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,236] (value -15.880439438386839)>)
# Added acgam1p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,237] (value -6.907755278982137)>)
# Added g1p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,238] (value -13.475657997295878)>)
# Added dttp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,239] (value -7.664574713221858)>)
# Added glyc3p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,240] (value -5.19694018989626)>)
# Added glu5sa_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,241] (value -16.11809565095832)>)
# Added 1pyr5c_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,242] (value -14.558858010059607)>)
# Added glu5p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,243] (value -6.907755278982137)>)
# Added 6pgl_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,244] (value -6.907755278982137)>)
# Added gal_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,245] (value -6.907755278982137)>)
# Added udpg_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,246] (value -6.236623855529703)>)
# Added 13dpg_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,247] (value -11.391490157172388)>)
# Added gar_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,248] (value -6.907755278982137)>)
# Added fgam_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,249] (value -14.54924376590438)>)
# Added glyclt_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,250] (value -6.907755278982137)>)
# Added ser-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,251] (value -7.215001523367842)>)
# Added gly_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,252] (value -13.304582936288899)>)
# Added mlthf_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,253] (value -6.907755278982137)>)
# Added glycogen_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,254] (value -16.11809565095832)>)
# Added 2h3oppan_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,255] (value -13.2779897163672)>)
# Added adpglc_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,256] (value -10.635512328162633)>)
# Added pram_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,257] (value -6.907755278982137)>)
# Added glu-D_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,258] (value -4.2347593239287145)>)
# Added glx_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,259] (value -15.559120361812989)>)
# Added 2aobut_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,260] (value -10.991299413395549)>)
# Added glyc-R_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,261] (value -7.693024569127455)>)
# Added 3pg_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,262] (value -4.543802366063595)>)
# Added lgt-S_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,263] (value -16.11809565095832)>)
# Added gthrd_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,264] (value -2.6471383255603986)>)
# Added lac-D_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,265] (value -6.907755278982137)>)
# Added gmhep1p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,266] (value -16.11809565095832)>)
# Added gmhep7p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,267] (value -11.459989618554513)>)
# Added gmhep17bp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,268] (value -10.787923036373543)>)
# Added xmp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,269] (value -16.11809565095832)>)
# Added g3pc_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,270] (value -6.907755278982137)>)
# Added chol_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,271] (value -8.244630503605567)>)
# Added g3pe_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,272] (value -6.907755278982137)>)
# Added g3pg_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,273] (value -16.11809565095832)>)
# Added gsn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,274] (value -11.700140764015144)>)
# Added gtspmd_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,275] (value -16.11809565095832)>)
# Added spmd_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,276] (value -6.907755278982137)>)
# Added gua_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,277] (value -16.11809565095832)>)
# Added xan_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,278] (value -12.875491679104966)>)
# Added histd_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,279] (value -8.663638321354728)>)
# Added his-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,280] (value -15.957884156873625)>)
# Added hisp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,281] (value -16.11809565095832)>)
# Added hpyr_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,282] (value -6.907755278982137)>)
# Added hom-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,283] (value -16.11809565095832)>)
# Added phom_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,284] (value -6.907755278982137)>)
# Added suchms_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,285] (value -6.907755278982137)>)
# Added imacp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,286] (value -6.907755278982137)>)
# Added pydam_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,287] (value -16.11809565095832)>)
# Added prlp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,288] (value -16.11809565095832)>)
# Added eig3p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,289] (value -16.11809565095832)>)
# Added 2cpr5p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,290] (value -6.907755278982137)>)
# Added 3ig3p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,291] (value -15.034631787800807)>)
# Added ile-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,292] (value -6.907755278982137)>)
# Added 3c2hmp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,293] (value -11.56274642467883)>)
# Added 3c4mop_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,294] (value -16.11809565095832)>)
# Added 2ippm_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,295] (value -6.907755278982137)>)
# Added 3c3hmp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,296] (value -6.907755278982137)>)
# Added 3hmrsACP_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,297] (value -16.11809565095832)>)
# Added kdo_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,298] (value -9.007140568411932)>)
# Added ckdo_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,299] (value -6.907755278982137)>)
# Added kdo8p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,300] (value -6.907755278982137)>)
# Added lac-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,301] (value -14.011859141719398)>)
# Added 4mop_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,302] (value -6.907755278982137)>)
# Added leu-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,303] (value -15.884462220969418)>)
# Added mthgxl_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,304] (value -6.907755278982137)>)
# Added lipidX_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,305] (value -6.907755278982137)>)
# Added u23ga_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,306] (value -8.550581773935921)>)
# Added lipidAds_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,307] (value -6.907755278982137)>)
# Added agpgEC_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,308] (value -16.11809565095832)>)
# Added agpeEC_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,309] (value -16.11809565095832)>)
# Added agpcEC_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,310] (value -16.11809565095832)>)
# Added apgEC_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,311] (value -6.907755278982137)>)
# Added cdpea_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,312] (value -6.907755278982137)>)
# Added lpsEC_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,313] (value -16.11809565095832)>)
# Added 2mcit_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,314] (value -16.11809565095832)>)
# Added 2mcacn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,315] (value -11.831154126544968)>)
# Added micit_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,316] (value -15.730067081272415)>)
# Added 5mdru1p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,317] (value -16.11809565095832)>)
# Added met-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,318] (value -7.364520502155418)>)
# Added 5mthf_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,319] (value -6.907755278982137)>)
# Added mmcoa-S_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,320] (value -6.907755278982137)>)
# Added mmcoa-R_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,321] (value -9.1257063606302)>)
# Added lipidA_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,322] (value -6.907755278982137)>)
# Added kdolipid4_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,323] (value -8.606706974842796)>)
# Added 5mta_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,324] (value -6.907755278982137)>)
# Added 5mtr_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,325] (value -6.907755278982137)>)
# Added methf_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,326] (value -11.81279413321204)>)
# Added 5mdr1p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,327] (value -6.907755278982137)>)
# Added nmn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,328] (value -6.907755278982137)>)
# Added h2o_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,329] (value 0.0)>)
# Added nmn_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,330] (value -16.11809565095832)>)
# Added dnad_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,331] (value -6.907755278982137)>)
# Added nac_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,332] (value -6.907755278982137)>)
# Added nicrnt_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,333] (value -6.907755278982137)>)
# Added dgtp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,334] (value -14.950485635649668)>)
# Added dudp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,335] (value -6.907755278982137)>)
# Added datp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,336] (value -10.954279151355063)>)
# Added ncam_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,337] (value -16.11809565095832)>)
# Added quln_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,338] (value -8.808841300797656)>)
# Added xtsn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,339] (value -16.11809565095832)>)
# Added thymd_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,340] (value -6.907755278982137)>)
# Added dgsn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,341] (value -12.874330802797688)>)
# Added pppi_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,342] (value -16.11809565095832)>)
# Added no2_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,343] (value -8.869369830972028)>)
# Added orot5p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,344] (value -16.11809565095832)>)
# Added pro-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,345] (value -6.451986819158975)>)
# Added pnto-R_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,346] (value -16.11809565095832)>)
# Added ugmda_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,347] (value -14.392647111343477)>)
# Added uagmda_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,348] (value -16.11809565095832)>)
# Added trdrd_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,349] (value -16.11809565095832)>)
# Added trdox_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,350] (value -6.907755278982137)>)
# Added pdx5p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,351] (value -9.163793196137853)>)
# Added pydxn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,352] (value -6.907755278982137)>)
# Added peEC_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,353] (value -16.11809565095832)>)
# Added 3php_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,354] (value -16.11809565095832)>)
# Added pgpEC_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,355] (value -16.11809565095832)>)
# Added phe-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,356] (value -9.898823214942109)>)
# Added phpyr_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,357] (value -6.290088521103796)>)
# Added 4r5au_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,358] (value -16.11809565095832)>)
# Added 4ppan_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,359] (value -16.11809565095832)>)
# Added ppap_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,360] (value -16.11809565095832)>)
# Added 4ppcys_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,361] (value -6.907755278982137)>)
# Added pan4p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,362] (value -16.11809565095832)>)
# Added r1p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,363] (value -12.36580110957138)>)
# Added 34hpp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,364] (value -7.392151599804096)>)
# Added uaagmda_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,365] (value -16.11809565095832)>)
# Added peptidoEC_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,366] (value -16.11809565095832)>)
# Added fpram_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,367] (value -16.11809565095832)>)
# Added prbamp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,368] (value -16.11809565095832)>)
# Added prfp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,369] (value -16.11809565095832)>)
# Added skm5p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,370] (value -16.11809565095832)>)
# Added psEC_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,371] (value -16.11809565095832)>)
# Added pser-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,372] (value -14.611273381782265)>)
# Added pydx_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,373] (value -16.11809565095832)>)
# Added ribflv_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,374] (value -9.397555671021099)>)
# Added dmlz_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,375] (value -7.475351813490837)>)
# Added xu5p-D_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,376] (value -8.589599131574168)>)
# Added s7p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,377] (value -9.50403047417931)>)
# Added sucorn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,378] (value -6.907755278982137)>)
# Added so4_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,379] (value -6.907755278982137)>)
# Added sl26da_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,380] (value -16.11809565095832)>)
# Added sl2a6o_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,381] (value -16.11809565095832)>)
# Added sucglu_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,382] (value -16.11809565095832)>)
# Added sucgsa_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,383] (value -6.907755278982137)>)
# Added skm_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,384] (value -11.680759396291297)>)
# Added thr-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,385] (value -7.222044853908663)>)
# Added tyr-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,386] (value -9.988480547071575)>)
# Added tmao_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,387] (value -16.11809565095832)>)
# Added tma_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,388] (value -6.907755278982137)>)
# Added tre6p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,389] (value -16.11809565095832)>)
# Added tre_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,390] (value -10.943634937122853)>)
# Added tre_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,391] (value -16.11809565095832)>)
# Added glc-D_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,392] (value -3.7086110359765323)>)
# Added trp-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,393] (value -16.11809565095832)>)
# Added indole_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,394] (value -16.11809565095832)>)
# Added u3hga_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,395] (value -9.279266685380877)>)
# Added uamag_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,396] (value -6.907755278982137)>)
# Added ugmd_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,397] (value -8.31399017186195)>)
# Added u3aga_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,398] (value -15.546609007882452)>)
# Added uaccg_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,399] (value -16.11809565095832)>)
# Added uama_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,400] (value -16.11809565095832)>)
# Added uamr_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,401] (value -6.907755278982137)>)
# Added val-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,402] (value -4.017911310777666)>)
# Added xyl-D_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,403] (value -15.924017936836108)>)
# Added 4abut_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,404] (value -7.108709130442419)>)
# Added ac_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,405] (value -8.482418857128643)>)
# Added ala-L_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,406] (value -11.622105621608434)>)
# Added arab-L_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,407] (value -7.102532367666518)>)
# Added arg-L_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,408] (value -16.11809565095832)>)
# Added asn-L_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,409] (value -8.350908163262318)>)
# Added asp-L_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,410] (value -8.513729722304392)>)
# Added charge_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,411] (value 0.0)>)
# Added chol_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,412] (value -16.11809565095832)>)
# Added co2tot_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,413] (value -9.41294969240215)>)
# Added dms_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,414] (value -6.907755278982137)>)
# Added dmso_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,415] (value -16.11809565095832)>)
# Added for_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,416] (value -11.714528845374058)>)
# Added fru_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,417] (value -3.619353391465326)>)
# Added fum_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,418] (value -10.652970246524058)>)
# Added gal_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,419] (value -7.1025498129333995)>)
# Added glcn_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,420] (value -3.7090821614314557)>)
# Added glu-L_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,421] (value -6.907755278982137)>)
# Added glyb_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,422] (value -7.101651375098087)>)
# Added glyc3p_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,423] (value -16.11809565095832)>)
# Added h_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,424] (value 0.0)>)
# Added his-L_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,425] (value -16.11809565095832)>)
# Added ile-L_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,426] (value -7.137621326345415)>)
# Added k_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,427] (value -14.930542569435048)>)
# Added leu-L_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,428] (value -16.11809565095832)>)
# Added lys-L_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,429] (value -14.567378432626116)>)
# Added na1_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,430] (value -2.375155785828881)>)
# Added nh3_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,431] (value -3.825845309187094)>)
# Added o2_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,432] (value -9.01634239770303)>)
# Added orn_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,433] (value -16.11809565095832)>)
# Added pi_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,434] (value -2.7457520682862224)>)
# Added pro-L_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,435] (value -15.221223295301145)>)
# Added ptrc_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,436] (value -6.907755278982137)>)
# Added ser-L_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,437] (value -16.11809565095832)>)
# Added so4_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,438] (value -4.398156016603766)>)
# Added succ_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,439] (value -10.159701577265484)>)
# Added thr-L_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,440] (value -7.145161119857606)>)
# Added tma_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,441] (value -6.907755278982137)>)
# Added tmao_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,442] (value -16.11809565095832)>)
# Added val-L_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,443] (value -6.907755278982137)>)
# Added xyl-D_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,444] (value -16.11809565095832)>)
# Added h_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,445] (value 0.0)>)
# Added charge_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,446] (value 0.0)>)
# Added na1_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,447] (value -12.420416559253688)>)
# Added h2_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,448] (value -16.11809565095832)>)
# Added k_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,449] (value -16.11809565095832)>)
# Added no3_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,450] (value -6.907755278982137)>)
# Added biomass_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,451] (value 0.0)>)
# Added biomass_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,452] (value 0.0)>)
# Added orot_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,453] (value -16.11809565095832)>)
# 0

# %%
# Recreate model with met TVA applied
tmodel_glc = setup_model(CONDITIONS[0], "datafiles/ecoli_WT_Glc_mets_objval.txt")
# Out:
# ['Parameters', 'Exchange reactions', 'Reactions', 'Biomass Composition', 'Transmembrane reactions', 'Metabolites', 'references', 'Transmembrane_reactions_reed', 'Transmembrane reactions_Orth', 'Transmembrane reactions old', 'Sheet3', 'log', 'subsystems']
# *** Reading data from Reactions ***
# unknown metabolite '2dhglcn[c]' created
# unknown metabolite 'nadh[c]' created
# unknown metabolite 'glcn[c]' created
# unknown metabolite 'nad[c]' created
# unknown metabolite 'nadph[c]' created
# unknown metabolite 'nadp[c]' created
# unknown metabolite '2dhguln[c]' created
# unknown metabolite 'idon-L[c]' created
# unknown metabolite '3hcinnm[c]' created
# unknown metabolite 'o2[c]' created
# unknown metabolite 'dhcinnm[c]' created
# unknown metabolite 'h2o[c]' created
# unknown metabolite '3hpppn[c]' created
# unknown metabolite 'dhpppn[c]' created
# unknown metabolite 'phthr[c]' created
# unknown metabolite '4hthr[c]' created
# unknown metabolite 'pi[c]' created
# unknown metabolite '5dglcn[c]' created
# unknown metabolite 'ru5p-D[c]' created
# unknown metabolite 'ara5p[c]' created
# unknown metabolite 'ACP[c]' created
# unknown metabolite 'atp[c]' created
# unknown metabolite 'ttdca[c]' created
# unknown metabolite 'amp[c]' created
# unknown metabolite 'myrsACP[c]' created
# unknown metabolite 'ppi[c]' created
# unknown metabolite 'ttdcea[c]' created
# unknown metabolite 'tdeACP[c]' created
# unknown metabolite 'hdca[c]' created
# unknown metabolite 'palmACP[c]' created
# unknown metabolite 'hdcea[c]' created
# unknown metabolite 'hdeACP[c]' created
# unknown metabolite 'ocdcea[c]' created
# unknown metabolite 'octeACP[c]' created
# unknown metabolite 'dtdp4aaddg[c]' created
# unknown metabolite 'unagamu[c]' created
# unknown metabolite 'dtdp[c]' created
# unknown metabolite 'unagamuf[c]' created
# unknown metabolite 'arbt6p[c]' created
# unknown metabolite 'g6p[c]' created
# unknown metabolite 'hqn[c]' created
# unknown metabolite '4abut[c]' created
# unknown metabolite 'akg[c]' created
# unknown metabolite 'glu-L[c]' created
# unknown metabolite 'sucsal[c]' created
# unknown metabolite '4abutn[c]' created
# unknown metabolite 'acac[c]' created
# unknown metabolite 'accoa[c]' created
# unknown metabolite 'aacoa[c]' created
# unknown metabolite 'ac[c]' created
# unknown metabolite 'coa[c]' created
# unknown metabolite 'acald[c]' created
# unknown metabolite 'adocbip[c]' created
# unknown metabolite 'gtp[c]' created
# unknown metabolite 'agdpcbi[c]' created
# unknown metabolite 'co2tot[c]' created
# unknown metabolite 'adp[c]' created
# unknown metabolite 'malcoa[c]' created
# unknown metabolite 'ppa[c]' created
# unknown metabolite 'ppcoa[c]' created
# unknown metabolite 'uacgam[c]' created
# unknown metabolite 'udcpp[c]' created
# unknown metabolite 'ump[c]' created
# unknown metabolite 'unaga[c]' created
# unknown metabolite 'acglu[c]' created
# unknown metabolite 'acg5p[c]' created
# unknown metabolite '2obut[c]' created
# unknown metabolite 'pyr[c]' created
# unknown metabolite '2ahbut[c]' created
# unknown metabolite 'actp[c]' created
# unknown metabolite 'alac-S[c]' created
# unknown metabolite 'uacmamu[c]' created
# unknown metabolite 'udp[c]' created
# unknown metabolite 'acnam[c]' created
# unknown metabolite 'acmana[c]' created
# unknown metabolite 'acACP[c]' created
# unknown metabolite 'acorn[c]' created
# unknown metabolite 'orn[c]' created
# unknown metabolite 'acon-T[c]' created
# unknown metabolite 'amet[c]' created
# unknown metabolite 'aconm[c]' created
# unknown metabolite 'ahcys[c]' created
# unknown metabolite 'cit[c]' created
# unknown metabolite 'icit[c]' created
# unknown metabolite 'acg5sa[c]' created
# unknown metabolite 'apoACP[c]' created
# unknown metabolite 'pap[c]' created
# unknown metabolite 'adn[c]' created
# unknown metabolite 'ins[c]' created
# unknown metabolite 'nh3[c]' created
# unknown metabolite '4adcho[c]' created
# unknown metabolite '4abz[c]' created
# unknown metabolite 'chor[c]' created
# unknown metabolite 'gln-L[c]' created
# unknown metabolite 'ade[c]' created
# unknown metabolite 'hxan[c]' created
# unknown metabolite 'etoh[c]' created
# unknown metabolite 'gdp[c]' created
# unknown metabolite 'itp[c]' created
# unknown metabolite 'idp[c]' created
# unknown metabolite 'ametam[c]' created
# unknown metabolite 'camp[c]' created
# unknown metabolite 'adocbi[c]' created
# unknown metabolite 'rdmbzi[c]' created
# unknown metabolite 'adocbl[c]' created
# unknown metabolite 'gmp[c]' created
# unknown metabolite 'prpp[c]' created
# unknown metabolite 'aps[c]' created
# unknown metabolite 'paps[c]' created
# unknown metabolite 'dcamp[c]' created
# unknown metabolite 'fum[c]' created
# unknown metabolite '25aics[c]' created
# unknown metabolite 'aicar[c]' created
# unknown metabolite 'asp-L[c]' created
# unknown metabolite 'imp[c]' created
# unknown metabolite 'acgam6p[c]' created
# unknown metabolite 'gam6p[c]' created
# unknown metabolite 'adphep-DD[c]' created
# unknown metabolite 'adphep-LD[c]' created
# unknown metabolite 'agm[c]' created
# unknown metabolite 'ptrc[c]' created
# unknown metabolite 'urea[c]' created
# unknown metabolite 'hcys-L[c]' created
# unknown metabolite 'rhcys[c]' created
# unknown metabolite '10fthf[c]' created
# unknown metabolite 'fprica[c]' created
# unknown metabolite 'thf[c]' created
# unknown metabolite 'air[c]' created
# unknown metabolite '5caiz[c]' created
# unknown metabolite '5aizc[c]' created
# unknown metabolite 'ala-D[c]' created
# unknown metabolite 'alaala[c]' created
# unknown metabolite 'ala-L[c]' created
# unknown metabolite 'pydx5p[c]' created
# unknown metabolite 'pyam5p[c]' created
# unknown metabolite 'glyald[c]' created
# unknown metabolite 'glyc[c]' created
# unknown metabolite 'pacald[c]' created
# unknown metabolite 'pac[c]' created
# unknown metabolite 'alltt[c]' created
# unknown metabolite 'urdglyc[c]' created
# unknown metabolite 'alltn[c]' created
# unknown metabolite 'altrn[c]' created
# unknown metabolite '2ddglcn[c]' created
# unknown metabolite 'malt[c]' created
# unknown metabolite 'malttr[c]' created
# unknown metabolite 'glc-D[c]' created
# unknown metabolite 'maltttr[c]' created
# unknown metabolite 'maltpt[c]' created
# unknown metabolite 'malthx[c]' created
# unknown metabolite 'malthp[c]' created
# unknown metabolite 'acmanap[c]' created
# unknown metabolite '8aonn[c]' created
# unknown metabolite 'amob[c]' created
# unknown metabolite 'dann[c]' created
# unknown metabolite '2dmmq8[c]' created
# unknown metabolite 'mqn8[c]' created
# unknown metabolite '4ampm[c]' created
# unknown metabolite 'for[c]' created
# unknown metabolite 'r5p[c]' created
# unknown metabolite 'anth[c]' created
# unknown metabolite 'pran[c]' created
# unknown metabolite 'pmcoa[c]' created
# unknown metabolite 'ap4a[c]' created
# unknown metabolite 'ap5a[c]' created
# unknown metabolite '5apru[c]' created
# unknown metabolite '5aprbu[c]' created
# unknown metabolite 'arab-L[c]' created
# unknown metabolite 'rbl-L[c]' created
# unknown metabolite 'arg-L[c]' created
# unknown metabolite 'argsuc[c]' created
# unknown metabolite 'citr-L[c]' created
# unknown metabolite 'aspsa[c]' created
# unknown metabolite '4pasp[c]' created
# unknown metabolite 'asn-L[c]' created
# unknown metabolite 'ala-B[c]' created
# unknown metabolite 'cbp[c]' created
# unknown metabolite 'cbasp[c]' created
# unknown metabolite 'q8[c]' created
# unknown metabolite 'iasp[c]' created
# unknown metabolite 'q8h2[c]' created
# unknown metabolite 'mql8[c]' created
# unknown metabolite 'succ[c]' created
# unknown metabolite 'h2o2[c]' created
# unknown metabolite 'oaa[c]' created
# unknown metabolite 'succoa[c]' created
# unknown metabolite 'sucarg[c]' created
# unknown metabolite 'prbatp[c]' created
# unknown metabolite 'betald[c]' created
# unknown metabolite 'glyb[c]' created
# unknown metabolite 'btnso[c]' created
# unknown metabolite 'btn[c]' created
# unknown metabolite 'cys-L[c]' created
# unknown metabolite 'dtbt[c]' created
# unknown metabolite 'but[c]' created
# unknown metabolite 'btcoa[c]' created
# unknown metabolite 'actACP[c]' created
# unknown metabolite 'malACP[c]' created
# unknown metabolite 'ddcaACP[c]' created
# unknown metabolite 'cbi[c]' created
# unknown metabolite 'cbl1[c]' created
# unknown metabolite 'cdpdag1[c]' created
# unknown metabolite 'cmp[c]' created
# unknown metabolite 'paEC[c]' created
# unknown metabolite '4c2me[c]' created
# unknown metabolite '2p4c2me[c]' created
# unknown metabolite 'pphn[c]' created
# unknown metabolite '3psme[c]' created
# unknown metabolite '4hbz[c]' created
# unknown metabolite 'cinnm[c]' created
# unknown metabolite 'cenchddd[c]' created
# unknown metabolite 'pgEC[c]' created
# unknown metabolite 'clpnEC[c]' created
# unknown metabolite 'csn[c]' created
# unknown metabolite 'cpppg3[c]' created
# unknown metabolite 'pppg9[c]' created
# unknown metabolite 'bbtcoa[c]' created
# unknown metabolite 'crn[c]' created
# unknown metabolite 'crncoa[c]' created
# unknown metabolite 'gbbtn[c]' created
# unknown metabolite 'ctbtcoa[c]' created
# unknown metabolite 'ctbt[c]' created
# unknown metabolite 'ura[c]' created
# unknown metabolite 'utp[c]' created
# unknown metabolite 'ctp[c]' created
# unknown metabolite 'cyan[c]' created
# unknown metabolite 'tsul[c]' created
# unknown metabolite 'so3[c]' created
# unknown metabolite 'tcynt[c]' created
# unknown metabolite 'cynt[c]' created
# unknown metabolite 'acser[c]' created
# unknown metabolite 'h2s[c]' created
# unknown metabolite 'cyst-L[c]' created
# unknown metabolite 'cytd[c]' created
# unknown metabolite 'uri[c]' created
# unknown metabolite 'cdp[c]' created
# unknown metabolite 'dcmp[c]' created
# unknown metabolite 'dcdp[c]' created
# unknown metabolite 'fad[c]' created
# unknown metabolite 'fadh2[c]' created
# unknown metabolite 'dad-2[c]' created
# unknown metabolite 'din[c]' created
# unknown metabolite 'damp[c]' created
# unknown metabolite 'dadp[c]' created
# unknown metabolite '12dgrEC[c]' created
# unknown metabolite '26dap-M[c]' created
# unknown metabolite 'lys-L[c]' created
# unknown metabolite '26dap-LL[c]' created
# unknown metabolite 'db4p[c]' created
# unknown metabolite 'dctp[c]' created
# unknown metabolite 'dutp[c]' created
# unknown metabolite 'dcyt[c]' created
# unknown metabolite 'duri[c]' created
# unknown metabolite '2dh3dgal[c]' created
# unknown metabolite '2dh3dgal6p[c]' created
# unknown metabolite '2ddg6p[c]' created
# unknown metabolite 'e4p[c]' created
# unknown metabolite 'pep[c]' created
# unknown metabolite '2dda7p[c]' created
# unknown metabolite 'g3p[c]' created
# unknown metabolite 'dgmp[c]' created
# unknown metabolite 'dgdp[c]' created
# unknown metabolite '23dhmb[c]' created
# unknown metabolite '3mob[c]' created
# unknown metabolite '23dhmp[c]' created
# unknown metabolite '3mop[c]' created
# unknown metabolite 'dha[c]' created
# unknown metabolite 'dhap[c]' created
# unknown metabolite '23ddhb[c]' created
# unknown metabolite '23dhb[c]' created
# unknown metabolite '23dhba[c]' created
# unknown metabolite 'hkntd[c]' created
# unknown metabolite '23dhdp[c]' created
# unknown metabolite 'thdp[c]' created
# unknown metabolite 'dhf[c]' created
# unknown metabolite 'dhpt[c]' created
# unknown metabolite 'dhna[c]' created
# unknown metabolite 'octdp[c]' created
# unknown metabolite 'dhnpt[c]' created
# unknown metabolite '6hmhpt[c]' created
# unknown metabolite 'gcald[c]' created
# unknown metabolite 'dhor-S[c]' created
# unknown metabolite 'orot[c]' created
# unknown metabolite 'cechddd[c]' created
# unknown metabolite '25drapp[c]' created
# unknown metabolite '6hmhptpp[c]' created
# unknown metabolite 'dhptd[c]' created
# unknown metabolite 'hmfurn[c]' created
# unknown metabolite '3dhq[c]' created
# unknown metabolite '3dhsk[c]' created
# unknown metabolite '25dkglcn[c]' created
# unknown metabolite 'dkmpp[c]' created
# unknown metabolite '2kmb[c]' created
# unknown metabolite 'dmpp[c]' created
# unknown metabolite 'ipdp[c]' created
# unknown metabolite 'grdp[c]' created
# unknown metabolite 'h2mb4p[c]' created
# unknown metabolite '2omhmbl[c]' created
# unknown metabolite 'dmso[c]' created
# unknown metabolite 'dms[c]' created
# unknown metabolite '2dmmql8[c]' created
# unknown metabolite 'dhpmp[c]' created
# unknown metabolite 'ahdt[c]' created
# unknown metabolite '23doguln[c]' created
# unknown metabolite '3dhguln[c]' created
# unknown metabolite 'dpcoa[c]' created
# unknown metabolite '2dhp[c]' created
# unknown metabolite 'pant-R[c]' created
# unknown metabolite '2dr5p[c]' created
# unknown metabolite 'dtmp[c]' created
# unknown metabolite 'dump[c]' created
# unknown metabolite '2dr1p[c]' created
# unknown metabolite 'dxyl5p[c]' created
# unknown metabolite '2me4p[c]' created
# unknown metabolite 'dxyl[c]' created
# unknown metabolite '4per[c]' created
# unknown metabolite 'ecaEC[c]' created
# unknown metabolite 'udcpdp[c]' created
# unknown metabolite '6pgc[c]' created
# unknown metabolite 'kdo2lipid4[c]' created
# unknown metabolite 'kdo2lipid4L[c]' created
# unknown metabolite 'lipa[c]' created
# unknown metabolite 'kdo2lipid4p[c]' created
# unknown metabolite 'lipa_cold[c]' created
# unknown metabolite '2pg[c]' created
# unknown metabolite 'seramp[c]' created
# unknown metabolite 'enter[c]' created
# unknown metabolite 'etha[c]' created
# unknown metabolite 'f6p[c]' created
# unknown metabolite 'ocdca[c]' created
# unknown metabolite 'fdp[c]' created
# unknown metabolite 'fuc-L[c]' created
# unknown metabolite 'fcl-L[c]' created
# unknown metabolite 'fc1p[c]' created
# unknown metabolite 'lald-L[c]' created
# unknown metabolite 'fe2[c]' created
# unknown metabolite 'ppp9[c]' created
# unknown metabolite 'pheme[c]' created
# unknown metabolite 'suc6p[c]' created
# unknown metabolite 'fru[c]' created
# unknown metabolite 'h2[c]' created
# unknown metabolite 'fmn[c]' created
# unknown metabolite 'f1p[c]' created
# unknown metabolite 'mal-L[c]' created
# unknown metabolite 'gam1p[c]' created
# unknown metabolite 'acgam1p[c]' created
# unknown metabolite 'g1p[c]' created
# unknown metabolite 'dttp[c]' created
# unknown metabolite 'dtdpglu[c]' created
# unknown metabolite 'glu1sa[c]' created
# unknown metabolite '5aop[c]' created
# unknown metabolite 'glyc3p[c]' created
# unknown metabolite 'glu5sa[c]' created
# unknown metabolite '1pyr5c[c]' created
# unknown metabolite 'glu5p[c]' created
# unknown metabolite '6pgl[c]' created
# unknown metabolite 'galct-D[c]' created
# unknown metabolite '5dh4dglc[c]' created
# unknown metabolite 'galctn-D[c]' created
# unknown metabolite 'gal[c]' created
# unknown metabolite 'gal1p[c]' created
# unknown metabolite 'melib[c]' created
# unknown metabolite 'udpg[c]' created
# unknown metabolite '13dpg[c]' created
# unknown metabolite 'gar[c]' created
# unknown metabolite 'fgam[c]' created
# unknown metabolite 'glyclt[c]' created
# unknown metabolite 'gdpddman[c]' created
# unknown metabolite 'gdpofuc[c]' created
# unknown metabolite 'ser-L[c]' created
# unknown metabolite 'gly[c]' created
# unknown metabolite 'mlthf[c]' created
# unknown metabolite 'glycogen[c]' created
# unknown metabolite '2h3oppan[c]' created
# unknown metabolite 'glcr[c]' created
# unknown metabolite 'adpglc[c]' created
# unknown metabolite 'galt1p[c]' created
# unknown metabolite 'tag6p-D[c]' created
# unknown metabolite 'glucys[c]' created
# unknown metabolite 'pram[c]' created
# unknown metabolite 'glu-D[c]' created
# unknown metabolite 'glutrna[c]' created
# unknown metabolite 'trnaglu[c]' created
# unknown metabolite 'glx[c]' created
# unknown metabolite '2aobut[c]' created
# unknown metabolite 'glyc-R[c]' created
# unknown metabolite '3pg[c]' created
# unknown metabolite 'lgt-S[c]' created
# unknown metabolite 'gthrd[c]' created
# unknown metabolite 'lac-D[c]' created
# unknown metabolite 'gdpmann[c]' created
# unknown metabolite 'gmhep1p[c]' created
# unknown metabolite 'gmhep7p[c]' created
# unknown metabolite 'gmhep17bp[c]' created
# unknown metabolite 'xmp[c]' created
# unknown metabolite 'gdpfuc[c]' created
# unknown metabolite 'gp4g[c]' created
# unknown metabolite 'g3pc[c]' created
# unknown metabolite 'chol[c]' created
# unknown metabolite 'g3pe[c]' created
# unknown metabolite 'g3ps[c]' created
# unknown metabolite 'g3pg[c]' created
# unknown metabolite 'g3pi[c]' created
# unknown metabolite 'inost[c]' created
# unknown metabolite 'frdp[c]' created
# unknown metabolite 'gsn[c]' created
# unknown metabolite 'gtspmd[c]' created
# unknown metabolite 'spmd[c]' created
# unknown metabolite 'gthox[c]' created
# unknown metabolite 'gua[c]' created
# unknown metabolite 'xan[c]' created
# unknown metabolite 'glcur[c]' created
# unknown metabolite 'fruur[c]' created
# unknown metabolite 'galur[c]' created
# unknown metabolite 'tagur[c]' created
# unknown metabolite '3ophb[c]' created
# unknown metabolite 'hemeO[c]' created
# unknown metabolite '4mhetz[c]' created
# unknown metabolite '4mpetz[c]' created
# unknown metabolite 'histd[c]' created
# unknown metabolite 'his-L[c]' created
# unknown metabolite 'hisp[c]' created
# unknown metabolite 'hkndd[c]' created
# unknown metabolite 'op4en[c]' created
# unknown metabolite 'ppbng[c]' created
# unknown metabolite 'hmbil[c]' created
# unknown metabolite '4ahmmp[c]' created
# unknown metabolite '4h2opntn[c]' created
# unknown metabolite 'hpyr[c]' created
# unknown metabolite 'hom-L[c]' created
# unknown metabolite 'phom[c]' created
# unknown metabolite 'suchms[c]' created
# unknown metabolite 'imacp[c]' created
# unknown metabolite 'pydam[c]' created
# unknown metabolite 'ichor[c]' created
# unknown metabolite 'prlp[c]' created
# unknown metabolite 'eig3p[c]' created
# unknown metabolite '2cpr5p[c]' created
# unknown metabolite '3ig3p[c]' created
# unknown metabolite 'ile-L[c]' created
# unknown metabolite '3c2hmp[c]' created
# unknown metabolite '3c4mop[c]' created
# unknown metabolite '2ippm[c]' created
# unknown metabolite '3c3hmp[c]' created
# unknown metabolite '3hmrsACP[c]' created
# unknown metabolite 'kdo[c]' created
# unknown metabolite 'ckdo[c]' created
# unknown metabolite 'kdo8p[c]' created
# unknown metabolite '3dhgulnp[c]' created
# unknown metabolite 'xu5p-L[c]' created
# unknown metabolite 'lcts[c]' created
# unknown metabolite 'lac-L[c]' created
# unknown metabolite '12ppd-S[c]' created
# unknown metabolite '4mop[c]' created
# unknown metabolite 'leu-L[c]' created
# unknown metabolite 'mthgxl[c]' created
# unknown metabolite 'lipidX[c]' created
# unknown metabolite 'u23ga[c]' created
# unknown metabolite 'lipidAds[c]' created
# unknown metabolite 'agpgEC[c]' created
# unknown metabolite 'agpeEC[c]' created
# unknown metabolite 'agpcEC[c]' created
# unknown metabolite 'apgEC[c]' created
# unknown metabolite 'cdpea[c]' created
# unknown metabolite 'lpsEC[c]' created
# unknown metabolite '15dap[c]' created
# unknown metabolite 'mnl1p[c]' created
# unknown metabolite 'man1p[c]' created
# unknown metabolite 'man6p[c]' created
# unknown metabolite 'mana[c]' created
# unknown metabolite '2mcit[c]' created
# unknown metabolite '2mcacn[c]' created
# unknown metabolite 'micit[c]' created
# unknown metabolite '5mdru1p[c]' created
# unknown metabolite '2mecdp[c]' created
# unknown metabolite 'met-L[c]' created
# unknown metabolite '5mthf[c]' created
# unknown metabolite 'mi1p-D[c]' created
# unknown metabolite 'mmcoa-S[c]' created
# unknown metabolite 'mmcoa-R[c]' created
# unknown metabolite 'lipidA[c]' created
# unknown metabolite 'kdolipid4[c]' created
# unknown metabolite '5mta[c]' created
# unknown metabolite '5mtr[c]' created
# unknown metabolite 'methf[c]' created
# unknown metabolite '5mdr1p[c]' created
# unknown metabolite 'nmn[c]' created
# unknown metabolite 'h2o[e]' created
# unknown metabolite 'nad[e]' created
# unknown metabolite 'amp[e]' created
# unknown metabolite 'nmn[e]' created
# unknown metabolite 'dnad[c]' created
# unknown metabolite 'nac[c]' created
# unknown metabolite 'nicrnt[c]' created
# unknown metabolite 'dgtp[c]' created
# unknown metabolite 'dudp[c]' created
# unknown metabolite 'datp[c]' created
# unknown metabolite 'ncam[c]' created
# unknown metabolite 'dmbzid[c]' created
# unknown metabolite '5prdmbz[c]' created
# unknown metabolite 'quln[c]' created
# unknown metabolite 'sbzcoa[c]' created
# unknown metabolite 'xtsn[c]' created
# unknown metabolite 'thymd[c]' created
# unknown metabolite 'dgsn[c]' created
# unknown metabolite 'pppi[c]' created
# unknown metabolite 'no2[c]' created
# unknown metabolite 'ohpb[c]' created
# unknown metabolite '2ohph[c]' created
# unknown metabolite '2omph[c]' created
# unknown metabolite '2ombzl[c]' created
# unknown metabolite '2ommbl[c]' created
# unknown metabolite 'orot5p[c]' created
# unknown metabolite '2oph[c]' created
# unknown metabolite 'thmpp[c]' created
# unknown metabolite 'ssaltpp[c]' created
# unknown metabolite 'pro-L[c]' created
# unknown metabolite 'phaccoa[c]' created
# unknown metabolite 'pnto-R[c]' created
# unknown metabolite 'ugmda[c]' created
# unknown metabolite 'uagmda[c]' created
# unknown metabolite 'trdrd[c]' created
# unknown metabolite 'trdox[c]' created
# unknown metabolite 'pdx5p[c]' created
# unknown metabolite 'pydxn[c]' created
# unknown metabolite 'peamn[c]' created
# unknown metabolite 'peEC[c]' created
# unknown metabolite 'tagdp-D[c]' created
# unknown metabolite '3php[c]' created
# unknown metabolite '2pglyc[c]' created
# unknown metabolite 'pgpEC[c]' created
# unknown metabolite 'phe-L[c]' created
# unknown metabolite 'phpyr[c]' created
# unknown metabolite 'pcEC[c]' created
# unknown metabolite '4r5au[c]' created
# unknown metabolite '2mahmp[c]' created
# unknown metabolite '4ppan[c]' created
# unknown metabolite 'ppap[c]' created
# unknown metabolite '4ppcys[c]' created
# unknown metabolite 'pan4p[c]' created
# unknown metabolite 'r1p[c]' created
# unknown metabolite '34hpp[c]' created
# unknown metabolite 'pppn[c]' created
# unknown metabolite 'uaagmda[c]' created
# unknown metabolite 'peptidoEC[c]' created
# unknown metabolite 'fpram[c]' created
# unknown metabolite 'prbamp[c]' created
# unknown metabolite 'prfp[c]' created
# unknown metabolite 'skm5p[c]' created
# unknown metabolite 'psEC[c]' created
# unknown metabolite 'pser-L[c]' created
# unknown metabolite 'pydx[c]' created
# unknown metabolite 'ribflv[c]' created
# unknown metabolite 'dmlz[c]' created
# unknown metabolite 'rib-D[c]' created
# unknown metabolite 'ru5p-L[c]' created
# unknown metabolite 'xu5p-D[c]' created
# unknown metabolite 'rmn[c]' created
# unknown metabolite 'rml[c]' created
# unknown metabolite 'rml1p[c]' created
# unknown metabolite 's7p[c]' created
# unknown metabolite 'sucorn[c]' created
# unknown metabolite 'so4[c]' created
# unknown metabolite 'sbt6p[c]' created
# unknown metabolite 'sl26da[c]' created
# unknown metabolite 'sl2a6o[c]' created
# unknown metabolite 'seln[c]' created
# unknown metabolite 'selnp[c]' created
# unknown metabolite 'ser-D[c]' created
# unknown metabolite 'sucglu[c]' created
# unknown metabolite 'sucgsa[c]' created
# unknown metabolite '2shchc[c]' created
# unknown metabolite 'scl[c]' created
# unknown metabolite 'srch[c]' created
# unknown metabolite 'sheme[c]' created
# unknown metabolite 'skm[c]' created
# unknown metabolite 'N1aspmd[c]' created
# unknown metabolite 'n8aspmd[c]' created
# unknown metabolite 'o2s[c]' created
# unknown metabolite 'sucbz[c]' created
# unknown metabolite 'tartr-L[c]' created
# unknown metabolite 'taur[c]' created
# unknown metabolite 'aacald[c]' created
# unknown metabolite 'dtdp4addg[c]' created
# unknown metabolite 'dtdp4d6dg[c]' created
# unknown metabolite 'dtdp4d6dm[c]' created
# unknown metabolite 'dtdprmn[c]' created
# unknown metabolite 'thr-L[c]' created
# unknown metabolite 'tyr-L[c]' created
# unknown metabolite '4hba[c]' created
# unknown metabolite 'tmao[c]' created
# unknown metabolite 'tma[c]' created
# unknown metabolite 'thym[c]' created
# unknown metabolite 'thm[c]' created
# unknown metabolite 'thmmp[c]' created
# unknown metabolite 'tre6p[c]' created
# unknown metabolite 'tre[c]' created
# unknown metabolite 'tre[e]' created
# unknown metabolite 'glc-D[e]' created
# unknown metabolite 'trp-L[c]' created
# unknown metabolite 'indole[c]' created
# unknown metabolite 'u3hga[c]' created
# unknown metabolite 'uamag[c]' created
# unknown metabolite 'ugmd[c]' created
# unknown metabolite 'uacmam[c]' created
# unknown metabolite 'u3aga[c]' created
# unknown metabolite 'uaccg[c]' created
# unknown metabolite 'uama[c]' created
# unknown metabolite 'uamr[c]' created
# unknown metabolite 'udpgal[c]' created
# unknown metabolite 'udpgalfur[c]' created
# unknown metabolite 'udpglcur[c]' created
# unknown metabolite 'uppg3[c]' created
# unknown metabolite 'val-L[c]' created
# unknown metabolite 'xyl-D[c]' created
# unknown metabolite 'xylu-D[c]' created
# *** Reading data from Biomass Composition ***
# *** Reading data from Exchange reactions ***
# unknown metabolite '12ppd-S[e]' created
# unknown metabolite '15dap[e]' created
# unknown metabolite '26dap-M[e]' created
# unknown metabolite '2ddglcn[e]' created
# unknown metabolite '3hcinnm[e]' created
# unknown metabolite '3hpppn[e]' created
# unknown metabolite '4abut[e]' created
# unknown metabolite 'ac[e]' created
# unknown metabolite 'acac[e]' created
# unknown metabolite 'acald[e]' created
# unknown metabolite 'acgam[e]' created
# unknown metabolite 'acmana[e]' created
# unknown metabolite 'acnam[e]' created
# unknown metabolite 'ade[e]' created
# unknown metabolite 'adn[e]' created
# unknown metabolite 'akg[e]' created
# unknown metabolite 'ala-D[e]' created
# unknown metabolite 'ala-L[e]' created
# unknown metabolite 'alltn[e]' created
# unknown metabolite 'arab-L[e]' created
# unknown metabolite 'arg-L[e]' created
# unknown metabolite 'asn-L[e]' created
# unknown metabolite 'asp-L[e]' created
# unknown metabolite 'but[e]' created
# unknown metabolite 'charge[e]' created
# unknown metabolite 'cbl1[e]' created
# unknown metabolite 'chol[e]' created
# unknown metabolite 'cit[e]' created
# unknown metabolite 'co2tot[e]' created
# unknown metabolite 'crn[e]' created
# unknown metabolite 'csn[e]' created
# unknown metabolite 'cynt[e]' created
# unknown metabolite 'cys-L[e]' created
# unknown metabolite 'cytd[e]' created
# unknown metabolite 'dad-2[e]' created
# unknown metabolite 'dcyt[e]' created
# unknown metabolite 'dgsn[e]' created
# unknown metabolite 'dha[e]' created
# unknown metabolite 'din[e]' created
# unknown metabolite 'dms[e]' created
# unknown metabolite 'dmso[e]' created
# unknown metabolite 'duri[e]' created
# unknown metabolite 'etoh[e]' created
# unknown metabolite 'fe2[e]' created
# unknown metabolite 'for[e]' created
# unknown metabolite 'fru[e]' created
# unknown metabolite 'fuc1p-L[e]' created
# unknown metabolite 'fuc-L[e]' created
# unknown metabolite 'fum[e]' created
# unknown metabolite 'g6p[e]' created
# unknown metabolite 'gal[e]' created
# unknown metabolite 'galct-D[e]' created
# unknown metabolite 'galctn-D[e]' created
# unknown metabolite 'galt[e]' created
# unknown metabolite 'galur[e]' created
# unknown metabolite 'gam[e]' created
# unknown metabolite 'gbbtn[e]' created
# unknown metabolite 'glcn[e]' created
# unknown metabolite 'glcr[e]' created
# unknown metabolite 'glcur[e]' created
# unknown metabolite 'gln-L[e]' created
# unknown metabolite 'glu-L[e]' created
# unknown metabolite 'gly[e]' created
# unknown metabolite 'glyald[e]' created
# unknown metabolite 'glyb[e]' created
# unknown metabolite 'glyc[e]' created
# unknown metabolite 'glyc3p[e]' created
# unknown metabolite 'glyclt[e]' created
# unknown metabolite 'gsn[e]' created
# unknown metabolite 'gua[e]' created
# unknown metabolite 'h[e]' created
# unknown metabolite 'hdca[e]' created
# unknown metabolite 'his-L[e]' created
# unknown metabolite 'hxan[e]' created
# unknown metabolite 'idon-L[e]' created
# unknown metabolite 'ile-L[e]' created
# unknown metabolite 'indole[e]' created
# unknown metabolite 'ins[e]' created
# unknown metabolite 'k[e]' created
# unknown metabolite 'lac-D[e]' created
# unknown metabolite 'lac-L[e]' created
# unknown metabolite 'lcts[e]' created
# unknown metabolite 'leu-L[e]' created
# unknown metabolite 'lys-L[e]' created
# unknown metabolite 'mal-L[e]' created
# unknown metabolite 'malt[e]' created
# unknown metabolite 'malthx[e]' created
# unknown metabolite 'maltpt[e]' created
# unknown metabolite 'malttr[e]' created
# unknown metabolite 'maltttr[e]' created
# unknown metabolite 'man[e]' created
# unknown metabolite 'man6p[e]' created
# unknown metabolite 'melib[e]' created
# unknown metabolite 'met-D[e]' created
# unknown metabolite 'met-L[e]' created
# unknown metabolite 'mnl[e]' created
# unknown metabolite 'na1[e]' created
# unknown metabolite 'nac[e]' created
# unknown metabolite 'nh3[e]' created
# unknown metabolite 'no2[e]' created
# unknown metabolite 'no3[e]' created
# unknown metabolite 'o2[e]' created
# unknown metabolite 'ocdca[e]' created
# unknown metabolite 'orn[e]' created
# unknown metabolite 'phe-L[e]' created
# unknown metabolite 'pi[e]' created
# unknown metabolite 'pnto-R[e]' created
# unknown metabolite 'pppn[e]' created
# unknown metabolite 'pro-L[e]' created
# unknown metabolite 'ptrc[e]' created
# unknown metabolite 'pyr[e]' created
# unknown metabolite 'rib-D[e]' created
# unknown metabolite 'rmn[e]' created
# unknown metabolite 'sbt-D[e]' created
# unknown metabolite 'ser-D[e]' created
# unknown metabolite 'ser-L[e]' created
# unknown metabolite 'so4[e]' created
# unknown metabolite 'spmd[e]' created
# unknown metabolite 'succ[e]' created
# unknown metabolite 'sucr[e]' created
# unknown metabolite 'tartr-L[e]' created
# unknown metabolite 'taur[e]' created
# unknown metabolite 'thm[e]' created
# unknown metabolite 'thr-L[e]' created
# unknown metabolite 'thymd[e]' created
# unknown metabolite 'tma[e]' created
# unknown metabolite 'tmao[e]' created
# unknown metabolite 'trp-L[e]' created
# unknown metabolite 'tsul[e]' created
# unknown metabolite 'ttdca[e]' created
# unknown metabolite 'tyr-L[e]' created
# unknown metabolite 'ura[e]' created
# unknown metabolite 'urea[e]' created
# unknown metabolite 'uri[e]' created
# unknown metabolite 'val-L[e]' created
# unknown metabolite 'xan[e]' created
# unknown metabolite 'xtsn[e]' created
# unknown metabolite 'xyl-D[e]' created
# *** Reading data from Transmembrane reactions ***
# unknown metabolite 'h[c]' created
# unknown metabolite 'acgam[c]' created
# unknown metabolite 'charge[c]' created
# unknown metabolite 'electron[c]' created
# unknown metabolite 'electron[e]' created
# unknown metabolite 'fuc1p-L[c]' created
# unknown metabolite 'galt[c]' created
# unknown metabolite 'gam[c]' created
# unknown metabolite 'na1[c]' created
# unknown metabolite 'h2[e]' created
# unknown metabolite 'k[c]' created
# unknown metabolite 'malt6p[c]' created
# unknown metabolite 'man[c]' created
# unknown metabolite 'met-D[c]' created
# unknown metabolite 'mnl[c]' created
# unknown metabolite 'no3[c]' created
# unknown metabolite 'sbt-D[c]' created
# unknown metabolite 'sucr[c]' created
# *** Reading data from Parameters ***
# *** Reading data from Metabolites ***
# Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# *** Updating metabolite information ***
# 2dhglcn_c NOTHING DONE!
# nadh_c NOTHING DONE!
# glcn_c NOTHING DONE!
# nad_c NOTHING DONE!
# nadph_c NOTHING DONE!
# nadp_c NOTHING DONE!
# 2dhguln_c NOTHING DONE!
# idon-L_c NOTHING DONE!
# 3hcinnm_c NOTHING DONE!
# o2_c NOTHING DONE!
# dhcinnm_c NOTHING DONE!
# h2o_c NOTHING DONE!
# 3hpppn_c NOTHING DONE!
# dhpppn_c NOTHING DONE!
# phthr_c NOTHING DONE!
# 4hthr_c NOTHING DONE!
# pi_c NOTHING DONE!
# 5dglcn_c NOTHING DONE!
# ru5p-D_c NOTHING DONE!
# ara5p_c NOTHING DONE!
# ACP_c NOTHING DONE!
# atp_c NOTHING DONE!
# ttdca_c NOTHING DONE!
# amp_c NOTHING DONE!
# myrsACP_c NOTHING DONE!
# ppi_c NOTHING DONE!
# ttdcea_c NOTHING DONE!
# tdeACP_c NOTHING DONE!
# hdca_c NOTHING DONE!
# palmACP_c NOTHING DONE!
# hdcea_c NOTHING DONE!
# hdeACP_c NOTHING DONE!
# ocdcea_c NOTHING DONE!
# octeACP_c NOTHING DONE!
# dtdp4aaddg_c NOTHING DONE!
# unagamu_c NOTHING DONE!
# dtdp_c NOTHING DONE!
# unagamuf_c NOTHING DONE!
# arbt6p_c NOTHING DONE!
# g6p_c NOTHING DONE!
# hqn_c NOTHING DONE!
# 4abut_c NOTHING DONE!
# akg_c NOTHING DONE!
# glu-L_c NOTHING DONE!
# sucsal_c NOTHING DONE!
# 4abutn_c NOTHING DONE!
# acac_c NOTHING DONE!
# accoa_c NOTHING DONE!
# aacoa_c NOTHING DONE!
# ac_c NOTHING DONE!
# coa_c NOTHING DONE!
# acald_c NOTHING DONE!
# adocbip_c NOTHING DONE!
# gtp_c NOTHING DONE!
# agdpcbi_c NOTHING DONE!
# co2tot_c NOTHING DONE!
# adp_c NOTHING DONE!
# malcoa_c NOTHING DONE!
# ppa_c NOTHING DONE!
# ppcoa_c NOTHING DONE!
# uacgam_c NOTHING DONE!
# udcpp_c NOTHING DONE!
# ump_c NOTHING DONE!
# unaga_c NOTHING DONE!
# acglu_c NOTHING DONE!
# acg5p_c NOTHING DONE!
# 2obut_c NOTHING DONE!
# pyr_c NOTHING DONE!
# 2ahbut_c NOTHING DONE!
# actp_c NOTHING DONE!
# alac-S_c NOTHING DONE!
# uacmamu_c NOTHING DONE!
# udp_c NOTHING DONE!
# acnam_c NOTHING DONE!
# acmana_c NOTHING DONE!
# acACP_c NOTHING DONE!
# acorn_c NOTHING DONE!
# orn_c NOTHING DONE!
# acon-T_c NOTHING DONE!
# amet_c NOTHING DONE!
# aconm_c NOTHING DONE!
# ahcys_c NOTHING DONE!
# cit_c NOTHING DONE!
# icit_c NOTHING DONE!
# acg5sa_c NOTHING DONE!
# apoACP_c NOTHING DONE!
# pap_c NOTHING DONE!
# adn_c NOTHING DONE!
# ins_c NOTHING DONE!
# nh3_c NOTHING DONE!
# 4adcho_c NOTHING DONE!
# 4abz_c NOTHING DONE!
# chor_c NOTHING DONE!
# gln-L_c NOTHING DONE!
# ade_c NOTHING DONE!
# hxan_c NOTHING DONE!
# etoh_c NOTHING DONE!
# gdp_c NOTHING DONE!
# itp_c NOTHING DONE!
# idp_c NOTHING DONE!
# ametam_c NOTHING DONE!
# camp_c NOTHING DONE!
# adocbi_c NOTHING DONE!
# rdmbzi_c NOTHING DONE!
# adocbl_c NOTHING DONE!
# gmp_c NOTHING DONE!
# prpp_c NOTHING DONE!
# aps_c NOTHING DONE!
# paps_c NOTHING DONE!
# dcamp_c NOTHING DONE!
# fum_c NOTHING DONE!
# 25aics_c NOTHING DONE!
# aicar_c NOTHING DONE!
# asp-L_c NOTHING DONE!
# imp_c NOTHING DONE!
# acgam6p_c NOTHING DONE!
# gam6p_c NOTHING DONE!
# adphep-DD_c NOTHING DONE!
# adphep-LD_c NOTHING DONE!
# agm_c NOTHING DONE!
# ptrc_c NOTHING DONE!
# urea_c NOTHING DONE!
# hcys-L_c NOTHING DONE!
# rhcys_c NOTHING DONE!
# 10fthf_c NOTHING DONE!
# fprica_c NOTHING DONE!
# thf_c NOTHING DONE!
# air_c NOTHING DONE!
# 5caiz_c NOTHING DONE!
# 5aizc_c NOTHING DONE!
# ala-D_c NOTHING DONE!
# alaala_c NOTHING DONE!
# ala-L_c NOTHING DONE!
# pydx5p_c NOTHING DONE!
# pyam5p_c NOTHING DONE!
# glyald_c NOTHING DONE!
# glyc_c NOTHING DONE!
# pacald_c NOTHING DONE!
# pac_c NOTHING DONE!
# alltt_c NOTHING DONE!
# urdglyc_c NOTHING DONE!
# alltn_c NOTHING DONE!
# altrn_c NOTHING DONE!
# 2ddglcn_c NOTHING DONE!
# malt_c NOTHING DONE!
# malttr_c NOTHING DONE!
# glc-D_c NOTHING DONE!
# maltttr_c NOTHING DONE!
# maltpt_c NOTHING DONE!
# malthx_c NOTHING DONE!
# malthp_c NOTHING DONE!
# acmanap_c NOTHING DONE!
# 8aonn_c NOTHING DONE!
# amob_c NOTHING DONE!
# dann_c NOTHING DONE!
# 2dmmq8_c NOTHING DONE!
# mqn8_c NOTHING DONE!
# 4ampm_c NOTHING DONE!
# for_c NOTHING DONE!
# r5p_c NOTHING DONE!
# anth_c NOTHING DONE!
# pran_c NOTHING DONE!
# pmcoa_c NOTHING DONE!
# ap4a_c NOTHING DONE!
# ap5a_c NOTHING DONE!
# 5apru_c NOTHING DONE!
# 5aprbu_c NOTHING DONE!
# arab-L_c NOTHING DONE!
# rbl-L_c NOTHING DONE!
# arg-L_c NOTHING DONE!
# argsuc_c NOTHING DONE!
# citr-L_c NOTHING DONE!
# aspsa_c NOTHING DONE!
# 4pasp_c NOTHING DONE!
# asn-L_c NOTHING DONE!
# ala-B_c NOTHING DONE!
# cbp_c NOTHING DONE!
# cbasp_c NOTHING DONE!
# q8_c NOTHING DONE!
# iasp_c NOTHING DONE!
# q8h2_c NOTHING DONE!
# mql8_c NOTHING DONE!
# succ_c NOTHING DONE!
# h2o2_c NOTHING DONE!
# oaa_c NOTHING DONE!
# succoa_c NOTHING DONE!
# sucarg_c NOTHING DONE!
# prbatp_c NOTHING DONE!
# betald_c NOTHING DONE!
# glyb_c NOTHING DONE!
# btnso_c NOTHING DONE!
# btn_c NOTHING DONE!
# cys-L_c NOTHING DONE!
# dtbt_c NOTHING DONE!
# but_c NOTHING DONE!
# btcoa_c NOTHING DONE!
# actACP_c NOTHING DONE!
# malACP_c NOTHING DONE!
# ddcaACP_c NOTHING DONE!
# cbi_c NOTHING DONE!
# cbl1_c NOTHING DONE!
# cdpdag1_c NOTHING DONE!
# cmp_c NOTHING DONE!
# paEC_c NOTHING DONE!
# 4c2me_c NOTHING DONE!
# 2p4c2me_c NOTHING DONE!
# pphn_c NOTHING DONE!
# 3psme_c NOTHING DONE!
# 4hbz_c NOTHING DONE!
# cinnm_c NOTHING DONE!
# cenchddd_c NOTHING DONE!
# pgEC_c NOTHING DONE!
# clpnEC_c NOTHING DONE!
# csn_c NOTHING DONE!
# cpppg3_c NOTHING DONE!
# pppg9_c NOTHING DONE!
# bbtcoa_c NOTHING DONE!
# crn_c NOTHING DONE!
# crncoa_c NOTHING DONE!
# gbbtn_c NOTHING DONE!
# ctbtcoa_c NOTHING DONE!
# ctbt_c NOTHING DONE!
# ura_c NOTHING DONE!
# utp_c NOTHING DONE!
# ctp_c NOTHING DONE!
# cyan_c NOTHING DONE!
# tsul_c NOTHING DONE!
# so3_c NOTHING DONE!
# tcynt_c NOTHING DONE!
# cynt_c NOTHING DONE!
# acser_c NOTHING DONE!
# h2s_c NOTHING DONE!
# cyst-L_c NOTHING DONE!
# cytd_c NOTHING DONE!
# uri_c NOTHING DONE!
# cdp_c NOTHING DONE!
# dcmp_c NOTHING DONE!
# dcdp_c NOTHING DONE!
# fad_c NOTHING DONE!
# fadh2_c NOTHING DONE!
# dad-2_c NOTHING DONE!
# din_c NOTHING DONE!
# damp_c NOTHING DONE!
# dadp_c NOTHING DONE!
# 12dgrEC_c NOTHING DONE!
# 26dap-M_c NOTHING DONE!
# lys-L_c NOTHING DONE!
# 26dap-LL_c NOTHING DONE!
# db4p_c NOTHING DONE!
# dctp_c NOTHING DONE!
# dutp_c NOTHING DONE!
# dcyt_c NOTHING DONE!
# duri_c NOTHING DONE!
# 2dh3dgal_c NOTHING DONE!
# 2dh3dgal6p_c NOTHING DONE!
# 2ddg6p_c NOTHING DONE!
# e4p_c NOTHING DONE!
# pep_c NOTHING DONE!
# 2dda7p_c NOTHING DONE!
# g3p_c NOTHING DONE!
# dgmp_c NOTHING DONE!
# dgdp_c NOTHING DONE!
# 23dhmb_c NOTHING DONE!
# 3mob_c NOTHING DONE!
# 23dhmp_c NOTHING DONE!
# 3mop_c NOTHING DONE!
# dha_c NOTHING DONE!
# dhap_c NOTHING DONE!
# 23ddhb_c NOTHING DONE!
# 23dhb_c NOTHING DONE!
# 23dhba_c NOTHING DONE!
# hkntd_c NOTHING DONE!
# 23dhdp_c NOTHING DONE!
# thdp_c NOTHING DONE!
# dhf_c NOTHING DONE!
# dhpt_c NOTHING DONE!
# dhna_c NOTHING DONE!
# octdp_c NOTHING DONE!
# dhnpt_c NOTHING DONE!
# 6hmhpt_c NOTHING DONE!
# gcald_c NOTHING DONE!
# dhor-S_c NOTHING DONE!
# orot_c NOTHING DONE!
# cechddd_c NOTHING DONE!
# 25drapp_c NOTHING DONE!
# 6hmhptpp_c NOTHING DONE!
# dhptd_c NOTHING DONE!
# hmfurn_c NOTHING DONE!
# 3dhq_c NOTHING DONE!
# 3dhsk_c NOTHING DONE!
# 25dkglcn_c NOTHING DONE!
# dkmpp_c NOTHING DONE!
# 2kmb_c NOTHING DONE!
# dmpp_c NOTHING DONE!
# ipdp_c NOTHING DONE!
# grdp_c NOTHING DONE!
# h2mb4p_c NOTHING DONE!
# 2omhmbl_c NOTHING DONE!
# dmso_c NOTHING DONE!
# dms_c NOTHING DONE!
# 2dmmql8_c NOTHING DONE!
# dhpmp_c NOTHING DONE!
# ahdt_c NOTHING DONE!
# 23doguln_c NOTHING DONE!
# 3dhguln_c NOTHING DONE!
# dpcoa_c NOTHING DONE!
# 2dhp_c NOTHING DONE!
# pant-R_c NOTHING DONE!
# 2dr5p_c NOTHING DONE!
# dtmp_c NOTHING DONE!
# dump_c NOTHING DONE!
# 2dr1p_c NOTHING DONE!
# dxyl5p_c NOTHING DONE!
# 2me4p_c NOTHING DONE!
# dxyl_c NOTHING DONE!
# 4per_c NOTHING DONE!
# ecaEC_c NOTHING DONE!
# udcpdp_c NOTHING DONE!
# 6pgc_c NOTHING DONE!
# kdo2lipid4_c NOTHING DONE!
# kdo2lipid4L_c NOTHING DONE!
# lipa_c NOTHING DONE!
# kdo2lipid4p_c NOTHING DONE!
# lipa_cold_c NOTHING DONE!
# 2pg_c NOTHING DONE!
# seramp_c NOTHING DONE!
# enter_c NOTHING DONE!
# etha_c NOTHING DONE!
# f6p_c NOTHING DONE!
# ocdca_c NOTHING DONE!
# fdp_c NOTHING DONE!
# fuc-L_c NOTHING DONE!
# fcl-L_c NOTHING DONE!
# fc1p_c NOTHING DONE!
# lald-L_c NOTHING DONE!
# fe2_c NOTHING DONE!
# ppp9_c NOTHING DONE!
# pheme_c NOTHING DONE!
# suc6p_c NOTHING DONE!
# fru_c NOTHING DONE!
# h2_c NOTHING DONE!
# fmn_c NOTHING DONE!
# f1p_c NOTHING DONE!
# mal-L_c NOTHING DONE!
# gam1p_c NOTHING DONE!
# acgam1p_c NOTHING DONE!
# g1p_c NOTHING DONE!
# dttp_c NOTHING DONE!
# dtdpglu_c NOTHING DONE!
# glu1sa_c NOTHING DONE!
# 5aop_c NOTHING DONE!
# glyc3p_c NOTHING DONE!
# glu5sa_c NOTHING DONE!
# 1pyr5c_c NOTHING DONE!
# glu5p_c NOTHING DONE!
# 6pgl_c NOTHING DONE!
# galct-D_c NOTHING DONE!
# 5dh4dglc_c NOTHING DONE!
# galctn-D_c NOTHING DONE!
# gal_c NOTHING DONE!
# gal1p_c NOTHING DONE!
# melib_c NOTHING DONE!
# udpg_c NOTHING DONE!
# 13dpg_c NOTHING DONE!
# gar_c NOTHING DONE!
# fgam_c NOTHING DONE!
# glyclt_c NOTHING DONE!
# gdpddman_c NOTHING DONE!
# gdpofuc_c NOTHING DONE!
# ser-L_c NOTHING DONE!
# gly_c NOTHING DONE!
# mlthf_c NOTHING DONE!
# glycogen_c NOTHING DONE!
# 2h3oppan_c NOTHING DONE!
# glcr_c NOTHING DONE!
# adpglc_c NOTHING DONE!
# galt1p_c NOTHING DONE!
# tag6p-D_c NOTHING DONE!
# glucys_c NOTHING DONE!
# pram_c NOTHING DONE!
# glu-D_c NOTHING DONE!
# glutrna_c NOTHING DONE!
# trnaglu_c NOTHING DONE!
# glx_c NOTHING DONE!
# 2aobut_c NOTHING DONE!
# glyc-R_c NOTHING DONE!
# 3pg_c NOTHING DONE!
# lgt-S_c NOTHING DONE!
# gthrd_c NOTHING DONE!
# lac-D_c NOTHING DONE!
# gdpmann_c NOTHING DONE!
# gmhep1p_c NOTHING DONE!
# gmhep7p_c NOTHING DONE!
# gmhep17bp_c NOTHING DONE!
# xmp_c NOTHING DONE!
# gdpfuc_c NOTHING DONE!
# gp4g_c NOTHING DONE!
# g3pc_c NOTHING DONE!
# chol_c NOTHING DONE!
# g3pe_c NOTHING DONE!
# g3ps_c NOTHING DONE!
# g3pg_c NOTHING DONE!
# g3pi_c NOTHING DONE!
# inost_c NOTHING DONE!
# frdp_c NOTHING DONE!
# gsn_c NOTHING DONE!
# gtspmd_c NOTHING DONE!
# spmd_c NOTHING DONE!
# gthox_c NOTHING DONE!
# gua_c NOTHING DONE!
# xan_c NOTHING DONE!
# glcur_c NOTHING DONE!
# fruur_c NOTHING DONE!
# galur_c NOTHING DONE!
# tagur_c NOTHING DONE!
# 3ophb_c NOTHING DONE!
# hemeO_c NOTHING DONE!
# 4mhetz_c NOTHING DONE!
# 4mpetz_c NOTHING DONE!
# histd_c NOTHING DONE!
# his-L_c NOTHING DONE!
# hisp_c NOTHING DONE!
# hkndd_c NOTHING DONE!
# op4en_c NOTHING DONE!
# ppbng_c NOTHING DONE!
# hmbil_c NOTHING DONE!
# 4ahmmp_c NOTHING DONE!
# 4h2opntn_c NOTHING DONE!
# hpyr_c NOTHING DONE!
# hom-L_c NOTHING DONE!
# phom_c NOTHING DONE!
# suchms_c NOTHING DONE!
# imacp_c NOTHING DONE!
# pydam_c NOTHING DONE!
# ichor_c NOTHING DONE!
# prlp_c NOTHING DONE!
# eig3p_c NOTHING DONE!
# 2cpr5p_c NOTHING DONE!
# 3ig3p_c NOTHING DONE!
# ile-L_c NOTHING DONE!
# 3c2hmp_c NOTHING DONE!
# 3c4mop_c NOTHING DONE!
# 2ippm_c NOTHING DONE!
# 3c3hmp_c NOTHING DONE!
# 3hmrsACP_c NOTHING DONE!
# kdo_c NOTHING DONE!
# ckdo_c NOTHING DONE!
# kdo8p_c NOTHING DONE!
# 3dhgulnp_c NOTHING DONE!
# xu5p-L_c NOTHING DONE!
# lcts_c NOTHING DONE!
# lac-L_c NOTHING DONE!
# 12ppd-S_c NOTHING DONE!
# 4mop_c NOTHING DONE!
# leu-L_c NOTHING DONE!
# mthgxl_c NOTHING DONE!
# lipidX_c NOTHING DONE!
# u23ga_c NOTHING DONE!
# lipidAds_c NOTHING DONE!
# agpgEC_c NOTHING DONE!
# agpeEC_c NOTHING DONE!
# agpcEC_c NOTHING DONE!
# apgEC_c NOTHING DONE!
# cdpea_c NOTHING DONE!
# lpsEC_c NOTHING DONE!
# 15dap_c NOTHING DONE!
# mnl1p_c NOTHING DONE!
# man1p_c NOTHING DONE!
# man6p_c NOTHING DONE!
# mana_c NOTHING DONE!
# 2mcit_c NOTHING DONE!
# 2mcacn_c NOTHING DONE!
# micit_c NOTHING DONE!
# 5mdru1p_c NOTHING DONE!
# 2mecdp_c NOTHING DONE!
# met-L_c NOTHING DONE!
# 5mthf_c NOTHING DONE!
# mi1p-D_c NOTHING DONE!
# mmcoa-S_c NOTHING DONE!
# mmcoa-R_c NOTHING DONE!
# lipidA_c NOTHING DONE!
# kdolipid4_c NOTHING DONE!
# 5mta_c NOTHING DONE!
# 5mtr_c NOTHING DONE!
# methf_c NOTHING DONE!
# 5mdr1p_c NOTHING DONE!
# nmn_c NOTHING DONE!
# h2o_e NOTHING DONE!
# nad_e NOTHING DONE!
# amp_e NOTHING DONE!
# nmn_e NOTHING DONE!
# dnad_c NOTHING DONE!
# nac_c NOTHING DONE!
# nicrnt_c NOTHING DONE!
# dgtp_c NOTHING DONE!
# dudp_c NOTHING DONE!
# datp_c NOTHING DONE!
# ncam_c NOTHING DONE!
# dmbzid_c NOTHING DONE!
# 5prdmbz_c NOTHING DONE!
# quln_c NOTHING DONE!
# sbzcoa_c NOTHING DONE!
# xtsn_c NOTHING DONE!
# thymd_c NOTHING DONE!
# dgsn_c NOTHING DONE!
# pppi_c NOTHING DONE!
# no2_c NOTHING DONE!
# ohpb_c NOTHING DONE!
# 2ohph_c NOTHING DONE!
# 2omph_c NOTHING DONE!
# 2ombzl_c NOTHING DONE!
# 2ommbl_c NOTHING DONE!
# orot5p_c NOTHING DONE!
# 2oph_c NOTHING DONE!
# thmpp_c NOTHING DONE!
# ssaltpp_c NOTHING DONE!
# pro-L_c NOTHING DONE!
# phaccoa_c NOTHING DONE!
# pnto-R_c NOTHING DONE!
# ugmda_c NOTHING DONE!
# uagmda_c NOTHING DONE!
# trdrd_c NOTHING DONE!
# trdox_c NOTHING DONE!
# pdx5p_c NOTHING DONE!
# pydxn_c NOTHING DONE!
# peamn_c NOTHING DONE!
# peEC_c NOTHING DONE!
# tagdp-D_c NOTHING DONE!
# 3php_c NOTHING DONE!
# 2pglyc_c NOTHING DONE!
# pgpEC_c NOTHING DONE!
# phe-L_c NOTHING DONE!
# phpyr_c NOTHING DONE!
# pcEC_c NOTHING DONE!
# 4r5au_c NOTHING DONE!
# 2mahmp_c NOTHING DONE!
# 4ppan_c NOTHING DONE!
# ppap_c NOTHING DONE!
# 4ppcys_c NOTHING DONE!
# pan4p_c NOTHING DONE!
# r1p_c NOTHING DONE!
# 34hpp_c NOTHING DONE!
# pppn_c NOTHING DONE!
# uaagmda_c NOTHING DONE!
# peptidoEC_c NOTHING DONE!
# fpram_c NOTHING DONE!
# prbamp_c NOTHING DONE!
# prfp_c NOTHING DONE!
# skm5p_c NOTHING DONE!
# psEC_c NOTHING DONE!
# pser-L_c NOTHING DONE!
# pydx_c NOTHING DONE!
# ribflv_c NOTHING DONE!
# dmlz_c NOTHING DONE!
# rib-D_c NOTHING DONE!
# ru5p-L_c NOTHING DONE!
# xu5p-D_c NOTHING DONE!
# rmn_c NOTHING DONE!
# rml_c NOTHING DONE!
# rml1p_c NOTHING DONE!
# s7p_c NOTHING DONE!
# sucorn_c NOTHING DONE!
# so4_c NOTHING DONE!
# sbt6p_c NOTHING DONE!
# sl26da_c NOTHING DONE!
# sl2a6o_c NOTHING DONE!
# seln_c NOTHING DONE!
# selnp_c NOTHING DONE!
# ser-D_c NOTHING DONE!
# sucglu_c NOTHING DONE!
# sucgsa_c NOTHING DONE!
# 2shchc_c NOTHING DONE!
# scl_c NOTHING DONE!
# srch_c NOTHING DONE!
# sheme_c NOTHING DONE!
# skm_c NOTHING DONE!
# N1aspmd_c NOTHING DONE!
# n8aspmd_c NOTHING DONE!
# o2s_c NOTHING DONE!
# sucbz_c NOTHING DONE!
# tartr-L_c NOTHING DONE!
# taur_c NOTHING DONE!
# aacald_c NOTHING DONE!
# dtdp4addg_c NOTHING DONE!
# dtdp4d6dg_c NOTHING DONE!
# dtdp4d6dm_c NOTHING DONE!
# dtdprmn_c NOTHING DONE!
# thr-L_c NOTHING DONE!
# tyr-L_c NOTHING DONE!
# 4hba_c NOTHING DONE!
# tmao_c NOTHING DONE!
# tma_c NOTHING DONE!
# thym_c NOTHING DONE!
# thm_c NOTHING DONE!
# thmmp_c NOTHING DONE!
# tre6p_c NOTHING DONE!
# tre_c NOTHING DONE!
# tre_e NOTHING DONE!
# glc-D_e NOTHING DONE!
# trp-L_c NOTHING DONE!
# indole_c NOTHING DONE!
# u3hga_c NOTHING DONE!
# uamag_c NOTHING DONE!
# ugmd_c NOTHING DONE!
# uacmam_c NOTHING DONE!
# u3aga_c NOTHING DONE!
# uaccg_c NOTHING DONE!
# uama_c NOTHING DONE!
# uamr_c NOTHING DONE!
# udpgal_c NOTHING DONE!
# udpgalfur_c NOTHING DONE!
# udpglcur_c NOTHING DONE!
# uppg3_c NOTHING DONE!
# val-L_c NOTHING DONE!
# xyl-D_c NOTHING DONE!
# xylu-D_c NOTHING DONE!
# 12ppd-S_e NOTHING DONE!
# 15dap_e NOTHING DONE!
# 26dap-M_e NOTHING DONE!
# 2ddglcn_e NOTHING DONE!
# 3hcinnm_e NOTHING DONE!
# 3hpppn_e NOTHING DONE!
# 4abut_e NOTHING DONE!
# ac_e NOTHING DONE!
# acac_e NOTHING DONE!
# acald_e NOTHING DONE!
# acgam_e NOTHING DONE!
# acmana_e NOTHING DONE!
# acnam_e NOTHING DONE!
# ade_e NOTHING DONE!
# adn_e NOTHING DONE!
# akg_e NOTHING DONE!
# ala-D_e NOTHING DONE!
# ala-L_e NOTHING DONE!
# alltn_e NOTHING DONE!
# arab-L_e NOTHING DONE!
# arg-L_e NOTHING DONE!
# asn-L_e NOTHING DONE!
# asp-L_e NOTHING DONE!
# but_e NOTHING DONE!
# charge_e NOTHING DONE!
# cbl1_e NOTHING DONE!
# chol_e NOTHING DONE!
# cit_e NOTHING DONE!
# co2tot_e NOTHING DONE!
# crn_e NOTHING DONE!
# csn_e NOTHING DONE!
# cynt_e NOTHING DONE!
# cys-L_e NOTHING DONE!
# cytd_e NOTHING DONE!
# dad-2_e NOTHING DONE!
# dcyt_e NOTHING DONE!
# dgsn_e NOTHING DONE!
# dha_e NOTHING DONE!
# din_e NOTHING DONE!
# dms_e NOTHING DONE!
# dmso_e NOTHING DONE!
# duri_e NOTHING DONE!
# etoh_e NOTHING DONE!
# fe2_e NOTHING DONE!
# for_e NOTHING DONE!
# fru_e NOTHING DONE!
# fuc1p-L_e NOTHING DONE!
# fuc-L_e NOTHING DONE!
# fum_e NOTHING DONE!
# g6p_e NOTHING DONE!
# gal_e NOTHING DONE!
# galct-D_e NOTHING DONE!
# galctn-D_e NOTHING DONE!
# galt_e NOTHING DONE!
# galur_e NOTHING DONE!
# gam_e NOTHING DONE!
# gbbtn_e NOTHING DONE!
# glcn_e NOTHING DONE!
# glcr_e NOTHING DONE!
# glcur_e NOTHING DONE!
# gln-L_e NOTHING DONE!
# glu-L_e NOTHING DONE!
# gly_e NOTHING DONE!
# glyald_e NOTHING DONE!
# glyb_e NOTHING DONE!
# glyc_e NOTHING DONE!
# glyc3p_e NOTHING DONE!
# glyclt_e NOTHING DONE!
# gsn_e NOTHING DONE!
# gua_e NOTHING DONE!
# h_e NOTHING DONE!
# hdca_e NOTHING DONE!
# his-L_e NOTHING DONE!
# hxan_e NOTHING DONE!
# idon-L_e NOTHING DONE!
# ile-L_e NOTHING DONE!
# indole_e NOTHING DONE!
# ins_e NOTHING DONE!
# k_e NOTHING DONE!
# lac-D_e NOTHING DONE!
# lac-L_e NOTHING DONE!
# lcts_e NOTHING DONE!
# leu-L_e NOTHING DONE!
# lys-L_e NOTHING DONE!
# mal-L_e NOTHING DONE!
# malt_e NOTHING DONE!
# malthx_e NOTHING DONE!
# maltpt_e NOTHING DONE!
# malttr_e NOTHING DONE!
# maltttr_e NOTHING DONE!
# man_e NOTHING DONE!
# man6p_e NOTHING DONE!
# melib_e NOTHING DONE!
# met-D_e NOTHING DONE!
# met-L_e NOTHING DONE!
# mnl_e NOTHING DONE!
# na1_e NOTHING DONE!
# nac_e NOTHING DONE!
# nh3_e NOTHING DONE!
# no2_e NOTHING DONE!
# no3_e NOTHING DONE!
# o2_e NOTHING DONE!
# ocdca_e NOTHING DONE!
# orn_e NOTHING DONE!
# phe-L_e NOTHING DONE!
# pi_e NOTHING DONE!
# pnto-R_e NOTHING DONE!
# pppn_e NOTHING DONE!
# pro-L_e NOTHING DONE!
# ptrc_e NOTHING DONE!
# pyr_e NOTHING DONE!
# rib-D_e NOTHING DONE!
# rmn_e NOTHING DONE!
# sbt-D_e NOTHING DONE!
# ser-D_e NOTHING DONE!
# ser-L_e NOTHING DONE!
# so4_e NOTHING DONE!
# spmd_e NOTHING DONE!
# succ_e NOTHING DONE!
# sucr_e NOTHING DONE!
# tartr-L_e NOTHING DONE!
# taur_e NOTHING DONE!
# thm_e NOTHING DONE!
# thr-L_e NOTHING DONE!
# thymd_e NOTHING DONE!
# tma_e NOTHING DONE!
# tmao_e NOTHING DONE!
# trp-L_e NOTHING DONE!
# tsul_e NOTHING DONE!
# ttdca_e NOTHING DONE!
# tyr-L_e NOTHING DONE!
# ura_e NOTHING DONE!
# urea_e NOTHING DONE!
# uri_e NOTHING DONE!
# val-L_e NOTHING DONE!
# xan_e NOTHING DONE!
# xtsn_e NOTHING DONE!
# xyl-D_e NOTHING DONE!
# h_c NOTHING DONE!
# acgam_c NOTHING DONE!
# charge_c NOTHING DONE!
# electron_c NOTHING DONE!
# electron_e NOTHING DONE!
# fuc1p-L_c NOTHING DONE!
# galt_c NOTHING DONE!
# gam_c NOTHING DONE!
# na1_c NOTHING DONE!
# h2_e NOTHING DONE!
# k_c NOTHING DONE!
# malt6p_c NOTHING DONE!
# man_c NOTHING DONE!
# met-D_c NOTHING DONE!
# mnl_c NOTHING DONE!
# no3_c NOTHING DONE!
# sbt-D_c NOTHING DONE!
# sucr_c NOTHING DONE!
# *** Editing special metabolites ***
# *** Removing electrons from the model ***
# Initializing component contribution object...
# cxcalc is not installed, operating in read-only mode. A local cache may be loaded, but no compounds can be created. Install cxcalc and obtain a ChemAxon license to enable compound creation.
# Loading compounds from ecoli_compound.sqlite
# added reaction:  biomass_ce: biomass_c <=> biomass_e
# added reaction:  biomass_EX: biomass_e <=>
# ['Parameters', 'Exchange reactions', 'Reactions', 'Biomass Composition', 'Transmembrane reactions', 'Metabolites', 'references', 'Transmembrane_reactions_reed', 'Transmembrane reactions_Orth', 'Transmembrane reactions old', 'Sheet3', 'log', 'subsystems']
# biomass : 0.05 5mthf_c + 5e-05 accoa_c + 0.488 ala-L_c + 0.001 amp_c + 0.281 arg-L_c + 0.2
# biomass_ce : biomass_c <=> biomass_e
# ...
# Metabolite phpyr_c - Old: 0.0001 millimolar, 1.8545957687244532 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.8545957687244767, 'millimolar')>)
# Metabolite 4r5au_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite 4ppan_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.0000000000000147, 'millimolar')>)
# Metabolite ppap_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999958e-05, 'millimolar')>, <Quantity(1.0000000000000147, 'millimolar')>)
# Metabolite 4ppcys_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999958e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite pan4p_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite r1p_c - Old: 1.5890905485947e-06 molar, 4.2618760403243e-06 molar | New: (<Quantity(0.0015890905485946736, 'millimolar')>, <Quantity(0.004261876040324297, 'millimolar')>)
# Metabolite 34hpp_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite uaagmda_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999958e-05, 'millimolar')>, <Quantity(1.0000000000000147, 'millimolar')>)
# Metabolite peptidoEC_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999994e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite fpram_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999958e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite prbamp_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999994e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite prfp_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite skm5p_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite psEC_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.0000000000000147, 'millimolar')>)
# Metabolite pser-L_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999958e-05, 'millimolar')>, <Quantity(1.0000000000000147, 'millimolar')>)
# Metabolite pydx_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999958e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite ribflv_c - Old: 0.015311375157527536 millimolar, 0.08292651771636537 millimolar | New: (<Quantity(0.015311375157527412, 'millimolar')>, <Quantity(0.08292651771636679, 'millimolar')>)
# Metabolite dmlz_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.0000000000000147, 'millimolar')>)
# Metabolite xu5p-D_c - Old: 0.00013042841716804057 molar, 0.0001860306465223834 molar | New: (<Quantity(0.13042841716803932, 'millimolar')>, <Quantity(0.1860306465223872, 'millimolar')>)
# Metabolite s7p_c - Old: 7.455074867766725e-05 molar, 0.00010896737577295717 molar | New: (<Quantity(0.07455074867766656, 'millimolar')>, <Quantity(0.10896737577295881, 'millimolar')>)
# Metabolite sucorn_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.0000000000000147, 'millimolar')>)
# Metabolite so4_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.0000000000000147, 'millimolar')>)
# Metabolite sl26da_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.000000000000009, 'millimolar')>)
# Metabolite sl2a6o_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.000000000000009, 'millimolar')>)
# Metabolite sucglu_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.0000000000000147, 'millimolar')>)
# Metabolite sucgsa_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.0000000000000147, 'millimolar')>)
# Metabolite skm_c - Old: 0.008454942331367852 millimolar, 0.09753266809218342 millimolar | New: (<Quantity(0.008454942331367772, 'millimolar')>, <Quantity(0.09753266809218344, 'millimolar')>)
# Metabolite thr-L_c - Old: 0.0001 millimolar, 0.7303075187909025 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(0.7303075187909025, 'millimolar')>)
# Metabolite tyr-L_c - Old: 4.5925935951462314e-05 molar, 5.679006380595028e-05 molar | New: (<Quantity(0.04592593595146191, 'millimolar')>, <Quantity(0.056790063805950926, 'millimolar')>)
# Metabolite tmao_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999994e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite tma_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999994e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite tre6p_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.000000000000009, 'millimolar')>)
# Metabolite tre_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.0000000000000147, 'millimolar')>)
# Metabolite tre_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite glc-D_e - Old: 0.0245115452930728 molar, 0.0277697602131438 molar | New: (<Quantity(24.511545293072608, 'millimolar')>, <Quantity(27.769760213144323, 'millimolar')>)
# Metabolite trp-L_c - Old: 0.0001 millimolar, 0.06728716860537388 millimolar | New: (<Quantity(9.999999999999958e-05, 'millimolar')>, <Quantity(0.06728716860537384, 'millimolar')>)
# Metabolite indole_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite u3hga_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999958e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite uamag_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.99999931737788e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite ugmd_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.0000000000000147, 'millimolar')>)
# Metabolite u3aga_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.0000000000000147, 'millimolar')>)
# Metabolite uaccg_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.0000000000000147, 'millimolar')>)
# Metabolite uama_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.0000000000000147, 'millimolar')>)
# Metabolite uamr_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.0000000000000147, 'millimolar')>)
# Metabolite val-L_c - Old: 0.0001 millimolar, 17.990502292166138 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(17.990502292166447, 'millimolar')>)
# Metabolite xyl-D_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.0000000000000147, 'millimolar')>)
# Metabolite 4abut_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.0000000000000082, 'millimolar')>)
# Metabolite ac_e - Old: 1e-07 molar, 0.0029638913352753 molar | New: (<Quantity(9.999999999999958e-05, 'millimolar')>, <Quantity(0.20707720626155077, 'millimolar')>)
# Metabolite ala-L_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite arab-L_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999958e-05, 'millimolar')>, <Quantity(1.000000000000009, 'millimolar')>)
# Metabolite arg-L_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999958e-05, 'millimolar')>, <Quantity(1.000000000000009, 'millimolar')>)
# Metabolite asn-L_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.000000000000009, 'millimolar')>)
# Metabolite asp-L_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.000000000000009, 'millimolar')>)
# Metabolite charge_e - Old: 0.1 micromolar, 10 millimolar | New: (<Quantity(1000.0000000000089, 'millimolar')>, <Quantity(1000.0000000000089, 'millimolar')>)
# Metabolite chol_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999958e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite co2tot_e - Old: 0.06 millimolar, 0.1 millimolar | New: (<Quantity(0.05999999999999932, 'millimolar')>, <Quantity(0.10000000000000098, 'millimolar')>)
# Metabolite dms_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999994e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite dmso_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999994e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite for_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.000000000000009, 'millimolar')>)
# Metabolite fru_e - Old: 26.8 millimolar, 27.8 millimolar | New: (<Quantity(26.799999999999997, 'millimolar')>, <Quantity(27.799999999999994, 'millimolar')>)
# Metabolite fum_e - Old: 0.0001 millimolar, 0.15 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(0.15000000000000138, 'millimolar')>)
# Metabolite gal_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999958e-05, 'millimolar')>, <Quantity(1.000000000000009, 'millimolar')>)
# Metabolite glcn_e - Old: 24.5 millimolar, 25.5 millimolar | New: (<Quantity(24.5, 'millimolar')>, <Quantity(25.500000000000004, 'millimolar')>)
# Metabolite glu-L_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999958e-05, 'millimolar')>, <Quantity(1.000000000000009, 'millimolar')>)
# Metabolite glyb_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.000000000000009, 'millimolar')>)
# Metabolite glyc3p_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite h_e - Old: 0.00013676323053056464 millimolar, 0.00013676323053056464 millimolar | New: (<Quantity(1000.0000000000089, 'millimolar')>, <Quantity(1000.0000000000089, 'millimolar')>)
# Metabolite his-L_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999958e-05, 'millimolar')>, <Quantity(1.000000000000009, 'millimolar')>)
# Metabolite ile-L_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999958e-05, 'millimolar')>, <Quantity(1.0000000000000147, 'millimolar')>)
# Metabolite k_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite leu-L_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.000000000000009, 'millimolar')>)
# Metabolite lys-L_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999958e-05, 'millimolar')>, <Quantity(1.000000000000009, 'millimolar')>)
# Metabolite na1_e - Old: 0.0001 millimolar, 93.0 millimolar | New: (<Quantity(9.999999999999958e-05, 'millimolar')>, <Quantity(93.00000000000087, 'millimolar')>)
# Metabolite nh3_e - Old: 21.8 millimolar, 22.7 millimolar | New: (<Quantity(21.799999999999997, 'millimolar')>, <Quantity(22.700000000000006, 'millimolar')>)
# Metabolite o2_e - Old: 0.1 millimolar, 0.3 millimolar | New: (<Quantity(0.1214093823531272, 'millimolar')>, <Quantity(0.30000000000000226, 'millimolar')>)
# Metabolite orn_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.000000000000009, 'millimolar')>)
# Metabolite pi_e - Old: 64.1 millimolar, 64.2 millimolar | New: (<Quantity(64.20000000000086, 'millimolar')>, <Quantity(64.20000000000086, 'millimolar')>)
# Metabolite pro-L_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite ptrc_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999958e-05, 'millimolar')>, <Quantity(1.000000000000009, 'millimolar')>)
# Metabolite ser-L_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999958e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite so4_e - Old: 12.3 millimolar, 12.4 millimolar | New: (<Quantity(12.299999999999995, 'millimolar')>, <Quantity(12.400000000000004, 'millimolar')>)
# Metabolite succ_e - Old: 0.0001 millimolar, 42.4 millimolar | New: (<Quantity(9.999999999999994e-05, 'millimolar')>, <Quantity(42.400000000000375, 'millimolar')>)
# Metabolite thr-L_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.0000000000000147, 'millimolar')>)
# Metabolite tma_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999994e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite tmao_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999994e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite val-L_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999994e-05, 'millimolar')>, <Quantity(1.0000000000000147, 'millimolar')>)
# Metabolite xyl-D_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999958e-05, 'millimolar')>, <Quantity(1.000000000000009, 'millimolar')>)
# Metabolite h_c - Old: 3.347513949028939e-05 millimolar, 3.347513949028939e-05 millimolar | New: (<Quantity(1000.0, 'millimolar')>, <Quantity(1000.0, 'millimolar')>)
# Metabolite charge_c - Old: 0.1 micromolar, 10 millimolar | New: (<Quantity(1000.0, 'millimolar')>, <Quantity(1000.0, 'millimolar')>)
# Metabolite na1_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999958e-05, 'millimolar')>, <Quantity(1.0000000000000147, 'millimolar')>)
# Metabolite h2_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999883161154e-05, 'millimolar')>, <Quantity(1.0000000000000147, 'millimolar')>)
# Metabolite k_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite no3_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999994e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite biomass_c - Old: 0.1 micromolar, 10 millimolar | New: (<Quantity(1000.0000000000089, 'millimolar')>, <Quantity(1000.0000000000089, 'millimolar')>)
# Metabolite biomass_e - Old: 0.1 micromolar, 10 millimolar | New: (<Quantity(1000.0000000000089, 'millimolar')>, <Quantity(1000.0000000000089, 'millimolar')>)
# Metabolite orot_e - Old: 1e-07 molar, 7.687379884689302e-05 molar | New: (<Quantity(9.999999999999816e-05, 'millimolar')>, <Quantity(0.07687379884689308, 'millimolar')>)

# %%
for m in tmodel_glc.metabolites:
    print(m.id, m.lower_bound, m.upper_bound)
# Out:
# 2dhglcn_c 9.999999999999994e-05 millimolar 1.0000000000000002 millimolar
# nadh_c 9.999999999999816e-05 millimolar 2.8331401300858796 millimolar
# glcn_c 9.999999999999816e-05 millimolar 0.751009460922482 millimolar
# nad_c 9.999999999999958e-05 millimolar 21.680209268635853 millimolar
# nadph_c 9.999999999999994e-05 millimolar 2.8197358694660406 millimolar
# nadp_c 9.999999999999816e-05 millimolar 0.06950785924102032 millimolar
# 2dhguln_c 9.999999999999958e-05 millimolar 1.0000000000000002 millimolar
# idon-L_c 9.999999999999994e-05 millimolar 1.0000000000000002 millimolar
# o2_c 0.10000000000000009 millimolar 0.2470978718328591 millimolar
# h2o_c 1000.0000000000142 millimolar 1000.0000000000142 millimolar
# pi_c 20.0 millimolar 25.0 millimolar
# 5dglcn_c 9.999999999999994e-05 millimolar 1.0000000000000147 millimolar
# ru5p-D_c 0.2529258990048428 millimolar 0.43422349673789307 millimolar
# ara5p_c 9.999999999999994e-05 millimolar 1.0000000000000002 millimolar
# ACP_c 9.999999999999994e-05 millimolar 1.0000000000000002 millimolar
# atp_c 1.07390928425843 millimolar 1.5488588623986213 millimolar
# ttdca_c 9.999999999999994e-05 millimolar 1.0000000000000002 millimolar
# amp_c 9.999999999999887e-05 millimolar 2.099753181512876 millimolar
# myrsACP_c 9.999999999999994e-05 millimolar 1.0000000000000002 millimolar
# ppi_c 9.999999999999887e-05 millimolar 1.000000000000009 millimolar
# ttdcea_c 9.999999999999994e-05 millimolar 1.0000000000000002 millimolar
# tdeACP_c 9.999999999999994e-05 millimolar 1.0000000000000002 millimolar
# hdca_c 9.999999999999994e-05 millimolar 1.0000000000000002 millimolar
# palmACP_c 9.999999999999994e-05 millimolar 1.0000000000000002 millimolar
# hdcea_c 9.999999999999994e-05 millimolar 1.0000000000000002 millimolar
# hdeACP_c 9.999999999999958e-05 millimolar 1.0000000000000002 millimolar
# ocdcea_c 9.999999999999994e-05 millimolar 1.0000000000000002 millimolar
# octeACP_c 9.999999999999958e-05 millimolar 1.0000000000000002 millimolar
# dtdp_c 0.7920570976154991 millimolar 1.6723844264994927 millimolar
# g6p_c 0.8331641916238636 millimolar 1.1413781466564306 millimolar
# 4abut_c 9.999999999999958e-05 millimolar 1.0000000000000002 millimolar
# akg_c 0.22332074810516525 millimolar 0.30345089799289304 millimolar
# glu-L_c 14.48329556099599 millimolar 19.196262456452807 millimolar
# sucsal_c 9.999999999999994e-05 millimolar 1.0000000000000002 millimolar
# 4abutn_c 9.999999999999994e-05 millimolar 1.0000000000000002 millimolar
# accoa_c 9.999999999999994e-05 millimolar 3.01974343384571 millimolar
# ac_c 0.00048291167244015617 millimolar 1.0000000000000002 millimolar
# coa_c 9.999999999999994e-05 millimolar 94.4583161872691 millimolar
# acald_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# gtp_c 0.8181857847443271 millimolar 1.5193640729881532 millimolar
# co2tot_c 0.1999999999999977 millimolar 0.4000000000000001 millimolar
# adp_c 0.5804872270140016 millimolar 0.7666542358275786 millimolar
# malcoa_c 9.999999999999994e-05 millimolar 6.2549057746590115 millimolar
# ppa_c 9.999999999999994e-05 millimolar 1.000000000000009 millimolar
# ppcoa_c 0.008585566440419887 millimolar 0.02780710200274305 millimolar
# uacgam_c 1.9891701059352 millimolar 48.07363043748245 millimolar
# udcpp_c 9.999999999999994e-05 millimolar 1.0000000000000002 millimolar
# ump_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# acglu_c 9.999999999999958e-05 millimolar 1.0000000000000002 millimolar
# acg5p_c 9.999999999999994e-05 millimolar 1.000000000000009 millimolar
# 2obut_c 9.999999999999994e-05 millimolar 1.0000000000000002 millimolar
# pyr_c 9.999999999999887e-05 millimolar 16.54093737387252 millimolar
# 2ahbut_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# actp_c 9.999999999999816e-05 millimolar 4.9183975755305696 millimolar
# alac-S_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# udp_c 2.422483476964924 millimolar 10.133264217369797 millimolar
# acACP_c 9.999999999999994e-05 millimolar 1.0000000000000147 millimolar
# acorn_c 9.999999999999816e-05 millimolar 2.643720488381686 millimolar
# orn_c 9.999999999999816e-05 millimolar 0.23316039947858894 millimolar
# amet_c 9.999999999999816e-05 millimolar 5.425505086089706 millimolar
# cit_c 9.999999999999958e-05 millimolar 58.453682937570036 millimolar
# icit_c 0.45278998766924755 millimolar 0.5604891102588931 millimolar
# acg5sa_c 9.999999999999958e-05 millimolar 1.0000000000000147 millimolar
# pap_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# adn_c 0.00020709858744248958 millimolar 0.0006919119473422747 millimolar
# ins_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# nh3_c 0.04999999999999959 millimolar 1.0000000000000002 millimolar
# 4adcho_c 9.9999983554927e-05 millimolar 1.000000000000009 millimolar
# 4abz_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# chor_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# gln-L_c 1.654744489618875 millimolar 2.035418883995997 millimolar
# ade_c 0.0029568548321777734 millimolar 0.09141525331664965 millimolar
# hxan_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# gdp_c 0.1917706539297247 millimolar 0.9177632504334342 millimolar
# ametam_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# gmp_c 0.01956585726149315 millimolar 0.030276168294363647 millimolar
# prpp_c 9.999999999999994e-05 millimolar 1.000000000000009 millimolar
# aps_c 0.011566171110607015 millimolar 0.03321019014989537 millimolar
# paps_c 9.999999999999994e-05 millimolar 1.0000000000000147 millimolar
# dcamp_c 9.999999999999887e-05 millimolar 1.0000000000000002 millimolar
# fum_c 0.36695633853924514 millimolar 0.5519264085196675 millimolar
# 25aics_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# aicar_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# asp-L_c 0.9039711646320768 millimolar 1.0396074177473242 millimolar
# imp_c 0.36417295909872605 millimolar 3.6236924810315223 millimolar
# gam6p_c 9.999999999999958e-05 millimolar 5.405067300319711 millimolar
# adphep-DD_c 0.00012140938235312743 millimolar 1.0000000000000002 millimolar
# adphep-LD_c 9.999999999999816e-05 millimolar 0.823659572776197 millimolar
# ptrc_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# hcys-L_c 0.8668690873452923 millimolar 1.4843648755912826 millimolar
# 10fthf_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# fprica_c 9.999999999999958e-05 millimolar 1.0000000000000002 millimolar
# thf_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# air_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# 5caiz_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# 5aizc_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# ala-D_c 9.999999999999958e-05 millimolar 1.0000000000000002 millimolar
# alaala_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# ala-L_c 9.999999999999816e-05 millimolar 11.043674674399105 millimolar
# pydx5p_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# pyam5p_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# glyc_c 9.999999999999958e-05 millimolar 1.000000000000009 millimolar
# malt_c 9.999999999999958e-05 millimolar 1.000000000000009 millimolar
# malttr_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# glc-D_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# maltttr_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# maltpt_c 9.999999999999958e-05 millimolar 1.0000000000000002 millimolar
# malthx_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# malthp_c 9.999999999999958e-05 millimolar 1.0000000000000147 millimolar
# 2dmmq8_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# mqn8_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# for_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# r5p_c 0.16566647052920253 millimolar 0.21990673024630078 millimolar
# anth_c 0.001190884734474342 millimolar 0.014329068932374593 millimolar
# pran_c 9.999999999999958e-05 millimolar 1.0000000000000147 millimolar
# 5apru_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# 5aprbu_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# arab-L_c 9.999999999999958e-05 millimolar 1.0000000000000002 millimolar
# arg-L_c 9.999999999999816e-05 millimolar 48.512102021072934 millimolar
# argsuc_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# citr-L_c 0.47569956151796833 millimolar 5.838501843992367 millimolar
# aspsa_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# 4pasp_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# asn-L_c 0.22880172479817568 millimolar 0.2990276735146681 millimolar
# ala-B_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# cbp_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# cbasp_c 0.00010533525026811916 millimolar 3.5050802595628925 millimolar
# q8_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# iasp_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# q8h2_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# mql8_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# succ_c 0.5153572358713774 millimolar 0.7403862959467264 millimolar
# h2o2_c 9.999999999999994e-05 millimolar 1.0000000000000002 millimolar
# oaa_c 0.000521263873785091 millimolar 1.0000000000000147 millimolar
# succoa_c 9.999999999999958e-05 millimolar 10.005830987914187 millimolar
# sucarg_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# prbatp_c 9.999999999999994e-05 millimolar 1.0000000000000002 millimolar
# betald_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# glyb_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# btnso_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# btn_c 9.999999999999958e-05 millimolar 1.0000000000000147 millimolar
# cys-L_c 9.999999999999958e-05 millimolar 1.000000000000009 millimolar
# actACP_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# malACP_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# ddcaACP_c 9.999999999999958e-05 millimolar 1.0000000000000147 millimolar
# cdpdag1_c 9.999999999999958e-05 millimolar 1.0000000000000002 millimolar
# cmp_c 0.25293577480078505 millimolar 2.4284209364673313 millimolar
# paEC_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# pphn_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# 3psme_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# pgEC_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# clpnEC_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# csn_c 0.016565512011598383 millimolar 0.08401505195846563 millimolar
# ura_c 9.999999999999958e-05 millimolar 1.0000000000000002 millimolar
# utp_c 2.3163362417797857 millimolar 34.99142800060508 millimolar
# ctp_c 9.999999999999816e-05 millimolar 12.785329461759437 millimolar
# so3_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# acser_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# h2s_c 9.999999999999958e-05 millimolar 1.0000000000000002 millimolar
# cyst-L_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# cytd_c 0.000819369411326372 millimolar 0.019138411129290312 millimolar
# uri_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# cdp_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# dcmp_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# dcdp_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# fad_c 9.999999999999816e-05 millimolar 1.5438969950507069 millimolar
# fadh2_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# dad-2_c 0.003598100458433177 millimolar 0.01632801363150391 millimolar
# din_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# damp_c 9.999999999999816e-05 millimolar 0.08092757301723653 millimolar
# dadp_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# 12dgrEC_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# 26dap-M_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# lys-L_c 9.999999999999816e-05 millimolar 2.217095847240276 millimolar
# 26dap-LL_c 9.999999999999958e-05 millimolar 1.0000000000000147 millimolar
# db4p_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# dctp_c 0.05854335069331882 millimolar 0.1755508859532626 millimolar
# dutp_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# dcyt_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# duri_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# 2ddg6p_c 9.999999999999816e-05 millimolar 0.057027058930045386 millimolar
# e4p_c 0.012362503741650634 millimolar 0.10785233540288025 millimolar
# pep_c 0.034504781981836465 millimolar 0.06250058422650734 millimolar
# 2dda7p_c 9.999999999999994e-05 millimolar 1.0000000000000002 millimolar
# g3p_c 0.0003892358978111947 millimolar 1.000000000000009 millimolar
# dgmp_c 0.08870564496533341 millimolar 0.2535295207509902 millimolar
# dgdp_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# 23dhmb_c 9.999999861026469e-05 millimolar 1.0000000000000002 millimolar
# 3mob_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# 23dhmp_c 9.999999999999958e-05 millimolar 1.0000000000000147 millimolar
# 3mop_c 9.999999999999958e-05 millimolar 1.0000000000000147 millimolar
# dha_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# dhap_c 0.8210887873458381 millimolar 1.0352038098127225 millimolar
# 23dhdp_c 9.999999999999958e-05 millimolar 1.0000000000000147 millimolar
# thdp_c 9.999999999999958e-05 millimolar 1.0000000000000002 millimolar
# dhf_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# dhpt_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# dhnpt_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# 6hmhpt_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# gcald_c 9.999999999999958e-05 millimolar 1.0000000000000147 millimolar
# dhor-S_c 0.002839802059131147 millimolar 0.04848925260264896 millimolar
# orot_c 9.999999999999887e-05 millimolar 1.000000000000009 millimolar
# 25drapp_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# 6hmhptpp_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# 3dhq_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# 3dhsk_c 9.999999999999958e-05 millimolar 1.0000000000000147 millimolar
# 25dkglcn_c 9.999999999999958e-05 millimolar 1.000000000000009 millimolar
# dkmpp_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# 2kmb_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# dmpp_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# ipdp_c 9.999999999999958e-05 millimolar 1.000000000000009 millimolar
# h2mb4p_c 9.999999999999958e-05 millimolar 1.0000000000000147 millimolar
# dmso_c 9.999999999999994e-05 millimolar 1.0000000000000002 millimolar
# dms_c 9.999999999999994e-05 millimolar 1.0000000000000002 millimolar
# 2dmmql8_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# dhpmp_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# ahdt_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# dpcoa_c 9.999999999999958e-05 millimolar 1.0000000000000147 millimolar
# 2dhp_c 9.999999999999958e-05 millimolar 1.0000000000000002 millimolar
# pant-R_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# 2dr5p_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# dtmp_c 0.0001022954279237066 millimolar 1.0000000000000002 millimolar
# dump_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# 2dr1p_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# udcpdp_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# 6pgc_c 0.2998102415354885 millimolar 0.4691602860031934 millimolar
# kdo2lipid4_c 9.999999999999816e-05 millimolar 1.0000000000000082 millimolar
# kdo2lipid4L_c 9.999999999999958e-05 millimolar 1.0000000000000147 millimolar
# lipa_c 9.999999999999958e-05 millimolar 1.0000000000000147 millimolar
# 2pg_c 9.999999372402306e-05 millimolar 1.000000000000009 millimolar
# etha_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# f6p_c 0.2949509213346693 millimolar 0.3419853784020027 millimolar
# fdp_c 1.1960216637122925 millimolar 1.5632652126261695 millimolar
# fmn_c 9.999999999999816e-05 millimolar 0.34516027331606125 millimolar
# f1p_c 0.007259862626783357 millimolar 1.2053878900373598 millimolar
# mal-L_c 1.988288588599587 millimolar 2.316049634210315 millimolar
# gam1p_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# acgam1p_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# g1p_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# dttp_c 0.46915623880116075 millimolar 20.009238522970552 millimolar
# glyc3p_c 9.999999999999958e-05 millimolar 5.533469910918429 millimolar
# glu5sa_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# 1pyr5c_c 9.999999999999958e-05 millimolar 1.000000000000009 millimolar
# glu5p_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# 6pgl_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# gal_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# udpg_c 0.1367554447830436 millimolar 17.574880127000743 millimolar
# 13dpg_c 0.01129116318541232 millimolar 0.01835877687513674 millimolar
# gar_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# fgam_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# glyclt_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# ser-L_c 9.999999999999958e-05 millimolar 0.7354694733786807 millimolar
# gly_c 9.999999999999958e-05 millimolar 1.0000000000000002 millimolar
# mlthf_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# glycogen_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# 2h3oppan_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# adpglc_c 0.005854335069331897 millimolar 0.02404671098457849 millimolar
# pram_c 9.999999999999958e-05 millimolar 1.0000000000000002 millimolar
# glu-D_c 14.483295560995847 millimolar 19.19626245645298 millimolar
# glx_c 9.999999999999887e-05 millimolar 1.0000000000000002 millimolar
# 2aobut_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# glyc-R_c 0.455996889781632 millimolar 10.402429048143679 millimolar
# 3pg_c 1.184341411757462 millimolar 10.632899414949772 millimolar
# lgt-S_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# gthrd_c 6.432086230704892 millimolar 70.85368339488974 millimolar
# lac-D_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# gmhep1p_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# gmhep7p_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# gmhep17bp_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# xmp_c 9.999999999999958e-05 millimolar 1.000000000000009 millimolar
# g3pc_c 9.999999827797512e-05 millimolar 1.0000000000000147 millimolar
# chol_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# g3pe_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# g3pg_c 9.999999999999958e-05 millimolar 1.000000000000009 millimolar
# gsn_c 0.002719356452083162 millimolar 0.008292651771636537 millimolar
# gtspmd_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# spmd_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# gua_c 9.999999999999958e-05 millimolar 1.0153055749044344 millimolar
# xan_c 9.999999999999958e-05 millimolar 1.0000000000000002 millimolar
# histd_c 9.999999999999816e-05 millimolar 0.1727546252638132 millimolar
# his-L_c 9.999999999999816e-05 millimolar 0.6163809999312367 millimolar
# hisp_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# hpyr_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# hom-L_c 9.999999999999994e-05 millimolar 1.0000000000000147 millimolar
# phom_c 9.999999999999958e-05 millimolar 1.000000000000009 millimolar
# suchms_c 9.999999999999958e-05 millimolar 1.0000000000000147 millimolar
# imacp_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# pydam_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# prlp_c 9.999999999999958e-05 millimolar 1.0000000000000002 millimolar
# eig3p_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# 2cpr5p_c 9.999999999999994e-05 millimolar 1.0000000000000147 millimolar
# 3ig3p_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# ile-L_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# 3c2hmp_c 9.999999999999958e-05 millimolar 1.000000000000009 millimolar
# 3c4mop_c 9.999999999999958e-05 millimolar 1.000000000000009 millimolar
# 2ippm_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# 3c3hmp_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# 3hmrsACP_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# kdo_c 9.999999999999958e-05 millimolar 1.0000000000000002 millimolar
# ckdo_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# kdo8p_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# lac-L_c 9.999999999999958e-05 millimolar 1.000000000000009 millimolar
# 4mop_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# leu-L_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# mthgxl_c 9.999999999999958e-05 millimolar 1.0000000000000147 millimolar
# lipidX_c 9.999999999999958e-05 millimolar 1.0000000000000147 millimolar
# u23ga_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# lipidAds_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# agpgEC_c 9.999999999999958e-05 millimolar 1.0000000000000147 millimolar
# agpeEC_c 9.999999999999958e-05 millimolar 1.0000000000000147 millimolar
# agpcEC_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# apgEC_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# cdpea_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# lpsEC_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# 2mcit_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# 2mcacn_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# micit_c 9.999999999999958e-05 millimolar 1.0000000000000002 millimolar
# 5mdru1p_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# met-L_c 9.999999999999816e-05 millimolar 0.6333290135856178 millimolar
# 5mthf_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# mmcoa-S_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# mmcoa-R_c 9.999999999999958e-05 millimolar 1.0000000000000002 millimolar
# lipidA_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# kdolipid4_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# 5mta_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# 5mtr_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# methf_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# 5mdr1p_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# nmn_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# h2o_e 1000.0000000000089 millimolar 1000.0000000000089 millimolar
# nmn_e 9.999999999999958e-05 millimolar 1.0000000000000002 millimolar
# dnad_c 9.999999999999958e-05 millimolar 1.0000000000000147 millimolar
# nac_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# nicrnt_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# dgtp_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# dudp_c 9.999999999999958e-05 millimolar 1.000000000000009 millimolar
# datp_c 9.999999999999816e-05 millimolar 0.3969615781581211 millimolar
# ncam_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# quln_c 9.999999999999958e-05 millimolar 0.14940627261118225 millimolar
# xtsn_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# thymd_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# dgsn_c 0.000941681077075093 millimolar 0.0025630033518542535 millimolar
# pppi_c 9.999999999999994e-05 millimolar 1.0000000000000002 millimolar
# no2_c 9.999999999999958e-05 millimolar 1.0000000000000002 millimolar
# orot5p_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# pro-L_c 9.999999999999816e-05 millimolar 1.5773850744616515 millimolar
# pnto-R_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# ugmda_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# uagmda_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# trdrd_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# trdox_c 9.999999999999958e-05 millimolar 1.0000000000000002 millimolar
# pdx5p_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# pydxn_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# peEC_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# 3php_c 9.999999999999958e-05 millimolar 1.0000000000000002 millimolar
# pgpEC_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# phe-L_c 0.05023376162746347 millimolar 0.061391490998537926 millimolar
# phpyr_c 9.999999999999816e-05 millimolar 1.8545957687244767 millimolar
# 4r5au_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# 4ppan_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# ppap_c 9.999999999999958e-05 millimolar 1.0000000000000147 millimolar
# 4ppcys_c 9.999999999999958e-05 millimolar 1.0000000000000002 millimolar
# pan4p_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# r1p_c 0.0015890905485946736 millimolar 0.004261876040324297 millimolar
# 34hpp_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# uaagmda_c 9.999999999999958e-05 millimolar 1.0000000000000147 millimolar
# peptidoEC_c 9.999999999999994e-05 millimolar 1.0000000000000002 millimolar
# fpram_c 9.999999999999958e-05 millimolar 1.0000000000000002 millimolar
# prbamp_c 9.999999999999994e-05 millimolar 1.0000000000000002 millimolar
# prfp_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# skm5p_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# psEC_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# pser-L_c 9.999999999999958e-05 millimolar 1.0000000000000147 millimolar
# pydx_c 9.999999999999958e-05 millimolar 1.0000000000000002 millimolar
# ribflv_c 0.015311375157527412 millimolar 0.08292651771636679 millimolar
# dmlz_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# xu5p-D_c 0.13042841716803932 millimolar 0.1860306465223872 millimolar
# s7p_c 0.07455074867766656 millimolar 0.10896737577295881 millimolar
# sucorn_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# so4_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# sl26da_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# sl2a6o_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# sucglu_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# sucgsa_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# skm_c 0.008454942331367772 millimolar 0.09753266809218344 millimolar
# thr-L_c 9.999999999999816e-05 millimolar 0.7303075187909025 millimolar
# tyr-L_c 0.04592593595146191 millimolar 0.056790063805950926 millimolar
# tmao_c 9.999999999999994e-05 millimolar 1.0000000000000002 millimolar
# tma_c 9.999999999999994e-05 millimolar 1.0000000000000002 millimolar
# tre6p_c 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# tre_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# tre_e 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# glc-D_e 24.511545293072608 millimolar 27.769760213144323 millimolar
# trp-L_c 9.999999999999958e-05 millimolar 0.06728716860537384 millimolar
# indole_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# u3hga_c 9.999999999999958e-05 millimolar 1.0000000000000002 millimolar
# uamag_c 9.99999931737788e-05 millimolar 1.0000000000000002 millimolar
# ugmd_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# u3aga_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# uaccg_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# uama_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# uamr_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# val-L_c 9.999999999999816e-05 millimolar 17.990502292166447 millimolar
# xyl-D_c 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# 4abut_e 9.999999999999816e-05 millimolar 1.0000000000000082 millimolar
# ac_e 9.999999999999958e-05 millimolar 0.20707720626155077 millimolar
# ala-L_e 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# arab-L_e 9.999999999999958e-05 millimolar 1.000000000000009 millimolar
# arg-L_e 9.999999999999958e-05 millimolar 1.000000000000009 millimolar
# asn-L_e 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# asp-L_e 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# charge_e 1000.0000000000089 millimolar 1000.0000000000089 millimolar
# chol_e 9.999999999999958e-05 millimolar 1.0000000000000002 millimolar
# co2tot_e 0.05999999999999932 millimolar 0.10000000000000098 millimolar
# dms_e 9.999999999999994e-05 millimolar 1.0000000000000002 millimolar
# dmso_e 9.999999999999994e-05 millimolar 1.0000000000000002 millimolar
# for_e 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# fru_e 26.799999999999997 millimolar 27.799999999999994 millimolar
# fum_e 9.999999999999816e-05 millimolar 0.15000000000000138 millimolar
# gal_e 9.999999999999958e-05 millimolar 1.000000000000009 millimolar
# glcn_e 24.5 millimolar 25.500000000000004 millimolar
# glu-L_e 9.999999999999958e-05 millimolar 1.000000000000009 millimolar
# glyb_e 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# glyc3p_e 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# h_e 1000.0000000000089 millimolar 1000.0000000000089 millimolar
# his-L_e 9.999999999999958e-05 millimolar 1.000000000000009 millimolar
# ile-L_e 9.999999999999958e-05 millimolar 1.0000000000000147 millimolar
# k_e 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# leu-L_e 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# lys-L_e 9.999999999999958e-05 millimolar 1.000000000000009 millimolar
# na1_e 9.999999999999958e-05 millimolar 93.00000000000087 millimolar
# nh3_e 21.799999999999997 millimolar 22.700000000000006 millimolar
# o2_e 0.1214093823531272 millimolar 0.30000000000000226 millimolar
# orn_e 9.999999999999816e-05 millimolar 1.000000000000009 millimolar
# pi_e 64.20000000000086 millimolar 64.20000000000086 millimolar
# pro-L_e 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# ptrc_e 9.999999999999958e-05 millimolar 1.000000000000009 millimolar
# ser-L_e 9.999999999999958e-05 millimolar 1.0000000000000002 millimolar
# so4_e 12.299999999999995 millimolar 12.400000000000004 millimolar
# succ_e 9.999999999999994e-05 millimolar 42.400000000000375 millimolar
# thr-L_e 9.999999999999816e-05 millimolar 1.0000000000000147 millimolar
# tma_e 9.999999999999994e-05 millimolar 1.0000000000000002 millimolar
# tmao_e 9.999999999999994e-05 millimolar 1.0000000000000002 millimolar
# val-L_e 9.999999999999994e-05 millimolar 1.0000000000000147 millimolar
# xyl-D_e 9.999999999999958e-05 millimolar 1.000000000000009 millimolar
# h_c 1000.0 millimolar 1000.0 millimolar
# charge_c 1000.0 millimolar 1000.0 millimolar
# na1_c 9.999999999999958e-05 millimolar 1.0000000000000147 millimolar
# h2_e 9.999999883161154e-05 millimolar 1.0000000000000147 millimolar
# k_c 9.999999999999816e-05 millimolar 1.0000000000000002 millimolar
# no3_c 9.999999999999994e-05 millimolar 1.0000000000000002 millimolar
# biomass_c 1000.0000000000089 millimolar 1000.0000000000089 millimolar
# biomass_e 1000.0000000000089 millimolar 1000.0000000000089 millimolar
# orot_e 9.999999999999816e-05 millimolar 0.07687379884689308 millimolar

# %%
save_conc_bounds_linear(tmodel_glc, "results/bounds/ecoli_WT_Glc_concs_after_tva.csv")

# %%
# Recreate thermodynamic variables with new metabolite concentrations
tmodel_glc.m = None
tmodel_glc.objective = tmodel_glc.reactions.biomass_EX
tmodel_glc.add_TFBA_variables(qnorm='sep_norm')
add_rq_constraint(tmodel_glc, "WT-Glc_I", INPUT_EXP_DATA)
# Out:
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 10
# >>>>>> RQ: 0.74 (vCO2 = 12.9 / vO2 = -17.4) ERR: 0.17932102098560615

# %%
# Create one .mps.gz file per reaction in the model
# Make sure output folder exists
tfva_run_scenarios_one_model(tmodel_glc, "ecoli", "WT_Glc", "../results/WT_Glc/parallel")
# Out:
# 0
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2

# %%
# Save only the flux bounds from before and after the TFVA for Glc condition for later use
completed_ids = save_flux_bounds_tfva(tmodel_glc, "results/ecoli_WT_Glc_fluxes_no_metabolome_objval.txt", "results/bounds/ecoli_WT_Glc_bounds_no_metabolome_after_tfva.csv")

# %%
fva_glc = flux_variability_analysis(tmodel_glc, None, processes=1)

# %%
apply_fva_bounds(tmodel_glc, fva_glc)
# Out:
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.02817525405600171, 0.029478951950638044 ---> 0.02817525405600171, 0.029478951950638044
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -10.0, 9.990913480566938 ---> -10.0, 9.990913480566938
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -14.000000000000002, 13.987278872793715 ---> -14.0, 13.987278872793715
# Before/after: -100.0, 99.90913480566938 ---> -100.0, 99.90913480566938
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 99.971824745944 ---> -100.0, 99.971824745944
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.1851516695108684, 0.1937188271041929 ---> 0.1851516695108684, 0.1937188271041929
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.5568362668207236, 0.5826016518379836 ---> 0.5568362668207236, 0.5826016518379836
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.0335419691142817, 0.03509399041742256 ---> 0.0335419691142817, 0.03509399041742256
# Before/after: 0.0335419691142817, 0.03509399041742256 ---> 0.0335419691142817, 0.03509399041742256
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.004695875676000285, 0.004913158658439443 ---> 0.004695875676000285, 0.004913158658439443
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.15634515559615414, 0.16357940625388778 ---> 0.15634515559615414, 0.16357940625388778
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.33012609757736294, 0.3454013706068011 ---> 0.33012609757736294, 0.3454013706068011
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.016905152433601026, 0.017687371170382826 ---> 0.016905152433601026, 0.017687371170382826
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.39050164198283227, 0.40857055335779174 ---> 0.39050164198283227, 0.40857055335779174
# Before/after: 0.3301260975771143, 0.3454013706064245 ---> 0.3301260975771143, 0.3454013706064245
# Before/after: -0.34540137060662346, -0.3301260975774767 ---> -0.34540137060662346, -0.3301260975774767
# Before/after: 0.018515166951086837, 0.019371882710419286 ---> 0.018515166951086837, 0.019371882710419286
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.03622532664343077, 0.03790150965082262 ---> 0.03622532664343077, 0.03790150965082262
# Before/after: 0.03622532664343077, 0.03790150965082262 ---> 0.03622532664343077, 0.03790150965082262
# Before/after: 6.7083938226630835e-06, 7.018798100943968e-06 ---> 6.7083938226630835e-06, 7.018798100943968e-06
# Before/after: -99.8114941335777, 100.0 ---> -99.8114941335777, 100.0
# Before/after: -99.8114941335777, 100.0 ---> -99.8114941335777, 100.0
# Before/after: -100.0, 99.66484864461003 ---> -100.0, 99.66484864461003
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 3.957952355904126e-05, 4.141090872167297e-05 ---> 3.957952355904126e-05, 4.141090872167297e-05
# Before/after: 0.4732656874187313, 0.5765682096581484 ---> 0.4732656874187313, 0.5765682096581484
# Before/after: -99.66484864461003, 100.0 ---> -99.66484864461003, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 99.8114941335777 ---> -100.0, 99.8114941335777
# Before/after: 3.15, 100.0 ---> 3.15, 100.0
# Before/after: 0.06037554440571795, 0.06316918275136724 ---> 0.06037554440571795, 0.06316918275136724
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.15634515559617057, 0.1635794062539706 ---> 0.15634515559617057, 0.1635794062539706
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.02817525405600171, 0.029478951950638044 ---> 0.02817525405600171, 0.029478951950638044
# Before/after: -99.99073034141558, 100.0 ---> -99.99073034141558, 100.0
# Before/after: 0.009086519433060552, 0.009506962004083519 ---> 0.009086519433060552, 0.009506962004083519
# Before/after: -99.93457706008196, 100.0 ---> -99.93457706008196, 100.0
# Before/after: 0.012721127206283711, 0.013309746805715063 ---> 0.012721127206283711, 0.013309746805715063
# Before/after: 0.09086519433060403, 0.09506962004081743 ---> 0.09086519433060403, 0.09506962004081743
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.20594769036172678, 0.21547710116299715 ---> 0.20594769036172678, 0.21547710116299715
# Before/after: 0.2757149861194393, 0.2884726012312245 ---> 0.2757149861194393, 0.2884726012312245
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.00432691401574312, 0.004527124763847985 ---> 0.00432691401574312, 0.004527124763847985
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -99.84365484440384, 100.0 ---> -99.84365484440384, 100.0
# Before/after: 0.09794254981372022, 0.10247445201888464 ---> 0.09794254981372022, 0.10247445201888464
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -99.9887298983776, 100.0 ---> -99.9887298983776, 100.0
# Before/after: 0.21869363862515456, 0.22881281752161914 ---> 0.21869363862515456, 0.22881281752161914
# Before/after: 0.2372088055762414, 0.24818470023203842 ---> 0.2372088055762414, 0.24818470023203842
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 1.3416787652431594e-05, 1.4037596201887936e-05 ---> 1.3416787652431594e-05, 1.4037596201887936e-05
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.27571498611943906, 0.28847260123124374 ---> 0.27571498611943906, 0.28847260123124374
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.5568362668207385, 0.582601651837976 ---> 0.5568362668207385, 0.582601651837976
# Before/after: 0.1851516695108684, 0.19371882710419186 ---> 0.1851516695108684, 0.19371882710419186
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.2372088055762414, 0.24818470023203842 ---> 0.2372088055762414, 0.24818470023203842
# Before/after: 0.2372088055762414, 0.24818470023203842 ---> 0.2372088055762414, 0.24818470023203842
# Before/after: 0.050111701856739854, 0.05243042168362322 ---> 0.050111701856739854, 0.05243042168362322
# Before/after: 0.0335419691142817, 0.03509399041742156 ---> 0.0335419691142817, 0.03509399041742156
# Before/after: 0.0335419691142817, 0.03509399041742156 ---> 0.0335419691142817, 0.03509399041742156
# Before/after: -99.5267343125813, 100.0 ---> -99.5267343125813, 100.0
# Before/after: -99.5267343125813, 100.0 ---> -99.5267343125813, 100.0
# Before/after: -0.5765682096581486, -0.47326568741874553 ---> -0.5765682096581486, -0.47326568741874553
# Before/after: 6.708393826215797e-06, 7.018798100943968e-06 ---> 6.708393826215797e-06, 7.018798100943968e-06
# Before/after: 0.0335419691142817, 0.03509399041742256 ---> 0.0335419691142817, 0.03509399041742256
# Before/after: 0.27571498611943923, 0.2884726012312401 ---> 0.27571498611943923, 0.2884726012312401
# Before/after: 0.27571498611943923, 0.2884726012312401 ---> 0.27571498611943923, 0.2884726012312401
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -15.863310173812286, 36.04419364438183 ---> -15.863310173812286, 36.04419364438183
# Before/after: -36.03949116401469, 15.868000765736994 ---> -36.03949116401469, 15.868000765736994
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.033541969114281756, 0.03509399041741468 ---> 0.033541969114281756, 0.03509399041741468
# Before/after: 0.033541969114281756, 0.03509399041743677 ---> 0.033541969114281756, 0.03509399041743677
# Before/after: 3.957952358746297e-05, 4.141090872167297e-05 ---> 3.957952358746297e-05, 4.141090872167297e-05
# Before/after: 3.957952358746297e-05, 4.141090872167297e-05 ---> 3.957952358746297e-05, 4.141090872167297e-05
# Before/after: -100.0, 99.77643673829884 ---> -100.0, 99.77643673829884
# Before/after: -99.98343026725755, 100.0 ---> -99.98343026725755, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.005635050811200342, 0.005895790390127609 ---> 0.005635050811200342, 0.005895790390127609
# Before/after: 0.005635050811200342, 0.005895790390127609 ---> 0.005635050811200342, 0.005895790390127609
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 99.92208200574751 ---> -100.0, 99.92208200574751
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 99.99073034141558 ---> -100.0, 99.99073034141558
# Before/after: -100.0, 99.934577060082 ---> -100.0, 99.934577060082
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 6.7083938120049424e-06, 7.018798072522259e-06 ---> 6.7083938120049424e-06, 7.018798072522259e-06
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.04830043552457436, 0.05053534620109379 ---> 0.04830043552457436, 0.05053534620109379
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -99.85912372972, 100.0 ---> -99.85912372972, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 99.95169956447542 ---> -100.0, 99.95169956447542
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -99.98671738023074, 100.0 ---> -99.98671738023074, 100.0
# Before/after: -92.1661990689631, 100.0 ---> -92.1661990689631, 100.0
# Before/after: -99.66987390242282, 100.0 ---> -99.66987390242282, 100.0
# Before/after: -99.66987390242338, 100.0 ---> -99.66987390242338, 100.0
# Before/after: 0.03354196911428045, 0.035093990417426446 ---> 0.03354196911428045, 0.035093990417426446
# Before/after: -99.95169956447542, 100.0 ---> -99.95169956447542, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -25.10808949048567, 24.896690735127994 ---> -25.10808949048567, 24.896690735127994
# Before/after: -25.0, 25.0 ---> -25.0, 25.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.3301260975767093, 0.34540137060689347 ---> 0.3301260975767093, 0.34540137060689347
# Before/after: -0.019371882710419286, -0.018515166951086837 ---> -0.019371882710419286, -0.018515166951086837
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -99.98322901544287, 100.0 ---> -99.98322901544287, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -99.98322901544286, 100.0 ---> -99.98322901544286, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.016905152433601026, 0.017687371170382826 ---> 0.016905152433601026, 0.017687371170382826
# Before/after: 0.016905152433601026, 0.017687371170382826 ---> 0.016905152433601026, 0.017687371170382826
# Before/after: 0.016905152433601026, 0.017687371170382826 ---> 0.016905152433601026, 0.017687371170382826
# Before/after: -100.0, 99.81323160757773 ---> -100.0, 99.81323160757773
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -16.815970159880642, 23.947018425649187 ---> -16.815970159880642, 23.947018425649187
# Before/after: -100.0, 99.92208200574751 ---> -100.0, 99.92208200574751
# Before/after: -100.0, 99.97578269829947 ---> -100.0, 99.97578269829947
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.03354196911429591, 0.03509399041742256 ---> 0.03354196911429591, 0.03509399041742256
# Before/after: 6.70839392569178e-06, 7.018798100943968e-06 ---> 6.70839392569178e-06, 7.018798100943968e-06
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.060375544405715686, 0.06316918275136629 ---> 0.060375544405715686, 0.06316918275136629
# Before/after: 0.060375544405715686, 0.06316918275136629 ---> 0.060375544405715686, 0.06316918275136629
# Before/after: 0.033541969114253334, 0.03509399041742867 ---> 0.033541969114253334, 0.03509399041742867
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -99.76279119442376, 99.90205745018628 ---> -99.76279119442376, 99.90205745018628
# Before/after: -100.0, 99.66484864461003 ---> -100.0, 99.66484864461003
# Before/after: 0.09794254981372319, 0.10247445201888464 ---> 0.09794254981372319, 0.10247445201888464
# Before/after: 0.060375544405715686, 0.06316918275136629 ---> 0.060375544405715686, 0.06316918275136629
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.060375544405715686, 0.06316918275136629 ---> 0.060375544405715686, 0.06316918275136629
# Before/after: 0.060375544405715686, 0.06316918275136629 ---> 0.060375544405715686, 0.06316918275136629
# Before/after: 0.03622532664343077, 0.03790150965082035 ---> 0.03622532664343077, 0.03790150965082035
# Before/after: -0.1937188271041929, -0.1851516695108684 ---> -0.1937188271041929, -0.1851516695108684
# Before/after: -0.4085705533581603, -0.3905016419829719 ---> -0.4085705533581603, -0.3905016419829719
# Before/after: -99.81323160757772, 100.0 ---> -99.81323160757772, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.28711925561830315, 0.3004045579731687 ---> 0.28711925561830315, 0.3004045579731687
# Before/after: -0.3004045579731687, -0.28711925561830315 ---> -0.3004045579731687, -0.28711925561830315
# Before/after: -0.3004045579731687, -0.28711925561830315 ---> -0.3004045579731687, -0.28711925561830315
# Before/after: 0.28711925561830315, 0.3004045579731687 ---> 0.28711925561830315, 0.3004045579731687
# Before/after: 0.5568362668207385, 0.5826016518379316 ---> 0.5568362668207385, 0.5826016518379316
# Before/after: 0.1851516695108684, 0.1937188271041929 ---> 0.1851516695108684, 0.1937188271041929
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.02254020324480137, 0.023583161560510435 ---> 0.02254020324480137, 0.023583161560510435
# Before/after: 0.02817525405600171, 0.029478951950638044 ---> 0.02817525405600171, 0.029478951950638044
# Before/after: 0.02817525405600171, 0.029478951950638044 ---> 0.02817525405600171, 0.029478951950638044
# Before/after: 0.02817525405600171, 0.029478951950638044 ---> 0.02817525405600171, 0.029478951950638044
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.28711925561830315, 0.3004045579731667 ---> 0.28711925561830315, 0.3004045579731667
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.005635050811200342, 0.005895790390127609 ---> 0.005635050811200342, 0.005895790390127609
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.005635050811200342, 0.005895790390127609 ---> 0.005635050811200342, 0.005895790390127609
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.004695875676006267, 0.004913158658439443 ---> 0.004695875676006267, 0.004913158658439443
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.004695875676006267, 0.004913158658439443 ---> 0.004695875676006267, 0.004913158658439443
# Before/after: 0.09794254981372022, 0.10247445201888464 ---> 0.09794254981372022, 0.10247445201888464
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.005635050811200342, 0.005895790390127609 ---> 0.005635050811200342, 0.005895790390127609
# Before/after: 0.005635050811200342, 0.005895790390127609 ---> 0.005635050811200342, 0.005895790390127609
# Before/after: 3.957952356126171e-05, 4.141090869325126e-05 ---> 3.957952356126171e-05, 4.141090869325126e-05
# Before/after: 0.004695875676006267, 0.004913158658439443 ---> 0.004695875676006267, 0.004913158658439443
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.13148451892800797, 0.1375684424363109 ---> 0.13148451892800797, 0.1375684424363109
# Before/after: 0.004695875676006267, 0.004913158658439443 ---> 0.004695875676006267, 0.004913158658439443
# Before/after: 0.004695875676006267, 0.004913158658439443 ---> 0.004695875676006267, 0.004913158658439443
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -99.9996444551274, 100.0 ---> -99.9996444551274, 100.0
# Before/after: -100.0, 99.99964445512738 ---> -100.0, 99.99964445512738
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -99.98343026725755, 100.0 ---> -99.98343026725755, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.0018313915136545234, 0.0019161318766265367 ---> 0.0018313915136545234, 0.0019161318766265367
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 99.98343026725755 ---> -100.0, 99.98343026725755
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 99.81484833048913 ---> -100.0, 99.81484833048913
# Before/after: -99.8114941335777, 100.0 ---> -99.8114941335777, 100.0
# Before/after: 0.28711925561830315, 0.3004045579731667 ---> 0.28711925561830315, 0.3004045579731667
# Before/after: 0.2113814893582435, 0.2211623276105854 ---> 0.2113814893582435, 0.2211623276105854
# Before/after: -99.97182474594399, 100.0 ---> -99.97182474594399, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -0.22116232761061067, -0.2113814893582031 ---> -0.22116232761061067, -0.2113814893582031
# Before/after: -100.0, 99.85912372972 ---> -100.0, 99.85912372972
# Before/after: -99.85912372972, 100.0 ---> -99.85912372972, 100.0
# Before/after: 3.957952355904126e-05, 4.141090869325126e-05 ---> 3.957952355904126e-05, 4.141090869325126e-05
# Before/after: -100.0, 99.9887298983776 ---> -100.0, 99.9887298983776
# Before/after: 0.018515166951086837, 0.019371882710419286 ---> 0.018515166951086837, 0.019371882710419286
# Before/after: 0.15634515559613993, 0.1635794062539085 ---> 0.15634515559613993, 0.1635794062539085
# Before/after: -99.9091348056694, 100.0 ---> -99.9091348056694, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.011270101622400684, 0.011791580780255217 ---> 0.011270101622400684, 0.011791580780255217
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -0.05053534620109379, -0.04830043552457436 ---> -0.05053534620109379, -0.04830043552457436
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 92.16619906896217 ---> -100.0, 92.16619906896217
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -99.97578269829948, 100.0 ---> -99.97578269829948, 100.0
# Before/after: -99.97578269829948, 100.0 ---> -99.97578269829948, 100.0
# Before/after: -0.12353084626934038, -0.11806773128229288 ---> -0.12353084626934038, -0.11806773128229288
# Before/after: -100.0, 99.97578269829948 ---> -100.0, 99.97578269829948
# Before/after: -100.0, 99.92208200574751 ---> -100.0, 99.92208200574751
# Before/after: 6.708393826215797e-06, 7.018798072522259e-06 ---> 6.708393826215797e-06, 7.018798072522259e-06
# Before/after: 3.957952354186056e-05, 4.141090867568198e-05 ---> 3.957952354186056e-05, 4.141090867568198e-05
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 3.957952357325212e-05, 4.141090868259312e-05 ---> 3.957952357325212e-05, 4.141090868259312e-05
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 99.77643673829877 ---> -100.0, 99.77643673829877
# Before/after: 3.95795235768881e-05, 4.141090866482955e-05 ---> 3.95795235768881e-05, 4.141090866482955e-05
# Before/after: 0.08787995907943391, 0.09194625489365676 ---> 0.08787995907943391, 0.09194625489365676
# Before/after: 0.11806773128229288, 0.12353084626934038 ---> 0.11806773128229288, 0.12353084626934038
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.018515166951086837, 0.019371882710419286 ---> 0.018515166951086837, 0.019371882710419286
# Before/after: 0.3301260975776702, 0.3454013706065067 ---> 0.3301260975776702, 0.3454013706065067
# Before/after: 0.03622532664343077, 0.03790150965082262 ---> 0.03622532664343077, 0.03790150965082262
# Before/after: 0.3301260975776702, 0.3454013706065067 ---> 0.3301260975776702, 0.3454013706065067
# Before/after: 0.060375544405715686, 0.06316918275136629 ---> 0.060375544405715686, 0.06316918275136629
# Before/after: 0.3301260975776702, 0.34540137060650977 ---> 0.3301260975776702, 0.34540137060650977
# Before/after: 0.060375544405715686, 0.06316918275136629 ---> 0.060375544405715686, 0.06316918275136629
# Before/after: 0.3301260975776702, 0.3454013706065067 ---> 0.3301260975776702, 0.3454013706065067
# Before/after: 0.060375544405715686, 0.06316918275136629 ---> 0.060375544405715686, 0.06316918275136629
# Before/after: -100.0, 99.85912372971998 ---> -100.0, 99.85912372971998
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.27571498611943923, 0.2884726012312484 ---> 0.27571498611943923, 0.2884726012312484
# Before/after: -99.92382618814146, 99.99825581760605 ---> -99.92382618814146, 99.99825581760605
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -99.92208200574753, 100.0 ---> -99.92208200574753, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 3.9579523530619554e-05, 4.141090870746211e-05 ---> 3.9579523530619554e-05, 4.141090870746211e-05
# Before/after: -100.0, 99.97182474594399 ---> -100.0, 99.97182474594399
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.0018313915136189962, 0.001916131876896543 ---> 0.0018313915136189962, 0.001916131876896543
# Before/after: 6.708393826215797e-06, 7.0187980867331135e-06 ---> 6.708393826215797e-06, 7.0187980867331135e-06
# Before/after: 1.3416787652431594e-05, 1.4037596173466227e-05 ---> 1.3416787652431594e-05, 1.4037596173466227e-05
# Before/after: 6.708393826215797e-06, 7.0187980867331135e-06 ---> 6.708393826215797e-06, 7.0187980867331135e-06
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 99.48209902731405 ---> -100.0, 99.48209902731405
# Before/after: 0.016905152433601026, 0.017687371170382826 ---> 0.016905152433601026, 0.017687371170382826
# Before/after: -100.0, 99.8114941335777 ---> -100.0, 99.8114941335777
# Before/after: 0.15634515559615636, 0.16357940625388534 ---> 0.15634515559615636, 0.16357940625388534
# Before/after: 0.237208805576243, 0.2481847002320337 ---> 0.237208805576243, 0.2481847002320337
# Before/after: -0.24818470023203842, -0.2372088055762414 ---> -0.24818470023203842, -0.2372088055762414
# Before/after: -99.84365484440386, 100.0 ---> -99.84365484440386, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 99.8114941335777 ---> -100.0, 99.8114941335777
# Before/after: -100.0, 99.8114941335777 ---> -100.0, 99.8114941335777
# Before/after: 0.2757149861194393, 0.2884726012312423 ---> 0.2757149861194393, 0.2884726012312423
# Before/after: 0.2757149861193966, 0.2884726012312413 ---> 0.2757149861193966, 0.2884726012312413
# Before/after: 0.09794254981372022, 0.10247445201888464 ---> 0.09794254981372022, 0.10247445201888464
# Before/after: -100.0, 99.8114941335777 ---> -100.0, 99.8114941335777
# Before/after: 0.004695875676006267, 0.004913158658439443 ---> 0.004695875676006267, 0.004913158658439443
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -0.16357940625384515, -0.15634515559610426 ---> -0.16357940625384515, -0.15634515559610426
# Before/after: -49.87059508315708, 50.13539261503042 ---> -49.87059508315708, 50.13539261503042
# Before/after: 0.005635050811200342, 0.005895790390127609 ---> 0.005635050811200342, 0.005895790390127609
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.237208805576243, 0.2481847002320337 ---> 0.237208805576243, 0.2481847002320337
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -99.81484833048913, 100.0 ---> -99.81484833048913, 100.0
# Before/after: -100.0, 99.66484864461003 ---> -100.0, 99.66484864461003
# Before/after: -49.85368993072348, 50.15307998620081 ---> -49.85368993072348, 50.15307998620081
# Before/after: -50.15307998620081, 49.85368993072348 ---> -50.15307998620081, 49.85368993072348
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.01656973274245388, 0.017336431266201657 ---> 0.01656973274245388, 0.017336431266201657
# Before/after: -100.0, 92.16619906896273 ---> -100.0, 92.16619906896273
# Before/after: -99.77643673829884, 100.0 ---> -99.77643673829884, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 99.98671738023074 ---> -100.0, 99.98671738023074
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 99.84365484440386 ---> -100.0, 99.84365484440386
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -99.96377467335657, 100.0 ---> -99.96377467335657, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -99.96377467335657, 100.0 ---> -99.96377467335657, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -0.09194625489365676, -0.08787995907943391 ---> -0.09194625489365676, -0.08787995907943391
# Before/after: 0.011270101622400684, 0.011791580780255217 ---> 0.011270101622400684, 0.011791580780255217
# Before/after: 0.018515166951086837, 0.019371882710419286 ---> 0.018515166951086837, 0.019371882710419286
# Before/after: 0.011270101622400684, 0.011791580780255217 ---> 0.011270101622400684, 0.011791580780255217
# Before/after: 0.018515166951086837, 0.019371882710419286 ---> 0.018515166951086837, 0.019371882710419286
# Before/after: 0.04830043552457436, 0.05053534620109379 ---> 0.04830043552457436, 0.05053534620109379
# Before/after: 0.018515166951086837, 0.019371882710419286 ---> 0.018515166951086837, 0.019371882710419286
# Before/after: 0.018515166951086837, 0.019371882710419286 ---> 0.018515166951086837, 0.019371882710419286
# Before/after: 0.018515166951086837, 0.019371882710419286 ---> 0.018515166951086837, 0.019371882710419286
# Before/after: 0.018515166951086837, 0.019371882710419286 ---> 0.018515166951086837, 0.019371882710419286
# Before/after: 0.018515166951086837, 0.019371882710419286 ---> 0.018515166951086837, 0.019371882710419286
# Before/after: 0.018515166951086837, 0.019371882710419286 ---> 0.018515166951086837, 0.019371882710419286
# Before/after: 0.011270101622400684, 0.011791580780255217 ---> 0.011270101622400684, 0.011791580780255217
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.004695875676006267, 0.004913158658439443 ---> 0.004695875676006267, 0.004913158658439443
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.005635050811200342, 0.005895790390127609 ---> 0.005635050811200342, 0.005895790390127609
# Before/after: -100.0, 99.73032256832113 ---> -100.0, 99.73032256832113
# Before/after: -99.73032256832113, 100.0 ---> -99.73032256832113, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.670839382285755, 0.7018798083485249 ---> 0.670839382285755, 0.7018798083485249
# Before/after: 8.826068397839, 12.84593332748 ---> 8.826068397839, 12.84593332748
# Before/after: 0.0, 24.164469909410258 ---> 0.0, 24.164469909410258
# Before/after: -12.148855548767477, -9.302806592838524 ---> -12.148855548767477, -9.302806592838524
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -15.623185177713722, 88.88378986434954 ---> -15.623185177713722, 88.88378986434954
# Before/after: -8.259854073237221, -7.738956551238843 ---> -8.259854073237221, -7.738956551238843
# Before/after: -59.53735584989344, 0.0 ---> -59.53735584989344, 0.0
# Before/after: -0.6697596826790004, -0.640139759634593 ---> -0.6697596826790004, -0.640139759634593
# Before/after: -0.16357940625391376, -0.15634515559615458 ---> -0.16357940625391376, -0.15634515559615458
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -12.84593332748, -8.826068397839 ---> -12.84593332748, -8.826068397839
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -16.815970042341586, 23.947018425649873 ---> -16.815970042341586, 23.947018425649873
# Before/after: -16.815970042341586, 23.94701842564946 ---> -16.815970042341586, 23.94701842564946
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 7.738956551238331, 8.259854073233736 ---> 7.738956551238331, 8.259854073233736
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.0, 59.537362454584056 ---> 0.0, 59.537362454584056
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.15634515559611373, 0.16357940625387357 ---> 0.15634515559611373, 0.16357940625387357
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.670839382285755, 0.7018798083485249 ---> 0.670839382285755, 0.7018798083485249
# Before/after: 0.670839382285755, 0.7018798083485249 ---> 0.670839382285755, 0.7018798083485249
# Before/after: -99.73811580193951, 100.0 ---> -99.73811580193951, 100.0
# Before/after: -99.73811580193951, 100.0 ---> -99.73811580193951, 100.0
# Before/after: 0.261884198060484, 0.35540588204754797 ---> 0.261884198060484, 0.35540588204754797

# %%
apply_tfva_bounds(tmodel_glc, "results/bounds/ecoli_WT_Glc_bounds_no_metabolome_after_tfva.csv")
# Out:
# 2DGLCNRx: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# 2DGLCNRy: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# 2DGULRx: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# 2DGULRy: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# A5PISO: 0.02817525405600171, 0.029478951950638044 ---->  0.0281752540556174, 0.0294789519508729
# Before/after: 0.0281752540556174, 0.0294789519508729 ---> 0.0281752540556174, 0.0294789519508729
# AACPS1: -100.0, 100.0 ---->  -99.99073034141564, 100.0
# Before/after: -99.99073034141564, 100.0 ---> -99.99073034141564, 100.0
# AACPS3: -100.0, 100.0 ---->  -99.93457706008262, 100.0
# Before/after: -99.93457706008262, 100.0 ---> -99.93457706008262, 100.0
# ABTA: -100.0, 100.0 ---->  -0.0294789519508071, 99.3170608535056
# Before/after: -0.0294789519508071, 99.3170608535056 ---> -0.0294789519508071, 99.3170608535056
# ACCOACr: -100.0, 100.0 ---->  -91.88836946219683, 100.0
# Before/after: -91.88836946219683, 100.0 ---> -91.88836946219683, 100.0
# ACGK: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# ACGS: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# ACHBS: 0.1851516695108684, 0.1937188271041929 ---->  0.1851516695097389, 0.193718827105306
# Before/after: 0.1851516695097389, 0.193718827105306 ---> 0.1851516695097389, 0.193718827105306
# ACKr: -100.0, 100.0 ---->  -99.9801770454643, 100.0
# Before/after: -99.9801770454643, 100.0 ---> -99.9801770454643, 100.0
# ACLS: 0.5568362668207236, 0.5826016518379836 ---->  0.5568362668175353, 0.5826016518411882
# Before/after: 0.5568362668175353, 0.5826016518411882 ---> 0.5568362668175353, 0.5826016518411882
# ACOATA: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# ACODA: -100.0, 100.0 ---->  -1.0000178463087649e-10, 100.0
# Before/after: -1.0000178463087649e-10, 100.0 ---> 0.0, 100.0
# ACOTA: -100.0, 100.0 ---->  -100.0, -0.0
# Before/after: -100.0, -0.0 ---> -100.0, 0.0
# ACS: -100.0, 100.0 ---->  -12.830028728162077, 100.0
# Before/after: -12.830028728162077, 100.0 ---> -12.830028728162077, 100.0
# ADA: -100.0, 100.0 ---->  0.0, 99.79626671268484
# Before/after: 0.0, 99.79626671268484 ---> 0.0, 99.79626671268484
# ADCL: 0.0335419691142817, 0.03509399041742256 ---->  0.0335419691140952, 0.0350939904176202
# Before/after: 0.0335419691140952, 0.0350939904176202 ---> 0.0335419691140952, 0.0350939904176202
# ADCS: 0.0335419691142817, 0.03509399041742256 ---->  0.0335419691140952, 0.0350939906106679
# Before/after: 0.0335419691140952, 0.0350939906106679 ---> 0.0335419691140952, 0.0350939906106679
# ADD: -100.0, 100.0 ---->  0.0, 99.79626673598524
# Before/after: 0.0, 99.79626673598524 ---> 0.0, 99.79626673598524
# ADK1: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# ADK3: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# ADMDCr: 0.004695875676000285, 0.004913158658439443 ---->  0.0046958756759778, 0.0049131586584678
# Before/after: 0.0046958756759778, 0.0049131586584678 ---> 0.0046958756759778, 0.0049131586584678
# ADNK1: -100.0, 100.0 ---->  -100.0, 99.48741023203384
# Before/after: -100.0, 99.48741023203384 ---> -100.0, 99.48741023203384
# ADPT: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# ADSK: 0.15634515559615414, 0.16357940625388778 ---->  0.1563451555952455, 0.1635794062547996
# Before/after: 0.1563451555952455, 0.1635794062547996 ---> 0.1563451555952455, 0.1635794062547996
# ADSL1r: -100.0, 100.0 ---->  0.187163554572777, 100.0
# Before/after: 0.187163554572777, 100.0 ---> 0.187163554572777, 100.0
# ADSL2r: 0.33012609757736294, 0.3454013706068011 ---->  0.3301260975753592, 0.3454013706084993
# Before/after: 0.3301260975753592, 0.3454013706084993 ---> 0.3301260975753592, 0.3454013706084993
# ADSS: -100.0, 100.0 ---->  0.1871635545727628, 100.0
# Before/after: 0.1871635545727628, 100.0 ---> 0.1871635545727628, 100.0
# AGMHE: 0.016905152433601026, 0.017687371170382826 ---->  0.0169051524335039, 0.0176873711704801
# Before/after: 0.0169051524335039, 0.0176873711704801 ---> 0.0169051524335039, 0.0176873711704801
# AGPR: -100.0, 100.0 ---->  -100.0, 5.684341886080801e-13
# Before/after: -100.0, 5.684341886080801e-13 ---> -100.0, 0.0
# AICART: 0.39050164198283227, 0.40857055335779174 ---->  0.3905016419807339, 0.4085705533601924
# Before/after: 0.3905016419807339, 0.4085705533601924 ---> 0.3905016419807339, 0.4085705533601924
# AIRC2: 0.3301260975771143, 0.3454013706064245 ---->  0.3301260975753735, 0.3454013706085419
# Before/after: 0.3301260975753735, 0.3454013706085419 ---> 0.3301260975753735, 0.3454013706085419
# AIRC3: -0.34540137060662346, -0.3301260975774767 ---->  -0.3454013706084424, -0.330126097575345
# Before/after: -0.3454013706084424, -0.330126097575345 ---> -0.3454013706084424, -0.330126097575345
# ALAALAr: 0.018515166951086837, 0.019371882710419286 ---->  0.0185151669510514, 0.0193718827104873
# Before/after: 0.0185151669510514, 0.0193718827104873 ---> 0.0185151669510514, 0.0193718827104873
# ALAR: -100.0, 100.0 ---->  -99.9629696660984, 100.0
# Before/after: -99.9629696660984, 100.0 ---> -99.9629696660984, 100.0
# ALATAD2: -100.0, 100.0 ---->  -100.0, 99.96296966609822
# Before/after: -100.0, 99.96296966609822 ---> -100.0, 99.96296966609822
# ALATAL: -100.0, 100.0 ---->  -100.0, 99.6170848805935
# Before/after: -100.0, 99.6170848805935 ---> -100.0, 99.6170848805935
# ALATAL2: -100.0, 100.0 ---->  -99.9629696660984, 100.0
# Before/after: -99.9629696660984, 100.0 ---> -99.9629696660984, 100.0
# ALDD2x: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# AMALT1: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# AMALT2: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# AMALT3: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# AMALT4: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# ANPRT: 0.03622532664343077, 0.03790150965082262 ---->  0.0362253266432228, 0.0379015098595214
# Before/after: 0.0362253266432228, 0.0379015098595214 ---> 0.0362253266432228, 0.0379015098595214
# ANS: 0.03622532664343077, 0.03790150965082262 ---->  0.0362253266432228, 0.0379015096510298
# Before/after: 0.0362253266432228, 0.0379015096510298 ---> 0.0362253266432228, 0.0379015096510298
# APRAUR: 6.7083938226630835e-06, 7.018798100943968e-06 ---->  6.708393822819045e-06, 7.018798083524042e-06
# Before/after: 6.708393822819045e-06, 7.018798083524042e-06 ---> 6.708393822819045e-06, 7.018798083524042e-06
# ASNS1: -100.0, 100.0 ---->  -99.84637778145776, 100.0
# Before/after: -99.84637778145776, 100.0 ---> -99.84637778145776, 100.0
# ASNS2: -100.0, 100.0 ---->  -99.84637778145776, 100.0
# Before/after: -99.84637778145776, 100.0 ---> -99.84637778145776, 100.0
# ASP1DC: 3.957952355904126e-05, 4.141090872167297e-05 ---->  3.957952355460037e-05, 4.141090869280717e-05
# Before/after: 3.957952355460037e-05, 4.141090869280717e-05 ---> 3.957952355460037e-05, 4.141090869280717e-05
# ASPCT: 0.4732656874187313, 0.5765682096581484 ---->  0.4732656874175234, 0.5765682096593707
# Before/after: 0.4732656874175234, 0.5765682096593707 ---> 0.4732656874175234, 0.5765682096593707
# ASPO4: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# ASPO5: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# ASPO6: -100.0, 100.0 ---->  -46.98451243701175, 46.633443268271776
# Before/after: -46.98451243701175, 46.633443268271776 ---> -46.98451243701175, 46.633443268271776
# ASPT: -100.0, 100.0 ---->  -99.35815877105412, 97.98793850186254
# Before/after: -99.35815877105412, 97.98793850186254 ---> -99.35815877105412, 97.98793850186254
# ASPTA: -100.0, 100.0 ---->  -100.0, 98.1766720305032
# Before/after: -100.0, 98.1766720305032 ---> -100.0, 98.1766720305032
# ATPHYD: 3.15, 100.0 ---->  3.15, 100.0
# Before/after: 3.15, 100.0 ---> 3.15, 100.0
# ATPPRT: 0.06037554440571795, 0.06316918275136724 ---->  0.0603755444052893, 0.0631691827517413
# Before/after: 0.0603755444052893, 0.0631691827517413 ---> 0.0603755444052893, 0.0631691827517413
# BETALDHx: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# BETALDHy: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# BPNT: 0.15634515559617057, 0.1635794062539706 ---->  0.1563451555952392, 0.1635794062548029
# Before/after: 0.1563451555952392, 0.1635794062548029 ---> 0.1563451555952392, 0.1635794062548029
# BSORx: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# BSORy: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# C120SN: 0.02817525405600171, 0.029478951950638044 ---->  0.0281752540557942, 0.029478952072524
# Before/after: 0.0281752540557942, 0.029478952072524 ---> 0.0281752540557942, 0.029478952072524
# C140SN: -99.99073034141558, 100.0 ---->  -99.9907303414156, 100.0
# Before/after: -99.9907303414156, 100.0 ---> -99.9907303414156, 100.0
# C141SN: 0.009086519433060552, 0.009506962004083519 ---->  0.0090865194330085, 0.0095069620041314
# Before/after: 0.0090865194330085, 0.0095069620041314 ---> 0.0090865194330085, 0.0095069620041314
# C160SN: -99.93457706008196, 100.0 ---->  -99.93457706008236, 100.0
# Before/after: -99.93457706008236, 100.0 ---> -99.93457706008236, 100.0
# C161SN: 0.012721127206283711, 0.013309746805715063 ---->  0.0127211272061877, 0.0133097468057883
# Before/after: 0.0127211272061877, 0.0133097468057883 ---> 0.0127211272061877, 0.0133097468057883
# C181SN: 0.09086519433060403, 0.09506962004081743 ---->  0.090865194330135, 0.095069620041329
# Before/after: 0.090865194330135, 0.095069620041329 ---> 0.090865194330135, 0.095069620041329
# CAT: -100.0, 100.0 ---->  0.0, 23.493172112721453
# Before/after: 0.0, 23.493172112721453 ---> 0.0, 23.493172112721453
# CBPS: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# CHORM: 0.20594769036172678, 0.21547710116299715 ---->  0.2059476903616648, 0.2154771011630885
# Before/after: 0.2059476903616648, 0.2154771011630885 ---> 0.2059476903616648, 0.2154771011630885
# CHORS: 0.2757149861194393, 0.2884726012312245 ---->  0.2757149861177481, 0.2884726012328381
# Before/after: 0.2757149861177481, 0.2884726012328381 ---> 0.2757149861177481, 0.2884726012328381
# CITL: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# CLPNSEC: 0.00432691401574312, 0.004527124763847985 ---->  0.0043269140157135, 0.0045271247638777
# Before/after: 0.0043269140157135, 0.0045271247638777 ---> 0.0043269140157135, 0.0045271247638777
# CMPN: -100.0, 100.0 ---->  0.0, 99.79807734593317
# Before/after: 0.0, 99.79807734593317 ---> 0.0, 99.79807734593317
# CTPS2: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# CYSTL: 0.09794254981372022, 0.10247445201888464 ---->  0.097942549813105, 0.1024744520195639
# Before/after: 0.097942549813105, 0.1024744520195639 ---> 0.097942549813105, 0.1024744520195639
# cytd: -100.0, 100.0 ---->  0.0, 99.79807734593314
# Before/after: 0.0, 99.79807734593314 ---> 0.0, 99.79807734593314
# CYTDK2: -100.0, 100.0 ---->  -99.76446829288084, 99.93004350794756
# Before/after: -99.76446829288084, 99.93004350794756 ---> -99.76446829288084, 99.93004350794756
# DAAD: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# DADA: -100.0, 100.0 ---->  -0.0173364312663011, 99.79626675044034
# Before/after: -0.0173364312663011, 99.79626675044034 ---> -0.0173364312663011, 99.79626675044034
# DAGKEC: -99.9887298983776, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# DAPDC: 0.21869363862515456, 0.22881281752161914 ---->  0.2186936386251119, 0.2288128176447042
# Before/after: 0.2186936386251119, 0.2288128176447042 ---> 0.2186936386251119, 0.2288128176447042
# DAPE: 0.2372088055762414, 0.24818470023203842 ---->  0.2372088055748814, 0.2481847012577354
# Before/after: 0.2372088055748814, 0.2481847012577354 ---> 0.2372088055748814, 0.2481847012577354
# DB4PS: 1.3416787652431594e-05, 1.4037596201887936e-05 ---->  1.341678764563809e-05, 1.4037596167270137e-05
# Before/after: 1.341678764563809e-05, 1.4037596167270137e-05 ---> 1.341678764563809e-05, 1.4037596167270137e-05
# DCTPD: -100.0, 100.0 ---->  0.0, 99.57653243918318
# Before/after: 0.0, 99.57653243918318 ---> 0.0, 99.57653243918318
# DDPA: 0.27571498611943906, 0.28847260123124374 ---->  0.2757149861178627, 0.2884726012328382
# Before/after: 0.2757149861178627, 0.2884726012328382 ---> 0.2757149861178627, 0.2884726012328382
# DHAD1: 0.5568362668207385, 0.582601651837976 ---->  0.5568362668175353, 0.5826016518411882
# Before/after: 0.5568362668175353, 0.5826016518411882 ---> 0.5568362668175353, 0.5826016518411882
# DHAD2: 0.1851516695108684, 0.19371882710419186 ---->  0.1851516695108301, 0.1937188271042345
# Before/after: 0.1851516695108301, 0.1937188271042345 ---> 0.1851516695108301, 0.1937188271042345
# DHAPT: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# DHDPRy: 0.2372088055762414, 0.24818470023203842 ---->  0.2372088055748814, 0.2481847002334101
# Before/after: 0.2372088055748814, 0.2481847002334101 ---> 0.2372088055748814, 0.2481847002334101
# DHDPS: 0.2372088055762414, 0.24818470023203842 ---->  0.2372088055748814, 0.2481847002334101
# Before/after: 0.2372088055748814, 0.2481847002334101 ---> 0.2372088055748814, 0.2481847002334101
# DHFR: 0.050111701856739854, 0.05243042168362322 ---->  0.0501117018564514, 0.0524304216839245
# Before/after: 0.0501117018564514, 0.0524304216839245 ---> 0.0501117018564514, 0.0524304216839245
# DHFS: 0.0335419691142817, 0.03509399041742156 ---->  0.033541969113827, 0.0350939904176202
# Before/after: 0.033541969113827, 0.0350939904176202 ---> 0.033541969113827, 0.0350939904176202
# DHNPA2: 0.0335419691142817, 0.03509399041742156 ---->  0.0335419691140952, 0.0350939904176202
# Before/after: 0.0335419691140952, 0.0350939904176202 ---> 0.0335419691140952, 0.0350939904176202
# DHORD2: -99.5267343125813, 100.0 ---->  0.0, 99.01668045042484
# Before/after: 0.0, 99.01668045042484 ---> 0.0, 99.01668045042484
# DHORD5: -99.5267343125813, 100.0 ---->  -98.97874342519212, 0.573380868208389
# Before/after: -98.97874342519212, 0.573380868208389 ---> -98.97874342519212, 0.573380868208389
# DHORTS: -0.5765682096581486, -0.47326568741874553 ---->  -0.5765682096593565, -0.4732656874175092
# Before/after: -0.5765682096593565, -0.4732656874175092 ---> -0.5765682096593565, -0.4732656874175092
# DHPPDA2: 6.708393826215797e-06, 7.018798100943968e-06 ---->  6.708393822819045e-06, 7.018798083735511e-06
# Before/after: 6.708393822819045e-06, 7.018798083735511e-06 ---> 6.708393822819045e-06, 7.018798083735511e-06
# DHPS2: 0.0335419691142817, 0.03509399041742256 ---->  0.033541969114097, 0.0350939904176202
# Before/after: 0.033541969114097, 0.0350939904176202 ---> 0.033541969114097, 0.0350939904176202
# DHQD: 0.27571498611943923, 0.2884726012312401 ---->  0.2757149861177481, 0.2884726012328381
# Before/after: 0.2757149861177481, 0.2884726012328381 ---> 0.2757149861177481, 0.2884726012328381
# DHQS: 0.27571498611943923, 0.2884726012312401 ---->  0.2757149861177481, 0.2884726012328381
# Before/after: 0.2757149861177481, 0.2884726012328381 ---> 0.2757149861177481, 0.2884726012328381
# DKGLCNR1: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# DKGLCNR2x: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# DKGLCNR2y: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# DKMPPD: -15.863310173812286, 36.04419364438183 ---->  0.0, 0.0049131586584668
# Before/after: 0.0, 0.0049131586584668 ---> 0.0, 0.0049131586584668
# DKMPPD2: -36.03949116401469, 15.868000765736994 ---->  0.0, 0.0049131586584668
# Before/after: 0.0, 0.0049131586584668 ---> 0.0, 0.0049131586584668
# DMPPS: -100.0, 100.0 ---->  0.0, -0.0
# Before/after: 0.0, -0.0 ---> 0.0, 0.0
# DMSOR1: -100.0, 100.0 ---->  0.0, -0.0
# Before/after: 0.0, -0.0 ---> 0.0, 0.0
# DMSOR2: -100.0, 100.0 ---->  0.0, -0.0
# Before/after: 0.0, -0.0 ---> 0.0, 0.0
# DNMPPA: 0.033541969114281756, 0.03509399041741468 ---->  0.033541969114097, 0.0350911883167721
# Before/after: 0.033541969114097, 0.0350911883167721 ---> 0.033541969114097, 0.0350911883167721
# DNTPPA: 0.033541969114281756, 0.03509399041743677 ---->  0.033541969114097, 0.0350939904176202
# Before/after: 0.033541969114097, 0.0350939904176202 ---> 0.033541969114097, 0.0350939904176202
# DPCOAK: 3.957952358746297e-05, 4.141090872167297e-05 ---->  -4.141090869280717e-05, 4.141090869280717e-05
# Before/after: -4.141090869280717e-05, 4.141090869280717e-05 ---> -4.141090869280717e-05, 4.141090869280717e-05
# DPR: 3.957952358746297e-05, 4.141090872167297e-05 ---->  -4.141090869280717e-05, 4.141090869280717e-05
# Before/after: -4.141090869280717e-05, 4.141090869280717e-05 ---> -4.141090869280717e-05, 4.141090869280717e-05
# DURIPP: -100.0, 100.0 ---->  -100.0, 99.21762145754934
# Before/after: -100.0, 99.21762145754934 ---> -100.0, 99.21762145754934
# EDA: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# EDD: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# EDTXS1: 0.005635050811200342, 0.005895790390127609 ---->  0.0056350508111679, 0.0058957903901598
# Before/after: 0.0056350508111679, 0.0058957903901598 ---> 0.0056350508111679, 0.0058957903901598
# EDTXS2: 0.005635050811200342, 0.005895790390127609 ---->  0.0056350508111679, 0.0058957903901598
# Before/after: 0.0056350508111679, 0.0058957903901598 ---> 0.0056350508111679, 0.0058957903901598
# ETHAAL: -100.0, 99.92208200574751 ---->  -100.0, 99.59198945014178
# Before/after: -100.0, 99.59198945014178 ---> -100.0, 99.59198945014178
# F6PA: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# FAO1: -100.0, 99.99073034141558 ---->  -100.0, 99.99073034141566
# Before/after: -100.0, 99.99073034141566 ---> -100.0, 99.99073034141566
# FAO2: -100.0, 99.934577060082 ---->  -100.0, 99.933816555843
# Before/after: -100.0, 99.933816555843 ---> -100.0, 99.933816555843
# FBA: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# FBP: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# FMNAT: 6.7083938120049424e-06, 7.018798072522259e-06 ---->  6.708393822819045e-06, 7.01879808374609e-06
# Before/after: 6.708393822819045e-06, 7.01879808374609e-06 ---> 6.708393822819045e-06, 7.01879808374609e-06
# FRD2: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# FRD3: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# FRUK: -100.0, 100.0 ---->  0.0, -0.0
# Before/after: 0.0, -0.0 ---> 0.0, 0.0
# FTHFD: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# fum: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# G1PACT: 0.04830043552457436, 0.05053534620109379 ---->  0.0483004355241751, 0.0505353462014372
# Before/after: 0.0483004355241751, 0.0505353462014372 ---> 0.0483004355241751, 0.0505353462014372
# G1PP: -100.0, 100.0 ---->  -99.9645262626317, 99.57348032074516
# Before/after: -99.9645262626317, 99.57348032074516 ---> -99.9645262626317, 99.57348032074516
# G3PD2: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# G3PD5: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# G3PD6: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# G3PD7: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# G5SD: -100.0, 100.0 ---->  -99.78331887952297, 99.90781869993586
# Before/after: -99.78331887952297, 99.90781869993586 ---> -99.78331887952297, 99.90781869993586
# G6PDA: -100.0, 99.95169956447542 ---->  -100.0, 98.96411559314537
# Before/after: -100.0, 98.96411559314537 ---> -100.0, 98.96411559314537
# GALU: -99.98671738023074, 100.0 ---->  -6.061145154614849, 100.0
# Before/after: -6.061145154614849, 100.0 ---> -6.061145154614849, 100.0
# GARFT: -99.66987390242282, 100.0 ---->  -99.66987390242464, 99.60949835801928
# Before/after: -99.66987390242464, 99.60949835801928 ---> -99.66987390242464, 99.60949835801928
# GART: -99.66987390242338, 100.0 ---->  -99.27937218493288, 100.0
# Before/after: -99.27937218493288, 100.0 ---> -99.27937218493288, 100.0
# GCALDD: 0.03354196911428045, 0.035093990417426446 ---->  0.0335419691140952, 0.0350939904176202
# Before/after: 0.0335419691140952, 0.0350939904176202 ---> 0.0335419691140952, 0.0350939904176202
# GF6PTA: -99.95169956447542, 100.0 ---->  -99.95169956447587, 100.0
# Before/after: -99.95169956447587, 100.0 ---> -99.95169956447587, 100.0
# GK1: -100.0, 100.0 ---->  -99.8132316075789, 99.99999999999996
# Before/after: -99.8132316075789, 99.99999999999996 ---> -99.8132316075789, 100.0
# GLCP: -25.10808949048567, 24.896690735127994 ---->  -0.1080894904857956, 24.89669073512809
# Before/after: -0.1080894904857956, 24.89669073512809 ---> -0.1080894904857956, 24.89669073512809
# GLCS1: -25.0, 25.0 ---->  0.0, 25.0
# Before/after: 0.0, 25.0 ---> 0.0, 25.0
# GLGC: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# GLNS: -100.0, 100.0 ---->  -1.0000178463087649e-10, 100.0
# Before/after: -1.0000178463087649e-10, 100.0 ---> 0.0, 100.0
# GLU5K: -100.0, 100.0 ---->  -99.7833188795232, 100.0
# Before/after: -99.7833188795232, 100.0 ---> -99.7833188795232, 100.0
# GLUDy: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# GLUN: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# GLUPRT: 0.3301260975767093, 0.34540137060689347 ---->  0.330126097575363, 0.3454013706084993
# Before/after: 0.330126097575363, 0.3454013706084993 ---> 0.330126097575363, 0.3454013706084993
# GLUR: -0.019371882710419286, -0.018515166951086837 ---->  -0.0193718827104873, -0.018515166951019
# Before/after: -0.0193718827104873, -0.018515166951019 ---> -0.0193718827104873, -0.018515166951019
# GLUSy: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# GLXCL: -99.98322901544287, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# GLYATi: -100.0, 100.0 ---->  -100.0, 99.01964621573455
# Before/after: -100.0, 99.01964621573455 ---> -100.0, 99.01964621573455
# GLYCDx: -100.0, 100.0 ---->  -100.0, 99.88924441798528
# Before/after: -100.0, 99.88924441798528 ---> -100.0, 99.88924441798528
# GLYCK: -99.98322901544286, 100.0 ---->  0.0, 99.60473513339208
# Before/after: 0.0, 99.60473513339208 ---> 0.0, 99.60473513339208
# GLYCL: -100.0, 100.0 ---->  -99.94695049036508, 99.0362638842816
# Before/after: -99.94695049036508, 99.0362638842816 ---> -99.94695049036508, 99.0362638842816
# GLYCLTDx: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# GLYCLTDy: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# GLYCTO2: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# GLYCTO3: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# GLYCTO4: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# GLYK: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# GMHEPAT: 0.016905152433601026, 0.017687371170382826 ---->  0.0169051524335039, 0.0176873711704801
# Before/after: 0.0169051524335039, 0.0176873711704801 ---> 0.0169051524335039, 0.0176873711704801
# GMHEPK: 0.016905152433601026, 0.017687371170382826 ---->  0.0169051524335039, 0.0176873711704801
# Before/after: 0.0169051524335039, 0.0176873711704801 ---> 0.0169051524335039, 0.0176873711704801
# GMHEPPA: 0.016905152433601026, 0.017687371170382826 ---->  0.0169051524335039, 0.0176873711704801
# Before/after: 0.0169051524335039, 0.0176873711704801 ---> 0.0169051524335039, 0.0176873711704801
# GMPR: -100.0, 99.81323160757773 ---->  -100.0, 99.8132316075789
# Before/after: -100.0, 99.8132316075789 ---> -100.0, 99.8132316075789
# GMPS2: -100.0, 100.0 ---->  -99.8132316075789, 100.0
# Before/after: -99.8132316075789, 100.0 ---> -99.8132316075789, 100.0
# GND: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# GNK: -16.815970159880642, 23.947018425649187 ---->  0.0, 9.531228487787992
# Before/after: 0.0, 9.531228487787992 ---> 0.0, 9.531228487787992
# GPDDA2: -100.0, 99.92208200574751 ---->  -100.0, 99.38598014595055
# Before/after: -100.0, 99.38598014595055 ---> -100.0, 99.38598014595055
# GPDDA4: -100.0, 99.97578269829947 ---->  -99.68285464538904, 99.9757826982998
# Before/after: -99.68285464538904, 99.9757826982998 ---> -99.68285464538904, 99.9757826982998
# GSNK: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# GSPMDA: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# GSPMDS: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# GTPCI: 0.03354196911429591, 0.03509399041742256 ---->  0.033541969114097, 0.0350939904176201
# Before/after: 0.033541969114097, 0.0350939904176201 ---> 0.033541969114097, 0.0350939904176201
# GTPCII2: 6.70839392569178e-06, 7.018798100943968e-06 ---->  -7.018798083524042e-06, 7.018798083524042e-06
# Before/after: -7.018798083524042e-06, 7.018798083524042e-06 ---> -7.018798083524042e-06, 7.018798083524042e-06
# GUAD: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# GUAPRT: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# HEX1: -100.0, 100.0 ---->  -1.0000178463087649e-10, 100.0
# Before/after: -1.0000178463087649e-10, 100.0 ---> 0.0, 100.0
# histd: 0.060375544405715686, 0.06316918275136629 ---->  0.0603755444056872, 0.0631691827513947
# Before/after: 0.0603755444056872, 0.0631691827513947 ---> 0.0603755444056872, 0.0631691827513947
# HISTP: 0.060375544405715686, 0.06316918275136629 ---->  0.0603755444052893, 0.0631691827517413
# Before/after: 0.0603755444052893, 0.0631691827517413 ---> 0.0603755444052893, 0.0631691827517413
# HPPK2: 0.033541969114253334, 0.03509399041742867 ---->  0.0335419691140952, 0.0350939904176202
# Before/after: 0.0335419691140952, 0.0350939904176202 ---> 0.0335419691140952, 0.0350939904176202
# HPYRI: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# HPYRRx: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# HPYRRy: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# HSST: 0.09794254981372319, 0.10247445201888464 ---->  0.097942549813105, 0.1024744520195639
# Before/after: 0.097942549813105, 0.1024744520195639 ---> 0.097942549813105, 0.1024744520195639
# HSTPT: 0.060375544405715686, 0.06316918275136629 ---->  0.0603755444052893, 0.0631691828390714
# Before/after: 0.0603755444052893, 0.0631691828390714 ---> 0.0603755444052893, 0.0631691828390714
# HXPRT: -100.0, 100.0 ---->  -99.99530412432402, 100.0
# Before/after: -99.99530412432402, 100.0 ---> -99.99530412432402, 100.0
# HYPOE: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# ICDHyr: -100.0, 100.0 ---->  -99.25496578203771, 100.0
# Before/after: -99.25496578203771, 100.0 ---> -99.25496578203771, 100.0
# ICL: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# IDOND: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# IDOND2: -100.0, 100.0 ---->  -99.15964242841792, 100.0
# Before/after: -99.15964242841792, 100.0 ---> -99.15964242841792, 100.0
# IG3PS: 0.060375544405715686, 0.06316918275136629 ---->  0.0603755444052893, 0.0631691827517413
# Before/after: 0.0603755444052893, 0.0631691827517413 ---> 0.0603755444052893, 0.0631691827517413
# IGPDH: 0.060375544405715686, 0.06316918275136629 ---->  0.0603755444052893, 0.0631691827517413
# Before/after: 0.0603755444052893, 0.0631691827517413 ---> 0.0603755444052893, 0.0631691827517413
# IGPS: 0.03622532664343077, 0.03790150965082035 ---->  0.036225326643219, 0.0379014677350054
# Before/after: 0.036225326643219, 0.0379014677350054 ---> 0.036225326643219, 0.0379014677350054
# ILETA: -0.1937188271041929, -0.1851516695108684 ---->  -0.1937188271042345, -0.1851516695108301
# Before/after: -0.1937188271042345, -0.1851516695108301 ---> -0.1937188271042345, -0.1851516695108301
# IMPC: -0.4085705533581603, -0.3905016419829719 ---->  -0.4085705533602919, -0.3905016419799949
# Before/after: -0.4085705533602919, -0.3905016419799949 ---> -0.4085705533602919, -0.3905016419799949
# IMPD: -99.81323160757772, 100.0 ---->  -99.8132316075789, 100.0
# Before/after: -99.8132316075789, 100.0 ---> -99.8132316075789, 100.0
# INSK: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# IPDDIi: -100.0, 100.0 ---->  0.0, -0.0
# Before/after: 0.0, -0.0 ---> 0.0, 0.0
# IPDPS: -100.0, 100.0 ---->  0.0, -0.0
# Before/after: 0.0, -0.0 ---> 0.0, 0.0
# IPMD: 0.28711925561830315, 0.3004045579731687 ---->  0.2871192556166551, 0.3004045579748289
# Before/after: 0.2871192556166551, 0.3004045579748289 ---> 0.2871192556166551, 0.3004045579748289
# IPPMIa: -0.3004045579731687, -0.28711925561830315 ---->  -0.3004045579748289, -0.2871192556166551
# Before/after: -0.3004045579748289, -0.2871192556166551 ---> -0.3004045579748289, -0.2871192556166551
# IPPMIb: -0.3004045579731687, -0.28711925561830315 ---->  -0.3004045579748289, -0.2871192556166551
# Before/after: -0.3004045579748289, -0.2871192556166551 ---> -0.3004045579748289, -0.2871192556166551
# IPPS: 0.28711925561830315, 0.3004045579731687 ---->  0.2871192556166551, 0.3004045579748289
# Before/after: 0.2871192556166551, 0.3004045579748289 ---> 0.2871192556166551, 0.3004045579748289
# KARA1i: 0.5568362668207385, 0.5826016518379316 ---->  0.5568362668175352, 0.5824226630270382
# Before/after: 0.5568362668175352, 0.5824226630270382 ---> 0.5568362668175352, 0.5824226630270382
# KARA2i: 0.1851516695108684, 0.1937188271041929 ---->  0.1851516695097389, 0.193718827105306
# Before/after: 0.1851516695097389, 0.193718827105306 ---> 0.1851516695097389, 0.193718827105306
# KAS14: -100.0, 100.0 ---->  -99.85351685416369, 100.0
# Before/after: -99.85351685416369, 100.0 ---> -99.85351685416369, 100.0
# KAS15: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# KAS16: 0.02254020324480137, 0.023583161560510435 ---->  0.0225402032446719, 0.0235831615606407
# Before/after: 0.0225402032446719, 0.0235831615606407 ---> 0.0225402032446719, 0.0235831615606407
# KDOCT2: 0.02817525405600171, 0.029478951950638044 ---->  0.0281752540556174, 0.0294789519508729
# Before/after: 0.0281752540556174, 0.0294789519508729 ---> 0.0281752540556174, 0.0294789519508729
# KDOPP: 0.02817525405600171, 0.029478951950638044 ---->  0.0281752540556174, 0.0294789519508729
# Before/after: 0.0281752540556174, 0.0294789519508729 ---> 0.0281752540556174, 0.0294789519508729
# KDOPS: 0.02817525405600171, 0.029478951950638044 ---->  0.0281752540556174, 0.0294789519508729
# Before/after: 0.0281752540556174, 0.0294789519508729 ---> 0.0281752540556174, 0.0294789519508729
# LDHD2: -100.0, 100.0 ---->  0.0, 99.60557827429896
# Before/after: 0.0, 99.60557827429896 ---> 0.0, 99.60557827429896
# LEUTAi: 0.28711925561830315, 0.3004045579731667 ---->  0.2871192556182649, 0.3004045579732093
# Before/after: 0.2871192556182649, 0.3004045579732093 ---> 0.2871192556182649, 0.3004045579732093
# L-LACD2: -100.0, 100.0 ---->  1.3500311979441906e-13, 100.0
# Before/after: 1.3500311979441906e-13, 100.0 ---> 0.0, 100.0
# L-LACD3: -100.0, 100.0 ---->  -99.04800429803436, -0.0
# Before/after: -99.04800429803436, -0.0 ---> -99.04800429803436, 0.0
# LPADSS: 0.005635050811200342, 0.005895790390127609 ---->  0.0056350508111679, 0.0058957903901598
# Before/after: 0.0056350508111679, 0.0058957903901598 ---> 0.0056350508111679, 0.0058957903901598
# LPLIPA1: -100.0, 100.0 ---->  -100.0, 99.9995574379276
# Before/after: -100.0, 99.9995574379276 ---> -100.0, 99.9995574379276
# LPLIPA2: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# LPLIPA4: -100.0, 100.0 ---->  -99.99901789575394, 100.0
# Before/after: -99.99901789575394, 100.0 ---> -99.99901789575394, 100.0
# LPLIPA5: -100.0, 100.0 ---->  -100.0, 99.99950000034738
# Before/after: -100.0, 99.99950000034738 ---> -100.0, 99.99950000034738
# LPLIPA6: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# LPSSYNEC: 0.005635050811200342, 0.005895790390127609 ---->  0.0056350508111679, 0.0058957903901598
# Before/after: 0.0056350508111679, 0.0058957903901598 ---> 0.0056350508111679, 0.0058957903901598
# MACPD: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# MALS: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# MCITD: -100.0, 100.0 ---->  -0.1937188271052576, 100.0
# Before/after: -0.1937188271052576, 100.0 ---> -0.1937188271052576, 100.0
# MCITL2: -100.0, 100.0 ---->  -0.193718828170887, 100.0
# Before/after: -0.193718828170887, 100.0 ---> -0.193718828170887, 100.0
# MCITS: -100.0, 100.0 ---->  -0.1937188271052576, 100.0
# Before/after: -0.1937188271052576, 100.0 ---> -0.1937188271052576, 100.0
# MCOATA: -100.0, 100.0 ---->  -91.88836960725465, 100.0
# Before/after: -91.88836960725465, 100.0 ---> -91.88836960725465, 100.0
# MDH: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# MDH2: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# MDH3: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# MDRPD: 0.004695875676006267, 0.004913158658439443 ---->  0.0046958756758357, 0.0049131586586099
# Before/after: 0.0046958756758357, 0.0049131586586099 ---> 0.0046958756758357, 0.0049131586586099
# ME1: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# ME2: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# METAT: 0.004695875676006267, 0.004913158658439443 ---->  0.0046958756758935, 0.004913158658545
# Before/after: 0.0046958756758935, 0.004913158658545 ---> 0.0046958756758935, 0.004913158658545
# METS: 0.09794254981372022, 0.10247445201888464 ---->  0.097942549813105, 0.1024744520195639
# Before/after: 0.097942549813105, 0.1024744520195639 ---> 0.097942549813105, 0.1024744520195639
# MICITD: -100.0, 100.0 ---->  -0.193718828170887, 100.0
# Before/after: -0.193718828170887, 100.0 ---> -0.193718828170887, 100.0
# MLTG2: -100.0, 100.0 ---->  -100.0, 99.45077615632384
# Before/after: -100.0, 99.45077615632384 ---> -100.0, 99.45077615632384
# MLTG3: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# MLTG4: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# MLTG5: -100.0, 100.0 ---->  -99.17714356401672, 100.0
# Before/after: -99.17714356401672, 100.0 ---> -99.17714356401672, 100.0
# MLTP1: -100.0, 100.0 ---->  -100.0, 99.11029094662392
# Before/after: -100.0, 99.11029094662392 ---> -100.0, 99.11029094662392
# MLTP2: -100.0, 100.0 ---->  -99.57348032074552, 99.11953270250586
# Before/after: -99.57348032074552, 99.11953270250586 ---> -99.57348032074552, 99.11953270250586
# MLTP3: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# MMCD: -100.0, 100.0 ---->  -99.81484833049076, 100.0
# Before/after: -99.81484833049076, 100.0 ---> -99.81484833049076, 100.0
# MME: -100.0, 100.0 ---->  -99.81484833049063, 100.0
# Before/after: -99.81484833049063, 100.0 ---> -99.81484833049063, 100.0
# MMM2: -100.0, 100.0 ---->  -99.31117873032052, 100.0
# Before/after: -99.31117873032052, 100.0 ---> -99.31117873032052, 100.0
# MOAT: 0.005635050811200342, 0.005895790390127609 ---->  0.0056350508111679, 0.0058957904144937
# Before/after: 0.0056350508111679, 0.0058957904144937 ---> 0.0056350508111679, 0.0058957904144937
# MOAT2: 0.005635050811200342, 0.005895790390127609 ---->  0.0056350508111679, 0.0058957903901598
# Before/after: 0.0056350508111679, 0.0058957903901598 ---> 0.0056350508111679, 0.0058957903901598
# MOHMT: 3.957952356126171e-05, 4.141090869325126e-05 ---->  -4.141090869280717e-05, 4.141090869280717e-05
# Before/after: -4.141090869280717e-05, 4.141090869280717e-05 ---> -4.141090869280717e-05, 4.141090869280717e-05
# MTAN: 0.004695875676006267, 0.004913158658439443 ---->  0.0046958756759778, 0.0049131586787493
# Before/after: 0.0046958756759778, 0.0049131586787493 ---> 0.0046958756759778, 0.0049131586787493
# MTHFC: -100.0, 100.0 ---->  -99.09738414635646, 100.0
# Before/after: -99.09738414635646, 100.0 ---> -99.09738414635646, 100.0
# MTHFD: -100.0, 100.0 ---->  -98.88291245877954, 100.0
# Before/after: -98.88291245877954, 100.0 ---> -98.88291245877954, 100.0
# MTHFR2: 0.13148451892800797, 0.1375684424363109 ---->  0.1314845189271096, 0.1375684424371996
# Before/after: 0.1314845189271096, 0.1375684424371996 ---> 0.1314845189271096, 0.1375684424371996
# MTRI: 0.004695875676006267, 0.004913158658439443 ---->  0.0046958756758357, 0.0049131586787493
# Before/after: 0.0046958756758357, 0.0049131586787493 ---> 0.0046958756758357, 0.0049131586787493
# MTRK: 0.004695875676006267, 0.004913158658439443 ---->  0.0046958756758357, 0.0049131586787493
# Before/after: 0.0046958756758357, 0.0049131586787493 ---> 0.0046958756758357, 0.0049131586787493
# NADH10: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# NADH5: -100.0, 100.0 ---->  0.0, 99.07087333933876
# Before/after: 0.0, 99.07087333933876 ---> 0.0, 99.07087333933876
# NADH9: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# NADK: -99.9996444551274, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# NADPPPS: -100.0, 99.99964445512738 ---->  -0.000422035553683, 99.99964441737184
# Before/after: -0.000422035553683, 99.99964441737184 ---> -0.000422035553683, 99.99964441737184
# NAMNPP: -100.0, 100.0 ---->  -0.0019161713792925, 99.99864343712292
# Before/after: -0.0019161713792925, 99.99864343712292 ---> -0.0019161713792925, 99.99864343712292
# NDPK1: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# NDPK2: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# NDPK5: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# NDPK6: -100.0, 100.0 ---->  -99.7456177062387, 99.95936769464085
# Before/after: -99.7456177062387, 99.95936769464085 ---> -99.7456177062387, 99.95936769464085
# NDPK7: -100.0, 100.0 ---->  -99.68065736493006, 99.70896692981717
# Before/after: -99.68065736493006, 99.70896692981717 ---> -99.68065736493006, 99.70896692981717
# NMNN: -100.0, 100.0 ---->  -0.0019161713792925, 100.0
# Before/after: -0.0019161713792925, 100.0 ---> -0.0019161713792925, 100.0
# NNDPR: 0.0018313915136545234, 0.0019161318766265367 ---->  0.0018313915136294, 0.0019161318768028
# Before/after: 0.0018313915136294, 0.0019161318768028 ---> 0.0018313915136294, 0.0019161318768028
# NTD1: -100.0, 100.0 ---->  -99.28443535872434, 100.0
# Before/after: -99.28443535872434, 100.0 ---> -99.28443535872434, 100.0
# NTD10: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# NTD11: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# NTD2: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# NTD4: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# NTD5: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# NTD6: -100.0, 100.0 ---->  -100.0, 99.23191684441548
# Before/after: -100.0, 99.23191684441548 ---> -100.0, 99.23191684441548
# NTD8: -100.0, 100.0 ---->  -99.22885332318322, 99.8132316075789
# Before/after: -99.22885332318322, 99.8132316075789 ---> -99.22885332318322, 99.8132316075789
# NTD9: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# NTPTP1: -100.0, 100.0 ---->  -99.065567598359, 99.06486072185992
# Before/after: -99.065567598359, 99.06486072185992 ---> -99.065567598359, 99.06486072185992
# NTPTP2: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# OBTFL: -100.0, 99.81484833048913 ---->  -99.04200139559336, 99.31117869256502
# Before/after: -99.04200139559336, 99.31117869256502 ---> -99.04200139559336, 99.31117869256502
# OMCDC: 0.28711925561830315, 0.3004045579731667 ---->  0.2871192556166551, 0.3004045579748289
# Before/after: 0.2871192556166551, 0.3004045579748289 ---> 0.2871192556166551, 0.3004045579748289
# OMPDC: 0.2113814893582435, 0.2211623276105854 ---->  0.2113814893570378, 0.2211623276118359
# Before/after: 0.2113814893570378, 0.2211623276118359 ---> 0.2113814893570378, 0.2211623276118359
# ORPT: -0.22116232761061067, -0.2113814893582031 ---->  -0.2211623276118217, -0.211381489357052
# Before/after: -0.2211623276118217, -0.211381489357052 ---> -0.2211623276118217, -0.211381489357052
# P5CR: -99.85912372972, 100.0 ---->  -99.85912372972008, 100.0
# Before/after: -99.85912372972008, 100.0 ---> -99.85912372972008, 100.0
# PANTS: 3.957952355904126e-05, 4.141090869325126e-05 ---->  -4.141090869280717e-05, 4.141090869280717e-05
# Before/after: -4.141090869280717e-05, 4.141090869280717e-05 ---> -4.141090869280717e-05, 4.141090869280717e-05
# PAPAEC: -100.0, 99.9887298983776 ---->  -0.0117915807803257, 99.98872989837788
# Before/after: -0.0117915807803257, 99.98872989837788 ---> -0.0117915807803257, 99.98872989837788
# PAPPT3: 0.018515166951086837, 0.019371882710419286 ---->  0.0185151669510514, 0.019371882710454
# Before/after: 0.0185151669510514, 0.019371882710454 ---> 0.0185151669510514, 0.019371882710454
# PAPSR: 0.15634515559613993, 0.1635794062539085 ---->  0.1563451555952383, 0.1635794062548029
# Before/after: 0.1563451555952383, 0.1635794062548029 ---> 0.1563451555952383, 0.1635794062548029
# PDH: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# PDXPP: -100.0, 100.0 ---->  -1.0000178463087649e-10, 100.0
# Before/after: -1.0000178463087649e-10, 100.0 ---> 0.0, 100.0
# PEPTEC: 0.011270101622400684, 0.011791580780255217 ---->  0.0112701016223359, 0.0117915807803197
# Before/after: 0.0112701016223359, 0.0117915807803197 ---> 0.0112701016223359, 0.0117915807803197
# PFK: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# PFL: -100.0, 100.0 ---->  -100.0, 99.94321856479657
# Before/after: -100.0, 99.94321856479657 ---> -100.0, 99.94321856479657
# PGAMT: -0.05053534620109379, -0.04830043552457436 ---->  -0.0505353462014372, -0.0483004355241751
# Before/after: -0.0505353462014372, -0.0483004355241751 ---> -0.0505353462014372, -0.0483004355241751
# PGMT: -100.0, 100.0 ---->  -100.0, 5.647908095133971
# Before/after: -100.0, 5.647908095133971 ---> -100.0, 5.647908095133971
# PGPPEC: -99.97578269829948, 100.0 ---->  -99.23731075492584, 100.0
# Before/after: -99.23731075492584, 100.0 ---> -99.23731075492584, 100.0
# PGSAEC: -99.97578269829948, 100.0 ---->  -99.64990518262508, 100.0
# Before/after: -99.64990518262508, 100.0 ---> -99.64990518262508, 100.0
# PHETA1: -0.12353084626934038, -0.11806773128229288 ---->  -0.1235308462693716, -0.1180677312822595
# Before/after: -0.1235308462693716, -0.1180677312822595 ---> -0.1235308462693716, -0.1180677312822595
# PLIPA1: -100.0, 99.97578269829948 ---->  -100.0, 99.97578269829953
# Before/after: -100.0, 99.97578269829953 ---> -100.0, 99.97578269829953
# PMDPHT: 6.708393826215797e-06, 7.018798072522259e-06 ---->  6.708393822819045e-06, 7.018798083524042e-06
# Before/after: 6.708393822819045e-06, 7.018798083524042e-06 ---> 6.708393822819045e-06, 7.018798083524042e-06
# PNTK: 3.957952354186056e-05, 4.141090867568198e-05 ---->  -4.141090869280717e-05, 4.141090869280717e-05
# Before/after: -4.141090869280717e-05, 4.141090869280717e-05 ---> -4.141090869280717e-05, 4.141090869280717e-05
# ppa: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# PPC: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# PPCDC: 3.957952357325212e-05, 4.141090868259312e-05 ---->  3.957952355466747e-05, 4.141090892062493e-05
# Before/after: 3.957952355466747e-05, 4.141090892062493e-05 ---> 3.957952355466747e-05, 4.141090892062493e-05
# PPCK: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# PPM: -100.0, 100.0 ---->  -100.0, 99.36006011275026
# Before/after: -100.0, 99.36006011275026 ---> -100.0, 99.36006011275026
# PPNCL2: 3.95795235768881e-05, 4.141090866482955e-05 ---->  3.957952355466746e-05, 4.141090869282857e-05
# Before/after: 3.957952355466746e-05, 4.141090869282857e-05 ---> 3.957952355466746e-05, 4.141090869282857e-05
# PPND: 0.08787995907943391, 0.09194625489365676 ---->  0.0878799590794052, 0.0919414110713378
# Before/after: 0.0878799590794052, 0.0919414110713378 ---> 0.0878799590794052, 0.0919414110713378
# PPNDH: 0.11806773128229288, 0.12353084626934038 ---->  0.1180677312822595, 0.1235308462693716
# Before/after: 0.1180677312822595, 0.1235308462693716 ---> 0.1180677312822595, 0.1235308462693716
# PPS: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# PPTGS: 0.018515166951086837, 0.019371882710419286 ---->  0.0185151669510514, 0.019371882710454
# Before/after: 0.0185151669510514, 0.019371882710454 ---> 0.0185151669510514, 0.019371882710454
# PRAGSr: 0.3301260975776702, 0.3454013706065067 ---->  0.3301260975752882, 0.345401370608414
# Before/after: 0.3301260975752882, 0.345401370608414 ---> 0.3301260975752882, 0.345401370608414
# PRAIi: 0.03622532664343077, 0.03790150965082262 ---->  0.036225326643219, 0.0379015096510298
# Before/after: 0.036225326643219, 0.0379015096510298 ---> 0.036225326643219, 0.0379015096510298
# PRAIS: 0.3301260975776702, 0.3454013706065067 ---->  0.3301260975754356, 0.3454013706085703
# Before/after: 0.3301260975754356, 0.3454013706085703 ---> 0.3301260975754356, 0.3454013706085703
# PRAMPC: 0.060375544405715686, 0.06316918275136629 ---->  0.0603755444052893, 0.0631691827517413
# Before/after: 0.0603755444052893, 0.0631691827517413 ---> 0.0603755444052893, 0.0631691827517413
# PRASCS: 0.3301260975776702, 0.34540137060650977 ---->  0.330126097575345, 0.3454013706084566
# Before/after: 0.330126097575345, 0.3454013706084566 ---> 0.330126097575345, 0.3454013706084566
# PRATPP: 0.060375544405715686, 0.06316918275136629 ---->  0.0603755444052893, 0.0631691827517413
# Before/after: 0.0603755444052893, 0.0631691827517413 ---> 0.0603755444052893, 0.0631691827517413
# PRFGS: 0.3301260975776702, 0.3454013706065067 ---->  0.3301260975753735, 0.3454013706084993
# Before/after: 0.3301260975753735, 0.3454013706084993 ---> 0.3301260975753735, 0.3454013706084993
# PRMICIi: 0.060375544405715686, 0.06316918275136629 ---->  0.0603755444052893, 0.0631691827517413
# Before/after: 0.0603755444052893, 0.0631691827517413 ---> 0.0603755444052893, 0.0631691827517413
# PROD2: -100.0, 99.85912372971998 ---->  -100.0, 99.85912372972008
# Before/after: -100.0, 99.85912372972008 ---> -100.0, 99.85912372972008
# PRPPS: -100.0, 100.0 ---->  -99.36006015050684, 100.0
# Before/after: -99.36006015050684, 100.0 ---> -99.36006015050684, 100.0
# PSCVT: 0.27571498611943923, 0.2884726012312484 ---->  0.2757149861174071, 0.2876281695467882
# Before/after: 0.2757149861174071, 0.2876281695467882 ---> 0.2757149861174071, 0.2876281695467882
# PSDEC: -99.92382618814146, 99.99825581760605 ---->  -99.92382618814202, 99.99825581981963
# Before/after: -99.92382618814202, 99.99825581981963 ---> -99.92382618814202, 99.99825581981963
# PSSAEC: -99.92208200574753, 100.0 ---->  -99.92208200574822, 99.99687876208505
# Before/after: -99.92208200574822, 99.99687876208505 ---> -99.92208200574822, 99.99687876208505
# PTAr: -100.0, 100.0 ---->  -99.0270917434598, 100.0
# Before/after: -99.0270917434598, 100.0 ---> -99.0270917434598, 100.0
# PTPATi: 3.9579523530619554e-05, 4.141090870746211e-05 ---->  -4.141090869280717e-05, 4.141090869280717e-05
# Before/after: -4.141090869280717e-05, 4.141090869280717e-05 ---> -4.141090869280717e-05, 4.141090869280717e-05
# PUNP1: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# PUNP2: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# PUNP4: -100.0, 100.0 ---->  -99.88386997307563, 100.0
# Before/after: -99.88386997307563, 100.0 ---> -99.88386997307563, 100.0
# PUNP5: -100.0, 100.0 ---->  -99.01848891592604, 100.0
# Before/after: -99.01848891592604, 100.0 ---> -99.01848891592604, 100.0
# PUNP6: -100.0, 100.0 ---->  -0.0173364312663011, 98.9004445016599
# Before/after: -0.0173364312663011, 98.9004445016599 ---> -0.0173364312663011, 98.9004445016599
# ...
# Before/after: 0.2372088055748814, 0.2481847009170603 ---> 0.2372088055748814, 0.2481847009170603
# SDPTA: -0.24818470023203842, -0.2372088055762414 ---->  -0.2481847009170603, -0.2372088055748814
# Before/after: -0.2481847009170603, -0.2372088055748814 ---> -0.2481847009170603, -0.2372088055748814
# SERDL: -100.0, 100.0 ---->  0.0, 99.4411009020821
# Before/after: 0.0, 99.4411009020821 ---> 0.0, 99.4411009020821
# SHK3Dr: 0.2757149861194393, 0.2884726012312423 ---->  0.2757149861178627, 0.2884726012328381
# Before/after: 0.2757149861178627, 0.2884726012328381 ---> 0.2757149861178627, 0.2884726012328381
# SHKK: 0.2757149861193966, 0.2884726012312413 ---->  0.2757149861178627, 0.2884726012328381
# Before/after: 0.2757149861178627, 0.2884726012328381 ---> 0.2757149861178627, 0.2884726012328381
# SHSL1: 0.09794254981372022, 0.10247445201888464 ---->  0.097942549813105, 0.1024744520195639
# Before/after: 0.097942549813105, 0.1024744520195639 ---> 0.097942549813105, 0.1024744520195639
# SPMS: 0.004695875676006267, 0.004913158658439443 ---->  0.0046958756759778, 0.0049131586584678
# Before/after: 0.0046958756759778, 0.0049131586584678 ---> 0.0046958756759778, 0.0049131586584678
# SSALx: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# SSALy: -100.0, 100.0 ---->  -100.0, 99.7170689582786
# Before/after: -100.0, 99.7170689582786 ---> -100.0, 99.7170689582786
# SUCD: -100.0, 100.0 ---->  -99.13788650056937, 46.98634343257186
# Before/after: -99.13788650056937, 46.98634343257186 ---> -99.13788650056937, 46.98634343257186
# SUCOAS: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# SULR: -0.16357940625384515, -0.15634515559610426 ---->  -0.1635794062548029, -0.1563451555952383
# Before/after: -0.1635794062548029, -0.1563451555952383 ---> -0.1635794062548029, -0.1563451555952383
# TDSK: 0.005635050811200342, 0.005895790390127609 ---->  0.0056350508111679, 0.0058957903901598
# Before/after: 0.0056350508111679, 0.0058957903901598 ---> 0.0056350508111679, 0.0058957903901598
# TESTAKGDH: -100.0, 100.0 ---->  -100.0, 99.25496578203754
# Before/after: -100.0, 99.25496578203754 ---> -100.0, 99.25496578203754
# TESTNADTRHD: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# THDPS: 0.237208805576243, 0.2481847002320337 ---->  0.2372088055748814, 0.2481847002334101
# Before/after: 0.2372088055748814, 0.2481847002334101 ---> 0.2372088055748814, 0.2481847002334101
# THRD: -100.0, 100.0 ---->  -100.0, 99.11007704624126
# Before/after: -100.0, 99.11007704624126 ---> -100.0, 99.11007704624126
# THRDL: -99.81484833048913, 100.0 ---->  -99.81484833049048, 99.49633036207516
# Before/after: -99.81484833049048, 99.49633036207516 ---> -99.81484833049048, 99.49633036207516
# TMAOR1: -100.0, 100.0 ---->  0.0, -0.0
# Before/after: 0.0, -0.0 ---> 0.0, 0.0
# TMAOR2: -100.0, 100.0 ---->  0.0, -0.0
# Before/after: 0.0, -0.0 ---> 0.0, 0.0
# TMDK1: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# TMDS: 0.01656973274245388, 0.017336431266201657 ---->  0.0165697327423615, 0.0173364312663064
# Before/after: 0.0165697327423615, 0.0173364312663064 ---> 0.0165697327423615, 0.0173364312663064
# TRE6PH: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# TRE6PP: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# TRE6PS: -100.0, 99.98671738023074 ---->  -6.074427774383764, 99.72867297428115
# Before/after: -6.074427774383764, 99.72867297428115 ---> -6.074427774383764, 99.72867297428115
# TREH: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# TREHe: -100.0, 100.0 ---->  -6.074427774383764, 6.217248937900878e-14
# Before/after: -6.074427774383764, 6.217248937900878e-14 ---> -6.074427774383764, 0.0
# TRPAS2: -100.0, 100.0 ---->  -0.0379015096510357, 100.0
# Before/after: -0.0379015096510357, 100.0 ---> -0.0379015096510357, 100.0
# TRPS1: -99.96377467335657, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# TRPS2: -100.0, 100.0 ---->  0.0, 99.99212896028725
# Before/after: 0.0, 99.99212896028725 ---> 0.0, 99.99212896028725
# TRPS3: -99.96377467335657, 100.0 ---->  -99.96377467335684, 0.0379015096510357
# Before/after: -99.96377467335684, 0.0379015096510357 ---> -99.96377467335684, 0.0379015096510357
# TRSAR: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# TYRTA: -0.09194625489365676, -0.08787995907943391 ---->  -0.0919462548936849, -0.0878799590794052
# Before/after: -0.0919462548936849, -0.0878799590794052 ---> -0.0919462548936849, -0.0878799590794052
# U23GAAT: 0.011270101622400684, 0.011791580780255217 ---->  0.0112701016223359, 0.0117915807803203
# Before/after: 0.0112701016223359, 0.0117915807803203 ---> 0.0112701016223359, 0.0117915807803203
# UAAGDS: 0.018515166951086837, 0.019371882710419286 ---->  0.0185151669510514, 0.019371882710454
# Before/after: 0.0185151669510514, 0.019371882710454 ---> 0.0185151669510514, 0.019371882710454
# UAGAAT: 0.011270101622400684, 0.011791580780255217 ---->  0.0112701016223359, 0.0117915807803203
# Before/after: 0.0112701016223359, 0.0117915807803203 ---> 0.0112701016223359, 0.0117915807803203
# UAGCVT: 0.018515166951086837, 0.019371882710419286 ---->  0.018515166951019, 0.0193718827104873
# Before/after: 0.018515166951019, 0.0193718827104873 ---> 0.018515166951019, 0.0193718827104873
# UAGDP: 0.04830043552457436, 0.05053534620109379 ---->  0.0483004355241751, 0.0505353462014372
# Before/after: 0.0483004355241751, 0.0505353462014372 ---> 0.0483004355241751, 0.0505353462014372
# UAGPT3: 0.018515166951086837, 0.019371882710419286 ---->  0.0185151669510514, 0.019371882710454
# Before/after: 0.0185151669510514, 0.019371882710454 ---> 0.0185151669510514, 0.019371882710454
# UAMAGS: 0.018515166951086837, 0.019371882710419286 ---->  0.0185151669510514, 0.0193718827104873
# Before/after: 0.0185151669510514, 0.0193718827104873 ---> 0.0185151669510514, 0.0193718827104873
# UAMAS: 0.018515166951086837, 0.019371882710419286 ---->  0.018515166951019, 0.0193718827104873
# Before/after: 0.018515166951019, 0.0193718827104873 ---> 0.018515166951019, 0.0193718827104873
# UAPGR: 0.018515166951086837, 0.019371882710419286 ---->  0.018515166951019, 0.0193718827104873
# Before/after: 0.018515166951019, 0.0193718827104873 ---> 0.018515166951019, 0.0193718827104873
# UDCPDP: 0.018515166951086837, 0.019371882710419286 ---->  0.0185151669510514, 0.019371882710454
# Before/after: 0.0185151669510514, 0.019371882710454 ---> 0.0185151669510514, 0.019371882710454
# UGMDDS: 0.018515166951086837, 0.019371882710419286 ---->  0.0185151669510514, 0.019371882710454
# Before/after: 0.0185151669510514, 0.019371882710454 ---> 0.0185151669510514, 0.019371882710454
# UHGADA: 0.011270101622400684, 0.011791580780255217 ---->  0.0112701016223359, 0.0117915807803203
# Before/after: 0.0112701016223359, 0.0117915807803203 ---> 0.0112701016223359, 0.0117915807803203
# UMPK: -100.0, 100.0 ---->  -98.7783302193395, 100.0
# Before/after: -98.7783302193395, 100.0 ---> -98.7783302193395, 100.0
# UNK3: 0.004695875676006267, 0.004913158658439443 ---->  0.0046958756758935, 0.004913158658545
# Before/after: 0.0046958756758935, 0.004913158658545 ---> 0.0046958756758935, 0.004913158658545
# UPPRT: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# URIDK2r: -100.0, 100.0 ---->  -99.78103802562326, 100.0
# Before/after: -99.78103802562326, 100.0 ---> -99.78103802562326, 100.0
# URIK2: -100.0, 100.0 ---->  -99.37662980773676, 100.0
# Before/after: -99.37662980773676, 100.0 ---> -99.37662980773676, 100.0
# USHD: 0.005635050811200342, 0.005895790390127609 ---->  0.0056350508111679, 0.0058957903901598
# Before/after: 0.0056350508111679, 0.0058957903901598 ---> 0.0056350508111679, 0.0058957903901598
# VALTA: -100.0, 99.73032256832113 ---->  -100.0, 99.3474074489163
# Before/after: -100.0, 99.3474074489163 ---> -100.0, 99.3474074489163
# VPAMT: -99.73032256832113, 100.0 ---->  -99.73032256832118, 99.6170848805935
# Before/after: -99.73032256832118, 99.6170848805935 ---> -99.73032256832118, 99.6170848805935
# XPPT: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# biomass: 0.670839382285755, 0.7018798083485249 ---->  0.6708393822857204, 0.7018798083485507
# Before/after: 0.6708393822857204, 0.7018798083485507 ---> 0.6708393822857204, 0.7018798083485507
# EX_ac: 8.826068397839, 12.84593332748 ---->  8.826068397839, 12.84593332748
# Before/after: 8.826068397839, 12.84593332748 ---> 8.826068397839, 12.84593332748
# EX_h2o: -15.623185177713722, 88.88378986434954 ---->  16.103440453574393, 17.346813674214985
# Before/after: 16.103440453574393, 17.346813674214985 ---> 16.103440453574393, 17.346813674214985
# EX_nh3: -8.259854073237221, -7.738956551238843 ---->  -8.259854073276543, -7.738956551196683
# Before/after: -8.259854073276543, -7.738956551196683 ---> -8.259854073276543, -7.738956551196683
# EX_pi: -0.6697596826790004, -0.640139759634593 ---->  -0.6697596826828285, -0.6401397596305254
# Before/after: -0.6697596826828285, -0.6401397596305254 ---> -0.6697596826828285, -0.6401397596305254
# EX_so4: -0.16357940625391376, -0.15634515559615458 ---->  -0.163579406254803, -0.1563451555952384
# Before/after: -0.163579406254803, -0.1563451555952384 ---> -0.163579406254803, -0.1563451555952384
# ACt2r: -12.84593332748, -8.826068397839 ---->  -12.841706670631275, -8.82606839783898
# Before/after: -12.841706670631275, -8.82606839783898 ---> -12.841706670631275, -8.82606839783898
# ARGabc: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# ARGORNt7: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# ATPS4r: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# Cex: -100.0, 100.0 ---->  -100.0, -4.68771694194225
# Before/after: -100.0, -4.68771694194225 ---> -100.0, -4.68771694194225
# CHLabc: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# CHLt2r: -100.0, 100.0 ---->  -100.0, -0.0
# Before/after: -100.0, -0.0 ---> -100.0, 0.0
# CYTBD: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# DMSOR1e: -100.0, 100.0 ---->  0.0, -0.0
# Before/after: 0.0, -0.0 ---> 0.0, 0.0
# DMSOR2e: -100.0, 100.0 ---->  0.0, -0.0
# Before/after: 0.0, -0.0 ---> 0.0, 0.0
# FDH2: -100.0, 100.0 ---->  0.0, 99.492973892221
# Before/after: 0.0, 99.492973892221 ---> 0.0, 99.492973892221
# FDH3: -100.0, 100.0 ---->  -100.0, 89.9709872830552
# Before/after: -100.0, 89.9709872830552 ---> -100.0, 89.9709872830552
# FRUpts: -100.0, 100.0 ---->  0.0, -0.0
# Before/after: 0.0, -0.0 ---> 0.0, 0.0
# FRUpts2: -100.0, 100.0 ---->  0.0, -0.0
# Before/after: 0.0, -0.0 ---> 0.0, 0.0
# FUMt22: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# GALabc: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# GALt2: -100.0, 100.0 ---->  -100.0, -0.0
# Before/after: -100.0, -0.0 ---> -100.0, 0.0
# GLCDe: -16.815970042341586, 23.947018425649873 ---->  0.0, 9.531228305402164
# Before/after: 0.0, 9.531228305402164 ---> 0.0, 9.531228305402164
# GLCNt2r: -16.815970042341586, 23.94701842564946 ---->  0.0, 9.531228305809712
# Before/after: 0.0, 9.531228305809712 ---> 0.0, 9.531228305809712
# GLCpts: -100.0, 100.0 ---->  0.0, 12.148855548767475
# Before/after: 0.0, 12.148855548767475 ---> 0.0, 12.148855548767475
# GLCt2: -100.0, 100.0 ---->  0.0, 12.148855548767624
# Before/after: 0.0, 12.148855548767624 ---> 0.0, 12.148855548767624
# GLYBabc: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# GLYBt2r: -100.0, 100.0 ---->  -99.21155752779298, -0.0
# Before/after: -99.21155752779298, -0.0 ---> -99.21155752779298, 0.0
# GLYC3Pabc: -100.0, 100.0 ---->  0.0, 0.669759804874503
# Before/after: 0.0, 0.669759804874503 ---> 0.0, 0.669759804874503
# GLYC3Pt6: -100.0, 100.0 ---->  -0.669759682682809, -0.0
# Before/after: -0.669759682682809, -0.0 ---> -0.669759682682809, 0.0
# Ht: -100.0, 100.0 ---->  -100.0, -0.0
# Before/after: -100.0, -0.0 ---> -100.0, 0.0
# HYD1: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# HYD2: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# HYD3: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# ILEabc: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# ILEt2r: -100.0, 100.0 ---->  -99.83824418677182, -0.0
# Before/after: -99.83824418677182, -0.0 ---> -99.83824418677182, 0.0
# LEUabc: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# LEUt2r: -100.0, 100.0 ---->  -100.0, -0.0
# Before/after: -100.0, -0.0 ---> -100.0, 0.0
# LYSabc: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# LYSt2r: -100.0, 100.0 ---->  -99.04584148458156, 100.0
# Before/after: -99.04584148458156, 100.0 ---> -99.04584148458156, 100.0
# NADH6: -100.0, 100.0 ---->  0.0, 99.10547374602774
# Before/after: 0.0, 99.10547374602774 ---> 0.0, 99.10547374602774
# NADH7: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# NADH8: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# NH3t: 7.738956551238331, 8.259854073233736 ---->  7.738956551196809, 8.259854073276466
# Before/after: 7.738956551196809, 8.259854073276466 ---> 7.738956551196809, 8.259854073276466
# NMNt7: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# NO3R1: -100.0, 100.0 ---->  -99.75715855377368, -0.0
# Before/after: -99.75715855377368, -0.0 ---> -99.75715855377368, 0.0
# NO3R2: -100.0, 100.0 ---->  0.0, 99.5404870226032
# Before/after: 0.0, 99.5404870226032 ---> 0.0, 99.5404870226032
# ORNabc: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# PIabc: -100.0, 100.0 ---->  0.0, 0.6697596826827806
# Before/after: 0.0, 0.6697596826827806 ---> 0.0, 0.6697596826827806
# PIt2r: -100.0, 100.0 ---->  0.0, 0.6697596826832601
# Before/after: 0.0, 0.6697596826832601 ---> 0.0, 0.6697596826832601
# PTRCabc: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# PTRCORNt7: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# PTRCt2r: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# SUCCabc: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# SUCCt22: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# SUCFUMt: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# SULabc: 0.15634515559611373, 0.16357940625387357 ---->  0.1563451555952383, 0.1635794062548029
# Before/after: 0.1563451555952383, 0.1635794062548029 ---> 0.1563451555952383, 0.1635794062548029
# THD2: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# TMAOR1e: -100.0, 100.0 ---->  0.0, -0.0
# Before/after: 0.0, -0.0 ---> 0.0, 0.0
# TMAOR2e: -100.0, 100.0 ---->  0.0, -0.0
# Before/after: 0.0, -0.0 ---> 0.0, 0.0
# TREpts: -100.0, 100.0 ---->  2.8421709430404014e-14, 6.074427774383764
# Before/after: 2.8421709430404014e-14, 6.074427774383764 ---> 0.0, 6.074427774383764
# VALabc: -100.0, 100.0 ---->  0.0, 99.09722325952072
# Before/after: 0.0, 99.09722325952072 ---> 0.0, 99.09722325952072
# VALt2r: -100.0, 100.0 ---->  -100.0, -0.0
# Before/after: -100.0, -0.0 ---> -100.0, 0.0
# biomass_ce: 0.670839382285755, 0.7018798083485249 ---->  0.6708393822857204, 0.7018798083485507
# Before/after: 0.6708393822857204, 0.7018798083485507 ---> 0.6708393822857204, 0.7018798083485507
# biomass_EX: 0.670839382285755, 0.7018798083485249 ---->  0.670839382285755, 0.7018798083485249
# Before/after: 0.670839382285755, 0.7018798083485249 ---> 0.670839382285755, 0.7018798083485249
# OROTex: -99.73811580193951, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# DCTA: -99.73811580193951, 100.0 ---->  -99.7381158019396, 0.3554058820475489
# Before/after: -99.7381158019396, 0.3554058820475489 ---> -99.7381158019396, 0.3554058820475489
# EX_oro: 0.261884198060484, 0.35540588204754797 ---->  0.261884198060484, 0.3554058820475479
# Before/after: 0.261884198060484, 0.3554058820475479 ---> 0.261884198060484, 0.3554058820475479

# %%
# Save the TFVA bounds of the model
save_flux_bounds_complete(tmodel_glc, "results/bounds/ecoli_WT_Glc_no_metabolome_tfva.csv")

# %%
# Now repeat the process for Acetate condition
tmodel_ace = setup_model(CONDITIONS[1], mets_tva=None)
# Out:
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2731723
# Academic license 2731723 - for non-commercial use only - registered to l.___@student.rug.nl
# ['Parameters', 'Exchange reactions', 'Reactions', 'Biomass Composition', 'Transmembrane reactions', 'Metabolites', 'references', 'Transmembrane_reactions_reed', 'Transmembrane reactions_Orth', 'Transmembrane reactions old', 'Sheet3', 'log', 'subsystems']
# *** Reading data from Reactions ***
# unknown metabolite '2dhglcn[c]' created
# unknown metabolite 'nadh[c]' created
# unknown metabolite 'glcn[c]' created
# unknown metabolite 'nad[c]' created
# unknown metabolite 'nadph[c]' created
# unknown metabolite 'nadp[c]' created
# unknown metabolite '2dhguln[c]' created
# unknown metabolite 'idon-L[c]' created
# unknown metabolite '3hcinnm[c]' created
# unknown metabolite 'o2[c]' created
# unknown metabolite 'dhcinnm[c]' created
# unknown metabolite 'h2o[c]' created
# unknown metabolite '3hpppn[c]' created
# unknown metabolite 'dhpppn[c]' created
# unknown metabolite 'phthr[c]' created
# unknown metabolite '4hthr[c]' created
# unknown metabolite 'pi[c]' created
# unknown metabolite '5dglcn[c]' created
# unknown metabolite 'ru5p-D[c]' created
# unknown metabolite 'ara5p[c]' created
# unknown metabolite 'ACP[c]' created
# unknown metabolite 'atp[c]' created
# unknown metabolite 'ttdca[c]' created
# unknown metabolite 'amp[c]' created
# unknown metabolite 'myrsACP[c]' created
# unknown metabolite 'ppi[c]' created
# unknown metabolite 'ttdcea[c]' created
# unknown metabolite 'tdeACP[c]' created
# unknown metabolite 'hdca[c]' created
# unknown metabolite 'palmACP[c]' created
# unknown metabolite 'hdcea[c]' created
# unknown metabolite 'hdeACP[c]' created
# unknown metabolite 'ocdcea[c]' created
# unknown metabolite 'octeACP[c]' created
# unknown metabolite 'dtdp4aaddg[c]' created
# unknown metabolite 'unagamu[c]' created
# unknown metabolite 'dtdp[c]' created
# unknown metabolite 'unagamuf[c]' created
# unknown metabolite 'arbt6p[c]' created
# unknown metabolite 'g6p[c]' created
# unknown metabolite 'hqn[c]' created
# unknown metabolite '4abut[c]' created
# unknown metabolite 'akg[c]' created
# unknown metabolite 'glu-L[c]' created
# unknown metabolite 'sucsal[c]' created
# unknown metabolite '4abutn[c]' created
# unknown metabolite 'acac[c]' created
# unknown metabolite 'accoa[c]' created
# unknown metabolite 'aacoa[c]' created
# unknown metabolite 'ac[c]' created
# unknown metabolite 'coa[c]' created
# unknown metabolite 'acald[c]' created
# unknown metabolite 'adocbip[c]' created
# unknown metabolite 'gtp[c]' created
# unknown metabolite 'agdpcbi[c]' created
# unknown metabolite 'co2tot[c]' created
# unknown metabolite 'adp[c]' created
# unknown metabolite 'malcoa[c]' created
# unknown metabolite 'ppa[c]' created
# unknown metabolite 'ppcoa[c]' created
# unknown metabolite 'uacgam[c]' created
# unknown metabolite 'udcpp[c]' created
# unknown metabolite 'ump[c]' created
# unknown metabolite 'unaga[c]' created
# unknown metabolite 'acglu[c]' created
# unknown metabolite 'acg5p[c]' created
# unknown metabolite '2obut[c]' created
# unknown metabolite 'pyr[c]' created
# unknown metabolite '2ahbut[c]' created
# unknown metabolite 'actp[c]' created
# unknown metabolite 'alac-S[c]' created
# unknown metabolite 'uacmamu[c]' created
# unknown metabolite 'udp[c]' created
# unknown metabolite 'acnam[c]' created
# unknown metabolite 'acmana[c]' created
# unknown metabolite 'acACP[c]' created
# unknown metabolite 'acorn[c]' created
# unknown metabolite 'orn[c]' created
# unknown metabolite 'acon-T[c]' created
# unknown metabolite 'amet[c]' created
# unknown metabolite 'aconm[c]' created
# unknown metabolite 'ahcys[c]' created
# unknown metabolite 'cit[c]' created
# unknown metabolite 'icit[c]' created
# unknown metabolite 'acg5sa[c]' created
# unknown metabolite 'apoACP[c]' created
# unknown metabolite 'pap[c]' created
# unknown metabolite 'adn[c]' created
# unknown metabolite 'ins[c]' created
# unknown metabolite 'nh3[c]' created
# unknown metabolite '4adcho[c]' created
# unknown metabolite '4abz[c]' created
# unknown metabolite 'chor[c]' created
# unknown metabolite 'gln-L[c]' created
# unknown metabolite 'ade[c]' created
# unknown metabolite 'hxan[c]' created
# unknown metabolite 'etoh[c]' created
# unknown metabolite 'gdp[c]' created
# unknown metabolite 'itp[c]' created
# unknown metabolite 'idp[c]' created
# unknown metabolite 'ametam[c]' created
# unknown metabolite 'camp[c]' created
# unknown metabolite 'adocbi[c]' created
# unknown metabolite 'rdmbzi[c]' created
# unknown metabolite 'adocbl[c]' created
# unknown metabolite 'gmp[c]' created
# unknown metabolite 'prpp[c]' created
# unknown metabolite 'aps[c]' created
# unknown metabolite 'paps[c]' created
# unknown metabolite 'dcamp[c]' created
# unknown metabolite 'fum[c]' created
# unknown metabolite '25aics[c]' created
# unknown metabolite 'aicar[c]' created
# unknown metabolite 'asp-L[c]' created
# unknown metabolite 'imp[c]' created
# unknown metabolite 'acgam6p[c]' created
# unknown metabolite 'gam6p[c]' created
# unknown metabolite 'adphep-DD[c]' created
# unknown metabolite 'adphep-LD[c]' created
# unknown metabolite 'agm[c]' created
# unknown metabolite 'ptrc[c]' created
# unknown metabolite 'urea[c]' created
# unknown metabolite 'hcys-L[c]' created
# unknown metabolite 'rhcys[c]' created
# unknown metabolite '10fthf[c]' created
# unknown metabolite 'fprica[c]' created
# unknown metabolite 'thf[c]' created
# unknown metabolite 'air[c]' created
# unknown metabolite '5caiz[c]' created
# unknown metabolite '5aizc[c]' created
# unknown metabolite 'ala-D[c]' created
# unknown metabolite 'alaala[c]' created
# unknown metabolite 'ala-L[c]' created
# unknown metabolite 'pydx5p[c]' created
# unknown metabolite 'pyam5p[c]' created
# unknown metabolite 'glyald[c]' created
# unknown metabolite 'glyc[c]' created
# unknown metabolite 'pacald[c]' created
# unknown metabolite 'pac[c]' created
# unknown metabolite 'alltt[c]' created
# unknown metabolite 'urdglyc[c]' created
# unknown metabolite 'alltn[c]' created
# unknown metabolite 'altrn[c]' created
# unknown metabolite '2ddglcn[c]' created
# unknown metabolite 'malt[c]' created
# unknown metabolite 'malttr[c]' created
# unknown metabolite 'glc-D[c]' created
# unknown metabolite 'maltttr[c]' created
# unknown metabolite 'maltpt[c]' created
# unknown metabolite 'malthx[c]' created
# unknown metabolite 'malthp[c]' created
# unknown metabolite 'acmanap[c]' created
# unknown metabolite '8aonn[c]' created
# unknown metabolite 'amob[c]' created
# unknown metabolite 'dann[c]' created
# unknown metabolite '2dmmq8[c]' created
# unknown metabolite 'mqn8[c]' created
# unknown metabolite '4ampm[c]' created
# unknown metabolite 'for[c]' created
# unknown metabolite 'r5p[c]' created
# unknown metabolite 'anth[c]' created
# unknown metabolite 'pran[c]' created
# unknown metabolite 'pmcoa[c]' created
# unknown metabolite 'ap4a[c]' created
# unknown metabolite 'ap5a[c]' created
# unknown metabolite '5apru[c]' created
# unknown metabolite '5aprbu[c]' created
# unknown metabolite 'arab-L[c]' created
# unknown metabolite 'rbl-L[c]' created
# unknown metabolite 'arg-L[c]' created
# unknown metabolite 'argsuc[c]' created
# unknown metabolite 'citr-L[c]' created
# unknown metabolite 'aspsa[c]' created
# unknown metabolite '4pasp[c]' created
# unknown metabolite 'asn-L[c]' created
# unknown metabolite 'ala-B[c]' created
# unknown metabolite 'cbp[c]' created
# unknown metabolite 'cbasp[c]' created
# unknown metabolite 'q8[c]' created
# unknown metabolite 'iasp[c]' created
# unknown metabolite 'q8h2[c]' created
# unknown metabolite 'mql8[c]' created
# unknown metabolite 'succ[c]' created
# unknown metabolite 'h2o2[c]' created
# unknown metabolite 'oaa[c]' created
# unknown metabolite 'succoa[c]' created
# unknown metabolite 'sucarg[c]' created
# unknown metabolite 'prbatp[c]' created
# unknown metabolite 'betald[c]' created
# unknown metabolite 'glyb[c]' created
# unknown metabolite 'btnso[c]' created
# unknown metabolite 'btn[c]' created
# unknown metabolite 'cys-L[c]' created
# unknown metabolite 'dtbt[c]' created
# unknown metabolite 'but[c]' created
# unknown metabolite 'btcoa[c]' created
# unknown metabolite 'actACP[c]' created
# unknown metabolite 'malACP[c]' created
# unknown metabolite 'ddcaACP[c]' created
# unknown metabolite 'cbi[c]' created
# unknown metabolite 'cbl1[c]' created
# unknown metabolite 'cdpdag1[c]' created
# unknown metabolite 'cmp[c]' created
# unknown metabolite 'paEC[c]' created
# unknown metabolite '4c2me[c]' created
# unknown metabolite '2p4c2me[c]' created
# unknown metabolite 'pphn[c]' created
# unknown metabolite '3psme[c]' created
# unknown metabolite '4hbz[c]' created
# unknown metabolite 'cinnm[c]' created
# unknown metabolite 'cenchddd[c]' created
# unknown metabolite 'pgEC[c]' created
# unknown metabolite 'clpnEC[c]' created
# unknown metabolite 'csn[c]' created
# unknown metabolite 'cpppg3[c]' created
# unknown metabolite 'pppg9[c]' created
# unknown metabolite 'bbtcoa[c]' created
# unknown metabolite 'crn[c]' created
# unknown metabolite 'crncoa[c]' created
# unknown metabolite 'gbbtn[c]' created
# unknown metabolite 'ctbtcoa[c]' created
# unknown metabolite 'ctbt[c]' created
# unknown metabolite 'ura[c]' created
# unknown metabolite 'utp[c]' created
# unknown metabolite 'ctp[c]' created
# unknown metabolite 'cyan[c]' created
# unknown metabolite 'tsul[c]' created
# unknown metabolite 'so3[c]' created
# unknown metabolite 'tcynt[c]' created
# unknown metabolite 'cynt[c]' created
# unknown metabolite 'acser[c]' created
# unknown metabolite 'h2s[c]' created
# unknown metabolite 'cyst-L[c]' created
# unknown metabolite 'cytd[c]' created
# unknown metabolite 'uri[c]' created
# unknown metabolite 'cdp[c]' created
# unknown metabolite 'dcmp[c]' created
# unknown metabolite 'dcdp[c]' created
# unknown metabolite 'fad[c]' created
# unknown metabolite 'fadh2[c]' created
# unknown metabolite 'dad-2[c]' created
# unknown metabolite 'din[c]' created
# unknown metabolite 'damp[c]' created
# unknown metabolite 'dadp[c]' created
# unknown metabolite '12dgrEC[c]' created
# unknown metabolite '26dap-M[c]' created
# unknown metabolite 'lys-L[c]' created
# unknown metabolite '26dap-LL[c]' created
# unknown metabolite 'db4p[c]' created
# unknown metabolite 'dctp[c]' created
# unknown metabolite 'dutp[c]' created
# unknown metabolite 'dcyt[c]' created
# unknown metabolite 'duri[c]' created
# unknown metabolite '2dh3dgal[c]' created
# unknown metabolite '2dh3dgal6p[c]' created
# unknown metabolite '2ddg6p[c]' created
# unknown metabolite 'e4p[c]' created
# unknown metabolite 'pep[c]' created
# unknown metabolite '2dda7p[c]' created
# unknown metabolite 'g3p[c]' created
# unknown metabolite 'dgmp[c]' created
# unknown metabolite 'dgdp[c]' created
# unknown metabolite '23dhmb[c]' created
# unknown metabolite '3mob[c]' created
# unknown metabolite '23dhmp[c]' created
# unknown metabolite '3mop[c]' created
# unknown metabolite 'dha[c]' created
# unknown metabolite 'dhap[c]' created
# unknown metabolite '23ddhb[c]' created
# unknown metabolite '23dhb[c]' created
# unknown metabolite '23dhba[c]' created
# unknown metabolite 'hkntd[c]' created
# unknown metabolite '23dhdp[c]' created
# unknown metabolite 'thdp[c]' created
# unknown metabolite 'dhf[c]' created
# unknown metabolite 'dhpt[c]' created
# unknown metabolite 'dhna[c]' created
# unknown metabolite 'octdp[c]' created
# unknown metabolite 'dhnpt[c]' created
# unknown metabolite '6hmhpt[c]' created
# unknown metabolite 'gcald[c]' created
# unknown metabolite 'dhor-S[c]' created
# unknown metabolite 'orot[c]' created
# unknown metabolite 'cechddd[c]' created
# unknown metabolite '25drapp[c]' created
# unknown metabolite '6hmhptpp[c]' created
# unknown metabolite 'dhptd[c]' created
# unknown metabolite 'hmfurn[c]' created
# unknown metabolite '3dhq[c]' created
# unknown metabolite '3dhsk[c]' created
# unknown metabolite '25dkglcn[c]' created
# unknown metabolite 'dkmpp[c]' created
# unknown metabolite '2kmb[c]' created
# unknown metabolite 'dmpp[c]' created
# unknown metabolite 'ipdp[c]' created
# unknown metabolite 'grdp[c]' created
# unknown metabolite 'h2mb4p[c]' created
# unknown metabolite '2omhmbl[c]' created
# unknown metabolite 'dmso[c]' created
# unknown metabolite 'dms[c]' created
# unknown metabolite '2dmmql8[c]' created
# unknown metabolite 'dhpmp[c]' created
# unknown metabolite 'ahdt[c]' created
# unknown metabolite '23doguln[c]' created
# unknown metabolite '3dhguln[c]' created
# unknown metabolite 'dpcoa[c]' created
# unknown metabolite '2dhp[c]' created
# unknown metabolite 'pant-R[c]' created
# unknown metabolite '2dr5p[c]' created
# unknown metabolite 'dtmp[c]' created
# unknown metabolite 'dump[c]' created
# unknown metabolite '2dr1p[c]' created
# unknown metabolite 'dxyl5p[c]' created
# unknown metabolite '2me4p[c]' created
# unknown metabolite 'dxyl[c]' created
# unknown metabolite '4per[c]' created
# unknown metabolite 'ecaEC[c]' created
# unknown metabolite 'udcpdp[c]' created
# unknown metabolite '6pgc[c]' created
# unknown metabolite 'kdo2lipid4[c]' created
# unknown metabolite 'kdo2lipid4L[c]' created
# unknown metabolite 'lipa[c]' created
# unknown metabolite 'kdo2lipid4p[c]' created
# unknown metabolite 'lipa_cold[c]' created
# unknown metabolite '2pg[c]' created
# unknown metabolite 'seramp[c]' created
# unknown metabolite 'enter[c]' created
# unknown metabolite 'etha[c]' created
# unknown metabolite 'f6p[c]' created
# unknown metabolite 'ocdca[c]' created
# unknown metabolite 'fdp[c]' created
# unknown metabolite 'fuc-L[c]' created
# unknown metabolite 'fcl-L[c]' created
# unknown metabolite 'fc1p[c]' created
# unknown metabolite 'lald-L[c]' created
# unknown metabolite 'fe2[c]' created
# unknown metabolite 'ppp9[c]' created
# unknown metabolite 'pheme[c]' created
# unknown metabolite 'suc6p[c]' created
# unknown metabolite 'fru[c]' created
# unknown metabolite 'h2[c]' created
# unknown metabolite 'fmn[c]' created
# unknown metabolite 'f1p[c]' created
# unknown metabolite 'mal-L[c]' created
# unknown metabolite 'gam1p[c]' created
# unknown metabolite 'acgam1p[c]' created
# unknown metabolite 'g1p[c]' created
# unknown metabolite 'dttp[c]' created
# unknown metabolite 'dtdpglu[c]' created
# unknown metabolite 'glu1sa[c]' created
# unknown metabolite '5aop[c]' created
# unknown metabolite 'glyc3p[c]' created
# unknown metabolite 'glu5sa[c]' created
# unknown metabolite '1pyr5c[c]' created
# unknown metabolite 'glu5p[c]' created
# unknown metabolite '6pgl[c]' created
# unknown metabolite 'galct-D[c]' created
# unknown metabolite '5dh4dglc[c]' created
# unknown metabolite 'galctn-D[c]' created
# unknown metabolite 'gal[c]' created
# unknown metabolite 'gal1p[c]' created
# unknown metabolite 'melib[c]' created
# unknown metabolite 'udpg[c]' created
# unknown metabolite '13dpg[c]' created
# unknown metabolite 'gar[c]' created
# unknown metabolite 'fgam[c]' created
# unknown metabolite 'glyclt[c]' created
# unknown metabolite 'gdpddman[c]' created
# unknown metabolite 'gdpofuc[c]' created
# unknown metabolite 'ser-L[c]' created
# unknown metabolite 'gly[c]' created
# unknown metabolite 'mlthf[c]' created
# unknown metabolite 'glycogen[c]' created
# unknown metabolite '2h3oppan[c]' created
# unknown metabolite 'glcr[c]' created
# unknown metabolite 'adpglc[c]' created
# unknown metabolite 'galt1p[c]' created
# unknown metabolite 'tag6p-D[c]' created
# unknown metabolite 'glucys[c]' created
# unknown metabolite 'pram[c]' created
# unknown metabolite 'glu-D[c]' created
# unknown metabolite 'glutrna[c]' created
# unknown metabolite 'trnaglu[c]' created
# unknown metabolite 'glx[c]' created
# unknown metabolite '2aobut[c]' created
# unknown metabolite 'glyc-R[c]' created
# unknown metabolite '3pg[c]' created
# unknown metabolite 'lgt-S[c]' created
# unknown metabolite 'gthrd[c]' created
# unknown metabolite 'lac-D[c]' created
# unknown metabolite 'gdpmann[c]' created
# unknown metabolite 'gmhep1p[c]' created
# unknown metabolite 'gmhep7p[c]' created
# unknown metabolite 'gmhep17bp[c]' created
# unknown metabolite 'xmp[c]' created
# unknown metabolite 'gdpfuc[c]' created
# unknown metabolite 'gp4g[c]' created
# unknown metabolite 'g3pc[c]' created
# unknown metabolite 'chol[c]' created
# unknown metabolite 'g3pe[c]' created
# unknown metabolite 'g3ps[c]' created
# unknown metabolite 'g3pg[c]' created
# unknown metabolite 'g3pi[c]' created
# unknown metabolite 'inost[c]' created
# unknown metabolite 'frdp[c]' created
# unknown metabolite 'gsn[c]' created
# unknown metabolite 'gtspmd[c]' created
# unknown metabolite 'spmd[c]' created
# unknown metabolite 'gthox[c]' created
# unknown metabolite 'gua[c]' created
# unknown metabolite 'xan[c]' created
# unknown metabolite 'glcur[c]' created
# unknown metabolite 'fruur[c]' created
# unknown metabolite 'galur[c]' created
# unknown metabolite 'tagur[c]' created
# unknown metabolite '3ophb[c]' created
# unknown metabolite 'hemeO[c]' created
# unknown metabolite '4mhetz[c]' created
# unknown metabolite '4mpetz[c]' created
# unknown metabolite 'histd[c]' created
# unknown metabolite 'his-L[c]' created
# unknown metabolite 'hisp[c]' created
# unknown metabolite 'hkndd[c]' created
# unknown metabolite 'op4en[c]' created
# unknown metabolite 'ppbng[c]' created
# unknown metabolite 'hmbil[c]' created
# unknown metabolite '4ahmmp[c]' created
# unknown metabolite '4h2opntn[c]' created
# unknown metabolite 'hpyr[c]' created
# unknown metabolite 'hom-L[c]' created
# unknown metabolite 'phom[c]' created
# unknown metabolite 'suchms[c]' created
# unknown metabolite 'imacp[c]' created
# unknown metabolite 'pydam[c]' created
# unknown metabolite 'ichor[c]' created
# unknown metabolite 'prlp[c]' created
# unknown metabolite 'eig3p[c]' created
# unknown metabolite '2cpr5p[c]' created
# unknown metabolite '3ig3p[c]' created
# unknown metabolite 'ile-L[c]' created
# unknown metabolite '3c2hmp[c]' created
# unknown metabolite '3c4mop[c]' created
# unknown metabolite '2ippm[c]' created
# unknown metabolite '3c3hmp[c]' created
# unknown metabolite '3hmrsACP[c]' created
# unknown metabolite 'kdo[c]' created
# unknown metabolite 'ckdo[c]' created
# unknown metabolite 'kdo8p[c]' created
# unknown metabolite '3dhgulnp[c]' created
# unknown metabolite 'xu5p-L[c]' created
# unknown metabolite 'lcts[c]' created
# unknown metabolite 'lac-L[c]' created
# unknown metabolite '12ppd-S[c]' created
# unknown metabolite '4mop[c]' created
# unknown metabolite 'leu-L[c]' created
# unknown metabolite 'mthgxl[c]' created
# unknown metabolite 'lipidX[c]' created
# unknown metabolite 'u23ga[c]' created
# unknown metabolite 'lipidAds[c]' created
# unknown metabolite 'agpgEC[c]' created
# unknown metabolite 'agpeEC[c]' created
# unknown metabolite 'agpcEC[c]' created
# unknown metabolite 'apgEC[c]' created
# unknown metabolite 'cdpea[c]' created
# unknown metabolite 'lpsEC[c]' created
# unknown metabolite '15dap[c]' created
# unknown metabolite 'mnl1p[c]' created
# unknown metabolite 'man1p[c]' created
# unknown metabolite 'man6p[c]' created
# unknown metabolite 'mana[c]' created
# unknown metabolite '2mcit[c]' created
# unknown metabolite '2mcacn[c]' created
# unknown metabolite 'micit[c]' created
# unknown metabolite '5mdru1p[c]' created
# unknown metabolite '2mecdp[c]' created
# unknown metabolite 'met-L[c]' created
# unknown metabolite '5mthf[c]' created
# unknown metabolite 'mi1p-D[c]' created
# unknown metabolite 'mmcoa-S[c]' created
# unknown metabolite 'mmcoa-R[c]' created
# unknown metabolite 'lipidA[c]' created
# unknown metabolite 'kdolipid4[c]' created
# unknown metabolite '5mta[c]' created
# unknown metabolite '5mtr[c]' created
# unknown metabolite 'methf[c]' created
# unknown metabolite '5mdr1p[c]' created
# unknown metabolite 'nmn[c]' created
# unknown metabolite 'h2o[e]' created
# unknown metabolite 'nad[e]' created
# unknown metabolite 'amp[e]' created
# unknown metabolite 'nmn[e]' created
# unknown metabolite 'dnad[c]' created
# unknown metabolite 'nac[c]' created
# unknown metabolite 'nicrnt[c]' created
# unknown metabolite 'dgtp[c]' created
# unknown metabolite 'dudp[c]' created
# unknown metabolite 'datp[c]' created
# unknown metabolite 'ncam[c]' created
# unknown metabolite 'dmbzid[c]' created
# unknown metabolite '5prdmbz[c]' created
# unknown metabolite 'quln[c]' created
# unknown metabolite 'sbzcoa[c]' created
# unknown metabolite 'xtsn[c]' created
# unknown metabolite 'thymd[c]' created
# unknown metabolite 'dgsn[c]' created
# unknown metabolite 'pppi[c]' created
# unknown metabolite 'no2[c]' created
# unknown metabolite 'ohpb[c]' created
# unknown metabolite '2ohph[c]' created
# unknown metabolite '2omph[c]' created
# unknown metabolite '2ombzl[c]' created
# unknown metabolite '2ommbl[c]' created
# unknown metabolite 'orot5p[c]' created
# unknown metabolite '2oph[c]' created
# unknown metabolite 'thmpp[c]' created
# unknown metabolite 'ssaltpp[c]' created
# unknown metabolite 'pro-L[c]' created
# unknown metabolite 'phaccoa[c]' created
# unknown metabolite 'pnto-R[c]' created
# unknown metabolite 'ugmda[c]' created
# unknown metabolite 'uagmda[c]' created
# unknown metabolite 'trdrd[c]' created
# unknown metabolite 'trdox[c]' created
# unknown metabolite 'pdx5p[c]' created
# unknown metabolite 'pydxn[c]' created
# unknown metabolite 'peamn[c]' created
# unknown metabolite 'peEC[c]' created
# unknown metabolite 'tagdp-D[c]' created
# unknown metabolite '3php[c]' created
# unknown metabolite '2pglyc[c]' created
# unknown metabolite 'pgpEC[c]' created
# unknown metabolite 'phe-L[c]' created
# unknown metabolite 'phpyr[c]' created
# unknown metabolite 'pcEC[c]' created
# unknown metabolite '4r5au[c]' created
# unknown metabolite '2mahmp[c]' created
# unknown metabolite '4ppan[c]' created
# unknown metabolite 'ppap[c]' created
# unknown metabolite '4ppcys[c]' created
# unknown metabolite 'pan4p[c]' created
# unknown metabolite 'r1p[c]' created
# unknown metabolite '34hpp[c]' created
# unknown metabolite 'pppn[c]' created
# unknown metabolite 'uaagmda[c]' created
# unknown metabolite 'peptidoEC[c]' created
# unknown metabolite 'fpram[c]' created
# unknown metabolite 'prbamp[c]' created
# unknown metabolite 'prfp[c]' created
# unknown metabolite 'skm5p[c]' created
# unknown metabolite 'psEC[c]' created
# unknown metabolite 'pser-L[c]' created
# unknown metabolite 'pydx[c]' created
# unknown metabolite 'ribflv[c]' created
# unknown metabolite 'dmlz[c]' created
# unknown metabolite 'rib-D[c]' created
# unknown metabolite 'ru5p-L[c]' created
# unknown metabolite 'xu5p-D[c]' created
# unknown metabolite 'rmn[c]' created
# unknown metabolite 'rml[c]' created
# unknown metabolite 'rml1p[c]' created
# unknown metabolite 's7p[c]' created
# unknown metabolite 'sucorn[c]' created
# unknown metabolite 'so4[c]' created
# unknown metabolite 'sbt6p[c]' created
# unknown metabolite 'sl26da[c]' created
# unknown metabolite 'sl2a6o[c]' created
# unknown metabolite 'seln[c]' created
# unknown metabolite 'selnp[c]' created
# unknown metabolite 'ser-D[c]' created
# unknown metabolite 'sucglu[c]' created
# unknown metabolite 'sucgsa[c]' created
# unknown metabolite '2shchc[c]' created
# unknown metabolite 'scl[c]' created
# unknown metabolite 'srch[c]' created
# unknown metabolite 'sheme[c]' created
# unknown metabolite 'skm[c]' created
# unknown metabolite 'N1aspmd[c]' created
# unknown metabolite 'n8aspmd[c]' created
# unknown metabolite 'o2s[c]' created
# unknown metabolite 'sucbz[c]' created
# unknown metabolite 'tartr-L[c]' created
# unknown metabolite 'taur[c]' created
# unknown metabolite 'aacald[c]' created
# unknown metabolite 'dtdp4addg[c]' created
# unknown metabolite 'dtdp4d6dg[c]' created
# unknown metabolite 'dtdp4d6dm[c]' created
# unknown metabolite 'dtdprmn[c]' created
# unknown metabolite 'thr-L[c]' created
# unknown metabolite 'tyr-L[c]' created
# unknown metabolite '4hba[c]' created
# unknown metabolite 'tmao[c]' created
# unknown metabolite 'tma[c]' created
# unknown metabolite 'thym[c]' created
# unknown metabolite 'thm[c]' created
# unknown metabolite 'thmmp[c]' created
# unknown metabolite 'tre6p[c]' created
# unknown metabolite 'tre[c]' created
# unknown metabolite 'tre[e]' created
# unknown metabolite 'glc-D[e]' created
# unknown metabolite 'trp-L[c]' created
# unknown metabolite 'indole[c]' created
# unknown metabolite 'u3hga[c]' created
# unknown metabolite 'uamag[c]' created
# unknown metabolite 'ugmd[c]' created
# unknown metabolite 'uacmam[c]' created
# unknown metabolite 'u3aga[c]' created
# unknown metabolite 'uaccg[c]' created
# unknown metabolite 'uama[c]' created
# unknown metabolite 'uamr[c]' created
# unknown metabolite 'udpgal[c]' created
# unknown metabolite 'udpgalfur[c]' created
# unknown metabolite 'udpglcur[c]' created
# unknown metabolite 'uppg3[c]' created
# unknown metabolite 'val-L[c]' created
# unknown metabolite 'xyl-D[c]' created
# unknown metabolite 'xylu-D[c]' created
# *** Reading data from Biomass Composition ***
# *** Reading data from Exchange reactions ***
# unknown metabolite '12ppd-S[e]' created
# unknown metabolite '15dap[e]' created
# unknown metabolite '26dap-M[e]' created
# unknown metabolite '2ddglcn[e]' created
# unknown metabolite '3hcinnm[e]' created
# unknown metabolite '3hpppn[e]' created
# unknown metabolite '4abut[e]' created
# unknown metabolite 'ac[e]' created
# unknown metabolite 'acac[e]' created
# unknown metabolite 'acald[e]' created
# unknown metabolite 'acgam[e]' created
# unknown metabolite 'acmana[e]' created
# unknown metabolite 'acnam[e]' created
# unknown metabolite 'ade[e]' created
# unknown metabolite 'adn[e]' created
# unknown metabolite 'akg[e]' created
# unknown metabolite 'ala-D[e]' created
# unknown metabolite 'ala-L[e]' created
# unknown metabolite 'alltn[e]' created
# unknown metabolite 'arab-L[e]' created
# unknown metabolite 'arg-L[e]' created
# unknown metabolite 'asn-L[e]' created
# unknown metabolite 'asp-L[e]' created
# unknown metabolite 'but[e]' created
# unknown metabolite 'charge[e]' created
# unknown metabolite 'cbl1[e]' created
# unknown metabolite 'chol[e]' created
# unknown metabolite 'cit[e]' created
# unknown metabolite 'co2tot[e]' created
# unknown metabolite 'crn[e]' created
# unknown metabolite 'csn[e]' created
# unknown metabolite 'cynt[e]' created
# unknown metabolite 'cys-L[e]' created
# unknown metabolite 'cytd[e]' created
# unknown metabolite 'dad-2[e]' created
# unknown metabolite 'dcyt[e]' created
# unknown metabolite 'dgsn[e]' created
# unknown metabolite 'dha[e]' created
# unknown metabolite 'din[e]' created
# unknown metabolite 'dms[e]' created
# unknown metabolite 'dmso[e]' created
# unknown metabolite 'duri[e]' created
# unknown metabolite 'etoh[e]' created
# unknown metabolite 'fe2[e]' created
# unknown metabolite 'for[e]' created
# unknown metabolite 'fru[e]' created
# unknown metabolite 'fuc1p-L[e]' created
# unknown metabolite 'fuc-L[e]' created
# unknown metabolite 'fum[e]' created
# unknown metabolite 'g6p[e]' created
# unknown metabolite 'gal[e]' created
# unknown metabolite 'galct-D[e]' created
# unknown metabolite 'galctn-D[e]' created
# unknown metabolite 'galt[e]' created
# unknown metabolite 'galur[e]' created
# unknown metabolite 'gam[e]' created
# unknown metabolite 'gbbtn[e]' created
# unknown metabolite 'glcn[e]' created
# unknown metabolite 'glcr[e]' created
# unknown metabolite 'glcur[e]' created
# unknown metabolite 'gln-L[e]' created
# unknown metabolite 'glu-L[e]' created
# unknown metabolite 'gly[e]' created
# unknown metabolite 'glyald[e]' created
# unknown metabolite 'glyb[e]' created
# unknown metabolite 'glyc[e]' created
# unknown metabolite 'glyc3p[e]' created
# unknown metabolite 'glyclt[e]' created
# unknown metabolite 'gsn[e]' created
# unknown metabolite 'gua[e]' created
# unknown metabolite 'h[e]' created
# unknown metabolite 'hdca[e]' created
# unknown metabolite 'his-L[e]' created
# unknown metabolite 'hxan[e]' created
# unknown metabolite 'idon-L[e]' created
# unknown metabolite 'ile-L[e]' created
# unknown metabolite 'indole[e]' created
# unknown metabolite 'ins[e]' created
# unknown metabolite 'k[e]' created
# unknown metabolite 'lac-D[e]' created
# unknown metabolite 'lac-L[e]' created
# unknown metabolite 'lcts[e]' created
# unknown metabolite 'leu-L[e]' created
# unknown metabolite 'lys-L[e]' created
# unknown metabolite 'mal-L[e]' created
# unknown metabolite 'malt[e]' created
# unknown metabolite 'malthx[e]' created
# unknown metabolite 'maltpt[e]' created
# unknown metabolite 'malttr[e]' created
# unknown metabolite 'maltttr[e]' created
# unknown metabolite 'man[e]' created
# unknown metabolite 'man6p[e]' created
# unknown metabolite 'melib[e]' created
# unknown metabolite 'met-D[e]' created
# unknown metabolite 'met-L[e]' created
# unknown metabolite 'mnl[e]' created
# unknown metabolite 'na1[e]' created
# unknown metabolite 'nac[e]' created
# unknown metabolite 'nh3[e]' created
# unknown metabolite 'no2[e]' created
# unknown metabolite 'no3[e]' created
# unknown metabolite 'o2[e]' created
# unknown metabolite 'ocdca[e]' created
# unknown metabolite 'orn[e]' created
# unknown metabolite 'phe-L[e]' created
# unknown metabolite 'pi[e]' created
# unknown metabolite 'pnto-R[e]' created
# unknown metabolite 'pppn[e]' created
# unknown metabolite 'pro-L[e]' created
# unknown metabolite 'ptrc[e]' created
# unknown metabolite 'pyr[e]' created
# unknown metabolite 'rib-D[e]' created
# unknown metabolite 'rmn[e]' created
# unknown metabolite 'sbt-D[e]' created
# unknown metabolite 'ser-D[e]' created
# unknown metabolite 'ser-L[e]' created
# unknown metabolite 'so4[e]' created
# unknown metabolite 'spmd[e]' created
# unknown metabolite 'succ[e]' created
# unknown metabolite 'sucr[e]' created
# unknown metabolite 'tartr-L[e]' created
# unknown metabolite 'taur[e]' created
# unknown metabolite 'thm[e]' created
# unknown metabolite 'thr-L[e]' created
# unknown metabolite 'thymd[e]' created
# unknown metabolite 'tma[e]' created
# unknown metabolite 'tmao[e]' created
# unknown metabolite 'trp-L[e]' created
# unknown metabolite 'tsul[e]' created
# unknown metabolite 'ttdca[e]' created
# unknown metabolite 'tyr-L[e]' created
# unknown metabolite 'ura[e]' created
# unknown metabolite 'urea[e]' created
# unknown metabolite 'uri[e]' created
# unknown metabolite 'val-L[e]' created
# unknown metabolite 'xan[e]' created
# unknown metabolite 'xtsn[e]' created
# unknown metabolite 'xyl-D[e]' created
# *** Reading data from Transmembrane reactions ***
# unknown metabolite 'h[c]' created
# unknown metabolite 'acgam[c]' created
# unknown metabolite 'charge[c]' created
# unknown metabolite 'electron[c]' created
# unknown metabolite 'electron[e]' created
# unknown metabolite 'fuc1p-L[c]' created
# unknown metabolite 'galt[c]' created
# unknown metabolite 'gam[c]' created
# unknown metabolite 'na1[c]' created
# unknown metabolite 'h2[e]' created
# unknown metabolite 'k[c]' created
# unknown metabolite 'malt6p[c]' created
# unknown metabolite 'man[c]' created
# unknown metabolite 'met-D[c]' created
# unknown metabolite 'mnl[c]' created
# unknown metabolite 'no3[c]' created
# unknown metabolite 'sbt-D[c]' created
# unknown metabolite 'sucr[c]' created
# *** Reading data from Parameters ***
# *** Reading data from Metabolites ***
# Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# *** Updating metabolite information ***
# 2dhglcn_c NOTHING DONE!
# nadh_c NOTHING DONE!
# glcn_c NOTHING DONE!
# nad_c NOTHING DONE!
# nadph_c NOTHING DONE!
# nadp_c NOTHING DONE!
# 2dhguln_c NOTHING DONE!
# idon-L_c NOTHING DONE!
# 3hcinnm_c NOTHING DONE!
# o2_c NOTHING DONE!
# dhcinnm_c NOTHING DONE!
# h2o_c NOTHING DONE!
# 3hpppn_c NOTHING DONE!
# dhpppn_c NOTHING DONE!
# phthr_c NOTHING DONE!
# 4hthr_c NOTHING DONE!
# pi_c NOTHING DONE!
# 5dglcn_c NOTHING DONE!
# ru5p-D_c NOTHING DONE!
# ara5p_c NOTHING DONE!
# ACP_c NOTHING DONE!
# atp_c NOTHING DONE!
# ttdca_c NOTHING DONE!
# amp_c NOTHING DONE!
# myrsACP_c NOTHING DONE!
# ppi_c NOTHING DONE!
# ttdcea_c NOTHING DONE!
# tdeACP_c NOTHING DONE!
# hdca_c NOTHING DONE!
# palmACP_c NOTHING DONE!
# hdcea_c NOTHING DONE!
# hdeACP_c NOTHING DONE!
# ocdcea_c NOTHING DONE!
# octeACP_c NOTHING DONE!
# dtdp4aaddg_c NOTHING DONE!
# unagamu_c NOTHING DONE!
# dtdp_c NOTHING DONE!
# unagamuf_c NOTHING DONE!
# arbt6p_c NOTHING DONE!
# g6p_c NOTHING DONE!
# hqn_c NOTHING DONE!
# 4abut_c NOTHING DONE!
# akg_c NOTHING DONE!
# glu-L_c NOTHING DONE!
# sucsal_c NOTHING DONE!
# 4abutn_c NOTHING DONE!
# acac_c NOTHING DONE!
# accoa_c NOTHING DONE!
# aacoa_c NOTHING DONE!
# ac_c NOTHING DONE!
# coa_c NOTHING DONE!
# acald_c NOTHING DONE!
# adocbip_c NOTHING DONE!
# gtp_c NOTHING DONE!
# agdpcbi_c NOTHING DONE!
# co2tot_c NOTHING DONE!
# adp_c NOTHING DONE!
# malcoa_c NOTHING DONE!
# ppa_c NOTHING DONE!
# ppcoa_c NOTHING DONE!
# uacgam_c NOTHING DONE!
# udcpp_c NOTHING DONE!
# ump_c NOTHING DONE!
# unaga_c NOTHING DONE!
# acglu_c NOTHING DONE!
# acg5p_c NOTHING DONE!
# 2obut_c NOTHING DONE!
# pyr_c NOTHING DONE!
# 2ahbut_c NOTHING DONE!
# actp_c NOTHING DONE!
# alac-S_c NOTHING DONE!
# uacmamu_c NOTHING DONE!
# udp_c NOTHING DONE!
# acnam_c NOTHING DONE!
# acmana_c NOTHING DONE!
# acACP_c NOTHING DONE!
# acorn_c NOTHING DONE!
# orn_c NOTHING DONE!
# acon-T_c NOTHING DONE!
# amet_c NOTHING DONE!
# aconm_c NOTHING DONE!
# ahcys_c NOTHING DONE!
# cit_c NOTHING DONE!
# icit_c NOTHING DONE!
# acg5sa_c NOTHING DONE!
# apoACP_c NOTHING DONE!
# pap_c NOTHING DONE!
# adn_c NOTHING DONE!
# ins_c NOTHING DONE!
# nh3_c NOTHING DONE!
# 4adcho_c NOTHING DONE!
# 4abz_c NOTHING DONE!
# chor_c NOTHING DONE!
# gln-L_c NOTHING DONE!
# ade_c NOTHING DONE!
# hxan_c NOTHING DONE!
# etoh_c NOTHING DONE!
# gdp_c NOTHING DONE!
# itp_c NOTHING DONE!
# idp_c NOTHING DONE!
# ametam_c NOTHING DONE!
# camp_c NOTHING DONE!
# adocbi_c NOTHING DONE!
# rdmbzi_c NOTHING DONE!
# adocbl_c NOTHING DONE!
# gmp_c NOTHING DONE!
# prpp_c NOTHING DONE!
# aps_c NOTHING DONE!
# paps_c NOTHING DONE!
# dcamp_c NOTHING DONE!
# fum_c NOTHING DONE!
# 25aics_c NOTHING DONE!
# aicar_c NOTHING DONE!
# asp-L_c NOTHING DONE!
# imp_c NOTHING DONE!
# acgam6p_c NOTHING DONE!
# gam6p_c NOTHING DONE!
# adphep-DD_c NOTHING DONE!
# adphep-LD_c NOTHING DONE!
# agm_c NOTHING DONE!
# ptrc_c NOTHING DONE!
# urea_c NOTHING DONE!
# hcys-L_c NOTHING DONE!
# rhcys_c NOTHING DONE!
# 10fthf_c NOTHING DONE!
# fprica_c NOTHING DONE!
# thf_c NOTHING DONE!
# air_c NOTHING DONE!
# 5caiz_c NOTHING DONE!
# 5aizc_c NOTHING DONE!
# ala-D_c NOTHING DONE!
# alaala_c NOTHING DONE!
# ala-L_c NOTHING DONE!
# pydx5p_c NOTHING DONE!
# pyam5p_c NOTHING DONE!
# glyald_c NOTHING DONE!
# glyc_c NOTHING DONE!
# pacald_c NOTHING DONE!
# pac_c NOTHING DONE!
# alltt_c NOTHING DONE!
# urdglyc_c NOTHING DONE!
# alltn_c NOTHING DONE!
# altrn_c NOTHING DONE!
# 2ddglcn_c NOTHING DONE!
# malt_c NOTHING DONE!
# malttr_c NOTHING DONE!
# glc-D_c NOTHING DONE!
# maltttr_c NOTHING DONE!
# maltpt_c NOTHING DONE!
# malthx_c NOTHING DONE!
# malthp_c NOTHING DONE!
# acmanap_c NOTHING DONE!
# 8aonn_c NOTHING DONE!
# amob_c NOTHING DONE!
# dann_c NOTHING DONE!
# 2dmmq8_c NOTHING DONE!
# mqn8_c NOTHING DONE!
# 4ampm_c NOTHING DONE!
# for_c NOTHING DONE!
# r5p_c NOTHING DONE!
# anth_c NOTHING DONE!
# pran_c NOTHING DONE!
# pmcoa_c NOTHING DONE!
# ap4a_c NOTHING DONE!
# ap5a_c NOTHING DONE!
# 5apru_c NOTHING DONE!
# 5aprbu_c NOTHING DONE!
# arab-L_c NOTHING DONE!
# rbl-L_c NOTHING DONE!
# arg-L_c NOTHING DONE!
# argsuc_c NOTHING DONE!
# citr-L_c NOTHING DONE!
# aspsa_c NOTHING DONE!
# 4pasp_c NOTHING DONE!
# asn-L_c NOTHING DONE!
# ala-B_c NOTHING DONE!
# cbp_c NOTHING DONE!
# cbasp_c NOTHING DONE!
# q8_c NOTHING DONE!
# iasp_c NOTHING DONE!
# q8h2_c NOTHING DONE!
# mql8_c NOTHING DONE!
# succ_c NOTHING DONE!
# h2o2_c NOTHING DONE!
# oaa_c NOTHING DONE!
# succoa_c NOTHING DONE!
# sucarg_c NOTHING DONE!
# prbatp_c NOTHING DONE!
# betald_c NOTHING DONE!
# glyb_c NOTHING DONE!
# btnso_c NOTHING DONE!
# btn_c NOTHING DONE!
# cys-L_c NOTHING DONE!
# dtbt_c NOTHING DONE!
# but_c NOTHING DONE!
# btcoa_c NOTHING DONE!
# actACP_c NOTHING DONE!
# malACP_c NOTHING DONE!
# ddcaACP_c NOTHING DONE!
# cbi_c NOTHING DONE!
# cbl1_c NOTHING DONE!
# cdpdag1_c NOTHING DONE!
# cmp_c NOTHING DONE!
# paEC_c NOTHING DONE!
# 4c2me_c NOTHING DONE!
# 2p4c2me_c NOTHING DONE!
# pphn_c NOTHING DONE!
# 3psme_c NOTHING DONE!
# 4hbz_c NOTHING DONE!
# cinnm_c NOTHING DONE!
# cenchddd_c NOTHING DONE!
# pgEC_c NOTHING DONE!
# clpnEC_c NOTHING DONE!
# csn_c NOTHING DONE!
# cpppg3_c NOTHING DONE!
# pppg9_c NOTHING DONE!
# bbtcoa_c NOTHING DONE!
# crn_c NOTHING DONE!
# crncoa_c NOTHING DONE!
# gbbtn_c NOTHING DONE!
# ctbtcoa_c NOTHING DONE!
# ctbt_c NOTHING DONE!
# ura_c NOTHING DONE!
# utp_c NOTHING DONE!
# ctp_c NOTHING DONE!
# cyan_c NOTHING DONE!
# tsul_c NOTHING DONE!
# so3_c NOTHING DONE!
# tcynt_c NOTHING DONE!
# cynt_c NOTHING DONE!
# acser_c NOTHING DONE!
# h2s_c NOTHING DONE!
# cyst-L_c NOTHING DONE!
# cytd_c NOTHING DONE!
# uri_c NOTHING DONE!
# cdp_c NOTHING DONE!
# dcmp_c NOTHING DONE!
# dcdp_c NOTHING DONE!
# fad_c NOTHING DONE!
# fadh2_c NOTHING DONE!
# dad-2_c NOTHING DONE!
# din_c NOTHING DONE!
# damp_c NOTHING DONE!
# dadp_c NOTHING DONE!
# 12dgrEC_c NOTHING DONE!
# 26dap-M_c NOTHING DONE!
# lys-L_c NOTHING DONE!
# 26dap-LL_c NOTHING DONE!
# db4p_c NOTHING DONE!
# dctp_c NOTHING DONE!
# dutp_c NOTHING DONE!
# dcyt_c NOTHING DONE!
# duri_c NOTHING DONE!
# 2dh3dgal_c NOTHING DONE!
# 2dh3dgal6p_c NOTHING DONE!
# 2ddg6p_c NOTHING DONE!
# e4p_c NOTHING DONE!
# pep_c NOTHING DONE!
# 2dda7p_c NOTHING DONE!
# g3p_c NOTHING DONE!
# dgmp_c NOTHING DONE!
# dgdp_c NOTHING DONE!
# 23dhmb_c NOTHING DONE!
# 3mob_c NOTHING DONE!
# 23dhmp_c NOTHING DONE!
# 3mop_c NOTHING DONE!
# dha_c NOTHING DONE!
# dhap_c NOTHING DONE!
# 23ddhb_c NOTHING DONE!
# 23dhb_c NOTHING DONE!
# 23dhba_c NOTHING DONE!
# hkntd_c NOTHING DONE!
# 23dhdp_c NOTHING DONE!
# thdp_c NOTHING DONE!
# dhf_c NOTHING DONE!
# dhpt_c NOTHING DONE!
# dhna_c NOTHING DONE!
# octdp_c NOTHING DONE!
# dhnpt_c NOTHING DONE!
# 6hmhpt_c NOTHING DONE!
# gcald_c NOTHING DONE!
# dhor-S_c NOTHING DONE!
# orot_c NOTHING DONE!
# cechddd_c NOTHING DONE!
# 25drapp_c NOTHING DONE!
# 6hmhptpp_c NOTHING DONE!
# dhptd_c NOTHING DONE!
# hmfurn_c NOTHING DONE!
# 3dhq_c NOTHING DONE!
# 3dhsk_c NOTHING DONE!
# 25dkglcn_c NOTHING DONE!
# dkmpp_c NOTHING DONE!
# 2kmb_c NOTHING DONE!
# dmpp_c NOTHING DONE!
# ipdp_c NOTHING DONE!
# grdp_c NOTHING DONE!
# h2mb4p_c NOTHING DONE!
# 2omhmbl_c NOTHING DONE!
# dmso_c NOTHING DONE!
# dms_c NOTHING DONE!
# 2dmmql8_c NOTHING DONE!
# dhpmp_c NOTHING DONE!
# ahdt_c NOTHING DONE!
# 23doguln_c NOTHING DONE!
# 3dhguln_c NOTHING DONE!
# dpcoa_c NOTHING DONE!
# 2dhp_c NOTHING DONE!
# pant-R_c NOTHING DONE!
# 2dr5p_c NOTHING DONE!
# dtmp_c NOTHING DONE!
# dump_c NOTHING DONE!
# 2dr1p_c NOTHING DONE!
# dxyl5p_c NOTHING DONE!
# 2me4p_c NOTHING DONE!
# dxyl_c NOTHING DONE!
# 4per_c NOTHING DONE!
# ecaEC_c NOTHING DONE!
# udcpdp_c NOTHING DONE!
# 6pgc_c NOTHING DONE!
# kdo2lipid4_c NOTHING DONE!
# kdo2lipid4L_c NOTHING DONE!
# lipa_c NOTHING DONE!
# kdo2lipid4p_c NOTHING DONE!
# lipa_cold_c NOTHING DONE!
# 2pg_c NOTHING DONE!
# seramp_c NOTHING DONE!
# enter_c NOTHING DONE!
# etha_c NOTHING DONE!
# f6p_c NOTHING DONE!
# ocdca_c NOTHING DONE!
# fdp_c NOTHING DONE!
# fuc-L_c NOTHING DONE!
# fcl-L_c NOTHING DONE!
# fc1p_c NOTHING DONE!
# lald-L_c NOTHING DONE!
# fe2_c NOTHING DONE!
# ppp9_c NOTHING DONE!
# pheme_c NOTHING DONE!
# suc6p_c NOTHING DONE!
# fru_c NOTHING DONE!
# h2_c NOTHING DONE!
# fmn_c NOTHING DONE!
# f1p_c NOTHING DONE!
# mal-L_c NOTHING DONE!
# gam1p_c NOTHING DONE!
# acgam1p_c NOTHING DONE!
# g1p_c NOTHING DONE!
# dttp_c NOTHING DONE!
# dtdpglu_c NOTHING DONE!
# glu1sa_c NOTHING DONE!
# 5aop_c NOTHING DONE!
# glyc3p_c NOTHING DONE!
# glu5sa_c NOTHING DONE!
# 1pyr5c_c NOTHING DONE!
# glu5p_c NOTHING DONE!
# 6pgl_c NOTHING DONE!
# galct-D_c NOTHING DONE!
# 5dh4dglc_c NOTHING DONE!
# galctn-D_c NOTHING DONE!
# gal_c NOTHING DONE!
# gal1p_c NOTHING DONE!
# melib_c NOTHING DONE!
# udpg_c NOTHING DONE!
# 13dpg_c NOTHING DONE!
# gar_c NOTHING DONE!
# fgam_c NOTHING DONE!
# glyclt_c NOTHING DONE!
# gdpddman_c NOTHING DONE!
# gdpofuc_c NOTHING DONE!
# ser-L_c NOTHING DONE!
# gly_c NOTHING DONE!
# mlthf_c NOTHING DONE!
# glycogen_c NOTHING DONE!
# 2h3oppan_c NOTHING DONE!
# glcr_c NOTHING DONE!
# adpglc_c NOTHING DONE!
# galt1p_c NOTHING DONE!
# tag6p-D_c NOTHING DONE!
# glucys_c NOTHING DONE!
# pram_c NOTHING DONE!
# glu-D_c NOTHING DONE!
# glutrna_c NOTHING DONE!
# trnaglu_c NOTHING DONE!
# glx_c NOTHING DONE!
# 2aobut_c NOTHING DONE!
# glyc-R_c NOTHING DONE!
# 3pg_c NOTHING DONE!
# lgt-S_c NOTHING DONE!
# gthrd_c NOTHING DONE!
# lac-D_c NOTHING DONE!
# gdpmann_c NOTHING DONE!
# gmhep1p_c NOTHING DONE!
# gmhep7p_c NOTHING DONE!
# gmhep17bp_c NOTHING DONE!
# xmp_c NOTHING DONE!
# gdpfuc_c NOTHING DONE!
# gp4g_c NOTHING DONE!
# g3pc_c NOTHING DONE!
# chol_c NOTHING DONE!
# g3pe_c NOTHING DONE!
# g3ps_c NOTHING DONE!
# g3pg_c NOTHING DONE!
# g3pi_c NOTHING DONE!
# inost_c NOTHING DONE!
# frdp_c NOTHING DONE!
# gsn_c NOTHING DONE!
# gtspmd_c NOTHING DONE!
# spmd_c NOTHING DONE!
# gthox_c NOTHING DONE!
# gua_c NOTHING DONE!
# xan_c NOTHING DONE!
# glcur_c NOTHING DONE!
# fruur_c NOTHING DONE!
# galur_c NOTHING DONE!
# tagur_c NOTHING DONE!
# 3ophb_c NOTHING DONE!
# hemeO_c NOTHING DONE!
# 4mhetz_c NOTHING DONE!
# 4mpetz_c NOTHING DONE!
# histd_c NOTHING DONE!
# his-L_c NOTHING DONE!
# hisp_c NOTHING DONE!
# hkndd_c NOTHING DONE!
# op4en_c NOTHING DONE!
# ppbng_c NOTHING DONE!
# hmbil_c NOTHING DONE!
# 4ahmmp_c NOTHING DONE!
# 4h2opntn_c NOTHING DONE!
# hpyr_c NOTHING DONE!
# hom-L_c NOTHING DONE!
# phom_c NOTHING DONE!
# suchms_c NOTHING DONE!
# imacp_c NOTHING DONE!
# pydam_c NOTHING DONE!
# ichor_c NOTHING DONE!
# prlp_c NOTHING DONE!
# eig3p_c NOTHING DONE!
# 2cpr5p_c NOTHING DONE!
# 3ig3p_c NOTHING DONE!
# ile-L_c NOTHING DONE!
# 3c2hmp_c NOTHING DONE!
# 3c4mop_c NOTHING DONE!
# 2ippm_c NOTHING DONE!
# 3c3hmp_c NOTHING DONE!
# 3hmrsACP_c NOTHING DONE!
# kdo_c NOTHING DONE!
# ckdo_c NOTHING DONE!
# kdo8p_c NOTHING DONE!
# 3dhgulnp_c NOTHING DONE!
# xu5p-L_c NOTHING DONE!
# lcts_c NOTHING DONE!
# lac-L_c NOTHING DONE!
# 12ppd-S_c NOTHING DONE!
# 4mop_c NOTHING DONE!
# leu-L_c NOTHING DONE!
# mthgxl_c NOTHING DONE!
# lipidX_c NOTHING DONE!
# u23ga_c NOTHING DONE!
# lipidAds_c NOTHING DONE!
# agpgEC_c NOTHING DONE!
# agpeEC_c NOTHING DONE!
# agpcEC_c NOTHING DONE!
# apgEC_c NOTHING DONE!
# cdpea_c NOTHING DONE!
# lpsEC_c NOTHING DONE!
# 15dap_c NOTHING DONE!
# mnl1p_c NOTHING DONE!
# man1p_c NOTHING DONE!
# man6p_c NOTHING DONE!
# mana_c NOTHING DONE!
# 2mcit_c NOTHING DONE!
# 2mcacn_c NOTHING DONE!
# micit_c NOTHING DONE!
# 5mdru1p_c NOTHING DONE!
# 2mecdp_c NOTHING DONE!
# met-L_c NOTHING DONE!
# 5mthf_c NOTHING DONE!
# mi1p-D_c NOTHING DONE!
# mmcoa-S_c NOTHING DONE!
# mmcoa-R_c NOTHING DONE!
# lipidA_c NOTHING DONE!
# kdolipid4_c NOTHING DONE!
# 5mta_c NOTHING DONE!
# 5mtr_c NOTHING DONE!
# methf_c NOTHING DONE!
# 5mdr1p_c NOTHING DONE!
# nmn_c NOTHING DONE!
# h2o_e NOTHING DONE!
# nad_e NOTHING DONE!
# amp_e NOTHING DONE!
# nmn_e NOTHING DONE!
# dnad_c NOTHING DONE!
# nac_c NOTHING DONE!
# nicrnt_c NOTHING DONE!
# dgtp_c NOTHING DONE!
# dudp_c NOTHING DONE!
# datp_c NOTHING DONE!
# ncam_c NOTHING DONE!
# dmbzid_c NOTHING DONE!
# 5prdmbz_c NOTHING DONE!
# quln_c NOTHING DONE!
# sbzcoa_c NOTHING DONE!
# xtsn_c NOTHING DONE!
# thymd_c NOTHING DONE!
# dgsn_c NOTHING DONE!
# pppi_c NOTHING DONE!
# no2_c NOTHING DONE!
# ohpb_c NOTHING DONE!
# 2ohph_c NOTHING DONE!
# 2omph_c NOTHING DONE!
# 2ombzl_c NOTHING DONE!
# 2ommbl_c NOTHING DONE!
# orot5p_c NOTHING DONE!
# 2oph_c NOTHING DONE!
# thmpp_c NOTHING DONE!
# ssaltpp_c NOTHING DONE!
# pro-L_c NOTHING DONE!
# phaccoa_c NOTHING DONE!
# pnto-R_c NOTHING DONE!
# ugmda_c NOTHING DONE!
# uagmda_c NOTHING DONE!
# trdrd_c NOTHING DONE!
# trdox_c NOTHING DONE!
# pdx5p_c NOTHING DONE!
# pydxn_c NOTHING DONE!
# peamn_c NOTHING DONE!
# peEC_c NOTHING DONE!
# tagdp-D_c NOTHING DONE!
# 3php_c NOTHING DONE!
# 2pglyc_c NOTHING DONE!
# pgpEC_c NOTHING DONE!
# phe-L_c NOTHING DONE!
# phpyr_c NOTHING DONE!
# pcEC_c NOTHING DONE!
# 4r5au_c NOTHING DONE!
# 2mahmp_c NOTHING DONE!
# 4ppan_c NOTHING DONE!
# ppap_c NOTHING DONE!
# 4ppcys_c NOTHING DONE!
# pan4p_c NOTHING DONE!
# r1p_c NOTHING DONE!
# 34hpp_c NOTHING DONE!
# pppn_c NOTHING DONE!
# uaagmda_c NOTHING DONE!
# peptidoEC_c NOTHING DONE!
# fpram_c NOTHING DONE!
# prbamp_c NOTHING DONE!
# prfp_c NOTHING DONE!
# skm5p_c NOTHING DONE!
# psEC_c NOTHING DONE!
# pser-L_c NOTHING DONE!
# pydx_c NOTHING DONE!
# ribflv_c NOTHING DONE!
# dmlz_c NOTHING DONE!
# rib-D_c NOTHING DONE!
# ru5p-L_c NOTHING DONE!
# xu5p-D_c NOTHING DONE!
# rmn_c NOTHING DONE!
# rml_c NOTHING DONE!
# rml1p_c NOTHING DONE!
# s7p_c NOTHING DONE!
# sucorn_c NOTHING DONE!
# so4_c NOTHING DONE!
# sbt6p_c NOTHING DONE!
# sl26da_c NOTHING DONE!
# sl2a6o_c NOTHING DONE!
# seln_c NOTHING DONE!
# selnp_c NOTHING DONE!
# ser-D_c NOTHING DONE!
# sucglu_c NOTHING DONE!
# sucgsa_c NOTHING DONE!
# 2shchc_c NOTHING DONE!
# scl_c NOTHING DONE!
# srch_c NOTHING DONE!
# sheme_c NOTHING DONE!
# skm_c NOTHING DONE!
# N1aspmd_c NOTHING DONE!
# n8aspmd_c NOTHING DONE!
# o2s_c NOTHING DONE!
# sucbz_c NOTHING DONE!
# tartr-L_c NOTHING DONE!
# taur_c NOTHING DONE!
# aacald_c NOTHING DONE!
# dtdp4addg_c NOTHING DONE!
# dtdp4d6dg_c NOTHING DONE!
# dtdp4d6dm_c NOTHING DONE!
# dtdprmn_c NOTHING DONE!
# thr-L_c NOTHING DONE!
# tyr-L_c NOTHING DONE!
# 4hba_c NOTHING DONE!
# tmao_c NOTHING DONE!
# tma_c NOTHING DONE!
# thym_c NOTHING DONE!
# thm_c NOTHING DONE!
# thmmp_c NOTHING DONE!
# tre6p_c NOTHING DONE!
# tre_c NOTHING DONE!
# tre_e NOTHING DONE!
# glc-D_e NOTHING DONE!
# trp-L_c NOTHING DONE!
# indole_c NOTHING DONE!
# u3hga_c NOTHING DONE!
# uamag_c NOTHING DONE!
# ugmd_c NOTHING DONE!
# uacmam_c NOTHING DONE!
# u3aga_c NOTHING DONE!
# uaccg_c NOTHING DONE!
# uama_c NOTHING DONE!
# uamr_c NOTHING DONE!
# udpgal_c NOTHING DONE!
# udpgalfur_c NOTHING DONE!
# udpglcur_c NOTHING DONE!
# uppg3_c NOTHING DONE!
# val-L_c NOTHING DONE!
# xyl-D_c NOTHING DONE!
# xylu-D_c NOTHING DONE!
# 12ppd-S_e NOTHING DONE!
# 15dap_e NOTHING DONE!
# 26dap-M_e NOTHING DONE!
# 2ddglcn_e NOTHING DONE!
# 3hcinnm_e NOTHING DONE!
# 3hpppn_e NOTHING DONE!
# 4abut_e NOTHING DONE!
# ac_e NOTHING DONE!
# acac_e NOTHING DONE!
# acald_e NOTHING DONE!
# acgam_e NOTHING DONE!
# acmana_e NOTHING DONE!
# acnam_e NOTHING DONE!
# ade_e NOTHING DONE!
# adn_e NOTHING DONE!
# akg_e NOTHING DONE!
# ala-D_e NOTHING DONE!
# ala-L_e NOTHING DONE!
# alltn_e NOTHING DONE!
# arab-L_e NOTHING DONE!
# arg-L_e NOTHING DONE!
# asn-L_e NOTHING DONE!
# asp-L_e NOTHING DONE!
# but_e NOTHING DONE!
# charge_e NOTHING DONE!
# cbl1_e NOTHING DONE!
# chol_e NOTHING DONE!
# cit_e NOTHING DONE!
# co2tot_e NOTHING DONE!
# crn_e NOTHING DONE!
# csn_e NOTHING DONE!
# cynt_e NOTHING DONE!
# cys-L_e NOTHING DONE!
# cytd_e NOTHING DONE!
# dad-2_e NOTHING DONE!
# dcyt_e NOTHING DONE!
# dgsn_e NOTHING DONE!
# dha_e NOTHING DONE!
# din_e NOTHING DONE!
# dms_e NOTHING DONE!
# dmso_e NOTHING DONE!
# duri_e NOTHING DONE!
# etoh_e NOTHING DONE!
# fe2_e NOTHING DONE!
# for_e NOTHING DONE!
# fru_e NOTHING DONE!
# fuc1p-L_e NOTHING DONE!
# fuc-L_e NOTHING DONE!
# fum_e NOTHING DONE!
# g6p_e NOTHING DONE!
# gal_e NOTHING DONE!
# galct-D_e NOTHING DONE!
# galctn-D_e NOTHING DONE!
# galt_e NOTHING DONE!
# galur_e NOTHING DONE!
# gam_e NOTHING DONE!
# gbbtn_e NOTHING DONE!
# glcn_e NOTHING DONE!
# glcr_e NOTHING DONE!
# glcur_e NOTHING DONE!
# gln-L_e NOTHING DONE!
# glu-L_e NOTHING DONE!
# gly_e NOTHING DONE!
# glyald_e NOTHING DONE!
# glyb_e NOTHING DONE!
# glyc_e NOTHING DONE!
# glyc3p_e NOTHING DONE!
# glyclt_e NOTHING DONE!
# gsn_e NOTHING DONE!
# gua_e NOTHING DONE!
# h_e NOTHING DONE!
# hdca_e NOTHING DONE!
# his-L_e NOTHING DONE!
# hxan_e NOTHING DONE!
# idon-L_e NOTHING DONE!
# ile-L_e NOTHING DONE!
# indole_e NOTHING DONE!
# ins_e NOTHING DONE!
# k_e NOTHING DONE!
# lac-D_e NOTHING DONE!
# lac-L_e NOTHING DONE!
# lcts_e NOTHING DONE!
# leu-L_e NOTHING DONE!
# lys-L_e NOTHING DONE!
# mal-L_e NOTHING DONE!
# malt_e NOTHING DONE!
# malthx_e NOTHING DONE!
# maltpt_e NOTHING DONE!
# malttr_e NOTHING DONE!
# maltttr_e NOTHING DONE!
# man_e NOTHING DONE!
# man6p_e NOTHING DONE!
# melib_e NOTHING DONE!
# met-D_e NOTHING DONE!
# met-L_e NOTHING DONE!
# mnl_e NOTHING DONE!
# na1_e NOTHING DONE!
# nac_e NOTHING DONE!
# nh3_e NOTHING DONE!
# no2_e NOTHING DONE!
# no3_e NOTHING DONE!
# o2_e NOTHING DONE!
# ocdca_e NOTHING DONE!
# orn_e NOTHING DONE!
# phe-L_e NOTHING DONE!
# pi_e NOTHING DONE!
# pnto-R_e NOTHING DONE!
# pppn_e NOTHING DONE!
# pro-L_e NOTHING DONE!
# ptrc_e NOTHING DONE!
# pyr_e NOTHING DONE!
# rib-D_e NOTHING DONE!
# rmn_e NOTHING DONE!
# sbt-D_e NOTHING DONE!
# ser-D_e NOTHING DONE!
# ser-L_e NOTHING DONE!
# so4_e NOTHING DONE!
# spmd_e NOTHING DONE!
# succ_e NOTHING DONE!
# sucr_e NOTHING DONE!
# tartr-L_e NOTHING DONE!
# taur_e NOTHING DONE!
# thm_e NOTHING DONE!
# thr-L_e NOTHING DONE!
# thymd_e NOTHING DONE!
# tma_e NOTHING DONE!
# tmao_e NOTHING DONE!
# trp-L_e NOTHING DONE!
# tsul_e NOTHING DONE!
# ttdca_e NOTHING DONE!
# tyr-L_e NOTHING DONE!
# ura_e NOTHING DONE!
# urea_e NOTHING DONE!
# uri_e NOTHING DONE!
# val-L_e NOTHING DONE!
# xan_e NOTHING DONE!
# xtsn_e NOTHING DONE!
# xyl-D_e NOTHING DONE!
# h_c NOTHING DONE!
# acgam_c NOTHING DONE!
# charge_c NOTHING DONE!
# electron_c NOTHING DONE!
# electron_e NOTHING DONE!
# fuc1p-L_c NOTHING DONE!
# galt_c NOTHING DONE!
# gam_c NOTHING DONE!
# na1_c NOTHING DONE!
# h2_e NOTHING DONE!
# k_c NOTHING DONE!
# malt6p_c NOTHING DONE!
# man_c NOTHING DONE!
# met-D_c NOTHING DONE!
# mnl_c NOTHING DONE!
# no3_c NOTHING DONE!
# sbt-D_c NOTHING DONE!
# sucr_c NOTHING DONE!
# *** Editing special metabolites ***
# *** Removing electrons from the model ***
# Initializing component contribution object...
# cxcalc is not installed, operating in read-only mode. A local cache may be loaded, but no compounds can be created. Install cxcalc and obtain a ChemAxon license to enable compound creation.
# Loading compounds from ecoli_compound.sqlite
# added reaction:  biomass_ce: biomass_c <=> biomass_e
# added reaction:  biomass_EX: biomass_e <=>
# ['Parameters', 'Exchange reactions', 'Reactions', 'Biomass Composition', 'Transmembrane reactions', 'Metabolites', 'references', 'Transmembrane_reactions_reed', 'Transmembrane reactions_Orth', 'Transmembrane reactions old', 'Sheet3', 'log', 'subsystems']
# biomass : 0.05 5mthf_c + 5e-05 accoa_c + 0.488 ala-L_c + 0.001 amp_c + 0.281 arg-L_c + 0.2
# biomass_ce : biomass_c <=> biomass_e
# biomass_EX : biomass_e <=>
# Identifying compounds...
# [████████████████████████████████████████] 777/777 Mg_e
#
# Estimating dfG0'...
# biomass_c 0 kilojoule / mole
# biomass_e 0 kilojoule / mole
# [████████████████████████████████████████] 777/777 Mg_e
#
# Estimating drG0'...
# [████████████████████████████████████████] 1066/1066 EX_oro
#
# model: 7.009065135841064e-05 molar, 0.00011734067620233436 molar, metabolome: 7.009065135841064e-05, 0.00011734067620233436
# Metabolome data applied: True
# model: 0.0009348246500177375 molar, 0.0015097713166455826 molar, metabolome: 0.0009348246500177375, 0.0015097713166455826
# Metabolome data applied: True
# model: 0.0006166643194721879 molar, 0.0007793629236311722 molar, metabolome: 0.0006166643194721879, 0.0007793629236311722
# Metabolome data applied: True
# model: 0.00011030971074525162 molar, 0.0003535917316718784 molar, metabolome: 0.00011030971074525162, 0.0003535917316718784
# Metabolome data applied: True
# model: 0.01341663605629893 molar, 0.014430417699438071 molar, metabolome: 0.01341663605629893, 0.014430417699438071
# Metabolome data applied: True
# model: 0.0005009961753328976 molar, 0.0009036957260887906 molar, metabolome: 0.0005009961753328976, 0.0009036957260887906
# Metabolome data applied: True
# model: 0.00046459596792199325 molar, 0.0007610968416581248 molar, metabolome: 0.00046459596792199325, 0.0007610968416581248
# Metabolome data applied: True
# model: 7.983731154166406e-05 molar, 9.252295104195315e-05 molar, metabolome: 7.983731154166406e-05, 9.252295104195315e-05
# Metabolome data applied: True
# model: 0.0019987586650170425 molar, 0.002162486986769957 molar, metabolome: 0.0019987586650170425, 0.002162486986769957
# Metabolome data applied: True
# model: 0.001710736644028702 molar, 0.0022978438991844586 molar, metabolome: 0.001710736644028702, 0.0022978438991844586
# Metabolome data applied: True
# model: 0.00029068236077340513 molar, 0.00045972157599847083 molar, metabolome: 0.00029068236077340513, 0.00045972157599847083
# Metabolome data applied: True
# model: -5.795823206416416e-07 molar, 2.5597076166154844e-05 molar, metabolome: -5.795823206416416e-07, 2.5597076166154844e-05
# Metabolome data applied: True
# model: 1.0879268060818518e-05 molar, 3.097273967129988e-05 molar, metabolome: 1.0879268060818518e-05, 3.097273967129988e-05
# Metabolome data applied: True
# model: 0.00045374906687021855 molar, 0.0006702361704623914 molar, metabolome: 0.00045374906687021855, 0.0006702361704623914
# Metabolome data applied: True
# model: 0.0013842496973992782 molar, 0.001688815760312522 molar, metabolome: 0.0013842496973992782, 0.001688815760312522
# Metabolome data applied: True
# model: 0.00103063729971154 molar, 0.00207696449113248 molar, metabolome: 0.00103063729971154, 0.00207696449113248
# Metabolome data applied: True
# model: 3.20542910830877e-05 molar, 7.95819400698849e-05 molar, metabolome: 3.20542910830877e-05, 7.95819400698849e-05
# Metabolome data applied: True
# model: 0.00018339641612205565 molar, 0.00026561764199800635 molar, metabolome: 0.00018339641612205565, 0.00026561764199800635
# Metabolome data applied: True
# model: 0.0006020658494872839 molar, 0.0007802063710336101 molar, metabolome: 0.0006020658494872839, 0.0007802063710336101
# Metabolome data applied: True
# model: 0.0003585998574525588 molar, 0.0004155635022414611 molar, metabolome: 0.0003585998574525588, 0.0004155635022414611
# Metabolome data applied: True
# model: 0.00047279111990077916 molar, 0.0005659914682051449 molar, metabolome: 0.00047279111990077916, 0.0005659914682051449
# Metabolome data applied: True
# model: 0.00011005312388720461 molar, 0.0001840477753987334 molar, metabolome: 0.00011005312388720461, 0.0001840477753987334
# Metabolome data applied: True
# model: 0.0002673804607203747 molar, 0.0004905693490477173 molar, metabolome: 0.0002673804607203747, 0.0004905693490477173
# Metabolome data applied: True
# model: 0.00013333846659863724 molar, 0.0001645957132634128 molar, metabolome: 0.00013333846659863724, 0.0001645957132634128
# Metabolome data applied: True
# model: 0.0018227264815018787 molar, 0.004008108010619341 molar, metabolome: 0.0018227264815018787, 0.004008108010619341
# Metabolome data applied: True
# model: 5.611697254713941e-06 molar, 1.652668243641766e-05 molar, metabolome: 5.611697254713941e-06, 1.652668243641766e-05
# Metabolome data applied: True
# model: 0.01341663605629893 molar, 0.014430417699438071 molar, metabolome: 0.01341663605629893, 0.014430417699438071
# Metabolome data applied: True
# model: 3.85723814810002e-05 molar, 5.6069966254885005e-05 molar, metabolome: 3.85723814810002e-05, 5.6069966254885005e-05
# Metabolome data applied: True
# model: 6.158712283562194e-05 molar, 6.852745253635546e-05 molar, metabolome: 6.158712283562194e-05, 6.852745253635546e-05
# Metabolome data applied: True
# model: 2.9499460056646602e-06 molar, 5.29178965423714e-06 molar, metabolome: 2.9499460056646602e-06, 5.29178965423714e-06
# Metabolome data applied: True
# model: 7.009065135841064e-05 molar, 0.00011734067620233436 molar, metabolome: 7.009065135841064e-05, 0.00011734067620233436
# Metabolome data applied: True
# model: 3.85723814810002e-05 molar, 5.6069966254885005e-05 molar, metabolome: 3.85723814810002e-05, 5.6069966254885005e-05
# Metabolome data applied: True
# model: 5.243890276620333e-05 molar, 8.736737793592446e-05 molar, metabolome: 5.243890276620333e-05, 8.736737793592446e-05
# Metabolome data applied: True
# model: 3.9003070705562776e-05 molar, 7.600438723568202e-05 molar, metabolome: 3.9003070705562776e-05, 7.600438723568202e-05
# Metabolome data applied: True
#
# Removing 9 orphan metabolites:
# Orphaned IDs: sucr_c, mnl_c, Mg_e, acgam_c, sbt-D_c, Mg_c, galt_c, man_c, gam_c
# Identifying compounds...
# [████████████████████████████████████████] 454/454 orot_e
#
# Estimating dfG0'...
# [████████████████████████████████████████] 454/454 orot_e
#
# Estimating drG0'...
# [████████████████████████████████████████] 622/622 EX_oro

# %%
# Apply thermodynamic variables and additional respiratory constraint
tmodel_ace.m = None
tmodel_ace.objective = tmodel_ace.reactions.biomass_EX
tmodel_ace.add_TFBA_variables(qnorm='sep_norm')

add_rq_constraint(tmodel_ace, "WT-Ace_I", INPUT_EXP_DATA)
# Out:
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 10
# >>>>>> RQ: 0.98 (vCO2 = 15.7 / vO2 = -16.0) ERR: 0.32137831084665863

# %%
tmodel_ace.m.Params.TimeLimit = 20
tmodel_ace.m.optimize()
# Out:
# Set parameter TimeLimit to value 20
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (linux64 - "Ubuntu 24.04.2 LTS")
#
# CPU model: AMD Ryzen 7 7800X3D 8-Core Processor, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  20
# NonConvex  2
#
# Academic license 2731723 - for non-commercial use only - registered to l.___@student.rug.nl
# Optimize a model with 6728 rows, 5411 columns and 155075 nonzeros
# Model fingerprint: 0xcd0e544f
# Model has 1 quadratic constraint
# Model has 300 simple general constraints
#   300 ABS
# Variable types: 4789 continuous, 622 integer (622 binary)
# Coefficient statistics:
#   Matrix range     [3e-06, 7e+05]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [4e-02, 1e+06]
#   RHS range        [2e-14, 1e+05]
# Presolve removed 4136 rows and 3211 columns
# Presolve time: 0.36s
# Presolved: 2596 rows, 2201 columns, 115978 nonzeros
# Presolved model has 1 bilinear constraint(s)
#
# Solving non-convex MIQCP
#
# Variable types: 1806 continuous, 395 integer (395 binary)
#
# Root relaxation: objective 3.320992e-01, 1535 iterations, 0.07 seconds (0.15 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.33210    0   53          -    0.33210      -     -    1s
#      0     0    0.33210    0   51          -    0.33210      -     -    1s
#      0     0    0.33210    0   51          -    0.33210      -     -    1s
#      0     0    0.33210    0    7          -    0.33210      -     -    1s
#      0     0    0.33210    0    8          -    0.33210      -     -    1s
#      0     0    0.33210    0    9          -    0.33210      -     -    1s
#      0     0    0.33210    0   11          -    0.33210      -     -    1s
#      0     0    0.33210    0    8          -    0.33210      -     -    2s
#      0     0    0.33210    0    7          -    0.33210      -     -    2s
#      0     0    0.33210    0    7          -    0.33210      -     -    2s
#      0     0    0.33210    0    7          -    0.33210      -     -    2s
#      0     0    0.33210    0    7          -    0.33210      -     -    2s
#      0     0    0.33210    0    7          -    0.33210      -     -    2s
#      0     2    0.33210    0    7          -    0.33210      -     -    3s
#    606   736    0.32738  107   15          -    0.33210      -  81.2    5s
# *  623   730             119       0.2942494    0.33210  12.9%  79.5    5s
# *  628   729             121       0.3211719    0.33210  3.40%  78.9    5s
# *  630   729             122       0.3265225    0.33210  1.71%  78.7    5s
# *  636   729             125       0.3269803    0.33210  1.57%  78.1    5s
# *  638   729             126       0.3270940    0.33210  1.53%  77.8    5s
# *  640   729             127       0.3271093    0.33210  1.53%  77.6    5s
# *  650   729             132       0.3271097    0.33210  1.53%  76.6    5s
# *  851   694             128       0.3320992    0.33210  0.00%  79.9    5s
#
# Cutting planes:
#   Learned: 105
#   Gomory: 8
#   Cover: 14
#   Implied bound: 30
#   Clique: 3
#   MIR: 10
#   Flow cover: 17
#   Inf proof: 1
#   RLT: 1
#   Relax-and-lift: 1
#   BQP: 1
#
# Explored 1156 nodes (96904 simplex iterations) in 5.46 seconds (10.41 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 8: 0.332099 0.32711 0.327109 ... 0.294249
# No other solutions better than 0.332099
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.320992425354e-01, best bound 3.320992425354e-01, gap 0.0000%

# %%
tva_run_scenarios_one_model_mets_locally(tmodel_ace, "ecoli", "WT_Ace", "../results/WT_Ace")
# Out:
# Set parameter MIPGap to value 0.001
# Added 2dhglcn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,0] (value -11.108631041715885)>)
# Added nadh_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,1] (value -5.866369595860432)>)
# Added glcn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,2] (value -7.194092308513203)>)
# Added nad_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,3] (value -4.766981743138312)>)
# Added nadph_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,4] (value -13.586858850509138)>)
# Added nadp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,5] (value -16.11809565095832)>)
# Added 2dhguln_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,6] (value -11.161967204766361)>)
# Added idon-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,7] (value -6.907755278982137)>)
# Added o2_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,8] (value -8.305726057581222)>)
# Added h2o_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,9] (value 0.0)>)
# Added pi_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,10] (value -3.818128417143383)>)
# Added 5dglcn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,11] (value -6.907755278982137)>)
# Added ru5p-D_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,12] (value -9.565721134323434)>)
# Added ara5p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,13] (value -12.966251122998695)>)
# Added ACP_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,14] (value -6.907755278982137)>)
# Added atp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,15] (value -6.9751515863514095)>)
# Added ttdca_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,16] (value -6.907755278982137)>)
# Added amp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,17] (value -7.09265740787158)>)
# Added myrsACP_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,18] (value -16.11809565095832)>)
# Added ppi_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,19] (value -8.594260080950502)>)
# Added ttdcea_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,20] (value -16.11809565095832)>)
# Added tdeACP_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,21] (value -16.11809565095832)>)
# Added hdca_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,22] (value -6.907755278982137)>)
# Added palmACP_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,23] (value -16.11809565095832)>)
# Added hdcea_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,24] (value -16.114965127609278)>)
# Added hdeACP_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,25] (value -16.11809565095832)>)
# Added ocdcea_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,26] (value -16.11809565095832)>)
# Added octeACP_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,27] (value -16.11809565095832)>)
# Added dtdp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,28] (value -7.140877075799557)>)
# Added g6p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,29] (value -7.157033736589977)>)
# Added 4abut_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,30] (value -6.907755278982137)>)
# Added akg_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,31] (value -9.11221859618521)>)
# Added glu-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,32] (value -4.3112598453063695)>)
# Added sucsal_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,33] (value -16.11809565095832)>)
# Added 4abutn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,34] (value -16.11809565095832)>)
# Added accoa_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,35] (value -5.8025834068845255)>)
# Added ac_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,36] (value -6.907755278982137)>)
# Added coa_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,37] (value -7.234613672806665)>)
# Added acald_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,38] (value -6.907755278982137)>)
# Added gtp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,39] (value -7.0090178404149075)>)
# Added co2tot_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,40] (value -7.824046010856292)>)
# Added adp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,41] (value -7.243073620742037)>)
# Added malcoa_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,42] (value -5.074389199180081)>)
# Added ppa_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,43] (value -6.907755278982137)>)
# Added ppcoa_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,44] (value -11.665428085544507)>)
# Added uacgam_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,45] (value -6.220037759421212)>)
# Added udcpp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,46] (value -6.907755278982137)>)
# Added ump_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,47] (value -6.907755278982137)>)
# Added acglu_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,48] (value -6.907755278982137)>)
# Added acg5p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,49] (value -16.11809565095832)>)
# Added 2obut_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,50] (value -6.907755278982137)>)
# Added pyr_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,51] (value -4.101916917844185)>)
# Added 2ahbut_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,52] (value -6.907755278982137)>)
# Added actp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,53] (value -12.20722526649275)>)
# Added alac-S_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,54] (value -6.907755278982137)>)
# Added udp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,55] (value -5.96867139750956)>)
# Added acACP_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,56] (value -16.11809565095832)>)
# Added acorn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,57] (value -5.935568078019076)>)
# Added orn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,58] (value -8.363783931464543)>)
# Added amet_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,59] (value -16.11809565095832)>)
# Added cit_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,60] (value -2.8395205829965944)>)
# Added icit_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,61] (value -6.215228958607475)>)
# Added acg5sa_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,62] (value -12.27002331962008)>)
# Added pap_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,63] (value -6.907755278982137)>)
# Added adn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,64] (value -15.39007088922244)>)
# Added ins_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,65] (value -12.541667343171502)>)
# Added nh3_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,66] (value -6.907755278982137)>)
# Added 4adcho_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,67] (value -16.11809565095832)>)
# Added 4abz_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,68] (value -16.11809565095832)>)
# Added chor_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,69] (value -16.11809565095832)>)
# Added gln-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,70] (value -6.075784030851338)>)
# Added ade_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,71] (value -9.300098208125469)>)
# Added hxan_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,72] (value -6.907755278982137)>)
# Added gdp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,73] (value -8.143279430694514)>)
# Added ametam_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,74] (value -6.907755278982137)>)
# Added gmp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,75] (value -10.382403105789674)>)
# Added prpp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,76] (value -16.11809565095832)>)
# Added aps_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,77] (value -11.367426004060738)>)
# Added paps_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,78] (value -16.11809565095832)>)
# Added dcamp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,79] (value -6.907755278982137)>)
# Added fum_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,80] (value -7.3078804144629546)>)
# Added 25aics_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,81] (value -6.907755278982137)>)
# Added aicar_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,82] (value -8.710495139713737)>)
# Added asp-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,83] (value -6.383727729218544)>)
# Added imp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,84] (value -6.87757793049575)>)
# Added gam6p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,85] (value -6.071427677030339)>)
# Added adphep-DD_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,86] (value -15.924097676685168)>)
# Added adphep-LD_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,87] (value -16.11809565095832)>)
# Added ptrc_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,88] (value -7.945543417422145)>)
# Added hcys-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,89] (value -7.050622587572744)>)
# Added 10fthf_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,90] (value -16.11809565095832)>)
# Added fprica_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,91] (value -13.893566268457311)>)
# Added thf_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,92] (value -16.11809565095832)>)
# Added air_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,93] (value -16.11809565095832)>)
# Added 5caiz_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,94] (value -6.907755278982137)>)
# Added 5aizc_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,95] (value -16.11809565095832)>)
# Added ala-D_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,96] (value -6.907755278982137)>)
# Added alaala_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,97] (value -6.907755278982137)>)
# Added ala-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,98] (value -4.505897442573834)>)
# Added pydx5p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,99] (value -16.11809565095832)>)
# Added pyam5p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,100] (value -6.907755278982137)>)
# Added glyc_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,101] (value -10.400897950626982)>)
# Added malt_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,102] (value -13.085779347929142)>)
# Added malttr_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,103] (value -16.11809565095832)>)
# Added glc-D_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,104] (value -6.907755278982137)>)
# Added maltttr_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,105] (value -6.907755278982137)>)
# Added maltpt_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,106] (value -8.319818890938977)>)
# Added malthx_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,107] (value -12.218960783737707)>)
# Added malthp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,108] (value -16.11809565095832)>)
# Added 2dmmq8_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,109] (value -16.11809565095832)>)
# Added mqn8_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,110] (value -16.11809565095832)>)
# Added for_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,111] (value -8.348074387126195)>)
# Added r5p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,112] (value -9.43872337440006)>)
# Added anth_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,113] (value -13.640814052732773)>)
# Added pran_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,114] (value -11.078485057012026)>)
# Added 5apru_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,115] (value -16.11809565095832)>)
# Added 5aprbu_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,116] (value -16.11809565095832)>)
# Added arab-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,117] (value -6.907755278982137)>)
# Added arg-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,118] (value -16.11809565095832)>)
# Added argsuc_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,119] (value -6.907755278982137)>)
# Added citr-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,120] (value -7.650724076287959)>)
# Added aspsa_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,121] (value -16.11809565095832)>)
# Added 4pasp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,122] (value -11.172037884702219)>)
# Added asn-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,123] (value -8.60386053965206)>)
# Added ala-B_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,124] (value -6.907755278982137)>)
# Added cbp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,125] (value -10.418901088623977)>)
# Added cbasp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,126] (value -5.6535418601663565)>)
# Added q8_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,127] (value -6.907755278982137)>)
# Added iasp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,128] (value -6.907755278982137)>)
# Added q8h2_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,129] (value -16.11809565095832)>)
# Added mql8_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,130] (value -13.827793118499372)>)
# Added succ_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,131] (value -7.415143734107133)>)
# Added h2o2_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,132] (value -16.11809565095832)>)
# Added oaa_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,133] (value -11.985850098104917)>)
# Added succoa_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,134] (value -4.604587257132716)>)
# Added sucarg_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,135] (value -6.907755278982137)>)
# Added prbatp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,136] (value -16.11809565095832)>)
# Added betald_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,137] (value -16.11809565095832)>)
# Added glyb_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,138] (value -6.907755278982137)>)
# Added btnso_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,139] (value -6.907755278982137)>)
# Added btn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,140] (value -16.11809565095832)>)
# Added cys-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,141] (value -16.11809565095832)>)
# Added actACP_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,142] (value -16.11809565095832)>)
# Added malACP_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,143] (value -16.11809565095832)>)
# Added ddcaACP_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,144] (value -16.11809565095832)>)
# Added cdpdag1_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,145] (value -16.11809565095832)>)
# Added cmp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,146] (value -8.282374956005755)>)
# Added paEC_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,147] (value -16.11809565095832)>)
# Added pphn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,148] (value -6.907755278982137)>)
# Added 3psme_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,149] (value -6.907755278982137)>)
# Added pgEC_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,150] (value -6.907755278982137)>)
# Added clpnEC_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,151] (value -16.11809565095832)>)
# Added csn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,152] (value -9.384514585191834)>)
# Added ura_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,153] (value -6.907755278982137)>)
# Added utp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,154] (value -6.067768547693658)>)
# Added ctp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,155] (value -4.359456901172543)>)
# Added so3_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,156] (value -6.907755278982137)>)
# Added acser_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,157] (value -6.907755278982137)>)
# Added h2s_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,158] (value -6.907755278982137)>)
# Added cyst-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,159] (value -6.907755278982137)>)
# Added cytd_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,160] (value -14.014730803106012)>)
# Added uri_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,161] (value -6.907755278982137)>)
# Added cdp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,162] (value -6.907755278982137)>)
# Added dcmp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,163] (value -14.157080983502464)>)
# Added dcdp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,164] (value -16.11809565095832)>)
# Added fad_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,165] (value -6.473445542655036)>)
# Added fadh2_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,166] (value -8.865893616102879)>)
# Added dad-2_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,167] (value -11.022628297602601)>)
# Added din_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,168] (value -11.312151742907318)>)
# Added damp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,169] (value -14.983738446740674)>)
# Added dadp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,170] (value -15.873324637216045)>)
# Added 12dgrEC_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,171] (value -16.11809565095832)>)
# Added 26dap-M_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,172] (value -16.11809565095832)>)
# Added lys-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,173] (value -8.458472497314341)>)
# Added 26dap-LL_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,174] (value -16.11809565095832)>)
# Added db4p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,175] (value -6.907755278982137)>)
# Added dctp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,176] (value -9.745743040666536)>)
# Added dutp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,177] (value -6.907755278982137)>)
# Added dcyt_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,178] (value -6.907755278982137)>)
# Added duri_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,179] (value -16.11809565095832)>)
# Added 2ddg6p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,180] (value -9.771984684701728)>)
# Added e4p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,181] (value -10.729141822888165)>)
# Added pep_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,182] (value -7.78587512203381)>)
# Added 2dda7p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,183] (value -16.11809565095832)>)
# Added g3p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,184] (value -10.326776920056497)>)
# Added dgmp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,185] (value -8.280030289046502)>)
# Added dgdp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,186] (value -11.23315352247065)>)
# Added 23dhmb_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,187] (value -9.543296237217124)>)
# Added 3mob_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,188] (value -6.907755278982137)>)
# Added 23dhmp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,189] (value -9.542226894311707)>)
# Added 3mop_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,190] (value -6.907755278982137)>)
# Added dha_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,191] (value -16.11809565095832)>)
# Added dhap_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,192] (value -7.656856873984514)>)
# Added 23dhdp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,193] (value -6.907755278982137)>)
# Added thdp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,194] (value -6.907755278982137)>)
# Added dhf_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,195] (value -16.11809565095832)>)
# Added dhpt_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,196] (value -6.907755278982137)>)
# Added dhnpt_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,197] (value -16.11809565095832)>)
# Added 6hmhpt_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,198] (value -6.907755278982137)>)
# Added gcald_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,199] (value -16.11809565095832)>)
# Added dhor-S_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,200] (value -11.930964976531053)>)
# Added orot_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,201] (value -9.79905782965568)>)
# Added 25drapp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,202] (value -8.561112423154363)>)
# Added 6hmhptpp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,203] (value -16.11809565095832)>)
# Added 3dhq_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,204] (value -6.907755278982137)>)
# Added 3dhsk_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,205] (value -6.907755278982137)>)
# Added 25dkglcn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,206] (value -16.11809565095832)>)
# Added dkmpp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,207] (value -16.11809565095832)>)
# Added 2kmb_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,208] (value -6.907755278982137)>)
# Added dmpp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,209] (value -13.412025781390474)>)
# Added ipdp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,210] (value -16.11809565095832)>)
# Added h2mb4p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,211] (value -16.11809565095832)>)
# Added dmso_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,212] (value -6.907755278982137)>)
# Added dms_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,213] (value -16.11809565095832)>)
# Added 2dmmql8_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,214] (value -15.321894413932254)>)
# Added dhpmp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,215] (value -6.907755278982137)>)
# Added ahdt_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,216] (value -6.907755278982137)>)
# Added dpcoa_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,217] (value -6.907755278982137)>)
# Added 2dhp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,218] (value -16.11809565095832)>)
# Added pant-R_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,219] (value -7.909935756585514)>)
# Added 2dr5p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,220] (value -9.99415638230634)>)
# Added dtmp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,221] (value -6.907755278982137)>)
# Added dump_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,222] (value -16.11809565095832)>)
# Added 2dr1p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,223] (value -10.247985130331532)>)
# Added udcpdp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,224] (value -6.907755278982137)>)
# Added 6pgc_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,225] (value -8.600315185152072)>)
# Added kdo2lipid4_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,226] (value -16.11809565095832)>)
# Added kdo2lipid4L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,227] (value -6.907755278982137)>)
# Added lipa_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,228] (value -6.907755278982137)>)
# Added 2pg_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,229] (value -9.682898565738721)>)
# Added etha_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,230] (value -16.11809565095832)>)
# Added f6p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,231] (value -8.22088678727777)>)
# Added fdp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,232] (value -8.922619800775708)>)
# Added fmn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,233] (value -7.971501688471257)>)
# Added f1p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,234] (value -11.833149651237251)>)
# Added mal-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,235] (value -6.307421832116768)>)
# Added gam1p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,236] (value -7.352849285850969)>)
# Added acgam1p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,237] (value -6.907755278982137)>)
# Added g1p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,238] (value -10.147445115368784)>)
# Added dttp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,239] (value -7.664574713221858)>)
# Added glyc3p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,240] (value -5.19694018989626)>)
# Added glu5sa_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,241] (value -6.907755278982137)>)
# Added 1pyr5c_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,242] (value -16.11809565095832)>)
# Added glu5p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,243] (value -6.907755278982137)>)
# Added 6pgl_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,244] (value -16.11809565095832)>)
# Added gal_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,245] (value -6.907755278982137)>)
# Added udpg_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,246] (value -8.897316301856668)>)
# Added 13dpg_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,247] (value -12.090657343238727)>)
# Added gar_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,248] (value -14.55904110049287)>)
# Added fgam_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,249] (value -16.11809565095832)>)
# Added glyclt_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,250] (value -6.907755278982137)>)
# Added ser-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,251] (value -7.215001523367842)>)
# Added gly_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,252] (value -16.11809565095832)>)
# Added mlthf_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,253] (value -6.907755278982137)>)
# Added glycogen_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,254] (value -6.907755278982137)>)
# Added 2h3oppan_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,255] (value -16.11809565095832)>)
# Added adpglc_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,256] (value -12.048328133660583)>)
# Added pram_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,257] (value -6.907755278982137)>)
# Added glu-D_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,258] (value -4.3112598453063695)>)
# Added glx_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,259] (value -14.623897840121142)>)
# Added 2aobut_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,260] (value -16.11809565095832)>)
# Added glyc-R_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,261] (value -7.693024569127455)>)
# Added 3pg_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,262] (value -4.543802366063595)>)
# Added lgt-S_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,263] (value -6.907755278982137)>)
# Added gthrd_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,264] (value -5.046456340680265)>)
# Added lac-D_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,265] (value -6.907755278982137)>)
# Added gmhep1p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,266] (value -6.907755278982137)>)
# Added gmhep7p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,267] (value -6.942031284679248)>)
# Added gmhep17bp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,268] (value -6.907755278982137)>)
# Added xmp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,269] (value -6.907755278982137)>)
# Added g3pc_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,270] (value -16.11809565095832)>)
# Added chol_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,271] (value -6.907755278982137)>)
# Added g3pe_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,272] (value -16.11809565095832)>)
# Added g3pg_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,273] (value -12.304100767306165)>)
# Added gsn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,274] (value -12.815115304149034)>)
# Added gtspmd_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,275] (value -13.34060370805616)>)
# Added spmd_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,276] (value -6.907755278982137)>)
# Added gua_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,277] (value -9.590489258792111)>)
# Added xan_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,278] (value -14.148171915746465)>)
# Added histd_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,279] (value -8.663638321354728)>)
# Added his-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,280] (value -7.3916452792451155)>)
# Added hisp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,281] (value -6.907755278982137)>)
# Added hpyr_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,282] (value -16.11809565095832)>)
# Added hom-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,283] (value -16.11809565095832)>)
# Added phom_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,284] (value -16.118095650958324)>)
# Added suchms_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,285] (value -16.11809565095832)>)
# Added imacp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,286] (value -6.907755278982137)>)
# Added pydam_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,287] (value -15.966559778906335)>)
# Added prlp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,288] (value -16.11809565095832)>)
# Added eig3p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,289] (value -10.927707137416917)>)
# Added 2cpr5p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,290] (value -6.907755278982137)>)
# Added 3ig3p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,291] (value -6.907755278982137)>)
# Added ile-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,292] (value -6.907755278982137)>)
# Added 3c2hmp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,293] (value -13.895790091704916)>)
# Added 3c4mop_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,294] (value -16.11809565095832)>)
# Added 2ippm_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,295] (value -6.907755278982137)>)
# Added 3c3hmp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,296] (value -6.907755278982137)>)
# Added 3hmrsACP_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,297] (value -16.11809565095832)>)
# Added kdo_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,298] (value -6.907755278982137)>)
# Added ckdo_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,299] (value -6.907755278982137)>)
# Added kdo8p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,300] (value -6.907755278982137)>)
# Added lac-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,301] (value -6.907755278982137)>)
# Added 4mop_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,302] (value -6.907755278982137)>)
# Added leu-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,303] (value -6.907755278982137)>)
# Added mthgxl_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,304] (value -6.907755278982137)>)
# Added lipidX_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,305] (value -6.907755278982137)>)
# Added u23ga_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,306] (value -6.907755278982137)>)
# Added lipidAds_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,307] (value -6.907755278982137)>)
# Added agpgEC_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,308] (value -16.11809565095832)>)
# Added agpeEC_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,309] (value -16.11809565095832)>)
# Added agpcEC_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,310] (value -6.907755278982137)>)
# Added apgEC_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,311] (value -16.11809565095832)>)
# Added cdpea_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,312] (value -16.11809565095832)>)
# Added lpsEC_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,313] (value -16.11809565095832)>)
# Added 2mcit_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,314] (value -6.907755278982137)>)
# Added 2mcacn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,315] (value -6.907755278982137)>)
# Added micit_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,316] (value -6.907755278982137)>)
# Added 5mdru1p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,317] (value -16.11809565095832)>)
# Added met-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,318] (value -7.535681091373741)>)
# Added 5mthf_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,319] (value -6.907755278982137)>)
# Added mmcoa-S_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,320] (value -6.907755278982137)>)
# Added mmcoa-R_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,321] (value -8.928546451301923)>)
# Added lipidA_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,322] (value -6.907755278982137)>)
# Added kdolipid4_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,323] (value -6.907755278982137)>)
# Added 5mta_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,324] (value -6.907755278982137)>)
# Added 5mtr_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,325] (value -12.43526015415223)>)
# Added methf_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,326] (value -16.11809565095832)>)
# Added 5mdr1p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,327] (value -6.907755278982137)>)
# Added nmn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,328] (value -16.11809565095832)>)
# Added h2o_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,329] (value 0.0)>)
# Added nmn_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,330] (value -10.027165034484549)>)
# Added dnad_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,331] (value -6.907755278982137)>)
# Added nac_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,332] (value -16.11809565095832)>)
# Added nicrnt_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,333] (value -6.907755278982137)>)
# Added dgtp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,334] (value -9.544043043895714)>)
# Added dudp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,335] (value -6.907755278982137)>)
# Added datp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,336] (value -16.11809565095832)>)
# Added ncam_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,337] (value -6.907755278982137)>)
# Added quln_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,338] (value -16.11809565095832)>)
# Added xtsn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,339] (value -16.11809565095832)>)
# Added thymd_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,340] (value -6.907755278982137)>)
# Added dgsn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,341] (value -12.874330802797688)>)
# Added pppi_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,342] (value -16.11809565095832)>)
# Added no2_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,343] (value -16.11809565095832)>)
# Added orot5p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,344] (value -16.11809565095832)>)
# Added pro-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,345] (value -6.451986819158975)>)
# Added pnto-R_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,346] (value -6.907755278982137)>)
# Added ugmda_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,347] (value -6.907755278982137)>)
# Added uagmda_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,348] (value -16.11809565095832)>)
# Added trdrd_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,349] (value -16.11809565095832)>)
# Added trdox_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,350] (value -6.907755278982137)>)
# Added pdx5p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,351] (value -6.907755278982137)>)
# Added pydxn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,352] (value -16.11809565095832)>)
# Added peEC_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,353] (value -16.11809565095832)>)
# Added 3php_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,354] (value -15.988883795901534)>)
# Added pgpEC_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,355] (value -16.11809565095832)>)
# Added phe-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,356] (value -9.695057754153993)>)
# Added phpyr_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,357] (value -6.290088521103796)>)
# Added 4r5au_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,358] (value -16.11809565095832)>)
# Added 4ppan_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,359] (value -6.907755278982137)>)
# Added ppap_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,360] (value -16.033310719164234)>)
# Added 4ppcys_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,361] (value -16.11809565095832)>)
# Added pan4p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,362] (value -6.907755278982137)>)
# Added r1p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,363] (value -12.149354060378112)>)
# Added 34hpp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,364] (value -7.326117574595175)>)
# Added uaagmda_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,365] (value -16.11809565095832)>)
# Added peptidoEC_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,366] (value -16.11809565095832)>)
# Added fpram_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,367] (value -6.907755278982137)>)
# Added prbamp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,368] (value -16.11809565095832)>)
# Added prfp_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,369] (value -6.907755278982137)>)
# Added skm5p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,370] (value -6.907755278982137)>)
# Added psEC_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,371] (value -16.11809565095832)>)
# Added pser-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,372] (value -6.907755278982137)>)
# Added pydx_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,373] (value -16.11809565095832)>)
# Added ribflv_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,374] (value -11.086914531457822)>)
# Added dmlz_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,375] (value -16.11809565095832)>)
# Added xu5p-D_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,376] (value -9.788910249667914)>)
# Added s7p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,377] (value -9.345388595139012)>)
# Added sucorn_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,378] (value -6.907755278982137)>)
# Added so4_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,379] (value -6.907755278982137)>)
# Added sl26da_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,380] (value -14.669901430263504)>)
# Added sl2a6o_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,381] (value -16.11809565095832)>)
# Added sucglu_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,382] (value -6.907755278982137)>)
# Added sucgsa_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,383] (value -6.907755278982137)>)
# Added skm_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,384] (value -11.680759396291297)>)
# Added thr-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,385] (value -7.222044853908663)>)
# Added tyr-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,386] (value -10.151870178894075)>)
# Added tmao_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,387] (value -16.11809565095832)>)
# Added tma_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,388] (value -6.907755278982137)>)
# Added tre6p_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,389] (value -16.11809565095832)>)
# Added tre_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,390] (value -10.915266558832128)>)
# Added tre_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,391] (value -12.454347111481177)>)
# Added glc-D_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,392] (value -3.582719258285546)>)
# Added trp-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,393] (value -16.11809565095832)>)
# Added indole_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,394] (value -6.907755278982137)>)
# Added u3hga_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,395] (value -6.907755278982137)>)
# Added uamag_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,396] (value -6.907755278982137)>)
# Added ugmd_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,397] (value -16.11809565095832)>)
# Added u3aga_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,398] (value -15.436212175036935)>)
# Added uaccg_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,399] (value -10.439163858281718)>)
# Added uama_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,400] (value -16.11809565095832)>)
# Added uamr_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,401] (value -6.907755278982137)>)
# Added val-L_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,402] (value -4.017911310777666)>)
# Added xyl-D_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,403] (value -15.924017936836108)>)
# Added 4abut_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,404] (value -7.108709130442419)>)
# Added ac_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,405] (value -3.5769017637367595)>)
# Added ala-L_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,406] (value -6.907755278982137)>)
# Added arab-L_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,407] (value -7.102532367666518)>)
# Added arg-L_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,408] (value -16.11809565095832)>)
# Added asn-L_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,409] (value -8.839794267618739)>)
# Added asp-L_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,410] (value -7.6405493829478965)>)
# Added charge_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,411] (value 0.0)>)
# Added chol_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,412] (value -16.11809565095832)>)
# Added co2tot_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,413] (value -9.721165995742174)>)
# Added dms_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,414] (value -6.907755278982137)>)
# Added dmso_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,415] (value -16.11809565095832)>)
# Added for_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,416] (value -9.923136134937486)>)
# Added fru_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,417] (value -3.619353391465326)>)
# Added fum_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,418] (value -16.11809565095832)>)
# Added gal_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,419] (value -7.1025498129333995)>)
# Added glcn_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,420] (value -3.7090821614314557)>)
# Added glu-L_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,421] (value -6.907755278982137)>)
# Added glyb_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,422] (value -7.101651375098087)>)
# Added glyc3p_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,423] (value -6.907755278982137)>)
# Added h_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,424] (value 0.0)>)
# Added his-L_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,425] (value -7.55185677332981)>)
# Added ile-L_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,426] (value -16.11809565095832)>)
# Added k_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,427] (value -14.930542569435048)>)
# Added leu-L_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,428] (value -7.14138870897104)>)
# Added lys-L_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,429] (value -6.907755278982137)>)
# Added na1_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,430] (value -13.998306945306215)>)
# Added nh3_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,431] (value -3.825845309187094)>)
# Added o2_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,432] (value -8.11172808330807)>)
# Added orn_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,433] (value -8.533737807758621)>)
# Added pi_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,434] (value -2.747310915055513)>)
# Added pro-L_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,435] (value -6.907755278982137)>)
# Added ptrc_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,436] (value -6.907755278982137)>)
# Added ser-L_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,437] (value -16.11809565095832)>)
# Added so4_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,438] (value -4.398156016603766)>)
# Added succ_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,439] (value -16.025847653395598)>)
# Added thr-L_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,440] (value -7.145161119857606)>)
# Added tma_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,441] (value -16.11809565095832)>)
# Added tmao_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,442] (value -6.907755278982137)>)
# Added val-L_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,443] (value -6.907755278982137)>)
# Added xyl-D_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,444] (value -16.11809565095832)>)
# Added h_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,445] (value 0.0)>)
# Added charge_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,446] (value 0.0)>)
# Added na1_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,447] (value -16.11809565095832)>)
# Added h2_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,448] (value -6.907755278982137)>)
# Added k_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,449] (value -16.11809565095832)>)
# Added no3_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,450] (value -6.907755278982137)>)
# Added biomass_c : <MVar ()>
# array(<gurobi.Var ln_conc[0,451] (value 0.0)>)
# Added biomass_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,452] (value 0.0)>)
# Added orot_e : <MVar ()>
# array(<gurobi.Var ln_conc[0,453] (value -9.473345456715522)>)
# 0

# %%
# Recreate model with met TVA applied
tmodel_ace = setup_model(CONDITIONS[1], "results/ecoli_WT_Ace_mets_objval.txt")
# Out:
# ['Parameters', 'Exchange reactions', 'Reactions', 'Biomass Composition', 'Transmembrane reactions', 'Metabolites', 'references', 'Transmembrane_reactions_reed', 'Transmembrane reactions_Orth', 'Transmembrane reactions old', 'Sheet3', 'log', 'subsystems']
# *** Reading data from Reactions ***
# unknown metabolite '2dhglcn[c]' created
# unknown metabolite 'nadh[c]' created
# unknown metabolite 'glcn[c]' created
# unknown metabolite 'nad[c]' created
# unknown metabolite 'nadph[c]' created
# unknown metabolite 'nadp[c]' created
# unknown metabolite '2dhguln[c]' created
# unknown metabolite 'idon-L[c]' created
# unknown metabolite '3hcinnm[c]' created
# unknown metabolite 'o2[c]' created
# unknown metabolite 'dhcinnm[c]' created
# unknown metabolite 'h2o[c]' created
# unknown metabolite '3hpppn[c]' created
# unknown metabolite 'dhpppn[c]' created
# unknown metabolite 'phthr[c]' created
# unknown metabolite '4hthr[c]' created
# unknown metabolite 'pi[c]' created
# unknown metabolite '5dglcn[c]' created
# unknown metabolite 'ru5p-D[c]' created
# unknown metabolite 'ara5p[c]' created
# unknown metabolite 'ACP[c]' created
# unknown metabolite 'atp[c]' created
# unknown metabolite 'ttdca[c]' created
# unknown metabolite 'amp[c]' created
# unknown metabolite 'myrsACP[c]' created
# unknown metabolite 'ppi[c]' created
# unknown metabolite 'ttdcea[c]' created
# unknown metabolite 'tdeACP[c]' created
# unknown metabolite 'hdca[c]' created
# unknown metabolite 'palmACP[c]' created
# unknown metabolite 'hdcea[c]' created
# unknown metabolite 'hdeACP[c]' created
# unknown metabolite 'ocdcea[c]' created
# unknown metabolite 'octeACP[c]' created
# unknown metabolite 'dtdp4aaddg[c]' created
# unknown metabolite 'unagamu[c]' created
# unknown metabolite 'dtdp[c]' created
# unknown metabolite 'unagamuf[c]' created
# unknown metabolite 'arbt6p[c]' created
# unknown metabolite 'g6p[c]' created
# unknown metabolite 'hqn[c]' created
# unknown metabolite '4abut[c]' created
# unknown metabolite 'akg[c]' created
# unknown metabolite 'glu-L[c]' created
# unknown metabolite 'sucsal[c]' created
# unknown metabolite '4abutn[c]' created
# unknown metabolite 'acac[c]' created
# unknown metabolite 'accoa[c]' created
# unknown metabolite 'aacoa[c]' created
# unknown metabolite 'ac[c]' created
# unknown metabolite 'coa[c]' created
# unknown metabolite 'acald[c]' created
# unknown metabolite 'adocbip[c]' created
# unknown metabolite 'gtp[c]' created
# unknown metabolite 'agdpcbi[c]' created
# unknown metabolite 'co2tot[c]' created
# unknown metabolite 'adp[c]' created
# unknown metabolite 'malcoa[c]' created
# unknown metabolite 'ppa[c]' created
# unknown metabolite 'ppcoa[c]' created
# unknown metabolite 'uacgam[c]' created
# unknown metabolite 'udcpp[c]' created
# unknown metabolite 'ump[c]' created
# unknown metabolite 'unaga[c]' created
# unknown metabolite 'acglu[c]' created
# unknown metabolite 'acg5p[c]' created
# unknown metabolite '2obut[c]' created
# unknown metabolite 'pyr[c]' created
# unknown metabolite '2ahbut[c]' created
# unknown metabolite 'actp[c]' created
# unknown metabolite 'alac-S[c]' created
# unknown metabolite 'uacmamu[c]' created
# unknown metabolite 'udp[c]' created
# unknown metabolite 'acnam[c]' created
# unknown metabolite 'acmana[c]' created
# unknown metabolite 'acACP[c]' created
# unknown metabolite 'acorn[c]' created
# unknown metabolite 'orn[c]' created
# unknown metabolite 'acon-T[c]' created
# unknown metabolite 'amet[c]' created
# unknown metabolite 'aconm[c]' created
# unknown metabolite 'ahcys[c]' created
# unknown metabolite 'cit[c]' created
# unknown metabolite 'icit[c]' created
# unknown metabolite 'acg5sa[c]' created
# unknown metabolite 'apoACP[c]' created
# unknown metabolite 'pap[c]' created
# unknown metabolite 'adn[c]' created
# unknown metabolite 'ins[c]' created
# unknown metabolite 'nh3[c]' created
# unknown metabolite '4adcho[c]' created
# unknown metabolite '4abz[c]' created
# unknown metabolite 'chor[c]' created
# unknown metabolite 'gln-L[c]' created
# unknown metabolite 'ade[c]' created
# unknown metabolite 'hxan[c]' created
# unknown metabolite 'etoh[c]' created
# unknown metabolite 'gdp[c]' created
# unknown metabolite 'itp[c]' created
# unknown metabolite 'idp[c]' created
# unknown metabolite 'ametam[c]' created
# unknown metabolite 'camp[c]' created
# unknown metabolite 'adocbi[c]' created
# unknown metabolite 'rdmbzi[c]' created
# unknown metabolite 'adocbl[c]' created
# unknown metabolite 'gmp[c]' created
# unknown metabolite 'prpp[c]' created
# unknown metabolite 'aps[c]' created
# unknown metabolite 'paps[c]' created
# unknown metabolite 'dcamp[c]' created
# unknown metabolite 'fum[c]' created
# unknown metabolite '25aics[c]' created
# unknown metabolite 'aicar[c]' created
# unknown metabolite 'asp-L[c]' created
# unknown metabolite 'imp[c]' created
# unknown metabolite 'acgam6p[c]' created
# unknown metabolite 'gam6p[c]' created
# unknown metabolite 'adphep-DD[c]' created
# unknown metabolite 'adphep-LD[c]' created
# unknown metabolite 'agm[c]' created
# unknown metabolite 'ptrc[c]' created
# unknown metabolite 'urea[c]' created
# unknown metabolite 'hcys-L[c]' created
# unknown metabolite 'rhcys[c]' created
# unknown metabolite '10fthf[c]' created
# unknown metabolite 'fprica[c]' created
# unknown metabolite 'thf[c]' created
# unknown metabolite 'air[c]' created
# unknown metabolite '5caiz[c]' created
# unknown metabolite '5aizc[c]' created
# unknown metabolite 'ala-D[c]' created
# unknown metabolite 'alaala[c]' created
# unknown metabolite 'ala-L[c]' created
# unknown metabolite 'pydx5p[c]' created
# unknown metabolite 'pyam5p[c]' created
# unknown metabolite 'glyald[c]' created
# unknown metabolite 'glyc[c]' created
# unknown metabolite 'pacald[c]' created
# unknown metabolite 'pac[c]' created
# unknown metabolite 'alltt[c]' created
# unknown metabolite 'urdglyc[c]' created
# unknown metabolite 'alltn[c]' created
# unknown metabolite 'altrn[c]' created
# unknown metabolite '2ddglcn[c]' created
# unknown metabolite 'malt[c]' created
# unknown metabolite 'malttr[c]' created
# unknown metabolite 'glc-D[c]' created
# unknown metabolite 'maltttr[c]' created
# unknown metabolite 'maltpt[c]' created
# unknown metabolite 'malthx[c]' created
# unknown metabolite 'malthp[c]' created
# unknown metabolite 'acmanap[c]' created
# unknown metabolite '8aonn[c]' created
# unknown metabolite 'amob[c]' created
# unknown metabolite 'dann[c]' created
# unknown metabolite '2dmmq8[c]' created
# unknown metabolite 'mqn8[c]' created
# unknown metabolite '4ampm[c]' created
# unknown metabolite 'for[c]' created
# unknown metabolite 'r5p[c]' created
# unknown metabolite 'anth[c]' created
# unknown metabolite 'pran[c]' created
# unknown metabolite 'pmcoa[c]' created
# unknown metabolite 'ap4a[c]' created
# unknown metabolite 'ap5a[c]' created
# unknown metabolite '5apru[c]' created
# unknown metabolite '5aprbu[c]' created
# unknown metabolite 'arab-L[c]' created
# unknown metabolite 'rbl-L[c]' created
# unknown metabolite 'arg-L[c]' created
# unknown metabolite 'argsuc[c]' created
# unknown metabolite 'citr-L[c]' created
# unknown metabolite 'aspsa[c]' created
# unknown metabolite '4pasp[c]' created
# unknown metabolite 'asn-L[c]' created
# unknown metabolite 'ala-B[c]' created
# unknown metabolite 'cbp[c]' created
# unknown metabolite 'cbasp[c]' created
# unknown metabolite 'q8[c]' created
# unknown metabolite 'iasp[c]' created
# unknown metabolite 'q8h2[c]' created
# unknown metabolite 'mql8[c]' created
# unknown metabolite 'succ[c]' created
# unknown metabolite 'h2o2[c]' created
# unknown metabolite 'oaa[c]' created
# unknown metabolite 'succoa[c]' created
# unknown metabolite 'sucarg[c]' created
# unknown metabolite 'prbatp[c]' created
# unknown metabolite 'betald[c]' created
# unknown metabolite 'glyb[c]' created
# unknown metabolite 'btnso[c]' created
# unknown metabolite 'btn[c]' created
# unknown metabolite 'cys-L[c]' created
# unknown metabolite 'dtbt[c]' created
# unknown metabolite 'but[c]' created
# unknown metabolite 'btcoa[c]' created
# unknown metabolite 'actACP[c]' created
# unknown metabolite 'malACP[c]' created
# unknown metabolite 'ddcaACP[c]' created
# unknown metabolite 'cbi[c]' created
# unknown metabolite 'cbl1[c]' created
# unknown metabolite 'cdpdag1[c]' created
# unknown metabolite 'cmp[c]' created
# unknown metabolite 'paEC[c]' created
# unknown metabolite '4c2me[c]' created
# unknown metabolite '2p4c2me[c]' created
# unknown metabolite 'pphn[c]' created
# unknown metabolite '3psme[c]' created
# unknown metabolite '4hbz[c]' created
# unknown metabolite 'cinnm[c]' created
# unknown metabolite 'cenchddd[c]' created
# unknown metabolite 'pgEC[c]' created
# unknown metabolite 'clpnEC[c]' created
# unknown metabolite 'csn[c]' created
# unknown metabolite 'cpppg3[c]' created
# unknown metabolite 'pppg9[c]' created
# unknown metabolite 'bbtcoa[c]' created
# unknown metabolite 'crn[c]' created
# unknown metabolite 'crncoa[c]' created
# unknown metabolite 'gbbtn[c]' created
# unknown metabolite 'ctbtcoa[c]' created
# unknown metabolite 'ctbt[c]' created
# unknown metabolite 'ura[c]' created
# unknown metabolite 'utp[c]' created
# unknown metabolite 'ctp[c]' created
# unknown metabolite 'cyan[c]' created
# unknown metabolite 'tsul[c]' created
# unknown metabolite 'so3[c]' created
# unknown metabolite 'tcynt[c]' created
# unknown metabolite 'cynt[c]' created
# unknown metabolite 'acser[c]' created
# unknown metabolite 'h2s[c]' created
# unknown metabolite 'cyst-L[c]' created
# unknown metabolite 'cytd[c]' created
# unknown metabolite 'uri[c]' created
# unknown metabolite 'cdp[c]' created
# unknown metabolite 'dcmp[c]' created
# unknown metabolite 'dcdp[c]' created
# unknown metabolite 'fad[c]' created
# unknown metabolite 'fadh2[c]' created
# unknown metabolite 'dad-2[c]' created
# unknown metabolite 'din[c]' created
# unknown metabolite 'damp[c]' created
# unknown metabolite 'dadp[c]' created
# unknown metabolite '12dgrEC[c]' created
# unknown metabolite '26dap-M[c]' created
# unknown metabolite 'lys-L[c]' created
# unknown metabolite '26dap-LL[c]' created
# unknown metabolite 'db4p[c]' created
# unknown metabolite 'dctp[c]' created
# unknown metabolite 'dutp[c]' created
# unknown metabolite 'dcyt[c]' created
# unknown metabolite 'duri[c]' created
# unknown metabolite '2dh3dgal[c]' created
# unknown metabolite '2dh3dgal6p[c]' created
# unknown metabolite '2ddg6p[c]' created
# unknown metabolite 'e4p[c]' created
# unknown metabolite 'pep[c]' created
# unknown metabolite '2dda7p[c]' created
# unknown metabolite 'g3p[c]' created
# unknown metabolite 'dgmp[c]' created
# unknown metabolite 'dgdp[c]' created
# unknown metabolite '23dhmb[c]' created
# unknown metabolite '3mob[c]' created
# unknown metabolite '23dhmp[c]' created
# unknown metabolite '3mop[c]' created
# unknown metabolite 'dha[c]' created
# unknown metabolite 'dhap[c]' created
# unknown metabolite '23ddhb[c]' created
# unknown metabolite '23dhb[c]' created
# unknown metabolite '23dhba[c]' created
# unknown metabolite 'hkntd[c]' created
# unknown metabolite '23dhdp[c]' created
# unknown metabolite 'thdp[c]' created
# unknown metabolite 'dhf[c]' created
# unknown metabolite 'dhpt[c]' created
# unknown metabolite 'dhna[c]' created
# unknown metabolite 'octdp[c]' created
# unknown metabolite 'dhnpt[c]' created
# unknown metabolite '6hmhpt[c]' created
# unknown metabolite 'gcald[c]' created
# unknown metabolite 'dhor-S[c]' created
# unknown metabolite 'orot[c]' created
# unknown metabolite 'cechddd[c]' created
# unknown metabolite '25drapp[c]' created
# unknown metabolite '6hmhptpp[c]' created
# unknown metabolite 'dhptd[c]' created
# unknown metabolite 'hmfurn[c]' created
# unknown metabolite '3dhq[c]' created
# unknown metabolite '3dhsk[c]' created
# unknown metabolite '25dkglcn[c]' created
# unknown metabolite 'dkmpp[c]' created
# unknown metabolite '2kmb[c]' created
# unknown metabolite 'dmpp[c]' created
# unknown metabolite 'ipdp[c]' created
# unknown metabolite 'grdp[c]' created
# unknown metabolite 'h2mb4p[c]' created
# unknown metabolite '2omhmbl[c]' created
# unknown metabolite 'dmso[c]' created
# unknown metabolite 'dms[c]' created
# unknown metabolite '2dmmql8[c]' created
# unknown metabolite 'dhpmp[c]' created
# unknown metabolite 'ahdt[c]' created
# unknown metabolite '23doguln[c]' created
# unknown metabolite '3dhguln[c]' created
# unknown metabolite 'dpcoa[c]' created
# unknown metabolite '2dhp[c]' created
# unknown metabolite 'pant-R[c]' created
# unknown metabolite '2dr5p[c]' created
# unknown metabolite 'dtmp[c]' created
# unknown metabolite 'dump[c]' created
# unknown metabolite '2dr1p[c]' created
# unknown metabolite 'dxyl5p[c]' created
# unknown metabolite '2me4p[c]' created
# unknown metabolite 'dxyl[c]' created
# unknown metabolite '4per[c]' created
# unknown metabolite 'ecaEC[c]' created
# unknown metabolite 'udcpdp[c]' created
# unknown metabolite '6pgc[c]' created
# unknown metabolite 'kdo2lipid4[c]' created
# unknown metabolite 'kdo2lipid4L[c]' created
# unknown metabolite 'lipa[c]' created
# unknown metabolite 'kdo2lipid4p[c]' created
# unknown metabolite 'lipa_cold[c]' created
# unknown metabolite '2pg[c]' created
# unknown metabolite 'seramp[c]' created
# unknown metabolite 'enter[c]' created
# unknown metabolite 'etha[c]' created
# unknown metabolite 'f6p[c]' created
# unknown metabolite 'ocdca[c]' created
# unknown metabolite 'fdp[c]' created
# unknown metabolite 'fuc-L[c]' created
# unknown metabolite 'fcl-L[c]' created
# unknown metabolite 'fc1p[c]' created
# unknown metabolite 'lald-L[c]' created
# unknown metabolite 'fe2[c]' created
# unknown metabolite 'ppp9[c]' created
# unknown metabolite 'pheme[c]' created
# unknown metabolite 'suc6p[c]' created
# unknown metabolite 'fru[c]' created
# unknown metabolite 'h2[c]' created
# unknown metabolite 'fmn[c]' created
# unknown metabolite 'f1p[c]' created
# unknown metabolite 'mal-L[c]' created
# unknown metabolite 'gam1p[c]' created
# unknown metabolite 'acgam1p[c]' created
# unknown metabolite 'g1p[c]' created
# unknown metabolite 'dttp[c]' created
# unknown metabolite 'dtdpglu[c]' created
# unknown metabolite 'glu1sa[c]' created
# unknown metabolite '5aop[c]' created
# unknown metabolite 'glyc3p[c]' created
# unknown metabolite 'glu5sa[c]' created
# unknown metabolite '1pyr5c[c]' created
# unknown metabolite 'glu5p[c]' created
# unknown metabolite '6pgl[c]' created
# unknown metabolite 'galct-D[c]' created
# unknown metabolite '5dh4dglc[c]' created
# unknown metabolite 'galctn-D[c]' created
# unknown metabolite 'gal[c]' created
# unknown metabolite 'gal1p[c]' created
# unknown metabolite 'melib[c]' created
# unknown metabolite 'udpg[c]' created
# unknown metabolite '13dpg[c]' created
# unknown metabolite 'gar[c]' created
# unknown metabolite 'fgam[c]' created
# unknown metabolite 'glyclt[c]' created
# unknown metabolite 'gdpddman[c]' created
# unknown metabolite 'gdpofuc[c]' created
# unknown metabolite 'ser-L[c]' created
# unknown metabolite 'gly[c]' created
# unknown metabolite 'mlthf[c]' created
# unknown metabolite 'glycogen[c]' created
# unknown metabolite '2h3oppan[c]' created
# unknown metabolite 'glcr[c]' created
# unknown metabolite 'adpglc[c]' created
# unknown metabolite 'galt1p[c]' created
# unknown metabolite 'tag6p-D[c]' created
# unknown metabolite 'glucys[c]' created
# unknown metabolite 'pram[c]' created
# unknown metabolite 'glu-D[c]' created
# unknown metabolite 'glutrna[c]' created
# unknown metabolite 'trnaglu[c]' created
# unknown metabolite 'glx[c]' created
# unknown metabolite '2aobut[c]' created
# unknown metabolite 'glyc-R[c]' created
# unknown metabolite '3pg[c]' created
# unknown metabolite 'lgt-S[c]' created
# unknown metabolite 'gthrd[c]' created
# unknown metabolite 'lac-D[c]' created
# unknown metabolite 'gdpmann[c]' created
# unknown metabolite 'gmhep1p[c]' created
# unknown metabolite 'gmhep7p[c]' created
# unknown metabolite 'gmhep17bp[c]' created
# unknown metabolite 'xmp[c]' created
# unknown metabolite 'gdpfuc[c]' created
# unknown metabolite 'gp4g[c]' created
# unknown metabolite 'g3pc[c]' created
# unknown metabolite 'chol[c]' created
# unknown metabolite 'g3pe[c]' created
# unknown metabolite 'g3ps[c]' created
# unknown metabolite 'g3pg[c]' created
# unknown metabolite 'g3pi[c]' created
# unknown metabolite 'inost[c]' created
# unknown metabolite 'frdp[c]' created
# unknown metabolite 'gsn[c]' created
# unknown metabolite 'gtspmd[c]' created
# unknown metabolite 'spmd[c]' created
# unknown metabolite 'gthox[c]' created
# unknown metabolite 'gua[c]' created
# unknown metabolite 'xan[c]' created
# unknown metabolite 'glcur[c]' created
# unknown metabolite 'fruur[c]' created
# unknown metabolite 'galur[c]' created
# unknown metabolite 'tagur[c]' created
# unknown metabolite '3ophb[c]' created
# unknown metabolite 'hemeO[c]' created
# unknown metabolite '4mhetz[c]' created
# unknown metabolite '4mpetz[c]' created
# unknown metabolite 'histd[c]' created
# unknown metabolite 'his-L[c]' created
# unknown metabolite 'hisp[c]' created
# unknown metabolite 'hkndd[c]' created
# unknown metabolite 'op4en[c]' created
# unknown metabolite 'ppbng[c]' created
# unknown metabolite 'hmbil[c]' created
# unknown metabolite '4ahmmp[c]' created
# unknown metabolite '4h2opntn[c]' created
# unknown metabolite 'hpyr[c]' created
# unknown metabolite 'hom-L[c]' created
# unknown metabolite 'phom[c]' created
# unknown metabolite 'suchms[c]' created
# unknown metabolite 'imacp[c]' created
# unknown metabolite 'pydam[c]' created
# unknown metabolite 'ichor[c]' created
# unknown metabolite 'prlp[c]' created
# unknown metabolite 'eig3p[c]' created
# unknown metabolite '2cpr5p[c]' created
# unknown metabolite '3ig3p[c]' created
# unknown metabolite 'ile-L[c]' created
# unknown metabolite '3c2hmp[c]' created
# unknown metabolite '3c4mop[c]' created
# unknown metabolite '2ippm[c]' created
# unknown metabolite '3c3hmp[c]' created
# unknown metabolite '3hmrsACP[c]' created
# unknown metabolite 'kdo[c]' created
# unknown metabolite 'ckdo[c]' created
# unknown metabolite 'kdo8p[c]' created
# unknown metabolite '3dhgulnp[c]' created
# unknown metabolite 'xu5p-L[c]' created
# unknown metabolite 'lcts[c]' created
# unknown metabolite 'lac-L[c]' created
# unknown metabolite '12ppd-S[c]' created
# unknown metabolite '4mop[c]' created
# unknown metabolite 'leu-L[c]' created
# unknown metabolite 'mthgxl[c]' created
# unknown metabolite 'lipidX[c]' created
# unknown metabolite 'u23ga[c]' created
# unknown metabolite 'lipidAds[c]' created
# unknown metabolite 'agpgEC[c]' created
# unknown metabolite 'agpeEC[c]' created
# unknown metabolite 'agpcEC[c]' created
# unknown metabolite 'apgEC[c]' created
# unknown metabolite 'cdpea[c]' created
# unknown metabolite 'lpsEC[c]' created
# unknown metabolite '15dap[c]' created
# unknown metabolite 'mnl1p[c]' created
# unknown metabolite 'man1p[c]' created
# unknown metabolite 'man6p[c]' created
# unknown metabolite 'mana[c]' created
# unknown metabolite '2mcit[c]' created
# unknown metabolite '2mcacn[c]' created
# unknown metabolite 'micit[c]' created
# unknown metabolite '5mdru1p[c]' created
# unknown metabolite '2mecdp[c]' created
# unknown metabolite 'met-L[c]' created
# unknown metabolite '5mthf[c]' created
# unknown metabolite 'mi1p-D[c]' created
# unknown metabolite 'mmcoa-S[c]' created
# unknown metabolite 'mmcoa-R[c]' created
# unknown metabolite 'lipidA[c]' created
# unknown metabolite 'kdolipid4[c]' created
# unknown metabolite '5mta[c]' created
# unknown metabolite '5mtr[c]' created
# unknown metabolite 'methf[c]' created
# unknown metabolite '5mdr1p[c]' created
# unknown metabolite 'nmn[c]' created
# unknown metabolite 'h2o[e]' created
# unknown metabolite 'nad[e]' created
# unknown metabolite 'amp[e]' created
# unknown metabolite 'nmn[e]' created
# unknown metabolite 'dnad[c]' created
# unknown metabolite 'nac[c]' created
# unknown metabolite 'nicrnt[c]' created
# unknown metabolite 'dgtp[c]' created
# unknown metabolite 'dudp[c]' created
# unknown metabolite 'datp[c]' created
# unknown metabolite 'ncam[c]' created
# unknown metabolite 'dmbzid[c]' created
# unknown metabolite '5prdmbz[c]' created
# unknown metabolite 'quln[c]' created
# unknown metabolite 'sbzcoa[c]' created
# unknown metabolite 'xtsn[c]' created
# unknown metabolite 'thymd[c]' created
# unknown metabolite 'dgsn[c]' created
# unknown metabolite 'pppi[c]' created
# unknown metabolite 'no2[c]' created
# unknown metabolite 'ohpb[c]' created
# unknown metabolite '2ohph[c]' created
# unknown metabolite '2omph[c]' created
# unknown metabolite '2ombzl[c]' created
# unknown metabolite '2ommbl[c]' created
# unknown metabolite 'orot5p[c]' created
# unknown metabolite '2oph[c]' created
# unknown metabolite 'thmpp[c]' created
# unknown metabolite 'ssaltpp[c]' created
# unknown metabolite 'pro-L[c]' created
# unknown metabolite 'phaccoa[c]' created
# unknown metabolite 'pnto-R[c]' created
# unknown metabolite 'ugmda[c]' created
# unknown metabolite 'uagmda[c]' created
# unknown metabolite 'trdrd[c]' created
# unknown metabolite 'trdox[c]' created
# unknown metabolite 'pdx5p[c]' created
# unknown metabolite 'pydxn[c]' created
# unknown metabolite 'peamn[c]' created
# unknown metabolite 'peEC[c]' created
# unknown metabolite 'tagdp-D[c]' created
# unknown metabolite '3php[c]' created
# unknown metabolite '2pglyc[c]' created
# unknown metabolite 'pgpEC[c]' created
# unknown metabolite 'phe-L[c]' created
# unknown metabolite 'phpyr[c]' created
# unknown metabolite 'pcEC[c]' created
# unknown metabolite '4r5au[c]' created
# unknown metabolite '2mahmp[c]' created
# unknown metabolite '4ppan[c]' created
# unknown metabolite 'ppap[c]' created
# unknown metabolite '4ppcys[c]' created
# unknown metabolite 'pan4p[c]' created
# unknown metabolite 'r1p[c]' created
# unknown metabolite '34hpp[c]' created
# unknown metabolite 'pppn[c]' created
# unknown metabolite 'uaagmda[c]' created
# unknown metabolite 'peptidoEC[c]' created
# unknown metabolite 'fpram[c]' created
# unknown metabolite 'prbamp[c]' created
# unknown metabolite 'prfp[c]' created
# unknown metabolite 'skm5p[c]' created
# unknown metabolite 'psEC[c]' created
# unknown metabolite 'pser-L[c]' created
# unknown metabolite 'pydx[c]' created
# unknown metabolite 'ribflv[c]' created
# unknown metabolite 'dmlz[c]' created
# unknown metabolite 'rib-D[c]' created
# unknown metabolite 'ru5p-L[c]' created
# unknown metabolite 'xu5p-D[c]' created
# unknown metabolite 'rmn[c]' created
# unknown metabolite 'rml[c]' created
# unknown metabolite 'rml1p[c]' created
# unknown metabolite 's7p[c]' created
# unknown metabolite 'sucorn[c]' created
# unknown metabolite 'so4[c]' created
# unknown metabolite 'sbt6p[c]' created
# unknown metabolite 'sl26da[c]' created
# unknown metabolite 'sl2a6o[c]' created
# unknown metabolite 'seln[c]' created
# unknown metabolite 'selnp[c]' created
# unknown metabolite 'ser-D[c]' created
# unknown metabolite 'sucglu[c]' created
# unknown metabolite 'sucgsa[c]' created
# unknown metabolite '2shchc[c]' created
# unknown metabolite 'scl[c]' created
# unknown metabolite 'srch[c]' created
# unknown metabolite 'sheme[c]' created
# unknown metabolite 'skm[c]' created
# unknown metabolite 'N1aspmd[c]' created
# unknown metabolite 'n8aspmd[c]' created
# unknown metabolite 'o2s[c]' created
# unknown metabolite 'sucbz[c]' created
# unknown metabolite 'tartr-L[c]' created
# unknown metabolite 'taur[c]' created
# unknown metabolite 'aacald[c]' created
# unknown metabolite 'dtdp4addg[c]' created
# unknown metabolite 'dtdp4d6dg[c]' created
# unknown metabolite 'dtdp4d6dm[c]' created
# unknown metabolite 'dtdprmn[c]' created
# unknown metabolite 'thr-L[c]' created
# unknown metabolite 'tyr-L[c]' created
# unknown metabolite '4hba[c]' created
# unknown metabolite 'tmao[c]' created
# unknown metabolite 'tma[c]' created
# unknown metabolite 'thym[c]' created
# unknown metabolite 'thm[c]' created
# unknown metabolite 'thmmp[c]' created
# unknown metabolite 'tre6p[c]' created
# unknown metabolite 'tre[c]' created
# unknown metabolite 'tre[e]' created
# unknown metabolite 'glc-D[e]' created
# unknown metabolite 'trp-L[c]' created
# unknown metabolite 'indole[c]' created
# unknown metabolite 'u3hga[c]' created
# unknown metabolite 'uamag[c]' created
# unknown metabolite 'ugmd[c]' created
# unknown metabolite 'uacmam[c]' created
# unknown metabolite 'u3aga[c]' created
# unknown metabolite 'uaccg[c]' created
# unknown metabolite 'uama[c]' created
# unknown metabolite 'uamr[c]' created
# unknown metabolite 'udpgal[c]' created
# unknown metabolite 'udpgalfur[c]' created
# unknown metabolite 'udpglcur[c]' created
# unknown metabolite 'uppg3[c]' created
# unknown metabolite 'val-L[c]' created
# unknown metabolite 'xyl-D[c]' created
# unknown metabolite 'xylu-D[c]' created
# *** Reading data from Biomass Composition ***
# *** Reading data from Exchange reactions ***
# unknown metabolite '12ppd-S[e]' created
# unknown metabolite '15dap[e]' created
# unknown metabolite '26dap-M[e]' created
# unknown metabolite '2ddglcn[e]' created
# unknown metabolite '3hcinnm[e]' created
# unknown metabolite '3hpppn[e]' created
# unknown metabolite '4abut[e]' created
# unknown metabolite 'ac[e]' created
# unknown metabolite 'acac[e]' created
# unknown metabolite 'acald[e]' created
# unknown metabolite 'acgam[e]' created
# unknown metabolite 'acmana[e]' created
# unknown metabolite 'acnam[e]' created
# unknown metabolite 'ade[e]' created
# unknown metabolite 'adn[e]' created
# unknown metabolite 'akg[e]' created
# unknown metabolite 'ala-D[e]' created
# unknown metabolite 'ala-L[e]' created
# unknown metabolite 'alltn[e]' created
# unknown metabolite 'arab-L[e]' created
# unknown metabolite 'arg-L[e]' created
# unknown metabolite 'asn-L[e]' created
# unknown metabolite 'asp-L[e]' created
# unknown metabolite 'but[e]' created
# unknown metabolite 'charge[e]' created
# unknown metabolite 'cbl1[e]' created
# unknown metabolite 'chol[e]' created
# unknown metabolite 'cit[e]' created
# unknown metabolite 'co2tot[e]' created
# unknown metabolite 'crn[e]' created
# unknown metabolite 'csn[e]' created
# unknown metabolite 'cynt[e]' created
# unknown metabolite 'cys-L[e]' created
# unknown metabolite 'cytd[e]' created
# unknown metabolite 'dad-2[e]' created
# unknown metabolite 'dcyt[e]' created
# unknown metabolite 'dgsn[e]' created
# unknown metabolite 'dha[e]' created
# unknown metabolite 'din[e]' created
# unknown metabolite 'dms[e]' created
# unknown metabolite 'dmso[e]' created
# unknown metabolite 'duri[e]' created
# unknown metabolite 'etoh[e]' created
# unknown metabolite 'fe2[e]' created
# unknown metabolite 'for[e]' created
# unknown metabolite 'fru[e]' created
# unknown metabolite 'fuc1p-L[e]' created
# unknown metabolite 'fuc-L[e]' created
# unknown metabolite 'fum[e]' created
# unknown metabolite 'g6p[e]' created
# unknown metabolite 'gal[e]' created
# unknown metabolite 'galct-D[e]' created
# unknown metabolite 'galctn-D[e]' created
# unknown metabolite 'galt[e]' created
# unknown metabolite 'galur[e]' created
# unknown metabolite 'gam[e]' created
# unknown metabolite 'gbbtn[e]' created
# unknown metabolite 'glcn[e]' created
# unknown metabolite 'glcr[e]' created
# unknown metabolite 'glcur[e]' created
# unknown metabolite 'gln-L[e]' created
# unknown metabolite 'glu-L[e]' created
# unknown metabolite 'gly[e]' created
# unknown metabolite 'glyald[e]' created
# unknown metabolite 'glyb[e]' created
# unknown metabolite 'glyc[e]' created
# unknown metabolite 'glyc3p[e]' created
# unknown metabolite 'glyclt[e]' created
# unknown metabolite 'gsn[e]' created
# unknown metabolite 'gua[e]' created
# unknown metabolite 'h[e]' created
# unknown metabolite 'hdca[e]' created
# unknown metabolite 'his-L[e]' created
# unknown metabolite 'hxan[e]' created
# unknown metabolite 'idon-L[e]' created
# unknown metabolite 'ile-L[e]' created
# unknown metabolite 'indole[e]' created
# unknown metabolite 'ins[e]' created
# unknown metabolite 'k[e]' created
# unknown metabolite 'lac-D[e]' created
# unknown metabolite 'lac-L[e]' created
# unknown metabolite 'lcts[e]' created
# unknown metabolite 'leu-L[e]' created
# unknown metabolite 'lys-L[e]' created
# unknown metabolite 'mal-L[e]' created
# unknown metabolite 'malt[e]' created
# unknown metabolite 'malthx[e]' created
# unknown metabolite 'maltpt[e]' created
# unknown metabolite 'malttr[e]' created
# unknown metabolite 'maltttr[e]' created
# unknown metabolite 'man[e]' created
# unknown metabolite 'man6p[e]' created
# unknown metabolite 'melib[e]' created
# unknown metabolite 'met-D[e]' created
# unknown metabolite 'met-L[e]' created
# unknown metabolite 'mnl[e]' created
# unknown metabolite 'na1[e]' created
# unknown metabolite 'nac[e]' created
# unknown metabolite 'nh3[e]' created
# unknown metabolite 'no2[e]' created
# unknown metabolite 'no3[e]' created
# unknown metabolite 'o2[e]' created
# unknown metabolite 'ocdca[e]' created
# unknown metabolite 'orn[e]' created
# unknown metabolite 'phe-L[e]' created
# unknown metabolite 'pi[e]' created
# unknown metabolite 'pnto-R[e]' created
# unknown metabolite 'pppn[e]' created
# unknown metabolite 'pro-L[e]' created
# unknown metabolite 'ptrc[e]' created
# unknown metabolite 'pyr[e]' created
# unknown metabolite 'rib-D[e]' created
# unknown metabolite 'rmn[e]' created
# unknown metabolite 'sbt-D[e]' created
# unknown metabolite 'ser-D[e]' created
# unknown metabolite 'ser-L[e]' created
# unknown metabolite 'so4[e]' created
# unknown metabolite 'spmd[e]' created
# unknown metabolite 'succ[e]' created
# unknown metabolite 'sucr[e]' created
# unknown metabolite 'tartr-L[e]' created
# unknown metabolite 'taur[e]' created
# unknown metabolite 'thm[e]' created
# unknown metabolite 'thr-L[e]' created
# unknown metabolite 'thymd[e]' created
# unknown metabolite 'tma[e]' created
# unknown metabolite 'tmao[e]' created
# unknown metabolite 'trp-L[e]' created
# unknown metabolite 'tsul[e]' created
# unknown metabolite 'ttdca[e]' created
# unknown metabolite 'tyr-L[e]' created
# unknown metabolite 'ura[e]' created
# unknown metabolite 'urea[e]' created
# unknown metabolite 'uri[e]' created
# unknown metabolite 'val-L[e]' created
# unknown metabolite 'xan[e]' created
# unknown metabolite 'xtsn[e]' created
# unknown metabolite 'xyl-D[e]' created
# *** Reading data from Transmembrane reactions ***
# unknown metabolite 'h[c]' created
# unknown metabolite 'acgam[c]' created
# unknown metabolite 'charge[c]' created
# unknown metabolite 'electron[c]' created
# unknown metabolite 'electron[e]' created
# unknown metabolite 'fuc1p-L[c]' created
# unknown metabolite 'galt[c]' created
# unknown metabolite 'gam[c]' created
# unknown metabolite 'na1[c]' created
# unknown metabolite 'h2[e]' created
# unknown metabolite 'k[c]' created
# unknown metabolite 'malt6p[c]' created
# unknown metabolite 'man[c]' created
# unknown metabolite 'met-D[c]' created
# unknown metabolite 'mnl[c]' created
# unknown metabolite 'no3[c]' created
# unknown metabolite 'sbt-D[c]' created
# unknown metabolite 'sucr[c]' created
# *** Reading data from Parameters ***
# *** Reading data from Metabolites ***
# Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# *** Updating metabolite information ***
# 2dhglcn_c NOTHING DONE!
# nadh_c NOTHING DONE!
# glcn_c NOTHING DONE!
# nad_c NOTHING DONE!
# nadph_c NOTHING DONE!
# nadp_c NOTHING DONE!
# 2dhguln_c NOTHING DONE!
# idon-L_c NOTHING DONE!
# 3hcinnm_c NOTHING DONE!
# o2_c NOTHING DONE!
# dhcinnm_c NOTHING DONE!
# h2o_c NOTHING DONE!
# 3hpppn_c NOTHING DONE!
# dhpppn_c NOTHING DONE!
# phthr_c NOTHING DONE!
# 4hthr_c NOTHING DONE!
# pi_c NOTHING DONE!
# 5dglcn_c NOTHING DONE!
# ru5p-D_c NOTHING DONE!
# ara5p_c NOTHING DONE!
# ACP_c NOTHING DONE!
# atp_c NOTHING DONE!
# ttdca_c NOTHING DONE!
# amp_c NOTHING DONE!
# myrsACP_c NOTHING DONE!
# ppi_c NOTHING DONE!
# ttdcea_c NOTHING DONE!
# tdeACP_c NOTHING DONE!
# hdca_c NOTHING DONE!
# palmACP_c NOTHING DONE!
# hdcea_c NOTHING DONE!
# hdeACP_c NOTHING DONE!
# ocdcea_c NOTHING DONE!
# octeACP_c NOTHING DONE!
# dtdp4aaddg_c NOTHING DONE!
# unagamu_c NOTHING DONE!
# dtdp_c NOTHING DONE!
# unagamuf_c NOTHING DONE!
# arbt6p_c NOTHING DONE!
# g6p_c NOTHING DONE!
# hqn_c NOTHING DONE!
# 4abut_c NOTHING DONE!
# akg_c NOTHING DONE!
# glu-L_c NOTHING DONE!
# sucsal_c NOTHING DONE!
# 4abutn_c NOTHING DONE!
# acac_c NOTHING DONE!
# accoa_c NOTHING DONE!
# aacoa_c NOTHING DONE!
# ac_c NOTHING DONE!
# coa_c NOTHING DONE!
# acald_c NOTHING DONE!
# adocbip_c NOTHING DONE!
# gtp_c NOTHING DONE!
# agdpcbi_c NOTHING DONE!
# co2tot_c NOTHING DONE!
# adp_c NOTHING DONE!
# malcoa_c NOTHING DONE!
# ppa_c NOTHING DONE!
# ppcoa_c NOTHING DONE!
# uacgam_c NOTHING DONE!
# udcpp_c NOTHING DONE!
# ump_c NOTHING DONE!
# unaga_c NOTHING DONE!
# acglu_c NOTHING DONE!
# acg5p_c NOTHING DONE!
# 2obut_c NOTHING DONE!
# pyr_c NOTHING DONE!
# 2ahbut_c NOTHING DONE!
# actp_c NOTHING DONE!
# alac-S_c NOTHING DONE!
# uacmamu_c NOTHING DONE!
# udp_c NOTHING DONE!
# acnam_c NOTHING DONE!
# acmana_c NOTHING DONE!
# acACP_c NOTHING DONE!
# acorn_c NOTHING DONE!
# orn_c NOTHING DONE!
# acon-T_c NOTHING DONE!
# amet_c NOTHING DONE!
# aconm_c NOTHING DONE!
# ahcys_c NOTHING DONE!
# cit_c NOTHING DONE!
# icit_c NOTHING DONE!
# acg5sa_c NOTHING DONE!
# apoACP_c NOTHING DONE!
# pap_c NOTHING DONE!
# adn_c NOTHING DONE!
# ins_c NOTHING DONE!
# nh3_c NOTHING DONE!
# 4adcho_c NOTHING DONE!
# 4abz_c NOTHING DONE!
# chor_c NOTHING DONE!
# gln-L_c NOTHING DONE!
# ade_c NOTHING DONE!
# hxan_c NOTHING DONE!
# etoh_c NOTHING DONE!
# gdp_c NOTHING DONE!
# itp_c NOTHING DONE!
# idp_c NOTHING DONE!
# ametam_c NOTHING DONE!
# camp_c NOTHING DONE!
# adocbi_c NOTHING DONE!
# rdmbzi_c NOTHING DONE!
# adocbl_c NOTHING DONE!
# gmp_c NOTHING DONE!
# prpp_c NOTHING DONE!
# aps_c NOTHING DONE!
# paps_c NOTHING DONE!
# dcamp_c NOTHING DONE!
# fum_c NOTHING DONE!
# 25aics_c NOTHING DONE!
# aicar_c NOTHING DONE!
# asp-L_c NOTHING DONE!
# imp_c NOTHING DONE!
# acgam6p_c NOTHING DONE!
# gam6p_c NOTHING DONE!
# adphep-DD_c NOTHING DONE!
# adphep-LD_c NOTHING DONE!
# agm_c NOTHING DONE!
# ptrc_c NOTHING DONE!
# urea_c NOTHING DONE!
# hcys-L_c NOTHING DONE!
# rhcys_c NOTHING DONE!
# 10fthf_c NOTHING DONE!
# fprica_c NOTHING DONE!
# thf_c NOTHING DONE!
# air_c NOTHING DONE!
# 5caiz_c NOTHING DONE!
# 5aizc_c NOTHING DONE!
# ala-D_c NOTHING DONE!
# alaala_c NOTHING DONE!
# ala-L_c NOTHING DONE!
# pydx5p_c NOTHING DONE!
# pyam5p_c NOTHING DONE!
# glyald_c NOTHING DONE!
# glyc_c NOTHING DONE!
# pacald_c NOTHING DONE!
# pac_c NOTHING DONE!
# alltt_c NOTHING DONE!
# urdglyc_c NOTHING DONE!
# alltn_c NOTHING DONE!
# altrn_c NOTHING DONE!
# 2ddglcn_c NOTHING DONE!
# malt_c NOTHING DONE!
# malttr_c NOTHING DONE!
# glc-D_c NOTHING DONE!
# maltttr_c NOTHING DONE!
# maltpt_c NOTHING DONE!
# malthx_c NOTHING DONE!
# malthp_c NOTHING DONE!
# acmanap_c NOTHING DONE!
# 8aonn_c NOTHING DONE!
# amob_c NOTHING DONE!
# dann_c NOTHING DONE!
# 2dmmq8_c NOTHING DONE!
# mqn8_c NOTHING DONE!
# 4ampm_c NOTHING DONE!
# for_c NOTHING DONE!
# r5p_c NOTHING DONE!
# anth_c NOTHING DONE!
# pran_c NOTHING DONE!
# pmcoa_c NOTHING DONE!
# ap4a_c NOTHING DONE!
# ap5a_c NOTHING DONE!
# 5apru_c NOTHING DONE!
# 5aprbu_c NOTHING DONE!
# arab-L_c NOTHING DONE!
# rbl-L_c NOTHING DONE!
# arg-L_c NOTHING DONE!
# argsuc_c NOTHING DONE!
# citr-L_c NOTHING DONE!
# aspsa_c NOTHING DONE!
# 4pasp_c NOTHING DONE!
# asn-L_c NOTHING DONE!
# ala-B_c NOTHING DONE!
# cbp_c NOTHING DONE!
# cbasp_c NOTHING DONE!
# q8_c NOTHING DONE!
# iasp_c NOTHING DONE!
# q8h2_c NOTHING DONE!
# mql8_c NOTHING DONE!
# succ_c NOTHING DONE!
# h2o2_c NOTHING DONE!
# oaa_c NOTHING DONE!
# succoa_c NOTHING DONE!
# sucarg_c NOTHING DONE!
# prbatp_c NOTHING DONE!
# betald_c NOTHING DONE!
# glyb_c NOTHING DONE!
# btnso_c NOTHING DONE!
# btn_c NOTHING DONE!
# cys-L_c NOTHING DONE!
# dtbt_c NOTHING DONE!
# but_c NOTHING DONE!
# btcoa_c NOTHING DONE!
# actACP_c NOTHING DONE!
# malACP_c NOTHING DONE!
# ddcaACP_c NOTHING DONE!
# cbi_c NOTHING DONE!
# cbl1_c NOTHING DONE!
# cdpdag1_c NOTHING DONE!
# cmp_c NOTHING DONE!
# paEC_c NOTHING DONE!
# 4c2me_c NOTHING DONE!
# 2p4c2me_c NOTHING DONE!
# pphn_c NOTHING DONE!
# 3psme_c NOTHING DONE!
# 4hbz_c NOTHING DONE!
# cinnm_c NOTHING DONE!
# cenchddd_c NOTHING DONE!
# pgEC_c NOTHING DONE!
# clpnEC_c NOTHING DONE!
# csn_c NOTHING DONE!
# cpppg3_c NOTHING DONE!
# pppg9_c NOTHING DONE!
# bbtcoa_c NOTHING DONE!
# crn_c NOTHING DONE!
# crncoa_c NOTHING DONE!
# gbbtn_c NOTHING DONE!
# ctbtcoa_c NOTHING DONE!
# ctbt_c NOTHING DONE!
# ura_c NOTHING DONE!
# utp_c NOTHING DONE!
# ctp_c NOTHING DONE!
# cyan_c NOTHING DONE!
# tsul_c NOTHING DONE!
# so3_c NOTHING DONE!
# tcynt_c NOTHING DONE!
# cynt_c NOTHING DONE!
# acser_c NOTHING DONE!
# h2s_c NOTHING DONE!
# cyst-L_c NOTHING DONE!
# cytd_c NOTHING DONE!
# uri_c NOTHING DONE!
# cdp_c NOTHING DONE!
# dcmp_c NOTHING DONE!
# dcdp_c NOTHING DONE!
# fad_c NOTHING DONE!
# fadh2_c NOTHING DONE!
# dad-2_c NOTHING DONE!
# din_c NOTHING DONE!
# damp_c NOTHING DONE!
# dadp_c NOTHING DONE!
# 12dgrEC_c NOTHING DONE!
# 26dap-M_c NOTHING DONE!
# lys-L_c NOTHING DONE!
# 26dap-LL_c NOTHING DONE!
# db4p_c NOTHING DONE!
# dctp_c NOTHING DONE!
# dutp_c NOTHING DONE!
# dcyt_c NOTHING DONE!
# duri_c NOTHING DONE!
# 2dh3dgal_c NOTHING DONE!
# 2dh3dgal6p_c NOTHING DONE!
# 2ddg6p_c NOTHING DONE!
# e4p_c NOTHING DONE!
# pep_c NOTHING DONE!
# 2dda7p_c NOTHING DONE!
# g3p_c NOTHING DONE!
# dgmp_c NOTHING DONE!
# dgdp_c NOTHING DONE!
# 23dhmb_c NOTHING DONE!
# 3mob_c NOTHING DONE!
# 23dhmp_c NOTHING DONE!
# 3mop_c NOTHING DONE!
# dha_c NOTHING DONE!
# dhap_c NOTHING DONE!
# 23ddhb_c NOTHING DONE!
# 23dhb_c NOTHING DONE!
# 23dhba_c NOTHING DONE!
# hkntd_c NOTHING DONE!
# 23dhdp_c NOTHING DONE!
# thdp_c NOTHING DONE!
# dhf_c NOTHING DONE!
# dhpt_c NOTHING DONE!
# dhna_c NOTHING DONE!
# octdp_c NOTHING DONE!
# dhnpt_c NOTHING DONE!
# 6hmhpt_c NOTHING DONE!
# gcald_c NOTHING DONE!
# dhor-S_c NOTHING DONE!
# orot_c NOTHING DONE!
# cechddd_c NOTHING DONE!
# 25drapp_c NOTHING DONE!
# 6hmhptpp_c NOTHING DONE!
# dhptd_c NOTHING DONE!
# hmfurn_c NOTHING DONE!
# 3dhq_c NOTHING DONE!
# 3dhsk_c NOTHING DONE!
# 25dkglcn_c NOTHING DONE!
# dkmpp_c NOTHING DONE!
# 2kmb_c NOTHING DONE!
# dmpp_c NOTHING DONE!
# ipdp_c NOTHING DONE!
# grdp_c NOTHING DONE!
# h2mb4p_c NOTHING DONE!
# 2omhmbl_c NOTHING DONE!
# dmso_c NOTHING DONE!
# dms_c NOTHING DONE!
# 2dmmql8_c NOTHING DONE!
# dhpmp_c NOTHING DONE!
# ahdt_c NOTHING DONE!
# 23doguln_c NOTHING DONE!
# 3dhguln_c NOTHING DONE!
# dpcoa_c NOTHING DONE!
# 2dhp_c NOTHING DONE!
# pant-R_c NOTHING DONE!
# 2dr5p_c NOTHING DONE!
# dtmp_c NOTHING DONE!
# dump_c NOTHING DONE!
# 2dr1p_c NOTHING DONE!
# dxyl5p_c NOTHING DONE!
# 2me4p_c NOTHING DONE!
# dxyl_c NOTHING DONE!
# 4per_c NOTHING DONE!
# ecaEC_c NOTHING DONE!
# udcpdp_c NOTHING DONE!
# 6pgc_c NOTHING DONE!
# kdo2lipid4_c NOTHING DONE!
# kdo2lipid4L_c NOTHING DONE!
# lipa_c NOTHING DONE!
# kdo2lipid4p_c NOTHING DONE!
# lipa_cold_c NOTHING DONE!
# 2pg_c NOTHING DONE!
# seramp_c NOTHING DONE!
# enter_c NOTHING DONE!
# etha_c NOTHING DONE!
# f6p_c NOTHING DONE!
# ocdca_c NOTHING DONE!
# fdp_c NOTHING DONE!
# fuc-L_c NOTHING DONE!
# fcl-L_c NOTHING DONE!
# fc1p_c NOTHING DONE!
# lald-L_c NOTHING DONE!
# fe2_c NOTHING DONE!
# ppp9_c NOTHING DONE!
# pheme_c NOTHING DONE!
# suc6p_c NOTHING DONE!
# fru_c NOTHING DONE!
# h2_c NOTHING DONE!
# fmn_c NOTHING DONE!
# f1p_c NOTHING DONE!
# mal-L_c NOTHING DONE!
# gam1p_c NOTHING DONE!
# acgam1p_c NOTHING DONE!
# g1p_c NOTHING DONE!
# dttp_c NOTHING DONE!
# dtdpglu_c NOTHING DONE!
# glu1sa_c NOTHING DONE!
# 5aop_c NOTHING DONE!
# glyc3p_c NOTHING DONE!
# glu5sa_c NOTHING DONE!
# 1pyr5c_c NOTHING DONE!
# glu5p_c NOTHING DONE!
# 6pgl_c NOTHING DONE!
# galct-D_c NOTHING DONE!
# 5dh4dglc_c NOTHING DONE!
# galctn-D_c NOTHING DONE!
# gal_c NOTHING DONE!
# gal1p_c NOTHING DONE!
# melib_c NOTHING DONE!
# udpg_c NOTHING DONE!
# 13dpg_c NOTHING DONE!
# gar_c NOTHING DONE!
# fgam_c NOTHING DONE!
# glyclt_c NOTHING DONE!
# gdpddman_c NOTHING DONE!
# gdpofuc_c NOTHING DONE!
# ser-L_c NOTHING DONE!
# gly_c NOTHING DONE!
# mlthf_c NOTHING DONE!
# glycogen_c NOTHING DONE!
# 2h3oppan_c NOTHING DONE!
# glcr_c NOTHING DONE!
# adpglc_c NOTHING DONE!
# galt1p_c NOTHING DONE!
# tag6p-D_c NOTHING DONE!
# glucys_c NOTHING DONE!
# pram_c NOTHING DONE!
# glu-D_c NOTHING DONE!
# glutrna_c NOTHING DONE!
# trnaglu_c NOTHING DONE!
# glx_c NOTHING DONE!
# 2aobut_c NOTHING DONE!
# glyc-R_c NOTHING DONE!
# 3pg_c NOTHING DONE!
# lgt-S_c NOTHING DONE!
# gthrd_c NOTHING DONE!
# lac-D_c NOTHING DONE!
# gdpmann_c NOTHING DONE!
# gmhep1p_c NOTHING DONE!
# gmhep7p_c NOTHING DONE!
# gmhep17bp_c NOTHING DONE!
# xmp_c NOTHING DONE!
# gdpfuc_c NOTHING DONE!
# gp4g_c NOTHING DONE!
# g3pc_c NOTHING DONE!
# chol_c NOTHING DONE!
# g3pe_c NOTHING DONE!
# g3ps_c NOTHING DONE!
# g3pg_c NOTHING DONE!
# g3pi_c NOTHING DONE!
# inost_c NOTHING DONE!
# frdp_c NOTHING DONE!
# gsn_c NOTHING DONE!
# gtspmd_c NOTHING DONE!
# spmd_c NOTHING DONE!
# gthox_c NOTHING DONE!
# gua_c NOTHING DONE!
# xan_c NOTHING DONE!
# glcur_c NOTHING DONE!
# fruur_c NOTHING DONE!
# galur_c NOTHING DONE!
# tagur_c NOTHING DONE!
# 3ophb_c NOTHING DONE!
# hemeO_c NOTHING DONE!
# 4mhetz_c NOTHING DONE!
# 4mpetz_c NOTHING DONE!
# histd_c NOTHING DONE!
# his-L_c NOTHING DONE!
# hisp_c NOTHING DONE!
# hkndd_c NOTHING DONE!
# op4en_c NOTHING DONE!
# ppbng_c NOTHING DONE!
# hmbil_c NOTHING DONE!
# 4ahmmp_c NOTHING DONE!
# 4h2opntn_c NOTHING DONE!
# hpyr_c NOTHING DONE!
# hom-L_c NOTHING DONE!
# phom_c NOTHING DONE!
# suchms_c NOTHING DONE!
# imacp_c NOTHING DONE!
# pydam_c NOTHING DONE!
# ichor_c NOTHING DONE!
# prlp_c NOTHING DONE!
# eig3p_c NOTHING DONE!
# 2cpr5p_c NOTHING DONE!
# 3ig3p_c NOTHING DONE!
# ile-L_c NOTHING DONE!
# 3c2hmp_c NOTHING DONE!
# 3c4mop_c NOTHING DONE!
# 2ippm_c NOTHING DONE!
# 3c3hmp_c NOTHING DONE!
# 3hmrsACP_c NOTHING DONE!
# kdo_c NOTHING DONE!
# ckdo_c NOTHING DONE!
# kdo8p_c NOTHING DONE!
# 3dhgulnp_c NOTHING DONE!
# xu5p-L_c NOTHING DONE!
# lcts_c NOTHING DONE!
# lac-L_c NOTHING DONE!
# 12ppd-S_c NOTHING DONE!
# 4mop_c NOTHING DONE!
# leu-L_c NOTHING DONE!
# mthgxl_c NOTHING DONE!
# lipidX_c NOTHING DONE!
# u23ga_c NOTHING DONE!
# lipidAds_c NOTHING DONE!
# agpgEC_c NOTHING DONE!
# agpeEC_c NOTHING DONE!
# agpcEC_c NOTHING DONE!
# apgEC_c NOTHING DONE!
# cdpea_c NOTHING DONE!
# lpsEC_c NOTHING DONE!
# 15dap_c NOTHING DONE!
# mnl1p_c NOTHING DONE!
# man1p_c NOTHING DONE!
# man6p_c NOTHING DONE!
# mana_c NOTHING DONE!
# 2mcit_c NOTHING DONE!
# 2mcacn_c NOTHING DONE!
# micit_c NOTHING DONE!
# 5mdru1p_c NOTHING DONE!
# 2mecdp_c NOTHING DONE!
# met-L_c NOTHING DONE!
# 5mthf_c NOTHING DONE!
# mi1p-D_c NOTHING DONE!
# mmcoa-S_c NOTHING DONE!
# mmcoa-R_c NOTHING DONE!
# lipidA_c NOTHING DONE!
# kdolipid4_c NOTHING DONE!
# 5mta_c NOTHING DONE!
# 5mtr_c NOTHING DONE!
# methf_c NOTHING DONE!
# 5mdr1p_c NOTHING DONE!
# nmn_c NOTHING DONE!
# h2o_e NOTHING DONE!
# nad_e NOTHING DONE!
# amp_e NOTHING DONE!
# nmn_e NOTHING DONE!
# dnad_c NOTHING DONE!
# nac_c NOTHING DONE!
# nicrnt_c NOTHING DONE!
# dgtp_c NOTHING DONE!
# dudp_c NOTHING DONE!
# datp_c NOTHING DONE!
# ncam_c NOTHING DONE!
# dmbzid_c NOTHING DONE!
# 5prdmbz_c NOTHING DONE!
# quln_c NOTHING DONE!
# sbzcoa_c NOTHING DONE!
# xtsn_c NOTHING DONE!
# thymd_c NOTHING DONE!
# dgsn_c NOTHING DONE!
# pppi_c NOTHING DONE!
# no2_c NOTHING DONE!
# ohpb_c NOTHING DONE!
# 2ohph_c NOTHING DONE!
# 2omph_c NOTHING DONE!
# 2ombzl_c NOTHING DONE!
# 2ommbl_c NOTHING DONE!
# orot5p_c NOTHING DONE!
# 2oph_c NOTHING DONE!
# thmpp_c NOTHING DONE!
# ssaltpp_c NOTHING DONE!
# pro-L_c NOTHING DONE!
# phaccoa_c NOTHING DONE!
# pnto-R_c NOTHING DONE!
# ugmda_c NOTHING DONE!
# uagmda_c NOTHING DONE!
# trdrd_c NOTHING DONE!
# trdox_c NOTHING DONE!
# pdx5p_c NOTHING DONE!
# pydxn_c NOTHING DONE!
# peamn_c NOTHING DONE!
# peEC_c NOTHING DONE!
# tagdp-D_c NOTHING DONE!
# 3php_c NOTHING DONE!
# 2pglyc_c NOTHING DONE!
# pgpEC_c NOTHING DONE!
# phe-L_c NOTHING DONE!
# phpyr_c NOTHING DONE!
# pcEC_c NOTHING DONE!
# 4r5au_c NOTHING DONE!
# 2mahmp_c NOTHING DONE!
# 4ppan_c NOTHING DONE!
# ppap_c NOTHING DONE!
# 4ppcys_c NOTHING DONE!
# pan4p_c NOTHING DONE!
# r1p_c NOTHING DONE!
# 34hpp_c NOTHING DONE!
# pppn_c NOTHING DONE!
# uaagmda_c NOTHING DONE!
# peptidoEC_c NOTHING DONE!
# fpram_c NOTHING DONE!
# prbamp_c NOTHING DONE!
# prfp_c NOTHING DONE!
# skm5p_c NOTHING DONE!
# psEC_c NOTHING DONE!
# pser-L_c NOTHING DONE!
# pydx_c NOTHING DONE!
# ribflv_c NOTHING DONE!
# dmlz_c NOTHING DONE!
# rib-D_c NOTHING DONE!
# ru5p-L_c NOTHING DONE!
# xu5p-D_c NOTHING DONE!
# rmn_c NOTHING DONE!
# rml_c NOTHING DONE!
# rml1p_c NOTHING DONE!
# s7p_c NOTHING DONE!
# sucorn_c NOTHING DONE!
# so4_c NOTHING DONE!
# sbt6p_c NOTHING DONE!
# sl26da_c NOTHING DONE!
# sl2a6o_c NOTHING DONE!
# seln_c NOTHING DONE!
# selnp_c NOTHING DONE!
# ser-D_c NOTHING DONE!
# sucglu_c NOTHING DONE!
# sucgsa_c NOTHING DONE!
# 2shchc_c NOTHING DONE!
# scl_c NOTHING DONE!
# srch_c NOTHING DONE!
# sheme_c NOTHING DONE!
# skm_c NOTHING DONE!
# N1aspmd_c NOTHING DONE!
# n8aspmd_c NOTHING DONE!
# o2s_c NOTHING DONE!
# sucbz_c NOTHING DONE!
# tartr-L_c NOTHING DONE!
# taur_c NOTHING DONE!
# aacald_c NOTHING DONE!
# dtdp4addg_c NOTHING DONE!
# dtdp4d6dg_c NOTHING DONE!
# dtdp4d6dm_c NOTHING DONE!
# dtdprmn_c NOTHING DONE!
# thr-L_c NOTHING DONE!
# tyr-L_c NOTHING DONE!
# 4hba_c NOTHING DONE!
# tmao_c NOTHING DONE!
# tma_c NOTHING DONE!
# thym_c NOTHING DONE!
# thm_c NOTHING DONE!
# thmmp_c NOTHING DONE!
# tre6p_c NOTHING DONE!
# tre_c NOTHING DONE!
# tre_e NOTHING DONE!
# glc-D_e NOTHING DONE!
# trp-L_c NOTHING DONE!
# indole_c NOTHING DONE!
# u3hga_c NOTHING DONE!
# uamag_c NOTHING DONE!
# ugmd_c NOTHING DONE!
# uacmam_c NOTHING DONE!
# u3aga_c NOTHING DONE!
# uaccg_c NOTHING DONE!
# uama_c NOTHING DONE!
# uamr_c NOTHING DONE!
# udpgal_c NOTHING DONE!
# udpgalfur_c NOTHING DONE!
# udpglcur_c NOTHING DONE!
# uppg3_c NOTHING DONE!
# val-L_c NOTHING DONE!
# xyl-D_c NOTHING DONE!
# xylu-D_c NOTHING DONE!
# 12ppd-S_e NOTHING DONE!
# 15dap_e NOTHING DONE!
# 26dap-M_e NOTHING DONE!
# 2ddglcn_e NOTHING DONE!
# 3hcinnm_e NOTHING DONE!
# 3hpppn_e NOTHING DONE!
# 4abut_e NOTHING DONE!
# ac_e NOTHING DONE!
# acac_e NOTHING DONE!
# acald_e NOTHING DONE!
# acgam_e NOTHING DONE!
# acmana_e NOTHING DONE!
# acnam_e NOTHING DONE!
# ade_e NOTHING DONE!
# adn_e NOTHING DONE!
# akg_e NOTHING DONE!
# ala-D_e NOTHING DONE!
# ala-L_e NOTHING DONE!
# alltn_e NOTHING DONE!
# arab-L_e NOTHING DONE!
# arg-L_e NOTHING DONE!
# asn-L_e NOTHING DONE!
# asp-L_e NOTHING DONE!
# but_e NOTHING DONE!
# charge_e NOTHING DONE!
# cbl1_e NOTHING DONE!
# chol_e NOTHING DONE!
# cit_e NOTHING DONE!
# co2tot_e NOTHING DONE!
# crn_e NOTHING DONE!
# csn_e NOTHING DONE!
# cynt_e NOTHING DONE!
# cys-L_e NOTHING DONE!
# cytd_e NOTHING DONE!
# dad-2_e NOTHING DONE!
# dcyt_e NOTHING DONE!
# dgsn_e NOTHING DONE!
# dha_e NOTHING DONE!
# din_e NOTHING DONE!
# dms_e NOTHING DONE!
# dmso_e NOTHING DONE!
# duri_e NOTHING DONE!
# etoh_e NOTHING DONE!
# fe2_e NOTHING DONE!
# for_e NOTHING DONE!
# fru_e NOTHING DONE!
# fuc1p-L_e NOTHING DONE!
# fuc-L_e NOTHING DONE!
# fum_e NOTHING DONE!
# g6p_e NOTHING DONE!
# gal_e NOTHING DONE!
# galct-D_e NOTHING DONE!
# galctn-D_e NOTHING DONE!
# galt_e NOTHING DONE!
# galur_e NOTHING DONE!
# gam_e NOTHING DONE!
# gbbtn_e NOTHING DONE!
# glcn_e NOTHING DONE!
# glcr_e NOTHING DONE!
# glcur_e NOTHING DONE!
# gln-L_e NOTHING DONE!
# glu-L_e NOTHING DONE!
# gly_e NOTHING DONE!
# glyald_e NOTHING DONE!
# glyb_e NOTHING DONE!
# glyc_e NOTHING DONE!
# glyc3p_e NOTHING DONE!
# glyclt_e NOTHING DONE!
# gsn_e NOTHING DONE!
# gua_e NOTHING DONE!
# h_e NOTHING DONE!
# hdca_e NOTHING DONE!
# his-L_e NOTHING DONE!
# hxan_e NOTHING DONE!
# idon-L_e NOTHING DONE!
# ile-L_e NOTHING DONE!
# indole_e NOTHING DONE!
# ins_e NOTHING DONE!
# k_e NOTHING DONE!
# lac-D_e NOTHING DONE!
# lac-L_e NOTHING DONE!
# lcts_e NOTHING DONE!
# leu-L_e NOTHING DONE!
# lys-L_e NOTHING DONE!
# mal-L_e NOTHING DONE!
# malt_e NOTHING DONE!
# malthx_e NOTHING DONE!
# maltpt_e NOTHING DONE!
# malttr_e NOTHING DONE!
# maltttr_e NOTHING DONE!
# man_e NOTHING DONE!
# man6p_e NOTHING DONE!
# melib_e NOTHING DONE!
# met-D_e NOTHING DONE!
# met-L_e NOTHING DONE!
# mnl_e NOTHING DONE!
# na1_e NOTHING DONE!
# nac_e NOTHING DONE!
# nh3_e NOTHING DONE!
# no2_e NOTHING DONE!
# no3_e NOTHING DONE!
# o2_e NOTHING DONE!
# ocdca_e NOTHING DONE!
# orn_e NOTHING DONE!
# phe-L_e NOTHING DONE!
# pi_e NOTHING DONE!
# pnto-R_e NOTHING DONE!
# pppn_e NOTHING DONE!
# pro-L_e NOTHING DONE!
# ptrc_e NOTHING DONE!
# pyr_e NOTHING DONE!
# rib-D_e NOTHING DONE!
# rmn_e NOTHING DONE!
# sbt-D_e NOTHING DONE!
# ser-D_e NOTHING DONE!
# ser-L_e NOTHING DONE!
# so4_e NOTHING DONE!
# spmd_e NOTHING DONE!
# succ_e NOTHING DONE!
# sucr_e NOTHING DONE!
# tartr-L_e NOTHING DONE!
# taur_e NOTHING DONE!
# thm_e NOTHING DONE!
# thr-L_e NOTHING DONE!
# thymd_e NOTHING DONE!
# tma_e NOTHING DONE!
# tmao_e NOTHING DONE!
# trp-L_e NOTHING DONE!
# tsul_e NOTHING DONE!
# ttdca_e NOTHING DONE!
# tyr-L_e NOTHING DONE!
# ura_e NOTHING DONE!
# urea_e NOTHING DONE!
# uri_e NOTHING DONE!
# val-L_e NOTHING DONE!
# xan_e NOTHING DONE!
# xtsn_e NOTHING DONE!
# xyl-D_e NOTHING DONE!
# h_c NOTHING DONE!
# acgam_c NOTHING DONE!
# charge_c NOTHING DONE!
# electron_c NOTHING DONE!
# electron_e NOTHING DONE!
# fuc1p-L_c NOTHING DONE!
# galt_c NOTHING DONE!
# gam_c NOTHING DONE!
# na1_c NOTHING DONE!
# h2_e NOTHING DONE!
# k_c NOTHING DONE!
# malt6p_c NOTHING DONE!
# man_c NOTHING DONE!
# met-D_c NOTHING DONE!
# mnl_c NOTHING DONE!
# no3_c NOTHING DONE!
# sbt-D_c NOTHING DONE!
# sucr_c NOTHING DONE!
# *** Editing special metabolites ***
# *** Removing electrons from the model ***
# Initializing component contribution object...
# cxcalc is not installed, operating in read-only mode. A local cache may be loaded, but no compounds can be created. Install cxcalc and obtain a ChemAxon license to enable compound creation.
# Loading compounds from ecoli_compound.sqlite
# added reaction:  biomass_ce: biomass_c <=> biomass_e
# added reaction:  biomass_EX: biomass_e <=>
# ['Parameters', 'Exchange reactions', 'Reactions', 'Biomass Composition', 'Transmembrane reactions', 'Metabolites', 'references', 'Transmembrane_reactions_reed', 'Transmembrane reactions_Orth', 'Transmembrane reactions old', 'Sheet3', 'log', 'subsystems']
# biomass : 0.05 5mthf_c + 5e-05 accoa_c + 0.488 ala-L_c + 0.001 amp_c + 0.281 arg-L_c + 0.2
# biomass_ce : biomass_c <=> biomass_e
# ...
# Metabolite phpyr_c - Old: 0.0001 millimolar, 1.8545957687244532 millimolar | New: (<Quantity(9.999995198280276e-05, 'millimolar')>, <Quantity(1.8545957687244503, 'millimolar')>)
# Metabolite 4r5au_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite 4ppan_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite ppap_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(0.9999999999999986, 'millimolar')>)
# Metabolite 4ppcys_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite pan4p_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite r1p_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite 34hpp_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite uaagmda_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite peptidoEC_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999994e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite fpram_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite prbamp_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999994e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite prfp_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite skm5p_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite psEC_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite pser-L_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite pydx_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite ribflv_c - Old: 0.015311375157527536 millimolar, 0.08292651771636537 millimolar | New: (<Quantity(0.01531137515752744, 'millimolar')>, <Quantity(0.08292651771636533, 'millimolar')>)
# Metabolite dmlz_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite xu5p-D_c - Old: 0.06952858012315177 millimolar, 2.689745217472421 millimolar | New: (<Quantity(0.06952858012315197, 'millimolar')>, <Quantity(2.6897452174724177, 'millimolar')>)
# Metabolite s7p_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite sucorn_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite so4_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite sl26da_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite sl2a6o_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite sucglu_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite sucgsa_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999958e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite skm_c - Old: 0.008454942331367852 millimolar, 0.09753266809218342 millimolar | New: (<Quantity(0.008454942331367878, 'millimolar')>, <Quantity(0.09753266809218362, 'millimolar')>)
# Metabolite thr-L_c - Old: 0.0001 millimolar, 0.7303075187909025 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(0.7303075187909025, 'millimolar')>)
# Metabolite tyr-L_c - Old: 0.0001 millimolar, 1.1211992920426703 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.1211992920426717, 'millimolar')>)
# Metabolite tmao_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999994e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite tma_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999994e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite tre6p_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite tre_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite tre_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite glc-D_e - Old: 26.7 millimolar, 27.8 millimolar | New: (<Quantity(26.70000000000005, 'millimolar')>, <Quantity(27.799999999999873, 'millimolar')>)
# Metabolite trp-L_c - Old: 0.0001 millimolar, 0.06728716860537388 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(0.06728716860537372, 'millimolar')>)
# Metabolite indole_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(0.9999999999999986, 'millimolar')>)
# Metabolite u3hga_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite uamag_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite ugmd_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite u3aga_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite uaccg_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite uama_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite uamr_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite val-L_c - Old: 0.0001 millimolar, 17.990502292166138 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(17.99050229216606, 'millimolar')>)
# Metabolite xyl-D_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite 4abut_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(0.9999999999999986, 'millimolar')>)
# Metabolite ac_e - Old: 0.0279621976830838 molar, 0.0383950951832531 molar | New: (<Quantity(27.962197683083808, 'millimolar')>, <Quantity(38.39509518325312, 'millimolar')>)
# Metabolite ala-L_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(0.9999999999999986, 'millimolar')>)
# Metabolite arab-L_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(0.9999999999999986, 'millimolar')>)
# Metabolite arg-L_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite asn-L_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite asp-L_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite charge_e - Old: 0.1 micromolar, 10 millimolar | New: (<Quantity(1000.0000003603731, 'millimolar')>, <Quantity(1000.0000003603731, 'millimolar')>)
# Metabolite chol_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite co2tot_e - Old: 0.06 millimolar, 0.1 millimolar | New: (<Quantity(0.05999999999999985, 'millimolar')>, <Quantity(0.09999999999999991, 'millimolar')>)
# Metabolite dms_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999994e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite dmso_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999994e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite for_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(0.9999999999999986, 'millimolar')>)
# Metabolite fru_e - Old: 26.8 millimolar, 27.8 millimolar | New: (<Quantity(26.799999999999997, 'millimolar')>, <Quantity(27.799999999999994, 'millimolar')>)
# Metabolite fum_e - Old: 0.0001 millimolar, 0.15 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(0.14999999999999977, 'millimolar')>)
# Metabolite gal_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(0.9999999999999986, 'millimolar')>)
# Metabolite glcn_e - Old: 24.5 millimolar, 25.5 millimolar | New: (<Quantity(24.5, 'millimolar')>, <Quantity(25.500000000000004, 'millimolar')>)
# Metabolite glu-L_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite glyb_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(0.9999999999999986, 'millimolar')>)
# Metabolite glyc3p_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite h_e - Old: 0.00013676323053056464 millimolar, 0.00013676323053056464 millimolar | New: (<Quantity(1000.0000003603731, 'millimolar')>, <Quantity(1000.0000003603731, 'millimolar')>)
# Metabolite his-L_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite ile-L_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(0.9999999999999986, 'millimolar')>)
# Metabolite k_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999958e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite leu-L_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(0.9999999999999986, 'millimolar')>)
# Metabolite lys-L_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite na1_e - Old: 0.0001 millimolar, 93.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(93.00000000000006, 'millimolar')>)
# Metabolite nh3_e - Old: 21.8 millimolar, 22.7 millimolar | New: (<Quantity(21.799999999999997, 'millimolar')>, <Quantity(22.700000000000006, 'millimolar')>)
# Metabolite o2_e - Old: 0.1 millimolar, 0.3 millimolar | New: (<Quantity(0.12140938235312827, 'millimolar')>, <Quantity(0.3000000000000001, 'millimolar')>)
# Metabolite orn_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite pi_e - Old: 64.1 millimolar, 64.2 millimolar | New: (<Quantity(64.19999999999995, 'millimolar')>, <Quantity(64.19999999999995, 'millimolar')>)
# Metabolite pro-L_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(0.9999999999999986, 'millimolar')>)
# Metabolite ptrc_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999958e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite ser-L_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite so4_e - Old: 12.3 millimolar, 12.4 millimolar | New: (<Quantity(12.299999999999995, 'millimolar')>, <Quantity(12.400000000000004, 'millimolar')>)
# Metabolite succ_e - Old: 0.0001 millimolar, 42.4 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(42.4, 'millimolar')>)
# Metabolite thr-L_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010799165115752699, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite tma_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999994e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite tmao_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(9.999999999999994e-05, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite val-L_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite xyl-D_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite h_c - Old: 3.347513949028939e-05 millimolar, 3.347513949028939e-05 millimolar | New: (<Quantity(1000.0, 'millimolar')>, <Quantity(1000.0, 'millimolar')>)
# Metabolite charge_c - Old: 0.1 micromolar, 10 millimolar | New: (<Quantity(1000.0, 'millimolar')>, <Quantity(1000.0, 'millimolar')>)
# Metabolite na1_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite h2_e - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite k_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite no3_c - Old: 0.0001 millimolar, 1.0 millimolar | New: (<Quantity(0.00010000000000000029, 'millimolar')>, <Quantity(1.0000000000000002, 'millimolar')>)
# Metabolite biomass_c - Old: 0.1 micromolar, 10 millimolar | New: (<Quantity(1000.0000003603731, 'millimolar')>, <Quantity(1000.0000003603731, 'millimolar')>)
# Metabolite biomass_e - Old: 0.1 micromolar, 10 millimolar | New: (<Quantity(1000.0000003603731, 'millimolar')>, <Quantity(1000.0000003603731, 'millimolar')>)
# Metabolite orot_e - Old: 1e-07 molar, 7.687379884689302e-05 molar | New: (<Quantity(9.999998876608934e-05, 'millimolar')>, <Quantity(0.07687379884689322, 'millimolar')>)

# %%
tmodel_ace.m = None
tmodel_ace.objective = tmodel_ace.reactions.biomass_EX
tmodel_ace.add_TFBA_variables(qnorm='sep_norm')

add_rq_constraint(tmodel_ace, "WT-Ace_I", INPUT_EXP_DATA)
# Out:
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 10
# >>>>>> RQ: 0.98 (vCO2 = 15.7 / vO2 = -16.0) ERR: 0.32137831084665863

# %%
# Save flux bounds from before and after the TFVA for Ace condition for later use
completed_ids = save_flux_bounds_tfva(tmodel_ace, "results/ecoli_WT_Ace_fluxes_objval.txt", "results/bounds/ecoli_WT_Ace_bounds_after_tfva.csv")
#save_flux_bounds_before_tfva(tmodel_ace, completed_ids, "results/bounds/ecoli_WT_Ace_bounds_before_tfva.csv")

# %%
# Save complete flux bounds for the model
# Save the base bounds before any analysis
# Save bounds with normal FVA applied
# Save bounds with normal FVA applied + TFVA

save_flux_bounds_complete(tmodel_ace, "results/bounds/complete_ecoli_WT_Ace_before.csv")
fva_ace = flux_variability_analysis(tmodel_ace, None, processes=1)
apply_fva_bounds(tmodel_ace, fva_ace)

# Save the normal FVA bounds of the model
save_flux_bounds_complete(tmodel_ace, "results/bounds/complete_ecoli_WT_Ace_fva.csv")
apply_tfva_bounds(tmodel_ace, "results/bounds/ecoli_WT_Ace_bounds_after_tfva.csv")

# Save the TFVA bounds of the model
save_flux_bounds_complete(tmodel_ace, "results/bounds/complete_ecoli_WT_Ace_tfva.csv")
# Out:
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.013948168186352014, 0.013948168186352014 ---> 0.013948168186352014, 0.013948168186352014
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -10.0, 9.995501715759904 ---> -10.0, 9.995501715759904
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -14.000000000000002, 13.993702402063866 ---> -14.0, 13.993702402063866
# Before/after: -100.0, 99.95501715759903 ---> -100.0, 99.95501715759903
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 99.98605183181364 ---> -100.0, 99.98605183181364
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.09165939093888467, 0.09165939093888653 ---> 0.0916593909388856, 0.0916593909388856
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.2756619651570318, 0.2756619651570301 ---> 0.27566196515703095, 0.27566196515703095
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.016604962126621103, 0.016604962126606893 ---> 0.016604962126613998, 0.016604962126613998
# Before/after: 0.016604962126606893, 0.016604962126606893 ---> 0.016604962126606893, 0.016604962126606893
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.002324694697725336, 0.002324694697719565 ---> 0.0023246946977224505, 0.0023246946977224505
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.07739871736527254, 0.07739871736531381 ---> 0.07739871736529318, 0.07739871736529318
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.16342902614309196, 0.16342902614348986 ---> 0.1634290261432909, 0.1634290261432909
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.008368900911811208, 0.008368900911811208 ---> 0.008368900911811208, 0.008368900911811208
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.19331795797110282, 0.19331795797125914 ---> 0.19331795797118098, 0.19331795797118098
# Before/after: 0.16342902614320565, 0.16342902614336197 ---> 0.1634290261432838, 0.1634290261432838
# Before/after: -0.16342902614320565, -0.16342902614333354 ---> -0.1634290261432696, -0.1634290261432696
# Before/after: 0.009165939093888466, 0.009165939093888466 ---> 0.009165939093888466, 0.009165939093888466
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.017933359096738304, 0.017933359096738304 ---> 0.017933359096738304, 0.017933359096738304
# Before/after: 0.017933359096738304, 0.017933359096738304 ---> 0.017933359096738304, 0.017933359096738304
# Before/after: 3.3209924481525377e-06, 3.3209925049959566e-06 ---> 3.320992476574247e-06, 3.320992476574247e-06
# Before/after: -99.90668011284845, 100.0 ---> -99.90668011284845, 100.0
# Before/after: -99.90668011284845, 100.0 ---> -99.90668011284845, 100.0
# Before/after: -100.0, 99.83408321843092 ---> -100.0, 99.83408321843092
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 1.959385525651669e-05, 1.959385531336011e-05 ---> 1.95938552849384e-05, 1.95938552849384e-05
# Before/after: 0.14475719740066495, 0.24601054480103812 ---> 0.14475719740066495, 0.24601054480103812
# Before/after: -99.83408321843092, 100.0 ---> -99.83408321843092, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 99.90668011284845 ---> -100.0, 99.90668011284845
# Before/after: 3.15, 100.0 ---> 3.15, 100.0
# Before/after: 0.02988893182789717, 0.02988893182789717 ---> 0.02988893182789717, 0.02988893182789717
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.07739871736528592, 0.07739871736531381 ---> 0.07739871736529987, 0.07739871736529987
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.013948168186352014, 0.013948168186352014 ---> 0.013948168186352014, 0.013948168186352014
# Before/after: -99.99541105266671, 100.0 ---> -99.99541105266671, 100.0
# Before/after: 0.004498284240098904, 0.00449828424009624 ---> 0.004498284240097572, 0.004498284240097572
# Before/after: -99.9676123534713, 100.0 ---> -99.9676123534713, 100.0
# Before/after: 0.006297597936136157, 0.006297597936132604 ---> 0.00629759793613438, 0.00629759793613438
# Before/after: 0.044982842400983714, 0.04498284240095529 ---> 0.0449828424009695, 0.0449828424009695
# Before/after: -92.50169748991931, 100.0 ---> -92.50169748991931, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.10195446745738257, 0.10195446745738257 ---> 0.10195446745738257, 0.10195446745738257
# Before/after: 0.13649278868073667, 0.13649278868072656 ---> 0.1364927886807316, 0.1364927886807316
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.0021420401143326306, 0.0021420401143326306 ---> 0.0021420401143326306, 0.0021420401143326306
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -99.92260128263474, 100.0 ---> -99.92260128263474, 100.0
# Before/after: 0.04848648940969986, 0.04848648940969985 ---> 0.04848648940969985, 0.04848648940969985
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -99.99442073272546, 100.0 ---> -99.99442073272546, 100.0
# Before/after: 0.1082643530654942, 0.1082643530654942 ---> 0.1082643530654942, 0.1082643530654942
# Before/after: 0.11743029215938267, 0.11743029215938267 ---> 0.11743029215938267, 0.11743029215938267
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 6.641985009991913e-06, 6.641984782618238e-06 ---> 6.641984896305075e-06, 6.641984896305075e-06
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.13649278868073045, 0.13649278868074077 ---> 0.1364927886807356, 0.1364927886807356
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.2756619651569788, 0.2756619651569749 ---> 0.27566196515697683, 0.27566196515697683
# Before/after: 0.09165939093888467, 0.09165939093888653 ---> 0.0916593909388856, 0.0916593909388856
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.11743029215938267, 0.11743029215938267 ---> 0.11743029215938267, 0.11743029215938267
# Before/after: 0.11743029215938267, 0.11743029215938267 ---> 0.11743029215938267, 0.11743029215938267
# Before/after: 0.02480781341715499, 0.02480781341716176 ---> 0.024807813417158375, 0.024807813417158375
# Before/after: 0.016604962126606893, 0.016604962126613665 ---> 0.01660496212661028, 0.01660496212661028
# Before/after: 0.016604962126606893, 0.016604962126613665 ---> 0.01660496212661028, 0.01660496212661028
# Before/after: -99.8552428025993, 100.0 ---> -99.8552428025993, 100.0
# Before/after: -99.8552428025993, 100.0 ---> -99.8552428025993, 100.0
# Before/after: -0.246010544801057, -0.14475719740069215 ---> -0.246010544801057, -0.14475719740069215
# Before/after: 3.3209925049959566e-06, 3.320992391309119e-06 ---> 3.3209924481525377e-06, 3.3209924481525377e-06
# Before/after: 0.016604962126606893, 0.016604962126613665 ---> 0.01660496212661028, 0.01660496212661028
# Before/after: 0.13649278868072778, 0.13649278868074077 ---> 0.13649278868073428, 0.13649278868073428
# Before/after: 0.13649278868072778, 0.13649278868074077 ---> 0.13649278868073428, 0.13649278868073428
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -22.666046076124214, 27.93894682835951 ---> -22.666046076124214, 27.93894682835951
# Before/after: -27.936622133665978, 22.668370770826385 ---> -27.936622133665978, 22.668370770826385
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.016604962126609543, 0.016604962126613665 ---> 0.016604962126611604, 0.016604962126611604
# Before/after: 0.016604962126609543, 0.016604962126613665 ---> 0.016604962126611604, 0.016604962126611604
# Before/after: 1.959385531336011e-05, 1.959385525651669e-05 ---> 1.95938552849384e-05, 1.95938552849384e-05
# Before/after: 1.959385531336011e-05, 1.959385525651669e-05 ---> 1.95938552849384e-05, 1.95938552849384e-05
# Before/after: -100.0, 99.88932493853302 ---> -100.0, 99.88932493853302
# Before/after: -99.99179714870945, 100.0 ---> -99.99179714870945, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.002789633637270403, 0.002789633637270403 ---> 0.002789633637270403, 0.002789633637270403
# Before/after: 0.002789633637270403, 0.002789633637270403 ---> 0.002789633637270403, 0.002789633637270403
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 99.9614266729799 ---> -100.0, 99.9614266729799
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 99.9954110526667 ---> -100.0, 99.9954110526667
# Before/after: -100.0, 99.96761235347131 ---> -100.0, 99.96761235347131
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 3.320992391309119e-06, 3.320992391309119e-06 ---> 3.320992391309119e-06, 3.320992391309119e-06
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.023911145462317738, 0.023911145462317738 ---> 0.023911145462317738, 0.023911145462317738
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -99.93025915906824, 100.0 ---> -99.93025915906824, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 99.97608885453768 ---> -100.0, 99.97608885453768
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -99.99342443499786, 100.0 ---> -99.99342443499786, 100.0
# Before/after: -100.0, 99.30492990144896 ---> -100.0, 99.30492990144896
# Before/after: -99.83657097385701, 100.0 ---> -99.83657097385701, 100.0
# Before/after: -99.83657097385696, 100.0 ---> -99.83657097385696, 100.0
# Before/after: 0.016604962126606893, 0.016604962126610473 ---> 0.016604962126608683, 0.016604962126608683
# Before/after: -99.97608885453768, 100.0 ---> -99.97608885453768, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -25.05114328334996, 24.94885671665004 ---> -25.05114328334996, 24.94885671665004
# Before/after: -25.0, 25.0 ---> -25.0, 25.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.16342902614265617, 0.16342902614373142 ---> 0.1634290261431938, 0.1634290261431938
# Before/after: -0.009165939093888466, -0.009165939093888466 ---> -0.009165939093888466, -0.009165939093888466
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -99.99169751893669, 100.0 ---> -99.99169751893669, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -99.99169751893669, 100.0 ---> -99.99169751893669, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.008368900911811208, 0.008368900911811208 ---> 0.008368900911811208, 0.008368900911811208
# Before/after: 0.008368900911811208, 0.008368900911811208 ---> 0.008368900911811208, 0.008368900911811208
# Before/after: 0.008368900911811208, 0.008368900911811208 ---> 0.008368900911811208, 0.008368900911811208
# Before/after: -100.0, 99.90754024988654 ---> -100.0, 99.90754024988654
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -19.299408944051812, 20.942576936342938 ---> -19.299408944051812, 20.942576936342938
# Before/after: -100.0, 99.9614266729799 ---> -100.0, 99.9614266729799
# Before/after: -100.0, 99.98801121734459 ---> -100.0, 99.98801121734459
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.01660496212661046, 0.016604962126613665 ---> 0.016604962126612062, 0.016604962126612062
# Before/after: 3.3209925049959566e-06, 3.320992391309119e-06 ---> 3.3209924481525377e-06, 3.3209924481525377e-06
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.02988893182789717, 0.02988893182789809 ---> 0.029888931827897633, 0.029888931827897633
# Before/after: 0.02988893182789717, 0.02988893182789809 ---> 0.029888931827897633, 0.029888931827897633
# Before/after: 0.01660496212661046, 0.01660496212659268 ---> 0.01660496212660157, 0.01660496212660157
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -99.88256970784062, 99.9515135105903 ---> -99.88256970784062, 99.9515135105903
# Before/after: -100.0, 99.83408321843092 ---> -100.0, 99.83408321843092
# Before/after: 0.04848648940969985, 0.04848648940969986 ---> 0.04848648940969985, 0.04848648940969985
# Before/after: 0.02988893182789717, 0.02988893182789809 ---> 0.029888931827897633, 0.029888931827897633
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.02988893182789717, 0.02988893182789809 ---> 0.029888931827897633, 0.029888931827897633
# Before/after: 0.02988893182789717, 0.02988893182789809 ---> 0.029888931827897633, 0.029888931827897633
# Before/after: 0.01793335909674454, 0.01793335909674454 ---> 0.01793335909674454, 0.01793335909674454
# Before/after: -0.09165939093888467, -0.09165939093888653 ---> -0.0916593909388856, -0.0916593909388856
# Before/after: -0.19331795797101473, -0.1933179579708999 ---> -0.1933179579709573, -0.1933179579709573
# Before/after: -99.90754024988657, 100.0 ---> -99.90754024988657, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.14213847580377603, 0.14213847580377767 ---> 0.14213847580377686, 0.14213847580377686
# Before/after: -0.14213847580377603, -0.14213847580377767 ---> -0.14213847580377686, -0.14213847580377686
# Before/after: -0.14213847580377603, -0.14213847580377767 ---> -0.14213847580377686, -0.14213847580377686
# Before/after: 0.14213847580377603, 0.14213847580377767 ---> 0.14213847580377686, 0.14213847580377686
# Before/after: 0.27566196515708086, 0.27566196515698493 ---> 0.2756619651570329, 0.2756619651570329
# Before/after: 0.09165939093888467, 0.09165939093888653 ---> 0.0916593909388856, 0.0916593909388856
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.011158534549081611, 0.011158534549081611 ---> 0.011158534549081611, 0.011158534549081611
# Before/after: 0.013948168186352014, 0.013948168186352014 ---> 0.013948168186352014, 0.013948168186352014
# Before/after: 0.013948168186352014, 0.013948168186352014 ---> 0.013948168186352014, 0.013948168186352014
# Before/after: 0.013948168186352014, 0.013948168186352014 ---> 0.013948168186352014, 0.013948168186352014
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.14213847580377603, 0.14213847580377767 ---> 0.14213847580377686, 0.14213847580377686
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.002789633637270403, 0.002789633637270403 ---> 0.002789633637270403, 0.002789633637270403
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.002789633637270403, 0.002789633637270403 ---> 0.002789633637270403, 0.002789633637270403
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.002324694697719565, 0.002324694697719565 ---> 0.002324694697719565, 0.002324694697719565
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.002324694697719565, 0.002324694697719565 ---> 0.002324694697719565, 0.002324694697719565
# Before/after: 0.04848648940969986, 0.04848648940969985 ---> 0.04848648940969985, 0.04848648940969985
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.002789633637270403, 0.002789633637270403 ---> 0.002789633637270403, 0.002789633637270403
# Before/after: 0.002789633637270403, 0.002789633637270403 ---> 0.002789633637270403, 0.002789633637270403
# Before/after: 1.9593855327570964e-05, 1.9593855327570964e-05 ---> 1.9593855327570964e-05, 1.9593855327570964e-05
# Before/after: 0.002324694697719565, 0.002324694697719565 ---> 0.002324694697719565, 0.002324694697719565
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.0650914515363094, 0.0650914515363094 ---> 0.0650914515363094, 0.0650914515363094
# Before/after: 0.002324694697719565, 0.002324694697719565 ---> 0.002324694697719565, 0.002324694697719565
# Before/after: 0.002324694697719565, 0.002324694697719565 ---> 0.002324694697719565, 0.002324694697719565
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -99.99982398740141, 100.0 ---> -99.99982398740141, 100.0
# Before/after: -100.0, 99.99982398740167 ---> -100.0, 99.99982398740167
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -99.99179714870945, 100.0 ---> -99.99179714870945, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.0009066309321513747, 0.0009066309319383237 ---> 0.0009066309320448491, 0.0009066309320448491
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 99.99179714870945 ---> -100.0, 99.99179714870945
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 99.90834060906111 ---> -100.0, 99.90834060906111
# Before/after: -99.90668011284845, 100.0 ---> -99.90668011284845, 100.0
# Before/after: 0.14213847580377603, 0.14213847580377767 ---> 0.14213847580377686, 0.14213847580377686
# Before/after: 0.10464447132194721, 0.10464447132191879 ---> 0.104644471321933, 0.104644471321933
# Before/after: -99.98605183181365, 100.0 ---> -99.98605183181365, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -0.10464447132194721, -0.10464447132190458 ---> -0.10464447132192589, -0.10464447132192589
# Before/after: -100.0, 99.93025915906824 ---> -100.0, 99.93025915906824
# Before/after: -99.93025915906824, 100.0 ---> -99.93025915906824, 100.0
# Before/after: 1.95938552849384e-05, 1.959385531336011e-05 ---> 1.9593855299149254e-05, 1.9593855299149254e-05
# Before/after: -100.0, 99.99442073272546 ---> -100.0, 99.99442073272546
# Before/after: 0.009165939093888466, 0.009165939093888466 ---> 0.009165939093888466, 0.009165939093888466
# Before/after: 0.07739871736531381, 0.07739871736531381 ---> 0.07739871736531381, 0.07739871736531381
# Before/after: -99.95501715759903, 100.0 ---> -99.95501715759903, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.005579267274540806, 0.005579267274540806 ---> 0.005579267274540806, 0.005579267274540806
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -0.023911145462317738, -0.023911145462317738 ---> -0.023911145462317738, -0.023911145462317738
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -99.30492990144853, 100.0 ---> -99.30492990144853, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -99.98801121734462, 100.0 ---> -99.98801121734462, 100.0
# Before/after: -99.98801121734462, 100.0 ---> -99.98801121734462, 100.0
# Before/after: -0.05844946668566558, -0.05844946668566558 ---> -0.05844946668566558, -0.05844946668566558
# Before/after: -100.0, 99.98801121734458 ---> -100.0, 99.98801121734458
# Before/after: -100.0, 99.96142667297988 ---> -100.0, 99.96142667297988
# Before/after: 3.3209924197308283e-06, 3.320992433941683e-06 ---> 3.3209924268362556e-06, 3.3209924268362556e-06
# Before/after: 1.959385531336011e-05, 1.9593855327570964e-05 ---> 1.9593855320465536e-05, 1.9593855320465536e-05
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 1.959385531336011e-05, 1.959385531336011e-05 ---> 1.959385531336011e-05, 1.959385531336011e-05
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 99.88932493853295 ---> -100.0, 99.88932493853295
# Before/after: 1.9593855327570964e-05, 1.959385531336011e-05 ---> 1.9593855320465536e-05, 1.9593855320465536e-05
# Before/after: 0.043505000771717, 0.043505000771717 ---> 0.043505000771717, 0.043505000771717
# Before/after: 0.05844946668566558, 0.05844946668566558 ---> 0.05844946668566558, 0.05844946668566558
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.009165939093888466, 0.009165939093888466 ---> 0.009165939093888466, 0.009165939093888466
# Before/after: 0.16342902614348986, 0.1634290261432976 ---> 0.16342902614339372, 0.16342902614339372
# Before/after: 0.017933359096738304, 0.01793335909674454 ---> 0.017933359096741423, 0.017933359096741423
# Before/after: 0.16342902614348986, 0.1634290261432976 ---> 0.16342902614339372, 0.16342902614339372
# Before/after: 0.02988893182789717, 0.02988893182789809 ---> 0.029888931827897633, 0.029888931827897633
# Before/after: 0.16342902614348986, 0.1634290261432976 ---> 0.16342902614339372, 0.16342902614339372
# Before/after: 0.02988893182789717, 0.02988893182789809 ---> 0.029888931827897633, 0.029888931827897633
# Before/after: 0.16342902614348986, 0.1634290261432976 ---> 0.16342902614339372, 0.16342902614339372
# Before/after: 0.02988893182789717, 0.02988893182789809 ---> 0.029888931827897633, 0.029888931827897633
# Before/after: -100.0, 99.93025915906824 ---> -100.0, 99.93025915906824
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.13649278868072778, 0.13649278868073667 ---> 0.13649278868073222, 0.13649278868073222
# Before/after: -99.96229013101046, 99.9991365419694 ---> -99.96229013101046, 99.9991365419694
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -99.96142667297988, 100.0 ---> -99.96142667297988, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 1.959385531336011e-05, 1.9593855317023845e-05 ---> 1.9593855315191977e-05, 1.9593855315191977e-05
# Before/after: -100.0, 99.98605183181365 ---> -100.0, 99.98605183181365
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.0009066309321497101, 0.0009066309323770838 ---> 0.000906630932263397, 0.000906630932263397
# Before/after: 3.3209924197308283e-06, 3.3209924197308283e-06 ---> 3.3209924197308283e-06, 3.3209924197308283e-06
# Before/after: 6.6419848394616565e-06, 6.6419848394616565e-06 ---> 6.6419848394616565e-06, 6.6419848394616565e-06
# Before/after: 3.3209924197308283e-06, 3.3209924197308283e-06 ---> 3.3209924197308283e-06, 3.3209924197308283e-06
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 99.74361296417948 ---> -100.0, 99.74361296417948
# Before/after: 0.008368900911811208, 0.008368900911811208 ---> 0.008368900911811208, 0.008368900911811208
# Before/after: -100.0, 99.90668011284845 ---> -100.0, 99.90668011284845
# Before/after: 0.0773987173653552, 0.07739871736532677 ---> 0.07739871736534099, 0.07739871736534099
# Before/after: 0.11743029215938267, 0.11743029215938189 ---> 0.11743029215938228, 0.11743029215938228
# Before/after: -0.11743029215938267, -0.11743029215938189 ---> -0.11743029215938228, -0.11743029215938228
# Before/after: -99.92260128263469, 100.0 ---> -99.92260128263469, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 99.90668011284845 ---> -100.0, 99.90668011284845
# Before/after: -100.0, 99.90668011284845 ---> -100.0, 99.90668011284845
# Before/after: 0.13649278868072778, 0.13649278868072656 ---> 0.13649278868072717, 0.13649278868072717
# Before/after: 0.13649278868072778, 0.13649278868072656 ---> 0.13649278868072717, 0.13649278868072717
# Before/after: 0.04848648940969985, 0.04848648940969986 ---> 0.04848648940969985, 0.04848648940969985
# Before/after: -100.0, 99.90668011284845 ---> -100.0, 99.90668011284845
# Before/after: 0.002324694697719565, 0.002324694697719565 ---> 0.002324694697719565, 0.002324694697719565
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -0.07739871736531517, -0.07739871736531381 ---> -0.07739871736531449, -0.07739871736531449
# Before/after: -49.93593805611553, 50.06406194388447 ---> -49.93593805611553, 50.06406194388447
# Before/after: 0.002789633637270403, 0.002789633637270403 ---> 0.002789633637270403, 0.002789633637270403
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.11743029215938267, 0.11743029215938189 ---> 0.11743029215938228, 0.11743029215938228
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -99.90834060906111, 100.0 ---> -99.90834060906111, 100.0
# Before/after: -100.0, 99.83408321843092 ---> -100.0, 99.83408321843092
# Before/after: -49.92756915520372, 50.07243084479628 ---> -49.92756915520372, 50.07243084479628
# Before/after: -50.07243084479628, 49.92756915520372 ---> -50.07243084479628, 49.92756915520372
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.008202851290548097, 0.008202851290548097 ---> 0.008202851290548097, 0.008202851290548097
# Before/after: -99.30492990144933, 100.0 ---> -99.30492990144933, 100.0
# Before/after: -99.88932493853298, 100.0 ---> -99.88932493853298, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 99.99342443499786 ---> -100.0, 99.99342443499786
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 99.92260128263463 ---> -100.0, 99.92260128263463
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -99.98206664090327, 100.0 ---> -99.98206664090327, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -99.98206664090326, 100.0 ---> -99.98206664090326, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -0.043505000771717, -0.043505000771717 ---> -0.043505000771717, -0.043505000771717
# Before/after: 0.005579267274540806, 0.005579267274540806 ---> 0.005579267274540806, 0.005579267274540806
# Before/after: 0.009165939093888466, 0.009165939093888466 ---> 0.009165939093888466, 0.009165939093888466
# Before/after: 0.005579267274540806, 0.005579267274540806 ---> 0.005579267274540806, 0.005579267274540806
# Before/after: 0.009165939093888466, 0.009165939093888466 ---> 0.009165939093888466, 0.009165939093888466
# Before/after: 0.023911145462317738, 0.023911145462317738 ---> 0.023911145462317738, 0.023911145462317738
# Before/after: 0.009165939093888466, 0.009165939093888466 ---> 0.009165939093888466, 0.009165939093888466
# Before/after: 0.009165939093888466, 0.009165939093888466 ---> 0.009165939093888466, 0.009165939093888466
# Before/after: 0.009165939093888466, 0.009165939093888466 ---> 0.009165939093888466, 0.009165939093888466
# Before/after: 0.009165939093888466, 0.009165939093888466 ---> 0.009165939093888466, 0.009165939093888466
# Before/after: 0.009165939093888466, 0.009165939093888466 ---> 0.009165939093888466, 0.009165939093888466
# Before/after: 0.009165939093888466, 0.009165939093888466 ---> 0.009165939093888466, 0.009165939093888466
# Before/after: 0.005579267274540806, 0.005579267274540806 ---> 0.005579267274540806, 0.005579267274540806
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.002324694697719565, 0.002324694697719565 ---> 0.002324694697719565, 0.002324694697719565
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.002789633637270403, 0.002789633637270403 ---> 0.002789633637270403, 0.002789633637270403
# Before/after: -100.0, 99.86649610450206 ---> -100.0, 99.86649610450206
# Before/after: -99.86649610450206, 100.0 ---> -99.86649610450206, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.3320992425321908, 0.3320992425321908 ---> 0.3320992425321908, 0.3320992425321908
# Before/after: -21.42339643527972, -11.62218664401248 ---> -21.42339643527972, -11.62218664401248
# Before/after: 7.80132813918901, 27.910014458727233 ---> 7.80132813918901, 27.910014458727233
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -37.86353251822114, 63.81898138784106 ---> -37.86353251822114, 63.81898138784106
# Before/after: -3.854613262342795, -3.652106567539761 ---> -3.854613262342795, -3.652106567539761
# Before/after: -55.29279898713247, 0.0 ---> -55.29279898713247, 0.0
# Before/after: -0.3169013848963118, -0.31690138489611286 ---> -0.31690138489621233, -0.31690138489621233
# Before/after: -0.07739871736533033, -0.0773987173652996 ---> -0.07739871736531496, -0.07739871736531496
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 11.62218664401248, 21.42339643527972 ---> 11.62218664401248, 21.42339643527972
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 92.19867186080977 ---> -100.0, 92.19867186080977
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 92.19867186081207 ---> -100.0, 92.19867186081207
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -19.29940865059038, 20.942576936342697 ---> -19.29940865059038, 20.942576936342697
# Before/after: -19.2994086505905, 20.942576936342697 ---> -19.2994086505905, 20.942576936342697
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 3.652106567538496, 3.8546132623419 ---> 3.652106567538496, 3.8546132623419
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.0, 55.292802289477734 ---> 0.0, 55.292802289477734
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.07739871736531381, 0.07739871736531381 ---> 0.07739871736531381, 0.07739871736531381
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# Before/after: 0.3320992425321908, 0.3320992425321908 ---> 0.3320992425321908, 0.3320992425321908
# Before/after: 0.3320992425321908, 0.3320992425321908 ---> 0.3320992425321908, 0.3320992425321908
# Before/after: -99.95988727392123, 100.0 ---> -99.95988727392123, 100.0
# Before/after: -99.95988727392123, 100.0 ---> -99.95988727392123, 100.0
# Before/after: 0.0401127260787766, 0.1413660734791382 ---> 0.0401127260787766, 0.1413660734791382
# 2DGLCNRx: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# 2DGLCNRy: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# 2DGULRx: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# 2DGULRy: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# A5PISO: 0.013948168186352014, 0.013948168186352014 ---->  0.0112827771185306, 0.0139481683510053
# Before/after: 0.0112827771185306, 0.0139481683510053 ---> 0.0112827771185306, 0.0139481683510053
# AACPS1: -100.0, 100.0 ---->  -99.99774344457656, 100.0
# Before/after: -99.99774344457656, 100.0 ---> -99.99774344457656, 100.0
# AACPS3: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# ABTA: -100.0, 100.0 ---->  -0.0138418032775007, 100.0
# Before/after: -0.0138418032775007, 100.0 ---> -0.0138418032775007, 100.0
# ACCOACr: -100.0, 100.0 ---->  -97.0446043577428, 99.09998386743658
# Before/after: -97.0446043577428, 99.09998386743658 ---> -97.0446043577428, 99.09998386743658
# ACGK: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# ACGS: -100.0, 100.0 ---->  0.0, 99.02040141055608
# Before/after: 0.0, 99.02040141055608 ---> 0.0, 99.02040141055608
# ACHBS: 0.0916593909388856, 0.0916593909388856 ---->  0.0741439639232197, 0.0916593909400234
# Before/after: 0.0741439639232197, 0.0916593909400234 ---> 0.0741439639232197, 0.0916593909400234
# ACLS: 0.27566196515703095, 0.27566196515703095 ---->  0.2229850164861578, 0.2756619651602655
# Before/after: 0.2229850164861578, 0.2756619651602655 ---> 0.2229850164861578, 0.2756619651602655
# ACOATA: -100.0, 100.0 ---->  -100.0, 99.9990000000002
# Before/after: -100.0, 99.9990000000002 ---> -100.0, 99.9990000000002
# ACOTA: -100.0, 100.0 ---->  -99.15364428740102, -0.0
# Before/after: -99.15364428740102, -0.0 ---> -99.15364428740102, 0.0
# ACS: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# ADA: -100.0, 100.0 ---->  0.0, 99.9233851759345
# Before/after: 0.0, 99.9233851759345 ---> 0.0, 99.9233851759345
# ADCL: 0.016604962126613998, 0.016604962126613998 ---->  0.0134318775223363, 0.0166049621268046
# Before/after: 0.0134318775223363, 0.0166049621268046 ---> 0.0134318775223363, 0.0166049621268046
# ADCS: 0.016604962126606893, 0.016604962126606893 ---->  0.0134318775223302, 0.0166049621268045
# Before/after: 0.0134318775223302, 0.0166049621268045 ---> 0.0134318775223302, 0.0166049621268045
# ADD: -100.0, 100.0 ---->  -4.96063583873413e-10, 99.32797192456135
# Before/after: -4.96063583873413e-10, 99.32797192456135 ---> 0.0, 99.32797192456135
# ADK1: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# ADK3: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# ADMDCr: 0.0023246946977224505, 0.0023246946977224505 ---->  0.0018804628531228, 0.0023246946977479
# Before/after: 0.0018804628531228, 0.0023246946977479 ---> 0.0018804628531228, 0.0023246946977479
# ADNK1: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# ADPT: -100.0, 100.0 ---->  -100.0, 99.74373614864597
# Before/after: -100.0, 99.74373614864597 ---> -100.0, 99.74373614864597
# ADSK: 0.07739871736529318, 0.07739871736529318 ---->  0.0626083988695357, 0.0773987182790478
# Before/after: 0.0626083988695357, 0.0773987182790478 ---> 0.0626083988695357, 0.0773987182790478
# ADSL1r: -100.0, 100.0 ---->  0.0749496229487221, 100.0
# Before/after: 0.0749496229487221, 100.0 ---> 0.0749496229487221, 100.0
# ADSL2r: 0.1634290261432909, 0.1634290261432909 ---->  0.132198956312719, 0.1634290261451667
# Before/after: 0.132198956312719, 0.1634290261451667 ---> 0.132198956312719, 0.1634290261451667
# ADSS: -100.0, 100.0 ---->  0.0749496230562272, 99.34481524545666
# Before/after: 0.0749496230562272, 99.34481524545666 ---> 0.0749496230562272, 99.34481524545666
# AGMHE: 0.008368900911811208, 0.008368900911811208 ---->  0.0067696662712575, 0.008368900911909
# Before/after: 0.0067696662712575, 0.008368900911909 ---> 0.0067696662712575, 0.008368900911909
# AICART: 0.19331795797118098, 0.19331795797118098 ---->  0.1563763509720956, 0.1933179766647725
# Before/after: 0.1563763509720956, 0.1933179766647725 ---> 0.1563763509720956, 0.1933179766647725
# AIRC2: 0.1634290261432838, 0.1634290261432838 ---->  0.1321989563127203, 0.1634290261452093
# Before/after: 0.1321989563127203, 0.1634290261452093 ---> 0.1321989563127203, 0.1634290261452093
# AIRC3: -0.1634290261432696, -0.1634290261432696 ---->  -0.1634290261451951, -0.1321989563127061
# Before/after: -0.1634290261451951, -0.1321989563127061 ---> -0.1634290261451951, -0.1321989563127061
# ALAALAr: 0.009165939093888466, 0.009165939093888466 ---->  0.0074143963924009, 0.009165939175498
# Before/after: 0.0074143963924009, 0.009165939175498 ---> 0.0074143963924009, 0.009165939175498
# ALAR: -100.0, 100.0 ---->  -99.98517120721569, 100.0
# Before/after: -99.98517120721569, 100.0 ---> -99.98517120721569, 100.0
# ALATAD2: -100.0, 100.0 ---->  -100.0, 99.9851712072154
# Before/after: -100.0, 99.9851712072154 ---> -100.0, 99.9851712072154
# ALATAL: -100.0, 100.0 ---->  -100.0, 99.8466616862051
# Before/after: -100.0, 99.8466616862051 ---> -100.0, 99.8466616862051
# ALATAL2: -100.0, 100.0 ---->  -99.98517120721556, 100.0
# Before/after: -99.98517120721556, 100.0 ---> -99.98517120721556, 100.0
# ALDD2x: -100.0, 100.0 ---->  0.0, 99.30357529605644
# Before/after: 0.0, 99.30357529605644 ---> 0.0, 99.30357529605644
# ANPRT: 0.017933359096738304, 0.017933359096738304 ---->  0.0145064277241166, 0.0179333590969489
# Before/after: 0.0145064277241166, 0.0179333590969489 ---> 0.0145064277241166, 0.0179333590969489
# ANS: 0.017933359096738304, 0.017933359096738304 ---->  0.0145064277241166, 0.0179333593084523
# Before/after: 0.0145064277241166, 0.0179333593084523 ---> 0.0145064277241166, 0.0179333593084523
# APRAUR: 3.320992476574247e-06, 3.320992476574247e-06 ---->  -3.3209924253609152e-06, 3.3209924253609152e-06
# Before/after: -3.3209924253609152e-06, 3.3209924253609152e-06 ---> -3.3209924253609152e-06, 3.3209924253609152e-06
# ASNS1: -100.0, 100.0 ---->  -99.93848200094772, 100.0
# Before/after: -99.93848200094772, 100.0 ---> -99.93848200094772, 100.0
# ASNS2: -100.0, 100.0 ---->  -99.8727836195531, 100.0
# Before/after: -99.8727836195531, 100.0 ---> -99.8727836195531, 100.0
# ASP1DC: 1.95938552849384e-05, 1.95938552849384e-05 ---->  1.5849615476362655e-05, 1.9593855309646778e-05
# Before/after: 1.5849615476362655e-05, 1.9593855309646778e-05 ---> 1.5849615476362655e-05, 1.9593855309646778e-05
# ASPCT: 0.14475719740066495, 0.24601054480103812 ---->  0.1247604182245538, 0.2460105448022886
# Before/after: 0.1247604182245538, 0.2460105448022886 ---> 0.1247604182245538, 0.2460105448022886
# ASPO4: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# ASPO5: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# ASPO6: -100.0, 100.0 ---->  -60.36168243010289, 60.04156590527751
# Before/after: -60.36168243010289, 60.04156590527751 ---> -60.36168243010289, 60.04156590527751
# ASPT: -100.0, 100.0 ---->  -100.0, 99.18908631097992
# Before/after: -100.0, 99.18908631097992 ---> -100.0, 99.18908631097992
# ...
# Before/after: -0.0009066309321235, 0.0009066309321235 ---> -0.0009066309321235, 0.0009066309321235
# RBFK: 3.3209924197308283e-06, 3.3209924197308283e-06 ---->  -3.3209924253613167e-06, 3.3209924253613167e-06
# Before/after: -3.3209924253613167e-06, 3.3209924253613167e-06 ---> -3.3209924253613167e-06, 3.3209924253613167e-06
# RBFSa: 6.6419848394616565e-06, 6.6419848394616565e-06 ---->  5.372751008932086e-06, 5.529985413568882e-06
# Before/after: 5.372751008932086e-06, 5.529985413568882e-06 ---> 5.372751008932086e-06, 5.529985413568882e-06
# RBFSb: 3.3209924197308283e-06, 3.3209924197308283e-06 ---->  -2.8021821281191204e-06, 2.802182128119117e-06
# Before/after: -2.8021821281191204e-06, 2.802182128119117e-06 ---> -2.8021821281191204e-06, 2.802182128119117e-06
# RNDR1: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# RNDR2: -100.0, 100.0 ---->  -99.61831569340494, 100.0
# Before/after: -99.61831569340494, 100.0 ---> -99.61831569340494, 100.0
# RNDR4: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# RNTR1: -100.0, 100.0 ---->  -99.993364652504, 100.0
# Before/after: -99.993364652504, 100.0 ---> -99.993364652504, 100.0
# RNTR2: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# S7PI: 0.008368900911811208, 0.008368900911811208 ---->  0.0067696662712575, 0.008368900911909
# Before/after: 0.0067696662712575, 0.008368900911909 ---> 0.0067696662712575, 0.008368900911909
# SADT2: 0.07739871736534099, 0.07739871736534099 ---->  0.0626083988695357, 0.07739871736645
# Before/after: 0.0626083988695357, 0.07739871736645 ---> 0.0626083988695357, 0.07739871736645
# SDPDS: 0.11743029215938228, 0.11743029215938228 ---->  0.0949902378379192, 0.1174302921607619
# Before/after: 0.0949902378379192, 0.1174302921607619 ---> 0.0949902378379192, 0.1174302921607619
# SDPTA: -0.11743029215938228, -0.11743029215938228 ---->  -0.1174302921607619, -0.0949902378379192
# Before/after: -0.1174302921607619, -0.0949902378379192 ---> -0.1174302921607619, -0.0949902378379192
# SERDL: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# SHK3Dr: 0.13649278868072717, 0.13649278868072717 ---->  0.1104100332335543, 0.1364927886823335
# Before/after: 0.1104100332335543, 0.1364927886823335 ---> 0.1104100332335543, 0.1364927886823335
# SHKK: 0.13649278868072717, 0.13649278868072717 ---->  0.1104100332335543, 0.1364927886823335
# Before/after: 0.1104100332335543, 0.1364927886823335 ---> 0.1104100332335543, 0.1364927886823335
# SHSL1: 0.04848648940969985, 0.04848648940969985 ---->  0.0392210823650884, 0.048486489700785
# Before/after: 0.0392210823650884, 0.048486489700785 ---> 0.0392210823650884, 0.048486489700785
# SPMS: 0.002324694697719565, 0.002324694697719565 ---->  0.0018804628531228, 0.0023246946977479
# Before/after: 0.0018804628531228, 0.0023246946977479 ---> 0.0018804628531228, 0.0023246946977479
# SSALx: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# SSALy: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# SUCOAS: -100.0, 100.0 ---->  -99.56087653235112, 100.0
# Before/after: -99.56087653235112, 100.0 ---> -99.56087653235112, 100.0
# SULR: -0.07739871736531449, -0.07739871736531449 ---->  -0.0773987182790478, -0.0626083988695357
# Before/after: -0.0773987182790478, -0.0626083988695357 ---> -0.0773987182790478, -0.0626083988695357
# TDSK: 0.002789633637270403, 0.002789633637270403 ---->  0.0022565554237525, 0.0027896336373027
# Before/after: 0.0022565554237525, 0.0027896336373027 ---> 0.0022565554237525, 0.0027896336373027
# TESTNADTRHD: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# THDPS: 0.11743029215938228, 0.11743029215938228 ---->  0.0949902378379192, 0.1174302921829063
# Before/after: 0.0949902378379192, 0.1174302921829063 ---> 0.0949902378379192, 0.1174302921829063
# THRAr: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# THRD: -100.0, 100.0 ---->  -100.0, 99.58667903981518
# Before/after: -100.0, 99.58667903981518 ---> -100.0, 99.58667903981518
# THRDL: -99.90834060906111, 100.0 ---->  -99.92585603607674, 99.78487370687267
# Before/after: -99.92585603607674, 99.78487370687267 ---> -99.92585603607674, 99.78487370687267
# TMAOR1: -100.0, 100.0 ---->  0.0, -0.0
# Before/after: 0.0, -0.0 ---> 0.0, 0.0
# TMAOR2: -100.0, 100.0 ---->  0.0, -0.0
# Before/after: 0.0, -0.0 ---> 0.0, 0.0
# TMDS: 0.008202851290548097, 0.008202851290548097 ---->  0.0066353474960294, 0.0082028512906431
# Before/after: 0.0066353474960294, 0.0082028512906431 ---> 0.0066353474960294, 0.0082028512906431
# TRE6PP: -100.0, 100.0 ---->  -1.0000178463087649e-10, 100.0
# Before/after: -1.0000178463087649e-10, 100.0 ---> 0.0, 100.0
# TRE6PS: -100.0, 99.99342443499786 ---->  -1.0000178463087649e-10, 99.18106824260144
# Before/after: -1.0000178463087649e-10, 99.18106824260144 ---> 0.0, 99.18106824260144
# TREHe: -100.0, 100.0 ---->  0.0, -0.0
# Before/after: 0.0, -0.0 ---> 0.0, 0.0
# TRPAS2: -100.0, 100.0 ---->  -0.0179333593084578, 100.0
# Before/after: -0.0179333593084578, 100.0 ---> -0.0179333593084578, 100.0
# TRPS2: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# TRPS3: -99.98206664090326, 100.0 ---->  -99.98549357227591, 0.0179333590969434
# Before/after: -99.98549357227591, 0.0179333590969434 ---> -99.98549357227591, 0.0179333590969434
# TRSAR: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# TYRTA: -0.043505000771717, -0.043505000771717 ---->  -0.0435050007717467, -0.0351915191089968
# Before/after: -0.0435050007717467, -0.0351915191089968 ---> -0.0435050007717467, -0.0351915191089968
# U23GAAT: 0.005579267274540806, 0.005579267274540806 ---->  0.0045131108475044, 0.0055792673404021
# Before/after: 0.0045131108475044, 0.0055792673404021 ---> 0.0045131108475044, 0.0055792673404021
# UAAGDS: 0.009165939093888466, 0.009165939093888466 ---->  0.0074143963924009, 0.0091659390939233
# Before/after: 0.0074143963924009, 0.0091659390939233 ---> 0.0074143963924009, 0.0091659390939233
# UAGAAT: 0.005579267274540806, 0.005579267274540806 ---->  0.0045131108475044, 0.0055792673404021
# Before/after: 0.0045131108475044, 0.0055792673404021 ---> 0.0045131108475044, 0.0055792673404021
# UAGCVT: 0.009165939093888466, 0.009165939093888466 ---->  0.0074143963923773, 0.0091659390939469
# Before/after: 0.0074143963923773, 0.0091659390939469 ---> 0.0074143963923773, 0.0091659390939469
# UAGDP: 0.023911145462317738, 0.023911145462317738 ---->  0.0193419036320603, 0.0239111454626417
# Before/after: 0.0193419036320603, 0.0239111454626417 ---> 0.0193419036320603, 0.0239111454626417
# UAGPT3: 0.009165939093888466, 0.009165939093888466 ---->  0.0074143963924009, 0.0091659390939233
# Before/after: 0.0074143963924009, 0.0091659390939233 ---> 0.0074143963924009, 0.0091659390939233
# UAMAGS: 0.009165939093888466, 0.009165939093888466 ---->  0.0074143963924009, 0.0091659392020892
# Before/after: 0.0074143963924009, 0.0091659392020892 ---> 0.0074143963924009, 0.0091659392020892
# UAMAS: 0.009165939093888466, 0.009165939093888466 ---->  0.0074143963923773, 0.0091659390939469
# Before/after: 0.0074143963923773, 0.0091659390939469 ---> 0.0074143963923773, 0.0091659390939469
# UAPGR: 0.009165939093888466, 0.009165939093888466 ---->  0.0074143963923773, 0.0091659390939469
# Before/after: 0.0074143963923773, 0.0091659390939469 ---> 0.0074143963923773, 0.0091659390939469
# UDCPDP: 0.009165939093888466, 0.009165939093888466 ---->  0.0074143963924009, 0.0091659390939233
# Before/after: 0.0074143963924009, 0.0091659390939233 ---> 0.0074143963924009, 0.0091659390939233
# UGMDDS: 0.009165939093888466, 0.009165939093888466 ---->  0.0074143963924009, 0.0091659390939233
# Before/after: 0.0074143963924009, 0.0091659390939233 ---> 0.0074143963924009, 0.0091659390939233
# UHGADA: 0.005579267274540806, 0.005579267274540806 ---->  0.0045131108475044, 0.0055792673404021
# Before/after: 0.0045131108475044, 0.0055792673404021 ---> 0.0045131108475044, 0.0055792673404021
# UMPK: -100.0, 100.0 ---->  -99.9056813560382, 99.84593255056208
# Before/after: -99.9056813560382, 99.84593255056208 ---> -99.9056813560382, 99.84593255056208
# UNK3: 0.002324694697719565, 0.002324694697719565 ---->  0.0018804628530384, 0.0023246946978336
# Before/after: 0.0018804628530384, 0.0023246946978336 ---> 0.0018804628530384, 0.0023246946978336
# UPPRT: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# USHD: 0.002789633637270403, 0.002789633637270403 ---->  0.0022565554237525, 0.0027896336373027
# Before/after: 0.0022565554237525, 0.0027896336373027 ---> 0.0022565554237525, 0.0027896336373027
# VALTA: -100.0, 99.86649610450206 ---->  -100.0, 99.73866939092557
# Before/after: -100.0, 99.73866939092557 ---> -100.0, 99.73866939092557
# VPAMT: -99.86649610450206, 100.0 ---->  -99.88616278405136, 99.8466616862052
# Before/after: -99.88616278405136, 99.8466616862052 ---> -99.88616278405136, 99.8466616862052
# XPPT: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# biomass: 0.3320992425321908, 0.3320992425321908 ---->  0.2686375504505491, 0.3320992429103541
# Before/after: 0.2686375504505491, 0.3320992429103541 ---> 0.2686375504505491, 0.3320992429103541
# EX_ac: -21.42339643527972, -11.62218664401248 ---->  -21.42339643527972, -11.62218664401248
# Before/after: -21.42339643527972, -11.62218664401248 ---> -21.42339643527972, -11.62218664401248
# EX_h2o: -37.86353251822114, 63.81898138784106 ---->  6.060068186342733, 8.04698386312377
# Before/after: 6.060068186342733, 8.04698386312377 ---> 6.060068186342733, 8.04698386312377
# EX_nh3: -3.854613262342795, -3.652106567539761 ---->  -3.854613262383346, -2.969546686396761
# Before/after: -3.854613262383346, -2.969546686396761 ---> -3.854613262383346, -2.969546686396761
# EX_pi: -0.31690138489621233, -0.31690138489621233 ---->  -0.3169013848999213, -0.2563438902255033
# Before/after: -0.3169013848999213, -0.2563438902255033 ---> -0.3169013848999213, -0.2563438902255033
# EX_so4: -0.07739871736531496, -0.07739871736531496 ---->  -0.0773987173808871, -0.0626083988695351
# Before/after: -0.0773987173808871, -0.0626083988695351 ---> -0.0773987173808871, -0.0626083988695351
# ACt2r: 11.62218664401248, 21.42339643527972 ---->  11.622186644012473, 21.42339643527976
# Before/after: 11.622186644012473, 21.42339643527976 ---> 11.622186644012473, 21.42339643527976
# ARGabc: -100.0, 100.0 ---->  -99.82668856676425, 99.83235240122718
# Before/after: -99.82668856676425, 99.83235240122718 ---> -99.82668856676425, 99.83235240122718
# ARGORNt7: -100.0, 100.0 ---->  -99.2262828411988, 100.0
# Before/after: -99.2262828411988, 100.0 ---> -99.2262828411988, 100.0
# ATPS4r: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# Cex: -100.0, 100.0 ---->  -2.329954687372058, -1.8771957341570271
# Before/after: -2.329954687372058, -1.8771957341570271 ---> -2.329954687372058, -1.8771957341570271
# CHLabc: -100.0, 100.0 ---->  0.0, 99.2562028460139
# Before/after: 0.0, 99.2562028460139 ---> 0.0, 99.2562028460139
# CHLt2r: -100.0, 100.0 ---->  -100.0, -0.0
# Before/after: -100.0, -0.0 ---> -100.0, 0.0
# CYTBD: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# DMSOR1e: -100.0, 100.0 ---->  0.0, -0.0
# Before/after: 0.0, -0.0 ---> 0.0, 0.0
# DMSOR2e: -100.0, 100.0 ---->  0.0, -0.0
# Before/after: 0.0, -0.0 ---> 0.0, 0.0
# FDH3: -100.0, 100.0 ---->  -100.0, 93.93993164734869
# Before/after: -100.0, 93.93993164734869 ---> -100.0, 93.93993164734869
# FRUpts: -100.0, 100.0 ---->  0.0, -0.0
# Before/after: 0.0, -0.0 ---> 0.0, 0.0
# FRUpts2: -100.0, 100.0 ---->  0.0, -0.0
# Before/after: 0.0, -0.0 ---> 0.0, 0.0
# FUMt22: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# GLCDe: -19.29940865059038, 20.942576936342697 ---->  0.0, -0.0
# Before/after: 0.0, -0.0 ---> 0.0, 0.0
# GLCNt2r: -19.2994086505905, 20.942576936342697 ---->  0.0, -0.0
# Before/after: 0.0, -0.0 ---> 0.0, 0.0
# GLCpts: -100.0, 100.0 ---->  0.0, -0.0
# Before/after: 0.0, -0.0 ---> 0.0, 0.0
# GLCt2: -100.0, 100.0 ---->  0.0, -0.0
# Before/after: 0.0, -0.0 ---> 0.0, 0.0
# GLYC3Pabc: -100.0, 100.0 ---->  0.0, 0.3169013848999089
# Before/after: 0.0, 0.3169013848999089 ---> 0.0, 0.3169013848999089
# GLYC3Pt6: -100.0, 100.0 ---->  -0.3169013848999213, -0.0
# Before/after: -0.3169013848999213, -0.0 ---> -0.3169013848999213, 0.0
# Ht: -100.0, 100.0 ---->  -100.0, -0.0
# Before/after: -100.0, -0.0 ---> -100.0, 0.0
# HYD1: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# HYD2: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# HYD3: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# ILEt2r: -100.0, 100.0 ---->  -100.0, -0.0
# Before/after: -100.0, -0.0 ---> -100.0, 0.0
# LEUabc: -100.0, 100.0 ---->  0.0, 99.1909193462294
# Before/after: 0.0, 99.1909193462294 ---> 0.0, 99.1909193462294
# LEUt2r: -100.0, 100.0 ---->  -100.0, -0.0
# Before/after: -100.0, -0.0 ---> -100.0, 0.0
# LYSabc: -100.0, 100.0 ---->  -9.159860780982855e-08, 100.0
# Before/after: -9.159860780982855e-08, 100.0 ---> 0.0, 100.0
# LYSt2r: -100.0, 100.0 ---->  -99.0927018223218, 2.00003569261753e-10
# Before/after: -99.0927018223218, 2.00003569261753e-10 ---> -99.0927018223218, 0.0
# NADH6: -100.0, 100.0 ---->  0.0, 99.16977238417527
# Before/after: 0.0, 99.16977238417527 ---> 0.0, 99.16977238417527
# NADH7: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# NADH8: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# NH3t: 3.652106567538496, 3.8546132623419 ---->  2.969546716635081, 3.854613393220864
# Before/after: 2.969546716635081, 3.854613393220864 ---> 2.969546716635081, 3.854613393220864
# NO3R2: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# ORNabc: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# PIabc: -100.0, 100.0 ---->  0.0, 0.3169013848999488
# Before/after: 0.0, 0.3169013848999488 ---> 0.0, 0.3169013848999488
# PIt2r: -100.0, 100.0 ---->  0.0, 0.3169014409734721
# Before/after: 0.0, 0.3169014409734721 ---> 0.0, 0.3169014409734721
# PTRCabc: -100.0, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# PTRCORNt7: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# PTRCt2r: -100.0, 100.0 ---->  -100.0, 1.0000178463087649e-10
# Before/after: -100.0, 1.0000178463087649e-10 ---> -100.0, 0.0
# SUCCabc: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# SUCCt22: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# SUCFUMt: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# SULabc: 0.07739871736531381, 0.07739871736531381 ---->  0.0626083988695357, 0.0773987182790478
# Before/after: 0.0626083988695357, 0.0773987182790478 ---> 0.0626083988695357, 0.0773987182790478
# THD2: -100.0, 100.0 ---->  -100.0, 100.0
# Before/after: -100.0, 100.0 ---> -100.0, 100.0
# TMAOR1e: -100.0, 100.0 ---->  0.0, -0.0
# Before/after: 0.0, -0.0 ---> 0.0, 0.0
# TMAOR2e: -100.0, 100.0 ---->  0.0, -0.0
# Before/after: 0.0, -0.0 ---> 0.0, 0.0
# TREpts: -100.0, 100.0 ---->  0.0, -0.0
# Before/after: 0.0, -0.0 ---> 0.0, 0.0
# biomass_ce: 0.3320992425321908, 0.3320992425321908 ---->  0.2686375504505491, 0.3320992425322231
# Before/after: 0.2686375504505491, 0.3320992425322231 ---> 0.2686375504505491, 0.3320992425322231
# biomass_EX: 0.3320992425321908, 0.3320992425321908 ---->  0.2686375504505812, 0.3320992425321908
# Before/after: 0.2686375504505812, 0.3320992425321908 ---> 0.2686375504505812, 0.3320992425321908
# OROTex: -99.95988727392123, 100.0 ---->  0.0, 100.0
# Before/after: 0.0, 100.0 ---> 0.0, 100.0
# DCTA: -99.95988727392123, 100.0 ---->  -99.95988727392128, 0.1413660734791904
# Before/after: -99.95988727392128, 0.1413660734791904 ---> -99.95988727392128, 0.1413660734791904
# EX_oro: 0.0401127260787766, 0.1413660734791382 ---->  0.0401127260787766, 0.1413660734791382
# Before/after: 0.0401127260787766, 0.1413660734791382 ---> 0.0401127260787766, 0.1413660734791382

# %%
tfva_run_scenarios_one_model(tmodel_ace, "ecoli", "WT_Ace", "../results/WT_Ace/parallel")
# Out:
# 0
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
